# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_Single_Trial_Classification_NSL_2Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 316 (delta 0), reused 0 (delta 0), pack-reused 313
# Receiving objects: 100% (316/316), 1.68 GiB | 38.48 MiB/s, done.
# Resolving deltas: 100% (128/128), done.
# Checking out files: 100% (93/93), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet, EEGNet_Patient
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import tensorflow as tf
import neural_structured_learning as nsl
# Out:
# Collecting neural_structured_learning
#   Downloading https://files.pythonhosted.org/packages/08/2e/22b1385d7d601ad0c81457a5b66b3bb6f3c400348c62ea3f07a5fc1b13bc/neural_structured_learning-1.1.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 9.0MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.8.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.4)
# Installing collected packages: neural-structured-learning
# Successfully installed neural-structured-learning-1.1.0

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()
cols = 3
rows = 14
acc_all = zeros([rows, cols])
X_tr = np.empty([100, 15, 4096])
X_ts = np.empty([60, 15, 4096])


for x in range(1,15):
  fName = 'EEG_Deep/Data2A/Eopched_S0' + str(x) + 'T.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_tr = mat['cleanRawEEGData']
  y_tr = mat['cleanClassLabels']
  y_tr = y_tr.flatten() 
  
  print(np.shape(r_X_tr))
  print(np.shape(y_tr))

  for t in range(r_X_tr.shape[0]):
    tril = r_X_tr[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_tr[t,:,:] = tril_filtered 
    
  # split data of each subject in training and validation
  X_train      = X_tr[0:70,:,1536:3072]
  Y_train      = y_tr[0:70]
  X_val       = X_tr[70:,:,1536:3072]
  Y_val       = y_tr[70:]

  print(np.shape(X_train))
  print(np.shape(Y_train))
  print(np.shape(X_val))
  print(np.shape(Y_val))
  
  # convert labels to one-hot encodings.
  Y_train      = np_utils.to_categorical(Y_train-1)
  Y_val       = np_utils.to_categorical(Y_val-1)

  kernels, chans, samples = 1, 15, 1536
  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
  X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
  print('X_train shape:', X_train.shape)
  print(X_train.shape[0], 'train samples')
  print(X_val.shape[0], 'val samples')

  fName = 'EEG_Deep/Data2A/Eopched_S0' + str(x) + 'E.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_ts = mat['cleanRawEEGData']
  y_ts = mat['cleanClassLabels']
  y_ts = y_ts.flatten() 

  print(np.shape(r_X_ts))
  print(np.shape(y_ts))

  for t in range(r_X_ts.shape[0]):
    tril = r_X_ts[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_ts[t,:,:] = tril_filtered 

  X_test      = X_ts[:,:,1536:3072]
  Y_test      = y_ts[:]
  print(np.shape(X_test))
  print(np.shape(Y_test))

  #convert labels to one-hot encodings.
  Y_test      = np_utils.to_categorical(Y_test-1)

  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

  print('X_train shape:', X_test.shape)
  print(X_test.shape[0], 'test samples')

   # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
  # model configurations may do better, but this is a good starting point)
  model = EEGNet(nb_classes = 2, Chans = 15, Samples = 1536, 
                 dropoutRate = 0.25, kernLength = 25, F1 = 8, 
                 D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

  adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
  adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
  # compile the model and set the optimizers
  adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
  batch_size = 32

  X_train = tf.cast(X_train, tf.float32)
  X_test = tf.cast(X_test, tf.float32)
  X_val = tf.cast(X_val, tf.float32)

  train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
  val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
  test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)

  val_steps = X_val.shape[0] // batch_size
  
  history = adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=500, verbose=1)

  # Plot training & validation accuracy values
  plt.plot(history.history['categorical_accuracy'])
  plt.plot(history.history['val_categorical_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  figName = 'Accuracy_A0' + str(x) + '.png'  
  plt.savefig(figName)

  print('\n# Evaluate on test data')
  results = adv_model.evaluate(test_data)
  print('test loss, test acc:', results)

  acc_all[x - 1, 0] = results[0]
  acc_all[x - 1, 1] = results[1]
  acc_all[x - 1, 2] = results[2]

  from keras import backend as K 
  # Do some code, e.g. train and save model
  K.clear_session()

print(acc_all)
# Out:
# EEG_Deep/Data2A/Eopched_S01T.mat
# (100, 15, 4096)
# (100,)
# (70, 15, 1536)
# (70,)
# (30, 15, 1536)
# (30,)
# X_train shape: (70, 1, 15, 1536)
# 70 train samples
# 30 val samples
# EEG_Deep/Data2A/Eopched_S01E.mat
# (60, 15, 4096)
# (60,)
# (60, 15, 1536)
# (60,)
# X_train shape: (60, 1, 15, 1536)
# 60 test samples
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 3 steps, validate on 1 steps
# Epoch 1/500
# 3/3 [==============================] - 0s 129ms/step - loss: 0.6827 - categorical_crossentropy: 0.6827 - categorical_accuracy: 0.5714 - val_loss: 0.6914 - val_categorical_crossentropy: 0.6914 - val_categorical_accuracy: 0.6667
# Epoch 2/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6539 - categorical_crossentropy: 0.6539 - categorical_accuracy: 0.6000 - val_loss: 0.6912 - val_categorical_crossentropy: 0.6912 - val_categorical_accuracy: 0.6667
# Epoch 3/500
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6253 - categorical_crossentropy: 0.6253 - categorical_accuracy: 0.7286 - val_loss: 0.6909 - val_categorical_crossentropy: 0.6909 - val_categorical_accuracy: 0.7333
# Epoch 4/500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6031 - categorical_crossentropy: 0.6031 - categorical_accuracy: 0.6857 - val_loss: 0.6901 - val_categorical_crossentropy: 0.6901 - val_categorical_accuracy: 0.6667
# Epoch 5/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5912 - categorical_crossentropy: 0.5912 - categorical_accuracy: 0.6429 - val_loss: 0.6891 - val_categorical_crossentropy: 0.6891 - val_categorical_accuracy: 0.6000
# Epoch 6/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5542 - categorical_crossentropy: 0.5542 - categorical_accuracy: 0.6714 - val_loss: 0.6880 - val_categorical_crossentropy: 0.6880 - val_categorical_accuracy: 0.6000
# Epoch 7/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5542 - categorical_crossentropy: 0.5542 - categorical_accuracy: 0.7571 - val_loss: 0.6866 - val_categorical_crossentropy: 0.6866 - val_categorical_accuracy: 0.6000
# Epoch 8/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5231 - categorical_crossentropy: 0.5231 - categorical_accuracy: 0.7571 - val_loss: 0.6853 - val_categorical_crossentropy: 0.6853 - val_categorical_accuracy: 0.6000
# Epoch 9/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5289 - categorical_crossentropy: 0.5289 - categorical_accuracy: 0.7286 - val_loss: 0.6840 - val_categorical_crossentropy: 0.6840 - val_categorical_accuracy: 0.6333
# Epoch 10/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5063 - categorical_crossentropy: 0.5063 - categorical_accuracy: 0.7429 - val_loss: 0.6826 - val_categorical_crossentropy: 0.6826 - val_categorical_accuracy: 0.6333
# Epoch 11/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4909 - categorical_crossentropy: 0.4909 - categorical_accuracy: 0.7714 - val_loss: 0.6806 - val_categorical_crossentropy: 0.6806 - val_categorical_accuracy: 0.6333
# Epoch 12/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4686 - categorical_crossentropy: 0.4686 - categorical_accuracy: 0.7857 - val_loss: 0.6784 - val_categorical_crossentropy: 0.6784 - val_categorical_accuracy: 0.6333
# Epoch 13/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4661 - categorical_crossentropy: 0.4661 - categorical_accuracy: 0.7714 - val_loss: 0.6764 - val_categorical_crossentropy: 0.6764 - val_categorical_accuracy: 0.6333
# Epoch 14/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4701 - categorical_crossentropy: 0.4701 - categorical_accuracy: 0.7857 - val_loss: 0.6749 - val_categorical_crossentropy: 0.6749 - val_categorical_accuracy: 0.6333
# Epoch 15/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4570 - categorical_crossentropy: 0.4570 - categorical_accuracy: 0.7429 - val_loss: 0.6733 - val_categorical_crossentropy: 0.6733 - val_categorical_accuracy: 0.6667
# Epoch 16/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4393 - categorical_crossentropy: 0.4393 - categorical_accuracy: 0.8000 - val_loss: 0.6721 - val_categorical_crossentropy: 0.6721 - val_categorical_accuracy: 0.6667
# Epoch 17/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4250 - categorical_crossentropy: 0.4250 - categorical_accuracy: 0.8000 - val_loss: 0.6709 - val_categorical_crossentropy: 0.6709 - val_categorical_accuracy: 0.7000
# Epoch 18/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4198 - categorical_crossentropy: 0.4198 - categorical_accuracy: 0.8286 - val_loss: 0.6695 - val_categorical_crossentropy: 0.6695 - val_categorical_accuracy: 0.7000
# Epoch 19/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4088 - categorical_crossentropy: 0.4088 - categorical_accuracy: 0.8429 - val_loss: 0.6680 - val_categorical_crossentropy: 0.6680 - val_categorical_accuracy: 0.7333
# Epoch 20/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4077 - categorical_crossentropy: 0.4077 - categorical_accuracy: 0.8143 - val_loss: 0.6667 - val_categorical_crossentropy: 0.6667 - val_categorical_accuracy: 0.7667
# Epoch 21/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3990 - categorical_crossentropy: 0.3990 - categorical_accuracy: 0.8286 - val_loss: 0.6655 - val_categorical_crossentropy: 0.6655 - val_categorical_accuracy: 0.7667
# Epoch 22/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3954 - categorical_crossentropy: 0.3954 - categorical_accuracy: 0.8714 - val_loss: 0.6648 - val_categorical_crossentropy: 0.6648 - val_categorical_accuracy: 0.7667
# Epoch 23/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3947 - categorical_crossentropy: 0.3947 - categorical_accuracy: 0.8857 - val_loss: 0.6645 - val_categorical_crossentropy: 0.6645 - val_categorical_accuracy: 0.7333
# Epoch 24/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3937 - categorical_crossentropy: 0.3937 - categorical_accuracy: 0.8857 - val_loss: 0.6647 - val_categorical_crossentropy: 0.6647 - val_categorical_accuracy: 0.7000
# Epoch 25/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3757 - categorical_crossentropy: 0.3757 - categorical_accuracy: 0.9000 - val_loss: 0.6647 - val_categorical_crossentropy: 0.6647 - val_categorical_accuracy: 0.7000
# Epoch 26/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3779 - categorical_crossentropy: 0.3779 - categorical_accuracy: 0.8429 - val_loss: 0.6641 - val_categorical_crossentropy: 0.6641 - val_categorical_accuracy: 0.7000
# Epoch 27/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3758 - categorical_crossentropy: 0.3758 - categorical_accuracy: 0.9286 - val_loss: 0.6636 - val_categorical_crossentropy: 0.6636 - val_categorical_accuracy: 0.7000
# Epoch 28/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3875 - categorical_crossentropy: 0.3875 - categorical_accuracy: 0.9286 - val_loss: 0.6633 - val_categorical_crossentropy: 0.6633 - val_categorical_accuracy: 0.7333
# Epoch 29/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3796 - categorical_crossentropy: 0.3796 - categorical_accuracy: 0.8714 - val_loss: 0.6626 - val_categorical_crossentropy: 0.6626 - val_categorical_accuracy: 0.7333
# Epoch 30/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3496 - categorical_crossentropy: 0.3496 - categorical_accuracy: 0.9143 - val_loss: 0.6626 - val_categorical_crossentropy: 0.6626 - val_categorical_accuracy: 0.7000
# Epoch 31/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3542 - categorical_crossentropy: 0.3542 - categorical_accuracy: 0.9286 - val_loss: 0.6626 - val_categorical_crossentropy: 0.6626 - val_categorical_accuracy: 0.7000
# Epoch 32/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3400 - categorical_crossentropy: 0.3400 - categorical_accuracy: 0.9286 - val_loss: 0.6620 - val_categorical_crossentropy: 0.6620 - val_categorical_accuracy: 0.7000
# Epoch 33/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3419 - categorical_crossentropy: 0.3419 - categorical_accuracy: 0.9429 - val_loss: 0.6618 - val_categorical_crossentropy: 0.6618 - val_categorical_accuracy: 0.7000
# Epoch 34/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3533 - categorical_crossentropy: 0.3533 - categorical_accuracy: 0.8571 - val_loss: 0.6620 - val_categorical_crossentropy: 0.6620 - val_categorical_accuracy: 0.7333
# Epoch 35/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3328 - categorical_crossentropy: 0.3328 - categorical_accuracy: 0.9286 - val_loss: 0.6622 - val_categorical_crossentropy: 0.6622 - val_categorical_accuracy: 0.7333
# Epoch 36/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3507 - categorical_crossentropy: 0.3507 - categorical_accuracy: 0.9143 - val_loss: 0.6620 - val_categorical_crossentropy: 0.6620 - val_categorical_accuracy: 0.7333
# Epoch 37/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3347 - categorical_crossentropy: 0.3347 - categorical_accuracy: 0.9000 - val_loss: 0.6617 - val_categorical_crossentropy: 0.6617 - val_categorical_accuracy: 0.7333
# Epoch 38/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3256 - categorical_crossentropy: 0.3256 - categorical_accuracy: 0.9143 - val_loss: 0.6618 - val_categorical_crossentropy: 0.6618 - val_categorical_accuracy: 0.6667
# Epoch 39/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3267 - categorical_crossentropy: 0.3267 - categorical_accuracy: 0.9429 - val_loss: 0.6623 - val_categorical_crossentropy: 0.6623 - val_categorical_accuracy: 0.6667
# Epoch 40/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3132 - categorical_crossentropy: 0.3132 - categorical_accuracy: 0.9286 - val_loss: 0.6623 - val_categorical_crossentropy: 0.6623 - val_categorical_accuracy: 0.6667
# Epoch 41/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3203 - categorical_crossentropy: 0.3203 - categorical_accuracy: 0.9429 - val_loss: 0.6622 - val_categorical_crossentropy: 0.6622 - val_categorical_accuracy: 0.6667
# Epoch 42/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3083 - categorical_crossentropy: 0.3083 - categorical_accuracy: 0.9429 - val_loss: 0.6615 - val_categorical_crossentropy: 0.6615 - val_categorical_accuracy: 0.6667
# Epoch 43/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3135 - categorical_crossentropy: 0.3135 - categorical_accuracy: 0.9571 - val_loss: 0.6624 - val_categorical_crossentropy: 0.6624 - val_categorical_accuracy: 0.6667
# Epoch 44/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3006 - categorical_crossentropy: 0.3006 - categorical_accuracy: 0.9286 - val_loss: 0.6638 - val_categorical_crossentropy: 0.6638 - val_categorical_accuracy: 0.7000
# Epoch 45/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2996 - categorical_crossentropy: 0.2996 - categorical_accuracy: 0.9286 - val_loss: 0.6650 - val_categorical_crossentropy: 0.6650 - val_categorical_accuracy: 0.7000
# Epoch 46/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3019 - categorical_crossentropy: 0.3019 - categorical_accuracy: 0.9286 - val_loss: 0.6651 - val_categorical_crossentropy: 0.6651 - val_categorical_accuracy: 0.7000
# Epoch 47/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3137 - categorical_crossentropy: 0.3137 - categorical_accuracy: 0.9286 - val_loss: 0.6659 - val_categorical_crossentropy: 0.6659 - val_categorical_accuracy: 0.6667
# Epoch 48/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2798 - categorical_crossentropy: 0.2798 - categorical_accuracy: 0.9571 - val_loss: 0.6673 - val_categorical_crossentropy: 0.6673 - val_categorical_accuracy: 0.6667
# Epoch 49/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2849 - categorical_crossentropy: 0.2849 - categorical_accuracy: 0.9571 - val_loss: 0.6687 - val_categorical_crossentropy: 0.6687 - val_categorical_accuracy: 0.6667
# Epoch 50/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2914 - categorical_crossentropy: 0.2914 - categorical_accuracy: 0.9286 - val_loss: 0.6699 - val_categorical_crossentropy: 0.6699 - val_categorical_accuracy: 0.7000
# Epoch 51/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2942 - categorical_crossentropy: 0.2942 - categorical_accuracy: 0.9571 - val_loss: 0.6715 - val_categorical_crossentropy: 0.6715 - val_categorical_accuracy: 0.7000
# Epoch 52/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2863 - categorical_crossentropy: 0.2863 - categorical_accuracy: 0.9286 - val_loss: 0.6706 - val_categorical_crossentropy: 0.6706 - val_categorical_accuracy: 0.7000
# Epoch 53/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2812 - categorical_crossentropy: 0.2812 - categorical_accuracy: 0.9714 - val_loss: 0.6692 - val_categorical_crossentropy: 0.6692 - val_categorical_accuracy: 0.7000
# Epoch 54/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2758 - categorical_crossentropy: 0.2758 - categorical_accuracy: 0.9714 - val_loss: 0.6704 - val_categorical_crossentropy: 0.6704 - val_categorical_accuracy: 0.6667
# Epoch 55/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2825 - categorical_crossentropy: 0.2825 - categorical_accuracy: 0.9429 - val_loss: 0.6715 - val_categorical_crossentropy: 0.6715 - val_categorical_accuracy: 0.7000
# Epoch 56/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2647 - categorical_crossentropy: 0.2647 - categorical_accuracy: 0.9571 - val_loss: 0.6738 - val_categorical_crossentropy: 0.6738 - val_categorical_accuracy: 0.7000
# Epoch 57/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2709 - categorical_crossentropy: 0.2709 - categorical_accuracy: 0.9857 - val_loss: 0.6756 - val_categorical_crossentropy: 0.6756 - val_categorical_accuracy: 0.7000
# Epoch 58/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2575 - categorical_crossentropy: 0.2575 - categorical_accuracy: 0.9571 - val_loss: 0.6764 - val_categorical_crossentropy: 0.6764 - val_categorical_accuracy: 0.7000
# Epoch 59/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2777 - categorical_crossentropy: 0.2777 - categorical_accuracy: 0.9571 - val_loss: 0.6772 - val_categorical_crossentropy: 0.6772 - val_categorical_accuracy: 0.7000
# Epoch 60/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2556 - categorical_crossentropy: 0.2556 - categorical_accuracy: 0.9714 - val_loss: 0.6771 - val_categorical_crossentropy: 0.6771 - val_categorical_accuracy: 0.6667
# Epoch 61/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2745 - categorical_crossentropy: 0.2745 - categorical_accuracy: 0.9714 - val_loss: 0.6780 - val_categorical_crossentropy: 0.6780 - val_categorical_accuracy: 0.6667
# Epoch 62/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2617 - categorical_crossentropy: 0.2617 - categorical_accuracy: 0.9857 - val_loss: 0.6799 - val_categorical_crossentropy: 0.6799 - val_categorical_accuracy: 0.6667
# Epoch 63/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2659 - categorical_crossentropy: 0.2659 - categorical_accuracy: 0.9571 - val_loss: 0.6816 - val_categorical_crossentropy: 0.6816 - val_categorical_accuracy: 0.7000
# Epoch 64/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2543 - categorical_crossentropy: 0.2543 - categorical_accuracy: 0.9714 - val_loss: 0.6831 - val_categorical_crossentropy: 0.6831 - val_categorical_accuracy: 0.7000
# Epoch 65/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2473 - categorical_crossentropy: 0.2473 - categorical_accuracy: 0.9857 - val_loss: 0.6831 - val_categorical_crossentropy: 0.6831 - val_categorical_accuracy: 0.7000
# Epoch 66/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2616 - categorical_crossentropy: 0.2616 - categorical_accuracy: 0.9857 - val_loss: 0.6825 - val_categorical_crossentropy: 0.6825 - val_categorical_accuracy: 0.7000
# Epoch 67/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2431 - categorical_crossentropy: 0.2431 - categorical_accuracy: 0.9714 - val_loss: 0.6833 - val_categorical_crossentropy: 0.6833 - val_categorical_accuracy: 0.7000
# Epoch 68/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2474 - categorical_crossentropy: 0.2474 - categorical_accuracy: 0.9571 - val_loss: 0.6852 - val_categorical_crossentropy: 0.6852 - val_categorical_accuracy: 0.7000
# Epoch 69/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2378 - categorical_crossentropy: 0.2378 - categorical_accuracy: 0.9857 - val_loss: 0.6882 - val_categorical_crossentropy: 0.6882 - val_categorical_accuracy: 0.7000
# Epoch 70/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2353 - categorical_crossentropy: 0.2353 - categorical_accuracy: 0.9857 - val_loss: 0.6926 - val_categorical_crossentropy: 0.6926 - val_categorical_accuracy: 0.7000
# Epoch 71/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2382 - categorical_crossentropy: 0.2382 - categorical_accuracy: 1.0000 - val_loss: 0.6950 - val_categorical_crossentropy: 0.6950 - val_categorical_accuracy: 0.6667
# Epoch 72/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2398 - categorical_crossentropy: 0.2398 - categorical_accuracy: 0.9857 - val_loss: 0.6945 - val_categorical_crossentropy: 0.6945 - val_categorical_accuracy: 0.6667
# Epoch 73/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2274 - categorical_crossentropy: 0.2274 - categorical_accuracy: 1.0000 - val_loss: 0.6935 - val_categorical_crossentropy: 0.6935 - val_categorical_accuracy: 0.6667
# Epoch 74/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2269 - categorical_crossentropy: 0.2269 - categorical_accuracy: 1.0000 - val_loss: 0.6915 - val_categorical_crossentropy: 0.6915 - val_categorical_accuracy: 0.7000
# Epoch 75/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2405 - categorical_crossentropy: 0.2405 - categorical_accuracy: 0.9714 - val_loss: 0.6890 - val_categorical_crossentropy: 0.6890 - val_categorical_accuracy: 0.7000
# Epoch 76/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2376 - categorical_crossentropy: 0.2376 - categorical_accuracy: 0.9857 - val_loss: 0.6907 - val_categorical_crossentropy: 0.6907 - val_categorical_accuracy: 0.6667
# Epoch 77/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2309 - categorical_crossentropy: 0.2309 - categorical_accuracy: 0.9714 - val_loss: 0.6962 - val_categorical_crossentropy: 0.6962 - val_categorical_accuracy: 0.6333
# Epoch 78/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2136 - categorical_crossentropy: 0.2136 - categorical_accuracy: 1.0000 - val_loss: 0.7008 - val_categorical_crossentropy: 0.7008 - val_categorical_accuracy: 0.6333
# Epoch 79/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2284 - categorical_crossentropy: 0.2284 - categorical_accuracy: 1.0000 - val_loss: 0.7014 - val_categorical_crossentropy: 0.7014 - val_categorical_accuracy: 0.6333
# Epoch 80/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2180 - categorical_crossentropy: 0.2180 - categorical_accuracy: 1.0000 - val_loss: 0.6995 - val_categorical_crossentropy: 0.6995 - val_categorical_accuracy: 0.6333
# Epoch 81/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2395 - categorical_crossentropy: 0.2395 - categorical_accuracy: 0.9857 - val_loss: 0.6988 - val_categorical_crossentropy: 0.6988 - val_categorical_accuracy: 0.6667
# Epoch 82/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2223 - categorical_crossentropy: 0.2223 - categorical_accuracy: 1.0000 - val_loss: 0.7024 - val_categorical_crossentropy: 0.7024 - val_categorical_accuracy: 0.6333
# Epoch 83/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2171 - categorical_crossentropy: 0.2171 - categorical_accuracy: 0.9857 - val_loss: 0.7090 - val_categorical_crossentropy: 0.7090 - val_categorical_accuracy: 0.6333
# Epoch 84/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2047 - categorical_crossentropy: 0.2047 - categorical_accuracy: 1.0000 - val_loss: 0.7156 - val_categorical_crossentropy: 0.7156 - val_categorical_accuracy: 0.6333
# Epoch 85/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2101 - categorical_crossentropy: 0.2101 - categorical_accuracy: 0.9571 - val_loss: 0.7174 - val_categorical_crossentropy: 0.7174 - val_categorical_accuracy: 0.6333
# Epoch 86/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2056 - categorical_crossentropy: 0.2056 - categorical_accuracy: 1.0000 - val_loss: 0.7152 - val_categorical_crossentropy: 0.7152 - val_categorical_accuracy: 0.6333
# Epoch 87/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2122 - categorical_crossentropy: 0.2122 - categorical_accuracy: 1.0000 - val_loss: 0.7140 - val_categorical_crossentropy: 0.7140 - val_categorical_accuracy: 0.6333
# Epoch 88/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2022 - categorical_crossentropy: 0.2022 - categorical_accuracy: 0.9857 - val_loss: 0.7131 - val_categorical_crossentropy: 0.7131 - val_categorical_accuracy: 0.6333
# Epoch 89/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2106 - categorical_crossentropy: 0.2106 - categorical_accuracy: 1.0000 - val_loss: 0.7166 - val_categorical_crossentropy: 0.7166 - val_categorical_accuracy: 0.6333
# Epoch 90/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2145 - categorical_crossentropy: 0.2145 - categorical_accuracy: 0.9857 - val_loss: 0.7166 - val_categorical_crossentropy: 0.7166 - val_categorical_accuracy: 0.6000
# Epoch 91/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2167 - categorical_crossentropy: 0.2167 - categorical_accuracy: 0.9857 - val_loss: 0.7118 - val_categorical_crossentropy: 0.7118 - val_categorical_accuracy: 0.6333
# Epoch 92/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2066 - categorical_crossentropy: 0.2066 - categorical_accuracy: 1.0000 - val_loss: 0.7092 - val_categorical_crossentropy: 0.7092 - val_categorical_accuracy: 0.6333
# Epoch 93/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2075 - categorical_crossentropy: 0.2075 - categorical_accuracy: 0.9857 - val_loss: 0.7163 - val_categorical_crossentropy: 0.7163 - val_categorical_accuracy: 0.6333
# Epoch 94/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1871 - categorical_crossentropy: 0.1871 - categorical_accuracy: 1.0000 - val_loss: 0.7223 - val_categorical_crossentropy: 0.7223 - val_categorical_accuracy: 0.6333
# Epoch 95/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2038 - categorical_crossentropy: 0.2038 - categorical_accuracy: 1.0000 - val_loss: 0.7242 - val_categorical_crossentropy: 0.7242 - val_categorical_accuracy: 0.6333
# Epoch 96/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2042 - categorical_crossentropy: 0.2042 - categorical_accuracy: 0.9857 - val_loss: 0.7256 - val_categorical_crossentropy: 0.7256 - val_categorical_accuracy: 0.6000
# Epoch 97/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1846 - categorical_crossentropy: 0.1846 - categorical_accuracy: 1.0000 - val_loss: 0.7283 - val_categorical_crossentropy: 0.7283 - val_categorical_accuracy: 0.6000
# Epoch 98/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1973 - categorical_crossentropy: 0.1973 - categorical_accuracy: 1.0000 - val_loss: 0.7329 - val_categorical_crossentropy: 0.7329 - val_categorical_accuracy: 0.5667
# Epoch 99/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1887 - categorical_crossentropy: 0.1887 - categorical_accuracy: 0.9857 - val_loss: 0.7358 - val_categorical_crossentropy: 0.7358 - val_categorical_accuracy: 0.6000
# Epoch 100/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2007 - categorical_crossentropy: 0.2007 - categorical_accuracy: 0.9714 - val_loss: 0.7379 - val_categorical_crossentropy: 0.7379 - val_categorical_accuracy: 0.6000
# Epoch 101/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1948 - categorical_crossentropy: 0.1948 - categorical_accuracy: 1.0000 - val_loss: 0.7387 - val_categorical_crossentropy: 0.7387 - val_categorical_accuracy: 0.6000
# Epoch 102/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1829 - categorical_crossentropy: 0.1829 - categorical_accuracy: 1.0000 - val_loss: 0.7387 - val_categorical_crossentropy: 0.7387 - val_categorical_accuracy: 0.6000
# Epoch 103/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2017 - categorical_crossentropy: 0.2017 - categorical_accuracy: 0.9714 - val_loss: 0.7449 - val_categorical_crossentropy: 0.7449 - val_categorical_accuracy: 0.5333
# Epoch 104/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1885 - categorical_crossentropy: 0.1885 - categorical_accuracy: 1.0000 - val_loss: 0.7483 - val_categorical_crossentropy: 0.7483 - val_categorical_accuracy: 0.5333
# Epoch 105/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1922 - categorical_crossentropy: 0.1922 - categorical_accuracy: 1.0000 - val_loss: 0.7455 - val_categorical_crossentropy: 0.7455 - val_categorical_accuracy: 0.5000
# Epoch 106/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1893 - categorical_crossentropy: 0.1893 - categorical_accuracy: 1.0000 - val_loss: 0.7401 - val_categorical_crossentropy: 0.7401 - val_categorical_accuracy: 0.5333
# Epoch 107/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1857 - categorical_crossentropy: 0.1857 - categorical_accuracy: 1.0000 - val_loss: 0.7415 - val_categorical_crossentropy: 0.7415 - val_categorical_accuracy: 0.5667
# Epoch 108/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1841 - categorical_crossentropy: 0.1841 - categorical_accuracy: 0.9571 - val_loss: 0.7446 - val_categorical_crossentropy: 0.7446 - val_categorical_accuracy: 0.5667
# Epoch 109/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1683 - categorical_crossentropy: 0.1683 - categorical_accuracy: 1.0000 - val_loss: 0.7550 - val_categorical_crossentropy: 0.7550 - val_categorical_accuracy: 0.5333
# Epoch 110/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1920 - categorical_crossentropy: 0.1920 - categorical_accuracy: 0.9714 - val_loss: 0.7579 - val_categorical_crossentropy: 0.7579 - val_categorical_accuracy: 0.5333
# Epoch 111/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1716 - categorical_crossentropy: 0.1716 - categorical_accuracy: 1.0000 - val_loss: 0.7525 - val_categorical_crossentropy: 0.7525 - val_categorical_accuracy: 0.5667
# Epoch 112/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1772 - categorical_crossentropy: 0.1772 - categorical_accuracy: 1.0000 - val_loss: 0.7488 - val_categorical_crossentropy: 0.7488 - val_categorical_accuracy: 0.5667
# Epoch 113/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1737 - categorical_crossentropy: 0.1737 - categorical_accuracy: 0.9857 - val_loss: 0.7503 - val_categorical_crossentropy: 0.7503 - val_categorical_accuracy: 0.6000
# Epoch 114/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1800 - categorical_crossentropy: 0.1800 - categorical_accuracy: 0.9857 - val_loss: 0.7585 - val_categorical_crossentropy: 0.7585 - val_categorical_accuracy: 0.5000
# Epoch 115/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1682 - categorical_crossentropy: 0.1682 - categorical_accuracy: 1.0000 - val_loss: 0.7654 - val_categorical_crossentropy: 0.7654 - val_categorical_accuracy: 0.4667
# Epoch 116/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1750 - categorical_crossentropy: 0.1750 - categorical_accuracy: 0.9857 - val_loss: 0.7669 - val_categorical_crossentropy: 0.7669 - val_categorical_accuracy: 0.4667
# Epoch 117/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1675 - categorical_crossentropy: 0.1675 - categorical_accuracy: 1.0000 - val_loss: 0.7653 - val_categorical_crossentropy: 0.7653 - val_categorical_accuracy: 0.5000
# Epoch 118/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1621 - categorical_crossentropy: 0.1621 - categorical_accuracy: 1.0000 - val_loss: 0.7642 - val_categorical_crossentropy: 0.7642 - val_categorical_accuracy: 0.5000
# Epoch 119/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1634 - categorical_crossentropy: 0.1634 - categorical_accuracy: 1.0000 - val_loss: 0.7640 - val_categorical_crossentropy: 0.7640 - val_categorical_accuracy: 0.5000
# Epoch 120/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1562 - categorical_crossentropy: 0.1562 - categorical_accuracy: 1.0000 - val_loss: 0.7704 - val_categorical_crossentropy: 0.7704 - val_categorical_accuracy: 0.5000
# Epoch 121/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1835 - categorical_crossentropy: 0.1835 - categorical_accuracy: 1.0000 - val_loss: 0.7843 - val_categorical_crossentropy: 0.7843 - val_categorical_accuracy: 0.5000
# Epoch 122/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1668 - categorical_crossentropy: 0.1668 - categorical_accuracy: 1.0000 - val_loss: 0.7905 - val_categorical_crossentropy: 0.7905 - val_categorical_accuracy: 0.5000
# Epoch 123/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1733 - categorical_crossentropy: 0.1733 - categorical_accuracy: 0.9857 - val_loss: 0.7949 - val_categorical_crossentropy: 0.7949 - val_categorical_accuracy: 0.5000
# Epoch 124/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1848 - categorical_crossentropy: 0.1848 - categorical_accuracy: 0.9857 - val_loss: 0.7966 - val_categorical_crossentropy: 0.7966 - val_categorical_accuracy: 0.5000
# Epoch 125/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1498 - categorical_crossentropy: 0.1498 - categorical_accuracy: 1.0000 - val_loss: 0.7876 - val_categorical_crossentropy: 0.7876 - val_categorical_accuracy: 0.5333
# Epoch 126/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1628 - categorical_crossentropy: 0.1628 - categorical_accuracy: 1.0000 - val_loss: 0.7726 - val_categorical_crossentropy: 0.7726 - val_categorical_accuracy: 0.5667
# Epoch 127/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1625 - categorical_crossentropy: 0.1625 - categorical_accuracy: 1.0000 - val_loss: 0.7737 - val_categorical_crossentropy: 0.7737 - val_categorical_accuracy: 0.4333
# Epoch 128/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1713 - categorical_crossentropy: 0.1713 - categorical_accuracy: 0.9857 - val_loss: 0.7890 - val_categorical_crossentropy: 0.7890 - val_categorical_accuracy: 0.4667
# Epoch 129/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1591 - categorical_crossentropy: 0.1591 - categorical_accuracy: 1.0000 - val_loss: 0.7976 - val_categorical_crossentropy: 0.7976 - val_categorical_accuracy: 0.4667
# Epoch 130/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1534 - categorical_crossentropy: 0.1534 - categorical_accuracy: 1.0000 - val_loss: 0.7947 - val_categorical_crossentropy: 0.7947 - val_categorical_accuracy: 0.5000
# Epoch 131/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1651 - categorical_crossentropy: 0.1651 - categorical_accuracy: 1.0000 - val_loss: 0.7875 - val_categorical_crossentropy: 0.7875 - val_categorical_accuracy: 0.5667
# Epoch 132/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1568 - categorical_crossentropy: 0.1568 - categorical_accuracy: 1.0000 - val_loss: 0.7823 - val_categorical_crossentropy: 0.7823 - val_categorical_accuracy: 0.5000
# Epoch 133/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1497 - categorical_crossentropy: 0.1497 - categorical_accuracy: 1.0000 - val_loss: 0.7939 - val_categorical_crossentropy: 0.7939 - val_categorical_accuracy: 0.4667
# Epoch 134/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1513 - categorical_crossentropy: 0.1513 - categorical_accuracy: 1.0000 - val_loss: 0.8079 - val_categorical_crossentropy: 0.8079 - val_categorical_accuracy: 0.4667
# Epoch 135/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1450 - categorical_crossentropy: 0.1450 - categorical_accuracy: 1.0000 - val_loss: 0.8163 - val_categorical_crossentropy: 0.8163 - val_categorical_accuracy: 0.5000
# Epoch 136/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1491 - categorical_crossentropy: 0.1491 - categorical_accuracy: 0.9857 - val_loss: 0.8205 - val_categorical_crossentropy: 0.8205 - val_categorical_accuracy: 0.4667
# Epoch 137/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1519 - categorical_crossentropy: 0.1519 - categorical_accuracy: 1.0000 - val_loss: 0.8220 - val_categorical_crossentropy: 0.8220 - val_categorical_accuracy: 0.4667
# Epoch 138/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1500 - categorical_crossentropy: 0.1500 - categorical_accuracy: 1.0000 - val_loss: 0.8183 - val_categorical_crossentropy: 0.8183 - val_categorical_accuracy: 0.5000
# Epoch 139/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1677 - categorical_crossentropy: 0.1677 - categorical_accuracy: 1.0000 - val_loss: 0.8110 - val_categorical_crossentropy: 0.8110 - val_categorical_accuracy: 0.5000
# Epoch 140/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1613 - categorical_crossentropy: 0.1613 - categorical_accuracy: 1.0000 - val_loss: 0.8058 - val_categorical_crossentropy: 0.8058 - val_categorical_accuracy: 0.5000
# Epoch 141/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1531 - categorical_crossentropy: 0.1531 - categorical_accuracy: 1.0000 - val_loss: 0.8038 - val_categorical_crossentropy: 0.8038 - val_categorical_accuracy: 0.4667
# Epoch 142/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1530 - categorical_crossentropy: 0.1530 - categorical_accuracy: 0.9857 - val_loss: 0.8076 - val_categorical_crossentropy: 0.8076 - val_categorical_accuracy: 0.5000
# Epoch 143/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1470 - categorical_crossentropy: 0.1470 - categorical_accuracy: 1.0000 - val_loss: 0.8123 - val_categorical_crossentropy: 0.8123 - val_categorical_accuracy: 0.5000
# Epoch 144/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1643 - categorical_crossentropy: 0.1643 - categorical_accuracy: 1.0000 - val_loss: 0.8158 - val_categorical_crossentropy: 0.8158 - val_categorical_accuracy: 0.5000
# Epoch 145/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1478 - categorical_crossentropy: 0.1478 - categorical_accuracy: 1.0000 - val_loss: 0.8188 - val_categorical_crossentropy: 0.8188 - val_categorical_accuracy: 0.5000
# Epoch 146/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1424 - categorical_crossentropy: 0.1424 - categorical_accuracy: 1.0000 - val_loss: 0.8148 - val_categorical_crossentropy: 0.8148 - val_categorical_accuracy: 0.5000
# Epoch 147/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1401 - categorical_crossentropy: 0.1401 - categorical_accuracy: 1.0000 - val_loss: 0.8088 - val_categorical_crossentropy: 0.8088 - val_categorical_accuracy: 0.5000
# Epoch 148/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1567 - categorical_crossentropy: 0.1567 - categorical_accuracy: 1.0000 - val_loss: 0.8245 - val_categorical_crossentropy: 0.8245 - val_categorical_accuracy: 0.5000
# Epoch 149/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1444 - categorical_crossentropy: 0.1444 - categorical_accuracy: 1.0000 - val_loss: 0.8347 - val_categorical_crossentropy: 0.8347 - val_categorical_accuracy: 0.5000
# Epoch 150/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1487 - categorical_crossentropy: 0.1487 - categorical_accuracy: 1.0000 - val_loss: 0.8303 - val_categorical_crossentropy: 0.8303 - val_categorical_accuracy: 0.4667
# Epoch 151/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1443 - categorical_crossentropy: 0.1443 - categorical_accuracy: 1.0000 - val_loss: 0.8191 - val_categorical_crossentropy: 0.8191 - val_categorical_accuracy: 0.4667
# Epoch 152/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1398 - categorical_crossentropy: 0.1398 - categorical_accuracy: 1.0000 - val_loss: 0.8142 - val_categorical_crossentropy: 0.8142 - val_categorical_accuracy: 0.4667
# Epoch 153/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1384 - categorical_crossentropy: 0.1384 - categorical_accuracy: 1.0000 - val_loss: 0.8152 - val_categorical_crossentropy: 0.8152 - val_categorical_accuracy: 0.4667
# Epoch 154/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1340 - categorical_crossentropy: 0.1340 - categorical_accuracy: 1.0000 - val_loss: 0.8215 - val_categorical_crossentropy: 0.8215 - val_categorical_accuracy: 0.4333
# Epoch 155/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1416 - categorical_crossentropy: 0.1416 - categorical_accuracy: 1.0000 - val_loss: 0.8240 - val_categorical_crossentropy: 0.8240 - val_categorical_accuracy: 0.4667
# Epoch 156/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1410 - categorical_crossentropy: 0.1410 - categorical_accuracy: 1.0000 - val_loss: 0.8319 - val_categorical_crossentropy: 0.8319 - val_categorical_accuracy: 0.4667
# Epoch 157/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1430 - categorical_crossentropy: 0.1430 - categorical_accuracy: 1.0000 - val_loss: 0.8321 - val_categorical_crossentropy: 0.8321 - val_categorical_accuracy: 0.4667
# Epoch 158/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1419 - categorical_crossentropy: 0.1419 - categorical_accuracy: 1.0000 - val_loss: 0.8245 - val_categorical_crossentropy: 0.8245 - val_categorical_accuracy: 0.5000
# Epoch 159/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1349 - categorical_crossentropy: 0.1349 - categorical_accuracy: 1.0000 - val_loss: 0.8245 - val_categorical_crossentropy: 0.8245 - val_categorical_accuracy: 0.5000
# Epoch 160/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1382 - categorical_crossentropy: 0.1382 - categorical_accuracy: 1.0000 - val_loss: 0.8322 - val_categorical_crossentropy: 0.8322 - val_categorical_accuracy: 0.5000
# Epoch 161/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1354 - categorical_crossentropy: 0.1354 - categorical_accuracy: 1.0000 - val_loss: 0.8381 - val_categorical_crossentropy: 0.8381 - val_categorical_accuracy: 0.5000
# Epoch 162/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1282 - categorical_crossentropy: 0.1282 - categorical_accuracy: 1.0000 - val_loss: 0.8415 - val_categorical_crossentropy: 0.8415 - val_categorical_accuracy: 0.4667
# Epoch 163/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1444 - categorical_crossentropy: 0.1444 - categorical_accuracy: 1.0000 - val_loss: 0.8355 - val_categorical_crossentropy: 0.8355 - val_categorical_accuracy: 0.4667
# Epoch 164/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1327 - categorical_crossentropy: 0.1327 - categorical_accuracy: 1.0000 - val_loss: 0.8332 - val_categorical_crossentropy: 0.8332 - val_categorical_accuracy: 0.4667
# Epoch 165/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1239 - categorical_crossentropy: 0.1239 - categorical_accuracy: 1.0000 - val_loss: 0.8445 - val_categorical_crossentropy: 0.8445 - val_categorical_accuracy: 0.4667
# Epoch 166/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1301 - categorical_crossentropy: 0.1301 - categorical_accuracy: 1.0000 - val_loss: 0.8640 - val_categorical_crossentropy: 0.8640 - val_categorical_accuracy: 0.4333
# Epoch 167/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1129 - categorical_crossentropy: 0.1129 - categorical_accuracy: 1.0000 - val_loss: 0.8737 - val_categorical_crossentropy: 0.8737 - val_categorical_accuracy: 0.4333
# Epoch 168/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1283 - categorical_crossentropy: 0.1283 - categorical_accuracy: 1.0000 - val_loss: 0.8704 - val_categorical_crossentropy: 0.8704 - val_categorical_accuracy: 0.4667
# Epoch 169/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1298 - categorical_crossentropy: 0.1298 - categorical_accuracy: 1.0000 - val_loss: 0.8602 - val_categorical_crossentropy: 0.8602 - val_categorical_accuracy: 0.4667
# Epoch 170/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1267 - categorical_crossentropy: 0.1267 - categorical_accuracy: 1.0000 - val_loss: 0.8415 - val_categorical_crossentropy: 0.8415 - val_categorical_accuracy: 0.4333
# Epoch 171/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1187 - categorical_crossentropy: 0.1187 - categorical_accuracy: 1.0000 - val_loss: 0.8321 - val_categorical_crossentropy: 0.8321 - val_categorical_accuracy: 0.4333
# Epoch 172/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1377 - categorical_crossentropy: 0.1377 - categorical_accuracy: 1.0000 - val_loss: 0.8349 - val_categorical_crossentropy: 0.8349 - val_categorical_accuracy: 0.4333
# Epoch 173/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1205 - categorical_crossentropy: 0.1205 - categorical_accuracy: 1.0000 - val_loss: 0.8463 - val_categorical_crossentropy: 0.8463 - val_categorical_accuracy: 0.4333
# Epoch 174/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1262 - categorical_crossentropy: 0.1262 - categorical_accuracy: 1.0000 - val_loss: 0.8476 - val_categorical_crossentropy: 0.8476 - val_categorical_accuracy: 0.4333
# Epoch 175/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1340 - categorical_crossentropy: 0.1340 - categorical_accuracy: 1.0000 - val_loss: 0.8477 - val_categorical_crossentropy: 0.8477 - val_categorical_accuracy: 0.4333
# Epoch 176/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1168 - categorical_crossentropy: 0.1168 - categorical_accuracy: 1.0000 - val_loss: 0.8560 - val_categorical_crossentropy: 0.8560 - val_categorical_accuracy: 0.4333
# Epoch 177/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1301 - categorical_crossentropy: 0.1301 - categorical_accuracy: 0.9857 - val_loss: 0.8662 - val_categorical_crossentropy: 0.8662 - val_categorical_accuracy: 0.4333
# Epoch 178/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1184 - categorical_crossentropy: 0.1184 - categorical_accuracy: 1.0000 - val_loss: 0.8642 - val_categorical_crossentropy: 0.8642 - val_categorical_accuracy: 0.4333
# Epoch 179/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1234 - categorical_crossentropy: 0.1234 - categorical_accuracy: 1.0000 - val_loss: 0.8470 - val_categorical_crossentropy: 0.8470 - val_categorical_accuracy: 0.4000
# Epoch 180/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1137 - categorical_crossentropy: 0.1137 - categorical_accuracy: 1.0000 - val_loss: 0.8430 - val_categorical_crossentropy: 0.8430 - val_categorical_accuracy: 0.4000
# Epoch 181/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1413 - categorical_crossentropy: 0.1413 - categorical_accuracy: 1.0000 - val_loss: 0.8523 - val_categorical_crossentropy: 0.8523 - val_categorical_accuracy: 0.4667
# Epoch 182/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1220 - categorical_crossentropy: 0.1220 - categorical_accuracy: 1.0000 - val_loss: 0.8581 - val_categorical_crossentropy: 0.8581 - val_categorical_accuracy: 0.4667
# Epoch 183/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1335 - categorical_crossentropy: 0.1335 - categorical_accuracy: 1.0000 - val_loss: 0.8688 - val_categorical_crossentropy: 0.8688 - val_categorical_accuracy: 0.4667
# Epoch 184/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1093 - categorical_crossentropy: 0.1093 - categorical_accuracy: 1.0000 - val_loss: 0.8683 - val_categorical_crossentropy: 0.8683 - val_categorical_accuracy: 0.4333
# Epoch 185/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1174 - categorical_crossentropy: 0.1174 - categorical_accuracy: 1.0000 - val_loss: 0.8648 - val_categorical_crossentropy: 0.8648 - val_categorical_accuracy: 0.4333
# Epoch 186/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1239 - categorical_crossentropy: 0.1239 - categorical_accuracy: 1.0000 - val_loss: 0.8696 - val_categorical_crossentropy: 0.8696 - val_categorical_accuracy: 0.4333
# Epoch 187/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1138 - categorical_crossentropy: 0.1138 - categorical_accuracy: 1.0000 - val_loss: 0.8658 - val_categorical_crossentropy: 0.8658 - val_categorical_accuracy: 0.5000
# Epoch 188/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1227 - categorical_crossentropy: 0.1227 - categorical_accuracy: 1.0000 - val_loss: 0.8629 - val_categorical_crossentropy: 0.8629 - val_categorical_accuracy: 0.4667
# Epoch 189/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1042 - categorical_crossentropy: 0.1042 - categorical_accuracy: 1.0000 - val_loss: 0.8632 - val_categorical_crossentropy: 0.8632 - val_categorical_accuracy: 0.5000
# Epoch 190/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1088 - categorical_crossentropy: 0.1088 - categorical_accuracy: 1.0000 - val_loss: 0.8591 - val_categorical_crossentropy: 0.8591 - val_categorical_accuracy: 0.4667
# Epoch 191/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1057 - categorical_crossentropy: 0.1057 - categorical_accuracy: 1.0000 - val_loss: 0.8500 - val_categorical_crossentropy: 0.8500 - val_categorical_accuracy: 0.4667
# Epoch 192/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1221 - categorical_crossentropy: 0.1221 - categorical_accuracy: 1.0000 - val_loss: 0.8457 - val_categorical_crossentropy: 0.8457 - val_categorical_accuracy: 0.5000
# Epoch 193/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1050 - categorical_crossentropy: 0.1050 - categorical_accuracy: 1.0000 - val_loss: 0.8417 - val_categorical_crossentropy: 0.8417 - val_categorical_accuracy: 0.5000
# Epoch 194/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1242 - categorical_crossentropy: 0.1242 - categorical_accuracy: 1.0000 - val_loss: 0.8480 - val_categorical_crossentropy: 0.8480 - val_categorical_accuracy: 0.5333
# Epoch 195/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1184 - categorical_crossentropy: 0.1184 - categorical_accuracy: 1.0000 - val_loss: 0.8521 - val_categorical_crossentropy: 0.8521 - val_categorical_accuracy: 0.5333
# Epoch 196/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1071 - categorical_crossentropy: 0.1071 - categorical_accuracy: 1.0000 - val_loss: 0.8699 - val_categorical_crossentropy: 0.8699 - val_categorical_accuracy: 0.5000
# Epoch 197/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1175 - categorical_crossentropy: 0.1175 - categorical_accuracy: 1.0000 - val_loss: 0.8863 - val_categorical_crossentropy: 0.8863 - val_categorical_accuracy: 0.5000
# Epoch 198/500
# ...
# Epoch 438/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0526 - categorical_crossentropy: 0.0526 - categorical_accuracy: 1.0000 - val_loss: 0.9661 - val_categorical_crossentropy: 0.9661 - val_categorical_accuracy: 0.5000
# Epoch 439/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0526 - categorical_crossentropy: 0.0526 - categorical_accuracy: 1.0000 - val_loss: 0.9745 - val_categorical_crossentropy: 0.9745 - val_categorical_accuracy: 0.4667
# Epoch 440/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0540 - categorical_crossentropy: 0.0540 - categorical_accuracy: 1.0000 - val_loss: 1.0022 - val_categorical_crossentropy: 1.0022 - val_categorical_accuracy: 0.4667
# Epoch 441/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0501 - categorical_crossentropy: 0.0501 - categorical_accuracy: 1.0000 - val_loss: 1.0184 - val_categorical_crossentropy: 1.0184 - val_categorical_accuracy: 0.5000
# Epoch 442/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0615 - categorical_crossentropy: 0.0615 - categorical_accuracy: 1.0000 - val_loss: 1.0067 - val_categorical_crossentropy: 1.0067 - val_categorical_accuracy: 0.5000
# Epoch 443/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0599 - categorical_crossentropy: 0.0599 - categorical_accuracy: 1.0000 - val_loss: 1.0078 - val_categorical_crossentropy: 1.0078 - val_categorical_accuracy: 0.5333
# Epoch 444/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0615 - categorical_crossentropy: 0.0615 - categorical_accuracy: 1.0000 - val_loss: 1.0048 - val_categorical_crossentropy: 1.0048 - val_categorical_accuracy: 0.5000
# Epoch 445/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0497 - categorical_crossentropy: 0.0497 - categorical_accuracy: 1.0000 - val_loss: 1.0419 - val_categorical_crossentropy: 1.0419 - val_categorical_accuracy: 0.5000
# Epoch 446/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0576 - categorical_crossentropy: 0.0576 - categorical_accuracy: 1.0000 - val_loss: 1.0439 - val_categorical_crossentropy: 1.0439 - val_categorical_accuracy: 0.5333
# Epoch 447/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0563 - categorical_crossentropy: 0.0563 - categorical_accuracy: 1.0000 - val_loss: 1.0702 - val_categorical_crossentropy: 1.0702 - val_categorical_accuracy: 0.5333
# Epoch 448/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0581 - categorical_crossentropy: 0.0581 - categorical_accuracy: 1.0000 - val_loss: 1.1742 - val_categorical_crossentropy: 1.1742 - val_categorical_accuracy: 0.4333
# Epoch 449/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0587 - categorical_crossentropy: 0.0587 - categorical_accuracy: 1.0000 - val_loss: 1.1425 - val_categorical_crossentropy: 1.1425 - val_categorical_accuracy: 0.4333
# Epoch 450/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0519 - categorical_crossentropy: 0.0519 - categorical_accuracy: 1.0000 - val_loss: 1.0444 - val_categorical_crossentropy: 1.0444 - val_categorical_accuracy: 0.5667
# Epoch 451/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0520 - categorical_crossentropy: 0.0520 - categorical_accuracy: 1.0000 - val_loss: 1.0086 - val_categorical_crossentropy: 1.0086 - val_categorical_accuracy: 0.5667
# Epoch 452/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0489 - categorical_crossentropy: 0.0489 - categorical_accuracy: 1.0000 - val_loss: 1.0256 - val_categorical_crossentropy: 1.0256 - val_categorical_accuracy: 0.5333
# Epoch 453/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0579 - categorical_crossentropy: 0.0579 - categorical_accuracy: 1.0000 - val_loss: 1.0420 - val_categorical_crossentropy: 1.0420 - val_categorical_accuracy: 0.5333
# Epoch 454/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0614 - categorical_crossentropy: 0.0614 - categorical_accuracy: 0.9857 - val_loss: 1.0205 - val_categorical_crossentropy: 1.0205 - val_categorical_accuracy: 0.5333
# Epoch 455/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0521 - categorical_crossentropy: 0.0521 - categorical_accuracy: 1.0000 - val_loss: 1.0013 - val_categorical_crossentropy: 1.0013 - val_categorical_accuracy: 0.5333
# Epoch 456/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0514 - categorical_crossentropy: 0.0514 - categorical_accuracy: 1.0000 - val_loss: 1.0311 - val_categorical_crossentropy: 1.0311 - val_categorical_accuracy: 0.5667
# Epoch 457/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0542 - categorical_crossentropy: 0.0542 - categorical_accuracy: 1.0000 - val_loss: 1.0329 - val_categorical_crossentropy: 1.0329 - val_categorical_accuracy: 0.6000
# Epoch 458/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0470 - categorical_crossentropy: 0.0470 - categorical_accuracy: 1.0000 - val_loss: 1.0073 - val_categorical_crossentropy: 1.0073 - val_categorical_accuracy: 0.6000
# Epoch 459/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0476 - categorical_crossentropy: 0.0476 - categorical_accuracy: 1.0000 - val_loss: 0.9787 - val_categorical_crossentropy: 0.9787 - val_categorical_accuracy: 0.6000
# Epoch 460/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0566 - categorical_crossentropy: 0.0566 - categorical_accuracy: 1.0000 - val_loss: 0.9981 - val_categorical_crossentropy: 0.9981 - val_categorical_accuracy: 0.5333
# Epoch 461/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0535 - categorical_crossentropy: 0.0535 - categorical_accuracy: 1.0000 - val_loss: 1.0410 - val_categorical_crossentropy: 1.0410 - val_categorical_accuracy: 0.5667
# Epoch 462/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0533 - categorical_crossentropy: 0.0533 - categorical_accuracy: 1.0000 - val_loss: 1.0654 - val_categorical_crossentropy: 1.0654 - val_categorical_accuracy: 0.6000
# Epoch 463/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0589 - categorical_crossentropy: 0.0589 - categorical_accuracy: 1.0000 - val_loss: 1.0437 - val_categorical_crossentropy: 1.0437 - val_categorical_accuracy: 0.5333
# Epoch 464/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0477 - categorical_crossentropy: 0.0477 - categorical_accuracy: 1.0000 - val_loss: 1.0963 - val_categorical_crossentropy: 1.0963 - val_categorical_accuracy: 0.5333
# Epoch 465/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0402 - categorical_crossentropy: 0.0402 - categorical_accuracy: 1.0000 - val_loss: 1.1603 - val_categorical_crossentropy: 1.1603 - val_categorical_accuracy: 0.4667
# Epoch 466/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0587 - categorical_crossentropy: 0.0587 - categorical_accuracy: 1.0000 - val_loss: 1.0757 - val_categorical_crossentropy: 1.0757 - val_categorical_accuracy: 0.4667
# Epoch 467/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0538 - categorical_crossentropy: 0.0538 - categorical_accuracy: 1.0000 - val_loss: 1.0307 - val_categorical_crossentropy: 1.0307 - val_categorical_accuracy: 0.4333
# Epoch 468/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0464 - categorical_crossentropy: 0.0464 - categorical_accuracy: 1.0000 - val_loss: 0.9997 - val_categorical_crossentropy: 0.9997 - val_categorical_accuracy: 0.5000
# Epoch 469/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0545 - categorical_crossentropy: 0.0545 - categorical_accuracy: 1.0000 - val_loss: 0.9972 - val_categorical_crossentropy: 0.9972 - val_categorical_accuracy: 0.5667
# Epoch 470/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0541 - categorical_crossentropy: 0.0541 - categorical_accuracy: 1.0000 - val_loss: 1.0502 - val_categorical_crossentropy: 1.0502 - val_categorical_accuracy: 0.5333
# Epoch 471/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0501 - categorical_crossentropy: 0.0501 - categorical_accuracy: 1.0000 - val_loss: 1.1267 - val_categorical_crossentropy: 1.1267 - val_categorical_accuracy: 0.4667
# Epoch 472/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0590 - categorical_crossentropy: 0.0590 - categorical_accuracy: 1.0000 - val_loss: 1.0792 - val_categorical_crossentropy: 1.0792 - val_categorical_accuracy: 0.5000
# Epoch 473/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0543 - categorical_crossentropy: 0.0543 - categorical_accuracy: 1.0000 - val_loss: 0.9981 - val_categorical_crossentropy: 0.9981 - val_categorical_accuracy: 0.4667
# Epoch 474/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0623 - categorical_crossentropy: 0.0623 - categorical_accuracy: 1.0000 - val_loss: 0.9814 - val_categorical_crossentropy: 0.9814 - val_categorical_accuracy: 0.5667
# Epoch 475/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0576 - categorical_crossentropy: 0.0576 - categorical_accuracy: 0.9857 - val_loss: 1.0488 - val_categorical_crossentropy: 1.0488 - val_categorical_accuracy: 0.5333
# Epoch 476/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0543 - categorical_crossentropy: 0.0543 - categorical_accuracy: 1.0000 - val_loss: 1.0492 - val_categorical_crossentropy: 1.0492 - val_categorical_accuracy: 0.4667
# Epoch 477/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0549 - categorical_crossentropy: 0.0549 - categorical_accuracy: 1.0000 - val_loss: 0.9749 - val_categorical_crossentropy: 0.9749 - val_categorical_accuracy: 0.5000
# Epoch 478/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0499 - categorical_crossentropy: 0.0499 - categorical_accuracy: 1.0000 - val_loss: 0.9459 - val_categorical_crossentropy: 0.9459 - val_categorical_accuracy: 0.5000
# Epoch 479/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0584 - categorical_crossentropy: 0.0584 - categorical_accuracy: 0.9857 - val_loss: 1.0066 - val_categorical_crossentropy: 1.0066 - val_categorical_accuracy: 0.4667
# Epoch 480/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0547 - categorical_crossentropy: 0.0547 - categorical_accuracy: 1.0000 - val_loss: 1.0854 - val_categorical_crossentropy: 1.0854 - val_categorical_accuracy: 0.5000
# Epoch 481/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0541 - categorical_crossentropy: 0.0541 - categorical_accuracy: 1.0000 - val_loss: 1.0785 - val_categorical_crossentropy: 1.0785 - val_categorical_accuracy: 0.4667
# Epoch 482/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0488 - categorical_crossentropy: 0.0488 - categorical_accuracy: 1.0000 - val_loss: 1.1066 - val_categorical_crossentropy: 1.1066 - val_categorical_accuracy: 0.4667
# Epoch 483/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0523 - categorical_crossentropy: 0.0523 - categorical_accuracy: 1.0000 - val_loss: 1.1019 - val_categorical_crossentropy: 1.1019 - val_categorical_accuracy: 0.4667
# Epoch 484/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0591 - categorical_crossentropy: 0.0591 - categorical_accuracy: 1.0000 - val_loss: 0.9997 - val_categorical_crossentropy: 0.9997 - val_categorical_accuracy: 0.5333
# Epoch 485/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0533 - categorical_crossentropy: 0.0533 - categorical_accuracy: 1.0000 - val_loss: 0.9770 - val_categorical_crossentropy: 0.9770 - val_categorical_accuracy: 0.5667
# Epoch 486/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0593 - categorical_crossentropy: 0.0593 - categorical_accuracy: 1.0000 - val_loss: 0.9979 - val_categorical_crossentropy: 0.9979 - val_categorical_accuracy: 0.5667
# Epoch 487/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0457 - categorical_crossentropy: 0.0457 - categorical_accuracy: 1.0000 - val_loss: 1.0265 - val_categorical_crossentropy: 1.0265 - val_categorical_accuracy: 0.5333
# Epoch 488/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0502 - categorical_crossentropy: 0.0502 - categorical_accuracy: 1.0000 - val_loss: 1.1169 - val_categorical_crossentropy: 1.1169 - val_categorical_accuracy: 0.5333
# Epoch 489/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0539 - categorical_crossentropy: 0.0539 - categorical_accuracy: 1.0000 - val_loss: 1.1767 - val_categorical_crossentropy: 1.1767 - val_categorical_accuracy: 0.4667
# Epoch 490/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0523 - categorical_crossentropy: 0.0523 - categorical_accuracy: 1.0000 - val_loss: 1.0867 - val_categorical_crossentropy: 1.0867 - val_categorical_accuracy: 0.5333
# Epoch 491/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0455 - categorical_crossentropy: 0.0455 - categorical_accuracy: 1.0000 - val_loss: 1.0201 - val_categorical_crossentropy: 1.0201 - val_categorical_accuracy: 0.5333
# Epoch 492/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0565 - categorical_crossentropy: 0.0565 - categorical_accuracy: 1.0000 - val_loss: 0.9936 - val_categorical_crossentropy: 0.9936 - val_categorical_accuracy: 0.5000
# Epoch 493/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0442 - categorical_crossentropy: 0.0442 - categorical_accuracy: 1.0000 - val_loss: 0.9937 - val_categorical_crossentropy: 0.9937 - val_categorical_accuracy: 0.4667
# Epoch 494/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0466 - categorical_crossentropy: 0.0466 - categorical_accuracy: 1.0000 - val_loss: 1.0325 - val_categorical_crossentropy: 1.0325 - val_categorical_accuracy: 0.4333
# Epoch 495/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0474 - categorical_crossentropy: 0.0474 - categorical_accuracy: 1.0000 - val_loss: 1.0747 - val_categorical_crossentropy: 1.0747 - val_categorical_accuracy: 0.4667
# Epoch 496/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0530 - categorical_crossentropy: 0.0530 - categorical_accuracy: 1.0000 - val_loss: 1.0816 - val_categorical_crossentropy: 1.0816 - val_categorical_accuracy: 0.5000
# Epoch 497/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0589 - categorical_crossentropy: 0.0589 - categorical_accuracy: 1.0000 - val_loss: 1.0735 - val_categorical_crossentropy: 1.0735 - val_categorical_accuracy: 0.5000
# Epoch 498/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0539 - categorical_crossentropy: 0.0539 - categorical_accuracy: 1.0000 - val_loss: 1.0608 - val_categorical_crossentropy: 1.0608 - val_categorical_accuracy: 0.5333
# Epoch 499/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0416 - categorical_crossentropy: 0.0416 - categorical_accuracy: 1.0000 - val_loss: 1.0658 - val_categorical_crossentropy: 1.0658 - val_categorical_accuracy: 0.5333
# Epoch 500/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0496 - categorical_crossentropy: 0.0496 - categorical_accuracy: 1.0000 - val_loss: 1.0475 - val_categorical_crossentropy: 1.0475 - val_categorical_accuracy: 0.5667
# # Evaluate on test data
# 2/2 [==============================] - 0s 45ms/step - loss: 8.7886 - categorical_crossentropy: 8.7886 - categorical_accuracy: 0.5500
# test loss, test acc: [8.788630276918411, 8.7886305, 0.55]
# [[0.58098717 0.58098716 0.69999999]
#  [0.30830576 0.30830574 0.81666666]
#  [0.04467091 0.04467091 0.98333335]
#  [0.23277258 0.23277259 0.91666669]
#  [1.12358636 1.12358642 0.48333332]
#  [0.4642421  0.4642421  0.80000001]
#  [0.33058339 0.33058339 0.86666667]
#  [0.74400288 0.74400288 0.44999999]
#  [0.10923911 0.10923912 0.96666664]
#  [1.3022531  1.30225313 0.56666666]
#  [0.6865847  0.68658471 0.80000001]
#  [0.82467422 0.82467425 0.58333331]
#  [0.99019709 0.99019706 0.55000001]
#  [8.78863028 8.78863049 0.55000001]]

# %%
import pandas as pd
df_accl_all = pd.DataFrame({'loss': acc_all[:, 0], 'categorical_crossentropy': acc_all[:, 1],'categorical_accuracy': acc_all[:, 2]})
df_accl_all.to_csv (r'df_accl_all.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
