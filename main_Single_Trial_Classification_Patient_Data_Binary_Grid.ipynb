# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_Single_Trial_Classification_Patient_Data_Binary_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 350 (delta 21), reused 0 (delta 0), pack-reused 313
# Receiving objects: 100% (350/350), 1.69 GiB | 36.88 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# Checking out files: 100% (95/95), done.

# %%
import scipy.io as spio
import numpy as np
import pandas as pd
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()
cols = 2
rows = 10
acc_all = zeros([rows, cols])
loss_all = zeros([rows, cols])
X_tr = np.empty([80, 12, 4096])
X_ts = np.empty([40, 12, 4096])
result=[]

h_cut = [30]
drop_out = [0.25]
k_len = [32, 64, 128]
n_epochs = 100

for h in h_cut:
  for d in drop_out:
    for kl in k_len:
      for x in range(1,11):
        fName = 'EEG_Deep/Data2A/parsed_P0' + str(x) + 'T.mat'  # Load Data
        print(fName)
        mat = spio.loadmat(fName)
        r_X_tr = mat['RawEEGData']
        y_tr = mat['Labels']
        y_tr = y_tr.flatten() 
  
        print(np.shape(r_X_tr))
        print(np.shape(y_tr))

        for t in range(r_X_tr.shape[0]):
          tril = r_X_tr[t,:,:]
          #tril = tril.transpose()
          tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, fs=250, order=4)
          # tril_filtered = tril_filtered.transpose()
          X_tr[t,:,:] = tril_filtered 
    
        # split data of each subject in training and validation
        X_train      = X_tr[0:60,:,2048:3584]
        Y_train      = y_tr[0:60]
        X_val       = X_tr[60:,:,2048:3584]
        Y_val       = y_tr[60:]

        print(np.shape(X_train))
        print(np.shape(Y_train))
        print(np.shape(X_val))
        print(np.shape(Y_val))
  
        # convert labels to one-hot encodings.
        Y_train = np_utils.to_categorical(Y_train-1, num_classes=2)
        Y_val = np_utils.to_categorical(Y_val-1, num_classes=2)

        kernels, chans, samples = 1, 12, 1536
        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
        X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
  
        print('X_train shape:', X_train.shape)
        print(X_train.shape[0], 'train samples')
        print(X_val.shape[0], 'val samples')

        fName = 'EEG_Deep/Data2A/parsed_P0' + str(x) + 'E.mat'  # Load Data
        print(fName)
        mat = spio.loadmat(fName)
        r_X_ts = mat['RawEEGData']
        y_ts = mat['Labels']
        y_ts = y_ts.flatten() 

        print(np.shape(r_X_ts))
        print(np.shape(y_ts))

        for t in range(r_X_ts.shape[0]):
          tril = r_X_ts[t,:,:]
          # tril = tril.transpose()
          tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, fs=250, order=4)
          # tril_filtered = tril_filtered.transpose()
          X_ts[t,:,:] = tril_filtered 

        X_test      = X_ts[:,:,2048:3584]
        Y_test      = y_ts[:]
        print(np.shape(X_test))
        print(np.shape(Y_test))

        #convert labels to one-hot encodings.
        Y_test      = np_utils.to_categorical(Y_test-1)

        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

        print('X_train shape:', X_test.shape)
        print(X_test.shape[0], 'test samples')

        kernels, chans, samples = 1, 12, 1536
        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_train = X_train.reshape(X_train.shape[0], kernels, chans, samples)
        X_val   = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
        print('X_train shape:', X_train.shape)
        print(X_train.shape[0], 'train samples')
        print(X_val.shape[0], 'val samples')

        X_test      = X_ts[:,:,2048:3584]
        Y_test      = y_ts[:]
        print(np.shape(X_test))
        print(np.shape(Y_test))

        #convert labels to one-hot encodings.
        Y_test      = np_utils.to_categorical(Y_test-1, num_classes=2)

        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

        print('X_train shape:', X_test.shape)
        print(X_test.shape[0], 'train samples')

        # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
        # model configurations may do better, but this is a good starting point)
        model = EEGNet(nb_classes = 2, Chans = 12, Samples = 1536,
                       dropoutRate = d, kernLength = kl, F1 = 8,D = 2, F2 = 16, 
                       norm_rate = 0.25, dropoutType = 'Dropout')
      
        # compile the model and set the optimizers
        model.compile(loss='categorical_crossentropy', optimizer='adam', 
                    metrics = ['accuracy'])

        # count number of parameters in the model
        numParams    = model.count_params() 

        # set a valid path for your system to record model checkpoints
        checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', verbose=1,
                                     save_best_only=True)
  
        # the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
        # the weights all to be 1
        class_weights = {0:1, 1:1}

        history = model.fit(X_train, Y_train, batch_size = 16, epochs = n_epochs, 
                            verbose = 2, validation_data=(X_val, Y_val),
                            callbacks=[checkpointer], class_weight = class_weights)
      
        print('\n# Evaluate on test data')
        results = model.evaluate(X_test, Y_test, batch_size=1)
        print('test loss, test acc:', results)

        acc_all[x - 1, 0] = results[0]
        acc_all[x - 1, 1] = results[1]

        from keras import backend as K 
        # Do some code, e.g. train and save model
        K.clear_session()

        out_f_name = 'df_accl_Patient_h' + str(h) + '_d' + str(d) + '_k' + str(kl) +'_epochs_' + str(n_epochs) + '.csv'
        print(out_f_name)
        df_accl_all = pd.DataFrame({'loss': acc_all[:, 0], 'acc': acc_all[:, 1]})
        print(df_accl_all)
        df_accl_all.to_csv (out_f_name, index = None, header=True) #Don't forget to add '.csv' at the end of the path
# Out:
# EEG_Deep/Data2A/parsed_P01T.mat
# (80, 12, 4096)
# (80,)
# (60, 12, 1536)
# (60,)
# (20, 12, 1536)
# (20,)
# X_train shape: (60, 1, 12, 1536)
# 60 train samples
# 20 val samples
# EEG_Deep/Data2A/parsed_P01E.mat
# (40, 12, 4096)
# (40,)
# (40, 12, 1536)
# (40,)
# X_train shape: (40, 1, 12, 1536)
# 40 test samples
# X_train shape: (60, 1, 12, 1536)
# 60 train samples
# 20 val samples
# (40, 12, 1536)
# (40,)
# X_train shape: (40, 1, 12, 1536)
# 40 train samples
# Train on 60 samples, validate on 20 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.79105, saving model to /tmp/checkpoint.h5
# 60/60 - 1s - loss: 0.7495 - acc: 0.4667 - val_loss: 0.7910 - val_acc: 0.0000e+00
# Epoch 2/100
#
# Epoch 00002: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1036 - acc: 1.0000 - val_loss: 1.6345 - val_acc: 0.7000
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1283 - acc: 1.0000 - val_loss: 1.6304 - val_acc: 0.7000
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1349 - acc: 0.9667 - val_loss: 1.6789 - val_acc: 0.6500
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1098 - acc: 0.9833 - val_loss: 1.7150 - val_acc: 0.5000
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1673 - acc: 0.9667 - val_loss: 1.7843 - val_acc: 0.4500
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0995 - acc: 1.0000 - val_loss: 1.8153 - val_acc: 0.4500
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1292 - acc: 0.9833 - val_loss: 1.7650 - val_acc: 0.5000
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1230 - acc: 0.9833 - val_loss: 1.7765 - val_acc: 0.5000
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1249 - acc: 0.9833 - val_loss: 1.7860 - val_acc: 0.5000
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1673 - acc: 0.9667 - val_loss: 1.7939 - val_acc: 0.4500
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0945 - acc: 1.0000 - val_loss: 1.8415 - val_acc: 0.4000
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1204 - acc: 0.9667 - val_loss: 1.9314 - val_acc: 0.3000
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0997 - acc: 1.0000 - val_loss: 1.9278 - val_acc: 0.4000
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1103 - acc: 0.9833 - val_loss: 1.9482 - val_acc: 0.4500
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1403 - acc: 0.9667 - val_loss: 2.0739 - val_acc: 0.3000
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0826 - acc: 1.0000 - val_loss: 2.1809 - val_acc: 0.3000
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0858 - acc: 1.0000 - val_loss: 2.3963 - val_acc: 0.3000
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0965 - acc: 0.9833 - val_loss: 2.6168 - val_acc: 0.3000
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0804 - acc: 1.0000 - val_loss: 2.6785 - val_acc: 0.3000
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0945 - acc: 0.9667 - val_loss: 2.7764 - val_acc: 0.3000
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0813 - acc: 1.0000 - val_loss: 3.0103 - val_acc: 0.2500
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0817 - acc: 0.9833 - val_loss: 2.5663 - val_acc: 0.3000
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0787 - acc: 1.0000 - val_loss: 2.0480 - val_acc: 0.3000
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0707 - acc: 0.9833 - val_loss: 1.7245 - val_acc: 0.5000
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0641 - acc: 1.0000 - val_loss: 1.6364 - val_acc: 0.5000
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1080 - acc: 0.9667 - val_loss: 1.7770 - val_acc: 0.5000
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.0895 - acc: 0.9833 - val_loss: 1.9578 - val_acc: 0.4500
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.79105
# 60/60 - 0s - loss: 0.1098 - acc: 0.9667 - val_loss: 2.1042 - val_acc: 0.3000
#
# # Evaluate on test data
# 40/40 [==============================] - 0s 3ms/sample - loss: 1.5074 - acc: 0.5000
# test loss, test acc: [1.5074481291361734, 0.5]
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:111: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# df_accl_Patient_h30_d0.25_k32_epochs_100.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9065648ccc47> in <module>()
#     155         out_f_name = 'df_accl_Patient_h' + str(h) + '_d' + str(d) + '_k' + str(kl) +'_epochs_' + str(n_epochs) + '.csv'
#     156         print(out_f_name)
# --> 157         df_accl_all = pd.DataFrame({'loss': acc_all[:, 0], 'acc': acc_all[:, 1]})
#     158         print(df_accl_all)
#     159         df_accl_all.to_csv (out_f_name, index = None, header=True) #Don't forget to add '.csv' at the end of the path
#
# NameError: name 'pd' is not defined

# %%
print(model.metrics_names)
# Out:
# ['loss', 'acc']
