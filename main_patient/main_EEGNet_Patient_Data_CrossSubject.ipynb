# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_patient/main_EEGNet_Patient_Data_CrossSubject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 418 (delta 66), reused 0 (delta 0), pack-reused 313
# Receiving objects: 100% (418/418), 1.69 GiB | 35.38 MiB/s, done.
# Resolving deltas: 100% (194/194), done.
# Checking out files: 100% (97/97), done.

# %%
import scipy.io as spio
import numpy as np
import pandas as pd
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()

X_tr = np.empty([80, 12, 4096])
X_ts = np.empty([40, 12, 4096])
result=[]

h_cut = [30]
drop_out = [0.25]
k_len = [32, 64, 128]
n_epochs = 500

outfname = 'accuray_epochs' + str(n_epochs) + '_filter_' + str(h_cut) + '_drop_' + str(drop_out) + '_patient_data.npy'

nsub = 10
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
acc_sub = zeros([nsub, nfilt,ndrop,nkl])

for sub_idx, x in enumerate(range(1,11)):
    for h_indx, h in enumerate(h_cut):
        fName = 'EEG_Deep/Data2A/parsed_P0' + str(x) + 'T.mat'  # Load Data
        print(fName)
        mat = spio.loadmat(fName)
        r_X_tr = mat['RawEEGData']
        y_tr = mat['Labels']
        y_tr = y_tr.flatten() 

        print(np.shape(r_X_tr))
        print(np.shape(y_tr))

        for t in range(r_X_tr.shape[0]):
            tril = r_X_tr[t,:,:]
            #tril = tril.transpose()
            tril_filtered = butter_bandpass_filter(tril, lowcut=8, highcut=h, fs=250, order=4)
            # tril_filtered = tril_filtered.transpose()
            X_tr[t,:,:] = tril_filtered 

            # split data of each subject in training and validation
        X_train      = X_tr[0:60,:,2048:3584]
        Y_train      = y_tr[0:60]
        X_val       = X_tr[60:,:,2048:3584]
        Y_val       = y_tr[60:]

        print(np.shape(X_train))
        print(np.shape(Y_train))
        print(np.shape(X_val))
        print(np.shape(Y_val))

        # convert labels to one-hot encodings.
        Y_train = np_utils.to_categorical(Y_train-1, num_classes=2)
        Y_val = np_utils.to_categorical(Y_val-1, num_classes=2)

        kernels, chans, samples = 1, 12, 1536
        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
        X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)

        print('X_train shape:', X_train.shape)
        print(X_train.shape[0], 'train samples')
        print(X_val.shape[0], 'val samples')

        fName = 'EEG_Deep/Data2A/parsed_P0' + str(x) + 'E.mat'  # Load Data
        print(fName)
        mat = spio.loadmat(fName)
        r_X_ts = mat['RawEEGData']
        y_ts = mat['Labels']
        y_ts = y_ts.flatten() 

        print(np.shape(r_X_ts))
        print(np.shape(y_ts))

        for t in range(r_X_ts.shape[0]):
            tril = r_X_ts[t,:,:]
            # tril = tril.transpose()
            tril_filtered = butter_bandpass_filter(tril, lowcut=8, highcut=h, fs=250, order=4)
            # tril_filtered = tril_filtered.transpose()
            X_ts[t,:,:] = tril_filtered 

        X_test      = X_ts[:,:,2048:3584]
        Y_test      = y_ts[:]
        print(np.shape(X_test))
        print(np.shape(Y_test))

        #convert labels to one-hot encodings.
        Y_test      = np_utils.to_categorical(Y_test-1)

        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

        print('X_train shape:', X_test.shape)
        print(X_test.shape[0], 'test samples')

        kernels, chans, samples = 1, 12, 1536
        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_train = X_train.reshape(X_train.shape[0], kernels, chans, samples)
        X_val   = X_val.reshape(X_val.shape[0], kernels, chans, samples)

        print('X_train shape:', X_train.shape)
        print(X_train.shape[0], 'train samples')
        print(X_val.shape[0], 'val samples')

        X_test      = X_ts[:,:,2048:3584]
        Y_test      = y_ts[:]
        print(np.shape(X_test))
        print(np.shape(Y_test))

        #convert labels to one-hot encodings.
        Y_test      = np_utils.to_categorical(Y_test-1, num_classes=2)

        # convert data to NCHW (trials, kernels, channels, samples) format. Data 
        # contains 22 channels and 500 time-points. Set the number of kernels to 1.
        X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

        print('X_train shape:', X_test.shape)
        print(X_test.shape[0], 'train samples')

        # acc_sub = zeros([rows, cols])
        for id_d, d in enumerate(drop_out):
            for id_kl, kl in enumerate(k_len):
              print(id_kl, id_d)
              # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
              # model configurations may do better, but this is a good starting point)
              model = EEGNet(nb_classes = 2, Chans = 12, Samples = 1536,
                             dropoutRate = d, kernLength = kl, F1 = 8,D = 2, F2 = 16,
                             norm_rate = 0.25, dropoutType = 'Dropout')

              # compile the model and set the optimizers
              model.compile(loss='categorical_crossentropy', optimizer='adam', 
                            metrics = ['accuracy'])

              # count number of parameters in the model
              numParams    = model.count_params() 

              # set a valid path for your system to record model checkpoints
              checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', verbose=1, save_best_only=True)

              # the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
              # the weights all to be 1
              class_weights = {0:1, 1:1}

              history = model.fit(X_train, Y_train, batch_size = 16, epochs = n_epochs, 
                                  verbose = 2, validation_data=(X_val, Y_val),
                                  callbacks=[checkpointer], class_weight = class_weights)

              print('\n# Evaluate on test data')
              results = model.evaluate(X_test, Y_test, batch_size=1)
              print('test loss, test acc:', results)

              acc_sub[sub_idx,h_indx,id_d, id_kl] = results[1]

              from keras import backend as K 
              # Do some code, e.g. train and save model
              K.clear_session()
              
np.save(outfname, acc_sub)
# Out:
# EEG_Deep/Data2A/parsed_P01T.mat
# (80, 12, 4096)
# (80,)
# (60, 12, 1536)
# (60,)
# (20, 12, 1536)
# (20,)
# X_train shape: (60, 1, 12, 1536)
# 60 train samples
# 20 val samples
# EEG_Deep/Data2A/parsed_P01E.mat
# (40, 12, 4096)
# (40,)
# (40, 12, 1536)
# (40,)
# X_train shape: (40, 1, 12, 1536)
# 40 test samples
# X_train shape: (60, 1, 12, 1536)
# 60 train samples
# 20 val samples
# (40, 12, 1536)
# (40,)
# X_train shape: (40, 1, 12, 1536)
# 40 train samples
# 0 0
# Train on 60 samples, validate on 20 samples
# Epoch 1/500
#
# Epoch 00001: val_loss improved from inf to 0.72716, saving model to /tmp/checkpoint.h5
# 60/60 - 6s - loss: 0.6542 - acc: 0.6333 - val_loss: 0.7272 - val_acc: 0.1000
# Epoch 2/500
#
# Epoch 00002: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.6039 - acc: 0.6667 - val_loss: 0.7595 - val_acc: 0.0000e+00
# Epoch 3/500
#
# Epoch 00003: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.5653 - acc: 0.6667 - val_loss: 0.7899 - val_acc: 0.0000e+00
# Epoch 4/500
#
# Epoch 00004: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.5579 - acc: 0.6667 - val_loss: 0.8254 - val_acc: 0.0000e+00
# Epoch 5/500
#
# Epoch 00005: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.5595 - acc: 0.6667 - val_loss: 0.8519 - val_acc: 0.0000e+00
# Epoch 6/500
#
# Epoch 00006: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.5246 - acc: 0.6667 - val_loss: 0.8827 - val_acc: 0.0000e+00
# Epoch 7/500
#
# Epoch 00007: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.5321 - acc: 0.6833 - val_loss: 0.9177 - val_acc: 0.0000e+00
# Epoch 8/500
#
# Epoch 00008: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.5062 - acc: 0.7000 - val_loss: 0.9536 - val_acc: 0.0000e+00
# Epoch 9/500
#
# Epoch 00009: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.4887 - acc: 0.7333 - val_loss: 0.9865 - val_acc: 0.0000e+00
# Epoch 10/500
#
# Epoch 00010: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.4790 - acc: 0.8000 - val_loss: 1.0271 - val_acc: 0.0000e+00
# Epoch 11/500
#
# Epoch 00011: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.4694 - acc: 0.7667 - val_loss: 1.0801 - val_acc: 0.0000e+00
# Epoch 12/500
#
# Epoch 00012: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.4556 - acc: 0.8167 - val_loss: 1.1481 - val_acc: 0.0000e+00
# Epoch 13/500
#
# Epoch 00013: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.4171 - acc: 0.8667 - val_loss: 1.2301 - val_acc: 0.0000e+00
# Epoch 14/500
#
# Epoch 00014: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.4285 - acc: 0.8333 - val_loss: 1.3179 - val_acc: 0.0000e+00
# Epoch 15/500
#
# Epoch 00015: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.4366 - acc: 0.7500 - val_loss: 1.4171 - val_acc: 0.0000e+00
# Epoch 16/500
#
# Epoch 00016: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3884 - acc: 0.8833 - val_loss: 1.5109 - val_acc: 0.0000e+00
# Epoch 17/500
#
# Epoch 00017: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3748 - acc: 0.8667 - val_loss: 1.6360 - val_acc: 0.0000e+00
# Epoch 18/500
#
# Epoch 00018: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3984 - acc: 0.8667 - val_loss: 1.7693 - val_acc: 0.0000e+00
# Epoch 19/500
#
# Epoch 00019: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3928 - acc: 0.8500 - val_loss: 1.9041 - val_acc: 0.0000e+00
# Epoch 20/500
#
# Epoch 00020: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3391 - acc: 0.9000 - val_loss: 2.0309 - val_acc: 0.0000e+00
# Epoch 21/500
#
# Epoch 00021: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3520 - acc: 0.8667 - val_loss: 2.1504 - val_acc: 0.0000e+00
# Epoch 22/500
#
# Epoch 00022: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3018 - acc: 0.9500 - val_loss: 2.2782 - val_acc: 0.0000e+00
# Epoch 23/500
#
# Epoch 00023: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3392 - acc: 0.8500 - val_loss: 2.4411 - val_acc: 0.0000e+00
# Epoch 24/500
#
# Epoch 00024: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3250 - acc: 0.8667 - val_loss: 2.5998 - val_acc: 0.0000e+00
# Epoch 25/500
#
# Epoch 00025: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.3724 - acc: 0.8333 - val_loss: 2.7475 - val_acc: 0.0000e+00
# Epoch 26/500
#
# Epoch 00026: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2877 - acc: 0.9500 - val_loss: 2.8724 - val_acc: 0.0000e+00
# Epoch 27/500
#
# Epoch 00027: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2730 - acc: 0.9667 - val_loss: 2.9913 - val_acc: 0.0000e+00
# Epoch 28/500
#
# Epoch 00028: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2645 - acc: 0.9333 - val_loss: 3.1008 - val_acc: 0.0000e+00
# Epoch 29/500
#
# Epoch 00029: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2957 - acc: 0.9167 - val_loss: 3.1693 - val_acc: 0.0000e+00
# Epoch 30/500
#
# Epoch 00030: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2921 - acc: 0.9167 - val_loss: 3.2535 - val_acc: 0.0000e+00
# Epoch 31/500
#
# Epoch 00031: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2774 - acc: 0.9000 - val_loss: 3.4168 - val_acc: 0.0000e+00
# Epoch 32/500
#
# Epoch 00032: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2859 - acc: 0.9500 - val_loss: 3.4895 - val_acc: 0.0000e+00
# Epoch 33/500
#
# Epoch 00033: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2800 - acc: 0.9500 - val_loss: 3.5726 - val_acc: 0.0000e+00
# Epoch 34/500
#
# Epoch 00034: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2445 - acc: 0.9333 - val_loss: 3.6832 - val_acc: 0.0000e+00
# Epoch 35/500
#
# Epoch 00035: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2917 - acc: 0.9333 - val_loss: 3.7520 - val_acc: 0.0000e+00
# Epoch 36/500
#
# Epoch 00036: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2493 - acc: 0.9167 - val_loss: 3.8330 - val_acc: 0.0000e+00
# Epoch 37/500
#
# Epoch 00037: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2210 - acc: 0.9333 - val_loss: 3.8660 - val_acc: 0.0000e+00
# Epoch 38/500
#
# Epoch 00038: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2375 - acc: 0.9333 - val_loss: 3.8423 - val_acc: 0.0000e+00
# Epoch 39/500
#
# Epoch 00039: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2338 - acc: 0.9500 - val_loss: 3.8411 - val_acc: 0.0000e+00
# Epoch 40/500
#
# Epoch 00040: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2144 - acc: 0.9667 - val_loss: 3.8624 - val_acc: 0.0000e+00
# Epoch 41/500
#
# Epoch 00041: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1983 - acc: 1.0000 - val_loss: 3.9079 - val_acc: 0.0000e+00
# Epoch 42/500
#
# Epoch 00042: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2633 - acc: 0.9000 - val_loss: 3.9074 - val_acc: 0.0000e+00
# Epoch 43/500
#
# Epoch 00043: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2036 - acc: 0.9833 - val_loss: 3.8724 - val_acc: 0.0000e+00
# Epoch 44/500
#
# Epoch 00044: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2130 - acc: 0.9500 - val_loss: 3.7974 - val_acc: 0.0000e+00
# Epoch 45/500
#
# Epoch 00045: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1948 - acc: 0.9500 - val_loss: 3.6834 - val_acc: 0.0500
# Epoch 46/500
#
# Epoch 00046: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2017 - acc: 0.9500 - val_loss: 3.6412 - val_acc: 0.1000
# Epoch 47/500
#
# Epoch 00047: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1761 - acc: 0.9833 - val_loss: 3.6686 - val_acc: 0.1000
# Epoch 48/500
#
# Epoch 00048: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1899 - acc: 0.9833 - val_loss: 3.7076 - val_acc: 0.1500
# Epoch 49/500
#
# Epoch 00049: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1680 - acc: 0.9833 - val_loss: 3.7848 - val_acc: 0.1500
# Epoch 50/500
#
# Epoch 00050: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1896 - acc: 0.9833 - val_loss: 3.8566 - val_acc: 0.1500
# Epoch 51/500
#
# Epoch 00051: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1885 - acc: 0.9833 - val_loss: 3.8233 - val_acc: 0.1500
# Epoch 52/500
#
# Epoch 00052: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1973 - acc: 0.9667 - val_loss: 3.7386 - val_acc: 0.2000
# Epoch 53/500
#
# Epoch 00053: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1595 - acc: 0.9833 - val_loss: 3.6334 - val_acc: 0.2500
# Epoch 54/500
#
# Epoch 00054: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.2093 - acc: 0.9667 - val_loss: 3.5748 - val_acc: 0.2500
# Epoch 55/500
#
# Epoch 00055: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1919 - acc: 0.9667 - val_loss: 3.5187 - val_acc: 0.2500
# Epoch 56/500
#
# Epoch 00056: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1975 - acc: 0.9667 - val_loss: 3.4810 - val_acc: 0.2500
# Epoch 57/500
#
# Epoch 00057: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1536 - acc: 1.0000 - val_loss: 3.4273 - val_acc: 0.2500
# Epoch 58/500
#
# Epoch 00058: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1650 - acc: 1.0000 - val_loss: 3.3534 - val_acc: 0.2500
# Epoch 59/500
#
# Epoch 00059: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1637 - acc: 0.9833 - val_loss: 3.3302 - val_acc: 0.2500
# Epoch 60/500
#
# Epoch 00060: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1649 - acc: 0.9500 - val_loss: 3.3528 - val_acc: 0.2500
# Epoch 61/500
#
# Epoch 00061: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1325 - acc: 1.0000 - val_loss: 3.3448 - val_acc: 0.2500
# Epoch 62/500
#
# Epoch 00062: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1469 - acc: 0.9667 - val_loss: 3.3232 - val_acc: 0.2500
# Epoch 63/500
#
# Epoch 00063: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1722 - acc: 0.9667 - val_loss: 3.2267 - val_acc: 0.2500
# Epoch 64/500
#
# Epoch 00064: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1841 - acc: 0.9667 - val_loss: 3.1654 - val_acc: 0.2500
# Epoch 65/500
#
# Epoch 00065: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1324 - acc: 1.0000 - val_loss: 3.0672 - val_acc: 0.2500
# Epoch 66/500
#
# Epoch 00066: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1826 - acc: 0.9500 - val_loss: 2.9016 - val_acc: 0.3000
# Epoch 67/500
#
# Epoch 00067: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1982 - acc: 0.9333 - val_loss: 2.7250 - val_acc: 0.3000
# Epoch 68/500
#
# Epoch 00068: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1482 - acc: 0.9667 - val_loss: 2.5633 - val_acc: 0.4500
# Epoch 69/500
#
# Epoch 00069: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1493 - acc: 0.9667 - val_loss: 2.4617 - val_acc: 0.4000
# Epoch 70/500
#
# Epoch 00070: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1693 - acc: 0.9833 - val_loss: 2.4353 - val_acc: 0.4000
# Epoch 71/500
#
# Epoch 00071: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1375 - acc: 1.0000 - val_loss: 2.5344 - val_acc: 0.3500
# Epoch 72/500
#
# Epoch 00072: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1504 - acc: 1.0000 - val_loss: 2.5754 - val_acc: 0.4000
# Epoch 73/500
#
# Epoch 00073: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1566 - acc: 0.9833 - val_loss: 2.5136 - val_acc: 0.4000
# Epoch 74/500
#
# Epoch 00074: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1231 - acc: 1.0000 - val_loss: 2.4875 - val_acc: 0.5000
# Epoch 75/500
#
# Epoch 00075: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1332 - acc: 0.9833 - val_loss: 2.4394 - val_acc: 0.6000
# Epoch 76/500
#
# Epoch 00076: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1257 - acc: 0.9833 - val_loss: 2.4239 - val_acc: 0.6000
# Epoch 77/500
#
# Epoch 00077: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1133 - acc: 0.9833 - val_loss: 2.4504 - val_acc: 0.6000
# Epoch 78/500
#
# Epoch 00078: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1281 - acc: 0.9833 - val_loss: 2.4913 - val_acc: 0.6000
# Epoch 79/500
#
# Epoch 00079: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1014 - acc: 0.9833 - val_loss: 2.4799 - val_acc: 0.6000
# Epoch 80/500
#
# Epoch 00080: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1168 - acc: 1.0000 - val_loss: 2.4905 - val_acc: 0.6000
# Epoch 81/500
#
# Epoch 00081: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1127 - acc: 1.0000 - val_loss: 2.5062 - val_acc: 0.6000
# Epoch 82/500
#
# Epoch 00082: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1358 - acc: 0.9667 - val_loss: 2.5733 - val_acc: 0.6000
# Epoch 83/500
#
# Epoch 00083: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1199 - acc: 1.0000 - val_loss: 2.5537 - val_acc: 0.6500
# Epoch 84/500
#
# Epoch 00084: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1155 - acc: 0.9833 - val_loss: 2.5285 - val_acc: 0.6500
# Epoch 85/500
#
# Epoch 00085: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1130 - acc: 0.9833 - val_loss: 2.3725 - val_acc: 0.6000
# Epoch 86/500
#
# Epoch 00086: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1309 - acc: 0.9667 - val_loss: 2.3383 - val_acc: 0.6000
# Epoch 87/500
#
# Epoch 00087: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0912 - acc: 1.0000 - val_loss: 2.4035 - val_acc: 0.6500
# Epoch 88/500
#
# Epoch 00088: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0984 - acc: 1.0000 - val_loss: 2.5068 - val_acc: 0.6500
# Epoch 89/500
#
# Epoch 00089: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0895 - acc: 1.0000 - val_loss: 2.5838 - val_acc: 0.6500
# Epoch 90/500
#
# Epoch 00090: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1078 - acc: 1.0000 - val_loss: 2.5806 - val_acc: 0.6500
# Epoch 91/500
#
# Epoch 00091: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1150 - acc: 1.0000 - val_loss: 2.5945 - val_acc: 0.6000
# Epoch 92/500
#
# Epoch 00092: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0763 - acc: 1.0000 - val_loss: 2.5888 - val_acc: 0.6000
# Epoch 93/500
#
# Epoch 00093: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1460 - acc: 0.9667 - val_loss: 2.5207 - val_acc: 0.6000
# Epoch 94/500
#
# Epoch 00094: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0863 - acc: 1.0000 - val_loss: 2.5041 - val_acc: 0.6000
# Epoch 95/500
#
# Epoch 00095: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0913 - acc: 1.0000 - val_loss: 2.5808 - val_acc: 0.6000
# Epoch 96/500
#
# Epoch 00096: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0911 - acc: 1.0000 - val_loss: 2.6927 - val_acc: 0.6000
# Epoch 97/500
#
# Epoch 00097: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1219 - acc: 0.9667 - val_loss: 2.7590 - val_acc: 0.6000
# Epoch 98/500
#
# Epoch 00098: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0734 - acc: 1.0000 - val_loss: 2.6902 - val_acc: 0.6000
# Epoch 99/500
#
# Epoch 00099: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0859 - acc: 1.0000 - val_loss: 2.5565 - val_acc: 0.6000
# Epoch 100/500
#
# Epoch 00100: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0640 - acc: 1.0000 - val_loss: 2.5606 - val_acc: 0.6000
# Epoch 101/500
#
# Epoch 00101: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0848 - acc: 1.0000 - val_loss: 2.7020 - val_acc: 0.6000
# Epoch 102/500
#
# Epoch 00102: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0676 - acc: 1.0000 - val_loss: 2.8036 - val_acc: 0.6000
# Epoch 103/500
#
# Epoch 00103: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0895 - acc: 1.0000 - val_loss: 2.8435 - val_acc: 0.5500
# Epoch 104/500
#
# Epoch 00104: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0603 - acc: 1.0000 - val_loss: 2.8689 - val_acc: 0.5000
# Epoch 105/500
#
# Epoch 00105: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0695 - acc: 1.0000 - val_loss: 2.9094 - val_acc: 0.4500
# Epoch 106/500
#
# Epoch 00106: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0808 - acc: 1.0000 - val_loss: 2.8521 - val_acc: 0.4500
# Epoch 107/500
#
# Epoch 00107: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1212 - acc: 0.9833 - val_loss: 2.6832 - val_acc: 0.4500
# Epoch 108/500
#
# Epoch 00108: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0771 - acc: 0.9833 - val_loss: 2.6969 - val_acc: 0.4000
# Epoch 109/500
#
# Epoch 00109: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0757 - acc: 1.0000 - val_loss: 3.0881 - val_acc: 0.3500
# Epoch 110/500
#
# Epoch 00110: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1149 - acc: 0.9333 - val_loss: 3.2892 - val_acc: 0.3000
# Epoch 111/500
#
# Epoch 00111: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0759 - acc: 1.0000 - val_loss: 3.4230 - val_acc: 0.2500
# Epoch 112/500
#
# Epoch 00112: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0654 - acc: 1.0000 - val_loss: 3.3721 - val_acc: 0.2500
# Epoch 113/500
#
# Epoch 00113: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1235 - acc: 0.9667 - val_loss: 3.1332 - val_acc: 0.3500
# Epoch 114/500
#
# Epoch 00114: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0684 - acc: 0.9833 - val_loss: 2.9604 - val_acc: 0.3500
# Epoch 115/500
#
# Epoch 00115: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0697 - acc: 1.0000 - val_loss: 2.9442 - val_acc: 0.3500
# Epoch 116/500
#
# Epoch 00116: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0622 - acc: 1.0000 - val_loss: 2.9136 - val_acc: 0.3500
# Epoch 117/500
#
# Epoch 00117: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0660 - acc: 1.0000 - val_loss: 3.0502 - val_acc: 0.3000
# Epoch 118/500
#
# Epoch 00118: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0801 - acc: 1.0000 - val_loss: 3.3395 - val_acc: 0.2000
# Epoch 119/500
#
# Epoch 00119: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0681 - acc: 0.9833 - val_loss: 3.3416 - val_acc: 0.2000
# Epoch 120/500
#
# Epoch 00120: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0658 - acc: 1.0000 - val_loss: 3.0697 - val_acc: 0.2500
# Epoch 121/500
#
# Epoch 00121: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0641 - acc: 1.0000 - val_loss: 2.9655 - val_acc: 0.2500
# Epoch 122/500
#
# Epoch 00122: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0661 - acc: 1.0000 - val_loss: 2.9426 - val_acc: 0.2500
# Epoch 123/500
#
# Epoch 00123: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0487 - acc: 1.0000 - val_loss: 3.0465 - val_acc: 0.2500
# Epoch 124/500
#
# Epoch 00124: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0510 - acc: 1.0000 - val_loss: 3.3294 - val_acc: 0.2500
# Epoch 125/500
#
# Epoch 00125: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1131 - acc: 0.9500 - val_loss: 3.2330 - val_acc: 0.2500
# Epoch 126/500
#
# Epoch 00126: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0579 - acc: 1.0000 - val_loss: 2.9120 - val_acc: 0.3500
# Epoch 127/500
#
# Epoch 00127: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0520 - acc: 1.0000 - val_loss: 2.7147 - val_acc: 0.4000
# Epoch 128/500
#
# Epoch 00128: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0653 - acc: 0.9833 - val_loss: 2.7043 - val_acc: 0.3500
# Epoch 129/500
#
# Epoch 00129: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0563 - acc: 1.0000 - val_loss: 2.9053 - val_acc: 0.3500
# Epoch 130/500
#
# Epoch 00130: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0594 - acc: 0.9833 - val_loss: 2.8585 - val_acc: 0.3500
# Epoch 131/500
#
# Epoch 00131: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0568 - acc: 1.0000 - val_loss: 2.9291 - val_acc: 0.3500
# Epoch 132/500
#
# Epoch 00132: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0538 - acc: 1.0000 - val_loss: 2.8757 - val_acc: 0.3500
# Epoch 133/500
#
# Epoch 00133: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0977 - acc: 0.9833 - val_loss: 2.8181 - val_acc: 0.4000
# Epoch 134/500
#
# Epoch 00134: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0454 - acc: 1.0000 - val_loss: 2.8847 - val_acc: 0.3500
# Epoch 135/500
#
# Epoch 00135: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0424 - acc: 1.0000 - val_loss: 2.9849 - val_acc: 0.3000
# Epoch 136/500
#
# Epoch 00136: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0680 - acc: 1.0000 - val_loss: 3.0232 - val_acc: 0.3000
# Epoch 137/500
#
# Epoch 00137: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0428 - acc: 1.0000 - val_loss: 2.9144 - val_acc: 0.3500
# Epoch 138/500
#
# Epoch 00138: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0409 - acc: 1.0000 - val_loss: 2.9413 - val_acc: 0.3000
# Epoch 139/500
#
# Epoch 00139: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0354 - acc: 1.0000 - val_loss: 2.9173 - val_acc: 0.3000
# Epoch 140/500
#
# Epoch 00140: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0672 - acc: 0.9833 - val_loss: 3.0869 - val_acc: 0.3000
# Epoch 141/500
#
# Epoch 00141: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0542 - acc: 1.0000 - val_loss: 3.0376 - val_acc: 0.3500
# Epoch 142/500
#
# Epoch 00142: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0506 - acc: 0.9667 - val_loss: 2.6501 - val_acc: 0.4000
# Epoch 143/500
#
# Epoch 00143: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0610 - acc: 1.0000 - val_loss: 2.5871 - val_acc: 0.4000
# Epoch 144/500
#
# Epoch 00144: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0489 - acc: 1.0000 - val_loss: 2.6645 - val_acc: 0.4000
# Epoch 145/500
#
# Epoch 00145: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0303 - acc: 1.0000 - val_loss: 2.8282 - val_acc: 0.4000
# Epoch 146/500
#
# Epoch 00146: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0516 - acc: 1.0000 - val_loss: 3.1170 - val_acc: 0.3500
# Epoch 147/500
#
# Epoch 00147: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0430 - acc: 1.0000 - val_loss: 3.6680 - val_acc: 0.2500
# Epoch 148/500
#
# Epoch 00148: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0365 - acc: 1.0000 - val_loss: 3.7187 - val_acc: 0.2500
# Epoch 149/500
#
# Epoch 00149: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0641 - acc: 1.0000 - val_loss: 3.6089 - val_acc: 0.2500
# Epoch 150/500
#
# Epoch 00150: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0314 - acc: 1.0000 - val_loss: 3.1532 - val_acc: 0.3000
# Epoch 151/500
#
# Epoch 00151: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0395 - acc: 1.0000 - val_loss: 3.0943 - val_acc: 0.3000
# Epoch 152/500
#
# Epoch 00152: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0849 - acc: 0.9833 - val_loss: 2.4307 - val_acc: 0.4000
# Epoch 153/500
#
# Epoch 00153: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0330 - acc: 1.0000 - val_loss: 2.5093 - val_acc: 0.4000
# Epoch 154/500
#
# Epoch 00154: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0501 - acc: 1.0000 - val_loss: 2.4956 - val_acc: 0.4000
# Epoch 155/500
#
# Epoch 00155: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0380 - acc: 1.0000 - val_loss: 2.5175 - val_acc: 0.4000
# Epoch 156/500
#
# Epoch 00156: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0802 - acc: 0.9833 - val_loss: 2.5515 - val_acc: 0.4000
# Epoch 157/500
#
# Epoch 00157: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0237 - acc: 1.0000 - val_loss: 2.5573 - val_acc: 0.4000
# Epoch 158/500
#
# Epoch 00158: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0420 - acc: 1.0000 - val_loss: 2.5621 - val_acc: 0.4000
# Epoch 159/500
#
# Epoch 00159: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0392 - acc: 1.0000 - val_loss: 2.3692 - val_acc: 0.4000
# Epoch 160/500
#
# Epoch 00160: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0336 - acc: 1.0000 - val_loss: 2.1833 - val_acc: 0.4000
# Epoch 161/500
#
# Epoch 00161: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0687 - acc: 0.9667 - val_loss: 2.5337 - val_acc: 0.4000
# Epoch 162/500
#
# Epoch 00162: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0451 - acc: 1.0000 - val_loss: 2.9765 - val_acc: 0.3500
# Epoch 163/500
#
# Epoch 00163: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0351 - acc: 1.0000 - val_loss: 2.8955 - val_acc: 0.4000
# Epoch 164/500
#
# Epoch 00164: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0698 - acc: 0.9833 - val_loss: 2.2266 - val_acc: 0.5500
# Epoch 165/500
#
# Epoch 00165: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0303 - acc: 1.0000 - val_loss: 1.6722 - val_acc: 0.6500
# Epoch 166/500
#
# Epoch 00166: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0721 - acc: 0.9833 - val_loss: 1.8549 - val_acc: 0.6500
# Epoch 167/500
#
# Epoch 00167: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1158 - acc: 0.9500 - val_loss: 1.9596 - val_acc: 0.6000
# Epoch 168/500
#
# Epoch 00168: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0323 - acc: 1.0000 - val_loss: 2.2876 - val_acc: 0.4000
# Epoch 169/500
#
# Epoch 00169: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.1121 - acc: 0.9500 - val_loss: 2.2210 - val_acc: 0.4000
# Epoch 170/500
#
# Epoch 00170: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0733 - acc: 0.9833 - val_loss: 2.0972 - val_acc: 0.5500
# Epoch 171/500
#
# Epoch 00171: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0336 - acc: 1.0000 - val_loss: 2.4092 - val_acc: 0.4500
# Epoch 172/500
#
# Epoch 00172: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0374 - acc: 1.0000 - val_loss: 2.6037 - val_acc: 0.4500
# Epoch 173/500
#
# Epoch 00173: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0863 - acc: 0.9500 - val_loss: 2.3973 - val_acc: 0.4500
# Epoch 174/500
#
# Epoch 00174: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0421 - acc: 1.0000 - val_loss: 2.0818 - val_acc: 0.6500
# Epoch 175/500
#
# Epoch 00175: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0446 - acc: 1.0000 - val_loss: 1.7848 - val_acc: 0.6500
# Epoch 176/500
#
# Epoch 00176: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0726 - acc: 1.0000 - val_loss: 1.9364 - val_acc: 0.6500
# Epoch 177/500
#
# Epoch 00177: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0352 - acc: 1.0000 - val_loss: 2.0203 - val_acc: 0.6500
# Epoch 178/500
#
# Epoch 00178: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0493 - acc: 1.0000 - val_loss: 2.0805 - val_acc: 0.5500
# Epoch 179/500
#
# Epoch 00179: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0409 - acc: 1.0000 - val_loss: 2.1149 - val_acc: 0.5000
# Epoch 180/500
#
# Epoch 00180: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0897 - acc: 0.9667 - val_loss: 2.0231 - val_acc: 0.5000
# Epoch 181/500
#
# Epoch 00181: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0247 - acc: 1.0000 - val_loss: 1.7485 - val_acc: 0.5500
# Epoch 182/500
#
# Epoch 00182: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0374 - acc: 1.0000 - val_loss: 1.7712 - val_acc: 0.5500
# Epoch 183/500
#
# Epoch 00183: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0553 - acc: 0.9833 - val_loss: 1.9798 - val_acc: 0.5500
# Epoch 184/500
#
# Epoch 00184: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0270 - acc: 1.0000 - val_loss: 2.2039 - val_acc: 0.5000
# Epoch 185/500
#
# Epoch 00185: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0309 - acc: 1.0000 - val_loss: 2.7550 - val_acc: 0.4000
# Epoch 186/500
#
# Epoch 00186: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0299 - acc: 1.0000 - val_loss: 3.2072 - val_acc: 0.3500
# Epoch 187/500
#
# Epoch 00187: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0784 - acc: 0.9833 - val_loss: 3.1619 - val_acc: 0.3500
# Epoch 188/500
#
# Epoch 00188: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0369 - acc: 1.0000 - val_loss: 2.1767 - val_acc: 0.5500
# Epoch 189/500
#
# Epoch 00189: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0297 - acc: 1.0000 - val_loss: 1.6719 - val_acc: 0.6500
# Epoch 190/500
#
# Epoch 00190: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0338 - acc: 1.0000 - val_loss: 1.7480 - val_acc: 0.6500
# Epoch 191/500
#
# Epoch 00191: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0437 - acc: 1.0000 - val_loss: 2.1386 - val_acc: 0.5000
# Epoch 192/500
#
# Epoch 00192: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0389 - acc: 1.0000 - val_loss: 2.5418 - val_acc: 0.4500
# Epoch 193/500
#
# Epoch 00193: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0412 - acc: 1.0000 - val_loss: 2.6232 - val_acc: 0.4500
# Epoch 194/500
#
# Epoch 00194: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0475 - acc: 1.0000 - val_loss: 2.6894 - val_acc: 0.4500
# Epoch 195/500
#
# Epoch 00195: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0420 - acc: 1.0000 - val_loss: 2.8288 - val_acc: 0.4000
# Epoch 196/500
#
# Epoch 00196: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0249 - acc: 1.0000 - val_loss: 2.8610 - val_acc: 0.4500
# Epoch 197/500
#
# Epoch 00197: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0252 - acc: 1.0000 - val_loss: 2.9387 - val_acc: 0.4500
# Epoch 198/500
#
# Epoch 00198: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0447 - acc: 1.0000 - val_loss: 3.1345 - val_acc: 0.3500
# Epoch 199/500
#
# Epoch 00199: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0309 - acc: 1.0000 - val_loss: 3.1586 - val_acc: 0.3500
# Epoch 200/500
#
# Epoch 00200: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0279 - acc: 1.0000 - val_loss: 3.0919 - val_acc: 0.4000
# Epoch 201/500
#
# Epoch 00201: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0233 - acc: 1.0000 - val_loss: 3.1237 - val_acc: 0.4000
# Epoch 202/500
#
# Epoch 00202: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0569 - acc: 0.9833 - val_loss: 2.6894 - val_acc: 0.4500
# Epoch 203/500
#
# Epoch 00203: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0274 - acc: 1.0000 - val_loss: 2.4227 - val_acc: 0.4500
# Epoch 204/500
#
# Epoch 00204: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0480 - acc: 0.9833 - val_loss: 2.2606 - val_acc: 0.6000
# Epoch 205/500
#
# Epoch 00205: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0235 - acc: 1.0000 - val_loss: 2.0310 - val_acc: 0.6500
# Epoch 206/500
#
# Epoch 00206: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0698 - acc: 1.0000 - val_loss: 1.7268 - val_acc: 0.6500
# Epoch 207/500
#
# Epoch 00207: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0337 - acc: 1.0000 - val_loss: 1.3944 - val_acc: 0.6500
# Epoch 208/500
#
# Epoch 00208: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0420 - acc: 0.9833 - val_loss: 1.1381 - val_acc: 0.7500
# Epoch 209/500
#
# Epoch 00209: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0377 - acc: 1.0000 - val_loss: 1.2618 - val_acc: 0.7000
# Epoch 210/500
#
# Epoch 00210: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0310 - acc: 1.0000 - val_loss: 1.4575 - val_acc: 0.6500
# Epoch 211/500
#
# Epoch 00211: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0278 - acc: 1.0000 - val_loss: 1.6602 - val_acc: 0.6500
# Epoch 212/500
#
# Epoch 00212: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0217 - acc: 1.0000 - val_loss: 1.7439 - val_acc: 0.6000
# Epoch 213/500
#
# Epoch 00213: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0623 - acc: 0.9833 - val_loss: 1.5578 - val_acc: 0.6500
# Epoch 214/500
#
# Epoch 00214: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0227 - acc: 1.0000 - val_loss: 1.2292 - val_acc: 0.7500
# Epoch 215/500
#
# Epoch 00215: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0489 - acc: 0.9833 - val_loss: 1.3192 - val_acc: 0.7500
# Epoch 216/500
#
# Epoch 00216: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0268 - acc: 1.0000 - val_loss: 1.7515 - val_acc: 0.6500
# Epoch 217/500
#
# Epoch 00217: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0415 - acc: 1.0000 - val_loss: 2.1191 - val_acc: 0.6000
# Epoch 218/500
#
# Epoch 00218: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0204 - acc: 1.0000 - val_loss: 2.1988 - val_acc: 0.6000
# Epoch 219/500
#
# Epoch 00219: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0197 - acc: 1.0000 - val_loss: 2.4198 - val_acc: 0.5500
# Epoch 220/500
#
# Epoch 00220: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0274 - acc: 1.0000 - val_loss: 2.5519 - val_acc: 0.4500
# Epoch 221/500
#
# Epoch 00221: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0244 - acc: 1.0000 - val_loss: 2.6882 - val_acc: 0.4500
# Epoch 222/500
#
# Epoch 00222: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0351 - acc: 1.0000 - val_loss: 2.8083 - val_acc: 0.4500
# Epoch 223/500
#
# Epoch 00223: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0173 - acc: 1.0000 - val_loss: 2.7414 - val_acc: 0.4500
# Epoch 224/500
#
# Epoch 00224: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0537 - acc: 0.9833 - val_loss: 1.9738 - val_acc: 0.6500
# Epoch 225/500
#
# Epoch 00225: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0307 - acc: 1.0000 - val_loss: 1.7850 - val_acc: 0.7500
# Epoch 226/500
#
# Epoch 00226: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0194 - acc: 1.0000 - val_loss: 1.9027 - val_acc: 0.7500
# Epoch 227/500
#
# Epoch 00227: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0441 - acc: 1.0000 - val_loss: 2.3361 - val_acc: 0.6500
# Epoch 228/500
#
# Epoch 00228: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0378 - acc: 1.0000 - val_loss: 2.6139 - val_acc: 0.6000
# Epoch 229/500
#
# Epoch 00229: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0308 - acc: 1.0000 - val_loss: 2.7908 - val_acc: 0.4500
# Epoch 230/500
#
# Epoch 00230: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0256 - acc: 1.0000 - val_loss: 2.8509 - val_acc: 0.4500
# Epoch 231/500
#
# Epoch 00231: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0332 - acc: 1.0000 - val_loss: 2.8824 - val_acc: 0.4500
# Epoch 232/500
#
# Epoch 00232: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0434 - acc: 0.9833 - val_loss: 2.6710 - val_acc: 0.4500
# Epoch 233/500
#
# Epoch 00233: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0176 - acc: 1.0000 - val_loss: 2.7326 - val_acc: 0.4500
# Epoch 234/500
#
# Epoch 00234: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0232 - acc: 1.0000 - val_loss: 2.8678 - val_acc: 0.4500
# Epoch 235/500
#
# Epoch 00235: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0166 - acc: 1.0000 - val_loss: 2.8660 - val_acc: 0.4500
# Epoch 236/500
#
# Epoch 00236: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0185 - acc: 1.0000 - val_loss: 2.9828 - val_acc: 0.4500
# Epoch 237/500
#
# Epoch 00237: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0205 - acc: 1.0000 - val_loss: 3.0268 - val_acc: 0.4500
# Epoch 238/500
#
# Epoch 00238: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0237 - acc: 1.0000 - val_loss: 2.9029 - val_acc: 0.4500
# Epoch 239/500
#
# Epoch 00239: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0171 - acc: 1.0000 - val_loss: 2.8024 - val_acc: 0.4500
# Epoch 240/500
#
# Epoch 00240: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0198 - acc: 1.0000 - val_loss: 2.9194 - val_acc: 0.4500
# Epoch 241/500
#
# Epoch 00241: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0194 - acc: 1.0000 - val_loss: 3.2096 - val_acc: 0.4500
# Epoch 242/500
#
# Epoch 00242: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0179 - acc: 1.0000 - val_loss: 3.4832 - val_acc: 0.4000
# Epoch 243/500
#
# Epoch 00243: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0113 - acc: 1.0000 - val_loss: 3.6241 - val_acc: 0.3500
# Epoch 244/500
#
# Epoch 00244: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0149 - acc: 1.0000 - val_loss: 3.5146 - val_acc: 0.4000
# Epoch 245/500
#
# Epoch 00245: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0166 - acc: 1.0000 - val_loss: 3.2697 - val_acc: 0.4500
# Epoch 246/500
#
# Epoch 00246: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0232 - acc: 1.0000 - val_loss: 3.1698 - val_acc: 0.4500
# Epoch 247/500
#
# Epoch 00247: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0244 - acc: 1.0000 - val_loss: 2.8351 - val_acc: 0.5000
# Epoch 248/500
#
# Epoch 00248: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0154 - acc: 1.0000 - val_loss: 2.6446 - val_acc: 0.5000
# Epoch 249/500
#
# Epoch 00249: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0318 - acc: 1.0000 - val_loss: 2.3019 - val_acc: 0.5500
# Epoch 250/500
#
# Epoch 00250: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0258 - acc: 1.0000 - val_loss: 2.1406 - val_acc: 0.6000
# Epoch 251/500
#
# Epoch 00251: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0202 - acc: 1.0000 - val_loss: 2.0904 - val_acc: 0.6000
# Epoch 252/500
#
# Epoch 00252: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0292 - acc: 1.0000 - val_loss: 2.0168 - val_acc: 0.6000
# Epoch 253/500
#
# Epoch 00253: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0272 - acc: 1.0000 - val_loss: 1.3942 - val_acc: 0.7500
# Epoch 254/500
#
# Epoch 00254: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0221 - acc: 1.0000 - val_loss: 1.3995 - val_acc: 0.8000
# Epoch 255/500
#
# Epoch 00255: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0176 - acc: 1.0000 - val_loss: 1.7223 - val_acc: 0.7000
# Epoch 256/500
#
# Epoch 00256: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0232 - acc: 1.0000 - val_loss: 2.5003 - val_acc: 0.5500
# Epoch 257/500
#
# Epoch 00257: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0213 - acc: 1.0000 - val_loss: 2.9580 - val_acc: 0.4500
# Epoch 258/500
#
# Epoch 00258: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0151 - acc: 1.0000 - val_loss: 3.0442 - val_acc: 0.4500
# Epoch 259/500
#
# Epoch 00259: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0117 - acc: 1.0000 - val_loss: 3.0660 - val_acc: 0.4500
# Epoch 260/500
#
# Epoch 00260: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0118 - acc: 1.0000 - val_loss: 3.1203 - val_acc: 0.4500
# Epoch 261/500
#
# Epoch 00261: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0205 - acc: 1.0000 - val_loss: 2.9623 - val_acc: 0.4500
# Epoch 262/500
#
# Epoch 00262: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0169 - acc: 1.0000 - val_loss: 2.3139 - val_acc: 0.4500
# Epoch 263/500
#
# Epoch 00263: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0188 - acc: 1.0000 - val_loss: 1.9523 - val_acc: 0.5500
# Epoch 264/500
#
# Epoch 00264: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0426 - acc: 1.0000 - val_loss: 1.3837 - val_acc: 0.7000
# Epoch 265/500
#
# Epoch 00265: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0272 - acc: 1.0000 - val_loss: 1.2062 - val_acc: 0.8000
# Epoch 266/500
#
# Epoch 00266: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0213 - acc: 1.0000 - val_loss: 1.2609 - val_acc: 0.8000
# Epoch 267/500
#
# Epoch 00267: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0150 - acc: 1.0000 - val_loss: 1.4556 - val_acc: 0.8000
# Epoch 268/500
#
# Epoch 00268: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0170 - acc: 1.0000 - val_loss: 1.8903 - val_acc: 0.6500
# Epoch 269/500
#
# Epoch 00269: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0914 - acc: 0.9667 - val_loss: 2.2144 - val_acc: 0.6000
# Epoch 270/500
#
# Epoch 00270: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0120 - acc: 1.0000 - val_loss: 1.7133 - val_acc: 0.6500
# Epoch 271/500
#
# Epoch 00271: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0151 - acc: 1.0000 - val_loss: 1.3568 - val_acc: 0.7500
# Epoch 272/500
#
# Epoch 00272: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0382 - acc: 1.0000 - val_loss: 1.4548 - val_acc: 0.6500
# Epoch 273/500
#
# Epoch 00273: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0164 - acc: 1.0000 - val_loss: 1.6932 - val_acc: 0.6500
# Epoch 274/500
#
# Epoch 00274: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0243 - acc: 1.0000 - val_loss: 2.0838 - val_acc: 0.5500
# Epoch 275/500
#
# Epoch 00275: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0188 - acc: 1.0000 - val_loss: 2.0384 - val_acc: 0.5500
# Epoch 276/500
#
# Epoch 00276: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0281 - acc: 1.0000 - val_loss: 2.2503 - val_acc: 0.5500
# Epoch 277/500
#
# Epoch 00277: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0138 - acc: 1.0000 - val_loss: 2.6268 - val_acc: 0.5500
# Epoch 278/500
#
# Epoch 00278: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0172 - acc: 1.0000 - val_loss: 2.7636 - val_acc: 0.5500
# Epoch 279/500
#
# Epoch 00279: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0293 - acc: 0.9833 - val_loss: 2.5296 - val_acc: 0.5500
# Epoch 280/500
#
# Epoch 00280: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0121 - acc: 1.0000 - val_loss: 2.0826 - val_acc: 0.6500
# Epoch 281/500
#
# Epoch 00281: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0305 - acc: 1.0000 - val_loss: 1.7406 - val_acc: 0.7500
# Epoch 282/500
#
# Epoch 00282: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0184 - acc: 1.0000 - val_loss: 1.6333 - val_acc: 0.7500
# Epoch 283/500
#
# Epoch 00283: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0205 - acc: 1.0000 - val_loss: 1.8779 - val_acc: 0.6500
# Epoch 284/500
#
# Epoch 00284: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0196 - acc: 1.0000 - val_loss: 1.9494 - val_acc: 0.6000
# Epoch 285/500
#
# Epoch 00285: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0149 - acc: 1.0000 - val_loss: 2.1354 - val_acc: 0.6000
# Epoch 286/500
#
# Epoch 00286: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0168 - acc: 1.0000 - val_loss: 2.3806 - val_acc: 0.5500
# Epoch 287/500
#
# Epoch 00287: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0682 - acc: 0.9833 - val_loss: 2.0986 - val_acc: 0.6000
# Epoch 288/500
#
# Epoch 00288: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0327 - acc: 1.0000 - val_loss: 1.5837 - val_acc: 0.7500
# Epoch 289/500
#
# Epoch 00289: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0183 - acc: 1.0000 - val_loss: 1.1271 - val_acc: 0.8000
# Epoch 290/500
#
# Epoch 00290: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0415 - acc: 1.0000 - val_loss: 1.3848 - val_acc: 0.8000
# Epoch 291/500
#
# Epoch 00291: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0140 - acc: 1.0000 - val_loss: 1.1720 - val_acc: 0.8000
# Epoch 292/500
#
# Epoch 00292: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0434 - acc: 0.9833 - val_loss: 1.0760 - val_acc: 0.8000
# Epoch 293/500
#
# Epoch 00293: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0201 - acc: 1.0000 - val_loss: 1.2106 - val_acc: 0.9000
# Epoch 294/500
#
# Epoch 00294: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0350 - acc: 1.0000 - val_loss: 1.5156 - val_acc: 0.8000
# Epoch 295/500
#
# Epoch 00295: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0305 - acc: 1.0000 - val_loss: 1.9972 - val_acc: 0.8000
# Epoch 296/500
#
# Epoch 00296: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0406 - acc: 1.0000 - val_loss: 2.2459 - val_acc: 0.6500
# Epoch 297/500
#
# Epoch 00297: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0289 - acc: 1.0000 - val_loss: 2.3053 - val_acc: 0.6000
# Epoch 298/500
#
# Epoch 00298: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0163 - acc: 1.0000 - val_loss: 2.5064 - val_acc: 0.5000
# Epoch 299/500
#
# Epoch 00299: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0414 - acc: 0.9833 - val_loss: 2.8701 - val_acc: 0.4500
# Epoch 300/500
#
# Epoch 00300: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0528 - acc: 0.9833 - val_loss: 2.7038 - val_acc: 0.5000
# Epoch 301/500
#
# Epoch 00301: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0574 - acc: 0.9833 - val_loss: 1.1241 - val_acc: 0.8000
# Epoch 302/500
#
# Epoch 00302: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0294 - acc: 1.0000 - val_loss: 0.7426 - val_acc: 0.8500
# Epoch 303/500
#
# Epoch 00303: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0411 - acc: 1.0000 - val_loss: 0.8921 - val_acc: 0.8000
# Epoch 304/500
#
# Epoch 00304: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0289 - acc: 1.0000 - val_loss: 1.2749 - val_acc: 0.8000
# Epoch 305/500
#
# Epoch 00305: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0342 - acc: 1.0000 - val_loss: 1.7839 - val_acc: 0.7000
# Epoch 306/500
#
# Epoch 00306: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0233 - acc: 1.0000 - val_loss: 2.0528 - val_acc: 0.6000
# Epoch 307/500
#
# Epoch 00307: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0211 - acc: 1.0000 - val_loss: 2.1380 - val_acc: 0.5500
# Epoch 308/500
#
# Epoch 00308: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0271 - acc: 1.0000 - val_loss: 2.1552 - val_acc: 0.5500
# Epoch 309/500
#
# Epoch 00309: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0264 - acc: 1.0000 - val_loss: 2.0220 - val_acc: 0.5500
# Epoch 310/500
#
# Epoch 00310: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0163 - acc: 1.0000 - val_loss: 1.9909 - val_acc: 0.6000
# Epoch 311/500
#
# Epoch 00311: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0146 - acc: 1.0000 - val_loss: 2.1117 - val_acc: 0.6000
# Epoch 312/500
#
# Epoch 00312: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0169 - acc: 1.0000 - val_loss: 2.5452 - val_acc: 0.5500
# Epoch 313/500
#
# Epoch 00313: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0180 - acc: 1.0000 - val_loss: 2.8516 - val_acc: 0.5500
# Epoch 314/500
#
# Epoch 00314: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0172 - acc: 1.0000 - val_loss: 3.2329 - val_acc: 0.4500
# Epoch 315/500
#
# Epoch 00315: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0302 - acc: 1.0000 - val_loss: 3.3497 - val_acc: 0.4500
# Epoch 316/500
#
# Epoch 00316: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0346 - acc: 1.0000 - val_loss: 3.2427 - val_acc: 0.4500
# Epoch 317/500
#
# Epoch 00317: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0134 - acc: 1.0000 - val_loss: 2.9662 - val_acc: 0.5000
# Epoch 318/500
#
# Epoch 00318: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0109 - acc: 1.0000 - val_loss: 2.8274 - val_acc: 0.5500
# Epoch 319/500
#
# Epoch 00319: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0274 - acc: 1.0000 - val_loss: 2.9067 - val_acc: 0.5000
# Epoch 320/500
#
# Epoch 00320: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0124 - acc: 1.0000 - val_loss: 3.1788 - val_acc: 0.5000
# Epoch 321/500
#
# Epoch 00321: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0127 - acc: 1.0000 - val_loss: 3.3393 - val_acc: 0.4500
# Epoch 322/500
#
# Epoch 00322: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0162 - acc: 1.0000 - val_loss: 3.2265 - val_acc: 0.4500
# Epoch 323/500
#
# Epoch 00323: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0234 - acc: 1.0000 - val_loss: 3.0338 - val_acc: 0.5000
# Epoch 324/500
#
# Epoch 00324: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0234 - acc: 1.0000 - val_loss: 2.7770 - val_acc: 0.5000
# Epoch 325/500
#
# Epoch 00325: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0101 - acc: 1.0000 - val_loss: 2.8258 - val_acc: 0.5000
# Epoch 326/500
#
# Epoch 00326: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0175 - acc: 1.0000 - val_loss: 2.8957 - val_acc: 0.5000
# Epoch 327/500
#
# Epoch 00327: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0082 - acc: 1.0000 - val_loss: 2.9472 - val_acc: 0.5000
# Epoch 328/500
#
# Epoch 00328: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0184 - acc: 1.0000 - val_loss: 2.9254 - val_acc: 0.5000
# Epoch 329/500
#
# Epoch 00329: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0198 - acc: 1.0000 - val_loss: 2.9626 - val_acc: 0.5000
# Epoch 330/500
#
# Epoch 00330: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0458 - acc: 1.0000 - val_loss: 2.6959 - val_acc: 0.5000
# Epoch 331/500
#
# Epoch 00331: val_loss did not improve from 0.72716
# 60/60 - 0s - loss: 0.0140 - acc: 1.0000 - val_loss: 2.3084 - val_acc: 0.5000
# Epoch 332/500
#
# Epoch 00332: val_loss did not improve from 0.72716
# ...
# 60/60 - 0s - loss: 0.0364 - acc: 1.0000 - val_loss: 1.4627 - val_acc: 0.5500
# Epoch 391/500
#
# Epoch 00391: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0230 - acc: 1.0000 - val_loss: 1.7400 - val_acc: 0.6000
# Epoch 392/500
#
# Epoch 00392: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0325 - acc: 1.0000 - val_loss: 2.0160 - val_acc: 0.6500
# Epoch 393/500
#
# Epoch 00393: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0222 - acc: 1.0000 - val_loss: 1.8637 - val_acc: 0.6500
# Epoch 394/500
#
# Epoch 00394: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0222 - acc: 1.0000 - val_loss: 1.6062 - val_acc: 0.6500
# Epoch 395/500
#
# Epoch 00395: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0489 - acc: 1.0000 - val_loss: 1.5455 - val_acc: 0.6500
# Epoch 396/500
#
# Epoch 00396: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0172 - acc: 1.0000 - val_loss: 1.7892 - val_acc: 0.6500
# Epoch 397/500
#
# Epoch 00397: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0139 - acc: 1.0000 - val_loss: 1.9524 - val_acc: 0.6500
# Epoch 398/500
#
# Epoch 00398: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0294 - acc: 1.0000 - val_loss: 1.9525 - val_acc: 0.6500
# Epoch 399/500
#
# Epoch 00399: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0279 - acc: 1.0000 - val_loss: 1.8350 - val_acc: 0.6500
# Epoch 400/500
#
# Epoch 00400: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0184 - acc: 1.0000 - val_loss: 1.5490 - val_acc: 0.6500
# Epoch 401/500
#
# Epoch 00401: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0183 - acc: 1.0000 - val_loss: 1.4880 - val_acc: 0.6000
# Epoch 402/500
#
# Epoch 00402: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0123 - acc: 1.0000 - val_loss: 1.4446 - val_acc: 0.5000
# Epoch 403/500
#
# Epoch 00403: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0119 - acc: 1.0000 - val_loss: 1.4630 - val_acc: 0.5500
# Epoch 404/500
#
# Epoch 00404: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0185 - acc: 1.0000 - val_loss: 1.4896 - val_acc: 0.5500
# Epoch 405/500
#
# Epoch 00405: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0143 - acc: 1.0000 - val_loss: 1.5412 - val_acc: 0.5500
# Epoch 406/500
#
# Epoch 00406: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0098 - acc: 1.0000 - val_loss: 1.6221 - val_acc: 0.6000
# Epoch 407/500
#
# Epoch 00407: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0294 - acc: 1.0000 - val_loss: 1.7311 - val_acc: 0.6000
# Epoch 408/500
#
# Epoch 00408: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0234 - acc: 1.0000 - val_loss: 1.6217 - val_acc: 0.6000
# Epoch 409/500
#
# Epoch 00409: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0849 - acc: 0.9833 - val_loss: 1.6802 - val_acc: 0.6500
# Epoch 410/500
#
# Epoch 00410: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0133 - acc: 1.0000 - val_loss: 1.7933 - val_acc: 0.6500
# Epoch 411/500
#
# Epoch 00411: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0372 - acc: 0.9833 - val_loss: 2.1413 - val_acc: 0.6500
# Epoch 412/500
#
# Epoch 00412: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0536 - acc: 1.0000 - val_loss: 1.9341 - val_acc: 0.6500
# Epoch 413/500
#
# Epoch 00413: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0306 - acc: 1.0000 - val_loss: 1.8507 - val_acc: 0.6000
# Epoch 414/500
#
# Epoch 00414: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0336 - acc: 0.9833 - val_loss: 1.6695 - val_acc: 0.5500
# Epoch 415/500
#
# Epoch 00415: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0277 - acc: 1.0000 - val_loss: 1.6608 - val_acc: 0.5500
# Epoch 416/500
#
# Epoch 00416: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0248 - acc: 1.0000 - val_loss: 1.9103 - val_acc: 0.5500
# Epoch 417/500
#
# Epoch 00417: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0280 - acc: 1.0000 - val_loss: 1.8257 - val_acc: 0.5500
# Epoch 418/500
#
# Epoch 00418: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0528 - acc: 0.9833 - val_loss: 1.9262 - val_acc: 0.6000
# Epoch 419/500
#
# Epoch 00419: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0172 - acc: 1.0000 - val_loss: 2.3168 - val_acc: 0.6500
# Epoch 420/500
#
# Epoch 00420: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0285 - acc: 1.0000 - val_loss: 2.5768 - val_acc: 0.6000
# Epoch 421/500
#
# Epoch 00421: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0174 - acc: 1.0000 - val_loss: 2.2736 - val_acc: 0.6500
# Epoch 422/500
#
# Epoch 00422: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0143 - acc: 1.0000 - val_loss: 2.0473 - val_acc: 0.6500
# Epoch 423/500
#
# Epoch 00423: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0147 - acc: 1.0000 - val_loss: 1.8051 - val_acc: 0.6500
# Epoch 424/500
#
# Epoch 00424: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0116 - acc: 1.0000 - val_loss: 1.5123 - val_acc: 0.5500
# Epoch 425/500
#
# Epoch 00425: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0268 - acc: 1.0000 - val_loss: 1.5947 - val_acc: 0.5000
# Epoch 426/500
#
# Epoch 00426: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0170 - acc: 1.0000 - val_loss: 1.7431 - val_acc: 0.6500
# Epoch 427/500
#
# Epoch 00427: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0182 - acc: 1.0000 - val_loss: 2.0239 - val_acc: 0.6500
# Epoch 428/500
#
# Epoch 00428: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0211 - acc: 1.0000 - val_loss: 1.5679 - val_acc: 0.5000
# Epoch 429/500
#
# Epoch 00429: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0366 - acc: 1.0000 - val_loss: 1.4110 - val_acc: 0.6000
# Epoch 430/500
#
# Epoch 00430: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0187 - acc: 1.0000 - val_loss: 1.3493 - val_acc: 0.5500
# Epoch 431/500
#
# Epoch 00431: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0226 - acc: 1.0000 - val_loss: 1.5013 - val_acc: 0.6000
# Epoch 432/500
#
# Epoch 00432: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0155 - acc: 1.0000 - val_loss: 1.8370 - val_acc: 0.6500
# Epoch 433/500
#
# Epoch 00433: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0171 - acc: 1.0000 - val_loss: 1.9323 - val_acc: 0.6500
# Epoch 434/500
#
# Epoch 00434: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0137 - acc: 1.0000 - val_loss: 1.8603 - val_acc: 0.6500
# Epoch 435/500
#
# Epoch 00435: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0139 - acc: 1.0000 - val_loss: 1.6250 - val_acc: 0.6500
# Epoch 436/500
#
# Epoch 00436: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0154 - acc: 1.0000 - val_loss: 1.4456 - val_acc: 0.6000
# Epoch 437/500
#
# Epoch 00437: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0256 - acc: 1.0000 - val_loss: 1.4097 - val_acc: 0.6500
# Epoch 438/500
#
# Epoch 00438: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0087 - acc: 1.0000 - val_loss: 1.3780 - val_acc: 0.6500
# Epoch 439/500
#
# Epoch 00439: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0132 - acc: 1.0000 - val_loss: 1.4425 - val_acc: 0.6500
# Epoch 440/500
#
# Epoch 00440: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0177 - acc: 1.0000 - val_loss: 1.6617 - val_acc: 0.6500
# Epoch 441/500
#
# Epoch 00441: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0375 - acc: 1.0000 - val_loss: 1.9695 - val_acc: 0.6500
# Epoch 442/500
#
# Epoch 00442: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0130 - acc: 1.0000 - val_loss: 3.0531 - val_acc: 0.5000
# Epoch 443/500
#
# Epoch 00443: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0333 - acc: 1.0000 - val_loss: 3.1799 - val_acc: 0.5000
# Epoch 444/500
#
# Epoch 00444: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0217 - acc: 1.0000 - val_loss: 2.2816 - val_acc: 0.6500
# Epoch 445/500
#
# Epoch 00445: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0261 - acc: 1.0000 - val_loss: 1.5774 - val_acc: 0.5500
# Epoch 446/500
#
# Epoch 00446: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0237 - acc: 1.0000 - val_loss: 1.5861 - val_acc: 0.5500
# Epoch 447/500
#
# Epoch 00447: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0288 - acc: 1.0000 - val_loss: 1.6119 - val_acc: 0.5500
# Epoch 448/500
#
# Epoch 00448: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0281 - acc: 1.0000 - val_loss: 1.8597 - val_acc: 0.6000
# Epoch 449/500
#
# Epoch 00449: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0097 - acc: 1.0000 - val_loss: 2.2231 - val_acc: 0.6000
# Epoch 450/500
#
# Epoch 00450: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0254 - acc: 1.0000 - val_loss: 1.9654 - val_acc: 0.5500
# Epoch 451/500
#
# Epoch 00451: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0282 - acc: 1.0000 - val_loss: 1.7498 - val_acc: 0.5500
# Epoch 452/500
#
# Epoch 00452: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0129 - acc: 1.0000 - val_loss: 1.7867 - val_acc: 0.5500
# Epoch 453/500
#
# Epoch 00453: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0147 - acc: 1.0000 - val_loss: 1.7426 - val_acc: 0.5500
# Epoch 454/500
#
# Epoch 00454: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0204 - acc: 1.0000 - val_loss: 1.6592 - val_acc: 0.6500
# Epoch 455/500
#
# Epoch 00455: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0408 - acc: 0.9833 - val_loss: 1.8478 - val_acc: 0.6000
# Epoch 456/500
#
# Epoch 00456: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0347 - acc: 1.0000 - val_loss: 1.9564 - val_acc: 0.5500
# Epoch 457/500
#
# Epoch 00457: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0084 - acc: 1.0000 - val_loss: 1.9412 - val_acc: 0.5500
# Epoch 458/500
#
# Epoch 00458: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0124 - acc: 1.0000 - val_loss: 1.8629 - val_acc: 0.5500
# Epoch 459/500
#
# Epoch 00459: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0189 - acc: 1.0000 - val_loss: 1.8945 - val_acc: 0.6500
# Epoch 460/500
#
# Epoch 00460: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0170 - acc: 1.0000 - val_loss: 1.7004 - val_acc: 0.5000
# Epoch 461/500
#
# Epoch 00461: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0138 - acc: 1.0000 - val_loss: 1.5374 - val_acc: 0.6000
# Epoch 462/500
#
# Epoch 00462: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0453 - acc: 0.9833 - val_loss: 2.0861 - val_acc: 0.6500
# Epoch 463/500
#
# Epoch 00463: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0399 - acc: 1.0000 - val_loss: 2.8482 - val_acc: 0.5500
# Epoch 464/500
#
# Epoch 00464: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0098 - acc: 1.0000 - val_loss: 1.8976 - val_acc: 0.6500
# Epoch 465/500
#
# Epoch 00465: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0376 - acc: 0.9833 - val_loss: 1.7576 - val_acc: 0.5500
# Epoch 466/500
#
# Epoch 00466: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0101 - acc: 1.0000 - val_loss: 1.8637 - val_acc: 0.5000
# Epoch 467/500
#
# Epoch 00467: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0326 - acc: 0.9833 - val_loss: 2.0842 - val_acc: 0.6500
# Epoch 468/500
#
# Epoch 00468: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0151 - acc: 1.0000 - val_loss: 2.1556 - val_acc: 0.6500
# Epoch 469/500
#
# Epoch 00469: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0352 - acc: 1.0000 - val_loss: 1.8933 - val_acc: 0.6500
# Epoch 470/500
#
# Epoch 00470: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0141 - acc: 1.0000 - val_loss: 1.7339 - val_acc: 0.6500
# Epoch 471/500
#
# Epoch 00471: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0177 - acc: 1.0000 - val_loss: 1.6242 - val_acc: 0.5500
# Epoch 472/500
#
# Epoch 00472: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0238 - acc: 1.0000 - val_loss: 1.6939 - val_acc: 0.6000
# Epoch 473/500
#
# Epoch 00473: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0270 - acc: 1.0000 - val_loss: 1.7827 - val_acc: 0.5000
# Epoch 474/500
#
# Epoch 00474: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0359 - acc: 1.0000 - val_loss: 1.8197 - val_acc: 0.5500
# Epoch 475/500
#
# Epoch 00475: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0089 - acc: 1.0000 - val_loss: 1.8115 - val_acc: 0.5500
# Epoch 476/500
#
# Epoch 00476: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0391 - acc: 1.0000 - val_loss: 1.7012 - val_acc: 0.5500
# Epoch 477/500
#
# Epoch 00477: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0146 - acc: 1.0000 - val_loss: 1.9013 - val_acc: 0.5500
# Epoch 478/500
#
# Epoch 00478: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0140 - acc: 1.0000 - val_loss: 2.0520 - val_acc: 0.6000
# Epoch 479/500
#
# Epoch 00479: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0109 - acc: 1.0000 - val_loss: 1.9587 - val_acc: 0.5500
# Epoch 480/500
#
# Epoch 00480: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0220 - acc: 1.0000 - val_loss: 1.7083 - val_acc: 0.6000
# Epoch 481/500
#
# Epoch 00481: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0128 - acc: 1.0000 - val_loss: 1.6319 - val_acc: 0.5500
# Epoch 482/500
#
# Epoch 00482: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0216 - acc: 1.0000 - val_loss: 1.7237 - val_acc: 0.5500
# Epoch 483/500
#
# Epoch 00483: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0098 - acc: 1.0000 - val_loss: 2.0036 - val_acc: 0.6000
# Epoch 484/500
#
# Epoch 00484: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0272 - acc: 1.0000 - val_loss: 2.3701 - val_acc: 0.6500
# Epoch 485/500
#
# Epoch 00485: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0198 - acc: 1.0000 - val_loss: 2.8384 - val_acc: 0.6000
# Epoch 486/500
#
# Epoch 00486: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0170 - acc: 1.0000 - val_loss: 2.1595 - val_acc: 0.6500
# Epoch 487/500
#
# Epoch 00487: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0144 - acc: 1.0000 - val_loss: 1.6610 - val_acc: 0.6500
# Epoch 488/500
#
# Epoch 00488: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0397 - acc: 1.0000 - val_loss: 1.8322 - val_acc: 0.6500
# Epoch 489/500
#
# Epoch 00489: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0127 - acc: 1.0000 - val_loss: 1.8589 - val_acc: 0.6500
# Epoch 490/500
#
# Epoch 00490: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0271 - acc: 1.0000 - val_loss: 1.5426 - val_acc: 0.6500
# Epoch 491/500
#
# Epoch 00491: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0105 - acc: 1.0000 - val_loss: 1.3456 - val_acc: 0.5500
# Epoch 492/500
#
# Epoch 00492: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0290 - acc: 1.0000 - val_loss: 1.5837 - val_acc: 0.6000
# Epoch 493/500
#
# Epoch 00493: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0159 - acc: 1.0000 - val_loss: 2.3828 - val_acc: 0.6500
# Epoch 494/500
#
# Epoch 00494: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0119 - acc: 1.0000 - val_loss: 2.7383 - val_acc: 0.6500
# Epoch 495/500
#
# Epoch 00495: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0394 - acc: 1.0000 - val_loss: 2.2964 - val_acc: 0.6500
# Epoch 496/500
#
# Epoch 00496: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0245 - acc: 1.0000 - val_loss: 2.0740 - val_acc: 0.6500
# Epoch 497/500
#
# Epoch 00497: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0469 - acc: 0.9667 - val_loss: 1.9579 - val_acc: 0.6500
# Epoch 498/500
#
# Epoch 00498: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0243 - acc: 1.0000 - val_loss: 1.8753 - val_acc: 0.6500
# Epoch 499/500
#
# Epoch 00499: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0215 - acc: 1.0000 - val_loss: 1.8628 - val_acc: 0.6000
# Epoch 500/500
#
# Epoch 00500: val_loss did not improve from 0.45579
# 60/60 - 0s - loss: 0.0098 - acc: 1.0000 - val_loss: 1.7629 - val_acc: 0.5500
#
# # Evaluate on test data
# 40/40 [==============================] - 0s 3ms/sample - loss: 0.4652 - acc: 0.8500
# test loss, test acc: [0.46515189064148216, 0.85]
