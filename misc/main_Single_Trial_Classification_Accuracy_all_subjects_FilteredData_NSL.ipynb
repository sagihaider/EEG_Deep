# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_Single_Trial_Classification_Accuracy_all_subjects_FilteredData_NSL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 222 (delta 34), reused 12 (delta 5), pack-reused 153
# Receiving objects: 100% (222/222), 860.09 MiB | 36.88 MiB/s, done.
# Resolving deltas: 100% (87/87), done.
# Checking out files: 100% (62/62), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting neural_structured_learning
#   Downloading https://files.pythonhosted.org/packages/08/2e/22b1385d7d601ad0c81457a5b66b3bb6f3c400348c62ea3f07a5fc1b13bc/neural_structured_learning-1.1.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 6.7MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.8.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.3.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.4)
# Installing collected packages: neural-structured-learning
# Successfully installed neural-structured-learning-1.1.0

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()
cols = 2
rows = 9
acc_all = zeros([rows, cols])
X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])


for x in range(1,10):
  fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_tr = mat['cleanRawEEGData']
  y_tr = mat['cleanClassLabels']
  
  print(np.shape(r_X_tr))
  print(np.shape(y_tr))

  for t in range(r_X_tr.shape[0]):
    tril = r_X_tr[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_tr[t,:,:] = tril_filtered 
    
  # split data of each subject in training and validation
  X_train      = X_tr[0:240,:,500:1250]
  Y_train      = y_tr[0:240]
  X_val       = X_tr[241:,:,500:1250]
  Y_val       = y_tr[241:]

  print(np.shape(X_train))
  print(np.shape(Y_train))
  print(np.shape(X_val))
  print(np.shape(Y_val))
  
  # convert labels to one-hot encodings.
  Y_train      = np_utils.to_categorical(Y_train-1)
  Y_val       = np_utils.to_categorical(Y_val-1)

  kernels, chans, samples = 1, 22, 750
  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
  X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
  print('X_train shape:', X_train.shape)
  print(X_train.shape[0], 'train samples')
  print(X_val.shape[0], 'val samples')

  # Load test data         
  fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_ts = mat['cleanRawEEGData']
  y_ts = mat['cleanClassLabels']

  print(np.shape(r_X_ts))
  print(np.shape(y_ts))

  for t in range(r_X_ts.shape[0]):
    tril = r_X_ts[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_ts[t,:,:] = tril_filtered 

  X_test      = X_ts[:,:,500:1250]
  Y_test      = y_ts[:]
  print(np.shape(X_test))
  print(np.shape(Y_test))

  #convert labels to one-hot encodings.
  Y_test      = np_utils.to_categorical(Y_test-1)

  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

  print('X_train shape:', X_test.shape)
  print(X_test.shape[0], 'train samples')

  # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
  # model configurations may do better, but this is a good starting point)
  model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                 dropoutRate = 0.5, kernLength = 25, F1 = 8, 
                 D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

  # compile the model and set the optimizers
  model.compile(loss='categorical_crossentropy', optimizer='adam', 
                metrics = ['accuracy'])

  # count number of parameters in the model
  numParams    = model.count_params() 

  # set a valid path for your system to record model checkpoints
  checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', verbose=1,
                                 save_best_only=True)
  
  # the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
  # the weights all to be 1
  class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
  history = model.fit(X_train, Y_train, batch_size = 16, epochs = 100, 
                      verbose = 2, validation_data=(X_val, Y_val),
                      callbacks=[checkpointer], class_weight = class_weights)
  
  # Plot training & validation accuracy values
  plt.plot(history.history['acc'])
  plt.plot(history.history['val_acc'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  figName = 'Accuracy_A0' + str(x) + '.png'  
  plt.savefig(figName)

  print('\n# Evaluate on test data')
  results = model.evaluate(X_test, Y_test, batch_size=1)
  print('test loss, test acc:', results)

  acc_all[x - 1, 0] = results[0]
  acc_all[x - 1, 1] = results[1]

  from keras import backend as K 
  # Do some code, e.g. train and save model
  K.clear_session()


print(acc_all)

import pandas as pd
df_accl_all = pd.DataFrame({'Loss ': acc_all[:, 0], 'Eval Acc': acc_all[:, 1]})
df_accl_all.to_csv (r'EEG_Deep/df_accl_8_12_Hz4_Class.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 0.4152 - acc: 0.8917 - val_loss: 0.5656 - val_acc: 0.7872
# Epoch 82/100
#
# Epoch 00082: val_loss improved from 0.56556 to 0.55989, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 0.4394 - acc: 0.8625 - val_loss: 0.5599 - val_acc: 0.7660
# Epoch 83/100
#
# Epoch 00083: val_loss improved from 0.55989 to 0.55329, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 0.4516 - acc: 0.8500 - val_loss: 0.5533 - val_acc: 0.7234
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.55329
# 240/240 - 0s - loss: 0.4033 - acc: 0.8833 - val_loss: 0.5638 - val_acc: 0.7234
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.55329
# 240/240 - 0s - loss: 0.4601 - acc: 0.8625 - val_loss: 0.5672 - val_acc: 0.7447
# Epoch 86/100
#
# Epoch 00086: val_loss improved from 0.55329 to 0.55177, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 0.3984 - acc: 0.8875 - val_loss: 0.5518 - val_acc: 0.7447
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.4225 - acc: 0.8708 - val_loss: 0.5608 - val_acc: 0.7660
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.4270 - acc: 0.8792 - val_loss: 0.5986 - val_acc: 0.7447
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.4323 - acc: 0.8833 - val_loss: 0.5783 - val_acc: 0.7447
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.4379 - acc: 0.8708 - val_loss: 0.5871 - val_acc: 0.7447
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.3881 - acc: 0.8833 - val_loss: 0.5663 - val_acc: 0.7872
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.3977 - acc: 0.9083 - val_loss: 0.5698 - val_acc: 0.7660
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.3736 - acc: 0.8958 - val_loss: 0.5686 - val_acc: 0.7234
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.55177
# 240/240 - 0s - loss: 0.3897 - acc: 0.8958 - val_loss: 0.5633 - val_acc: 0.7447
# Epoch 95/100
#
# Epoch 00095: val_loss improved from 0.55177 to 0.54561, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 0.4237 - acc: 0.8708 - val_loss: 0.5456 - val_acc: 0.7872
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.54561
# 240/240 - 0s - loss: 0.4126 - acc: 0.8833 - val_loss: 0.5595 - val_acc: 0.7660
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.54561
# 240/240 - 0s - loss: 0.4117 - acc: 0.8833 - val_loss: 0.5643 - val_acc: 0.7660
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.54561
# 240/240 - 0s - loss: 0.4071 - acc: 0.8875 - val_loss: 0.5592 - val_acc: 0.7447
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.54561
# 240/240 - 0s - loss: 0.3818 - acc: 0.9000 - val_loss: 0.5811 - val_acc: 0.7872
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.54561
# 240/240 - 0s - loss: 0.3841 - acc: 0.8833 - val_loss: 0.5525 - val_acc: 0.7660
# # Evaluate on test data
# 288/288 [==============================] - 1s 3ms/sample - loss: 0.5724 - acc: 0.7639
# test loss, test acc: [0.5723730965082723, 0.7638889]
# [[0.71559846 0.69097221]
#  [1.20042716 0.47916666]
#  [0.57773062 0.80208331]
#  [0.96457814 0.5798611 ]
#  [1.2832149  0.40972221]
#  [1.23114571 0.4375    ]
#  [0.68876875 0.72916669]
#  [0.67814202 0.75347221]
#  [0.5723731  0.7638889 ]]

# %%
from numpy import zeros
K.clear_session()
cols = 2
rows = 9
acc_all = zeros([rows, cols])
X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])


for x in range(1,10):
  fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_tr = mat['cleanRawEEGData']
  y_tr = mat['cleanClassLabels']
  
  print(np.shape(r_X_tr))
  print(np.shape(y_tr))

  for t in range(r_X_tr.shape[0]):
    tril = r_X_tr[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_tr[t,:,:] = tril_filtered 
    
  # split data of each subject in training and validation
  X_train      = X_tr[0:240,:,500:1250]
  Y_train      = y_tr[0:240]
  X_val       = X_tr[241:,:,500:1250]
  Y_val       = y_tr[241:]

  print(np.shape(X_train))
  print(np.shape(Y_train))
  print(np.shape(X_val))
  print(np.shape(Y_val))
  
  # convert labels to one-hot encodings.
  Y_train      = np_utils.to_categorical(Y_train-1)
  Y_val       = np_utils.to_categorical(Y_val-1)

  kernels, chans, samples = 1, 22, 750
  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
  X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
  print('X_train shape:', X_train.shape)
  print(X_train.shape[0], 'train samples')
  print(X_val.shape[0], 'val samples')

  # Load test data         
  fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_ts = mat['cleanRawEEGData']
  y_ts = mat['cleanClassLabels']

  print(np.shape(r_X_ts))
  print(np.shape(y_ts))

  for t in range(r_X_ts.shape[0]):
    tril = r_X_ts[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_ts[t,:,:] = tril_filtered 

  X_test      = X_ts[:,:,500:1250]
  Y_test      = y_ts[:]
  print(np.shape(X_test))
  print(np.shape(Y_test))

  #convert labels to one-hot encodings.
  Y_test      = np_utils.to_categorical(Y_test-1)

  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

  print('X_train shape:', X_test.shape)
  print(X_test.shape[0], 'train samples')

  # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
  # model configurations may do better, but this is a good starting point)
  model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                 dropoutRate = 0.5, kernLength = 25, F1 = 8, 
                 D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

  adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
  adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
  # compile the model and set the optimizers
  adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
  batch_size = 32

  X_train = tf.cast(X_train, tf.float32)
  X_test = tf.cast(X_test, tf.float32)
  X_val = tf.cast(X_val, tf.float32)


  train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
  val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
  test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)

  val_steps = X_val.shape[0] // batch_size

  
  adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=100, verbose=1)

  history = adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=100, verbose=1)

  # Plot training & validation accuracy values
  plt.plot(history.history['categorical_accuracy'])
  plt.plot(history.history['val_categorical_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  figName = 'Accuracy_A0' + str(x) + '.png'  
  plt.savefig(figName)

  print('\n# Evaluate on test data')
  results = adv_model.evaluate(test_data)
  print('test loss, test acc:', results)

  acc_all[x - 1, 0] = results[1]
  acc_all[x - 1, 1] = results[2]

  from keras import backend as K 
  # Do some code, e.g. train and save model
  K.clear_session()


print(acc_all)
# Out:
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288, 1)
# (240, 22, 750)
# (240, 1)
# (47, 22, 750)
# (47, 1)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/100
# 8/8 [==============================] - 0s 62ms/step - loss: 1.4046 - categorical_crossentropy: 1.4046 - categorical_accuracy: 0.2625 - val_loss: 1.3885 - val_categorical_crossentropy: 1.3885 - val_categorical_accuracy: 0.2553
# Epoch 2/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.3663 - categorical_crossentropy: 1.3663 - categorical_accuracy: 0.2917 - val_loss: 1.3883 - val_categorical_crossentropy: 1.3883 - val_categorical_accuracy: 0.2128
# Epoch 3/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3659 - categorical_crossentropy: 1.3659 - categorical_accuracy: 0.3542 - val_loss: 1.3874 - val_categorical_crossentropy: 1.3874 - val_categorical_accuracy: 0.1915
# Epoch 4/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.3542 - categorical_crossentropy: 1.3542 - categorical_accuracy: 0.3333 - val_loss: 1.3861 - val_categorical_crossentropy: 1.3861 - val_categorical_accuracy: 0.1915
# Epoch 5/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3306 - categorical_crossentropy: 1.3306 - categorical_accuracy: 0.3625 - val_loss: 1.3842 - val_categorical_crossentropy: 1.3842 - val_categorical_accuracy: 0.2128
# Epoch 6/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3180 - categorical_crossentropy: 1.3180 - categorical_accuracy: 0.3792 - val_loss: 1.3807 - val_categorical_crossentropy: 1.3807 - val_categorical_accuracy: 0.2553
# Epoch 7/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3051 - categorical_crossentropy: 1.3051 - categorical_accuracy: 0.4292 - val_loss: 1.3737 - val_categorical_crossentropy: 1.3737 - val_categorical_accuracy: 0.3830
# Epoch 8/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.2695 - categorical_crossentropy: 1.2695 - categorical_accuracy: 0.4542 - val_loss: 1.3624 - val_categorical_crossentropy: 1.3624 - val_categorical_accuracy: 0.4681
# Epoch 9/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.2350 - categorical_crossentropy: 1.2350 - categorical_accuracy: 0.5083 - val_loss: 1.3440 - val_categorical_crossentropy: 1.3440 - val_categorical_accuracy: 0.4255
# Epoch 10/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.1892 - categorical_crossentropy: 1.1892 - categorical_accuracy: 0.5125 - val_loss: 1.3191 - val_categorical_crossentropy: 1.3191 - val_categorical_accuracy: 0.4468
# Epoch 11/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.1330 - categorical_crossentropy: 1.1330 - categorical_accuracy: 0.5958 - val_loss: 1.2842 - val_categorical_crossentropy: 1.2842 - val_categorical_accuracy: 0.4468
# Epoch 12/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0760 - categorical_crossentropy: 1.0760 - categorical_accuracy: 0.6208 - val_loss: 1.2453 - val_categorical_crossentropy: 1.2453 - val_categorical_accuracy: 0.4043
# Epoch 13/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0232 - categorical_crossentropy: 1.0232 - categorical_accuracy: 0.6125 - val_loss: 1.2149 - val_categorical_crossentropy: 1.2149 - val_categorical_accuracy: 0.4468
# Epoch 14/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9940 - categorical_crossentropy: 0.9940 - categorical_accuracy: 0.6208 - val_loss: 1.1873 - val_categorical_crossentropy: 1.1873 - val_categorical_accuracy: 0.4681
# Epoch 15/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9447 - categorical_crossentropy: 0.9447 - categorical_accuracy: 0.6625 - val_loss: 1.1679 - val_categorical_crossentropy: 1.1679 - val_categorical_accuracy: 0.4468
# Epoch 16/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9200 - categorical_crossentropy: 0.9200 - categorical_accuracy: 0.6250 - val_loss: 1.1744 - val_categorical_crossentropy: 1.1744 - val_categorical_accuracy: 0.4681
# Epoch 17/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8911 - categorical_crossentropy: 0.8911 - categorical_accuracy: 0.6583 - val_loss: 1.1814 - val_categorical_crossentropy: 1.1814 - val_categorical_accuracy: 0.4681
# Epoch 18/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8807 - categorical_crossentropy: 0.8807 - categorical_accuracy: 0.6458 - val_loss: 1.1946 - val_categorical_crossentropy: 1.1946 - val_categorical_accuracy: 0.3617
# Epoch 19/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8759 - categorical_crossentropy: 0.8759 - categorical_accuracy: 0.6250 - val_loss: 1.2144 - val_categorical_crossentropy: 1.2144 - val_categorical_accuracy: 0.3830
# Epoch 20/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8426 - categorical_crossentropy: 0.8426 - categorical_accuracy: 0.6750 - val_loss: 1.2314 - val_categorical_crossentropy: 1.2314 - val_categorical_accuracy: 0.3191
# Epoch 21/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8198 - categorical_crossentropy: 0.8198 - categorical_accuracy: 0.7000 - val_loss: 1.2420 - val_categorical_crossentropy: 1.2420 - val_categorical_accuracy: 0.3191
# Epoch 22/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7985 - categorical_crossentropy: 0.7985 - categorical_accuracy: 0.7083 - val_loss: 1.2387 - val_categorical_crossentropy: 1.2387 - val_categorical_accuracy: 0.2979
# Epoch 23/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7992 - categorical_crossentropy: 0.7992 - categorical_accuracy: 0.6708 - val_loss: 1.2396 - val_categorical_crossentropy: 1.2396 - val_categorical_accuracy: 0.2979
# Epoch 24/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7695 - categorical_crossentropy: 0.7695 - categorical_accuracy: 0.7083 - val_loss: 1.2176 - val_categorical_crossentropy: 1.2176 - val_categorical_accuracy: 0.2766
# Epoch 25/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7732 - categorical_crossentropy: 0.7732 - categorical_accuracy: 0.6750 - val_loss: 1.2426 - val_categorical_crossentropy: 1.2426 - val_categorical_accuracy: 0.3191
# Epoch 26/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7708 - categorical_crossentropy: 0.7708 - categorical_accuracy: 0.6958 - val_loss: 1.2308 - val_categorical_crossentropy: 1.2308 - val_categorical_accuracy: 0.3191
# Epoch 27/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7893 - categorical_crossentropy: 0.7893 - categorical_accuracy: 0.6667 - val_loss: 1.2113 - val_categorical_crossentropy: 1.2113 - val_categorical_accuracy: 0.2979
# Epoch 28/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7533 - categorical_crossentropy: 0.7533 - categorical_accuracy: 0.7083 - val_loss: 1.1982 - val_categorical_crossentropy: 1.1982 - val_categorical_accuracy: 0.2979
# Epoch 29/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7799 - categorical_crossentropy: 0.7799 - categorical_accuracy: 0.6917 - val_loss: 1.1876 - val_categorical_crossentropy: 1.1876 - val_categorical_accuracy: 0.3617
# Epoch 30/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7276 - categorical_crossentropy: 0.7276 - categorical_accuracy: 0.7250 - val_loss: 1.1726 - val_categorical_crossentropy: 1.1726 - val_categorical_accuracy: 0.4468
# Epoch 31/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7126 - categorical_crossentropy: 0.7126 - categorical_accuracy: 0.7208 - val_loss: 1.1555 - val_categorical_crossentropy: 1.1555 - val_categorical_accuracy: 0.4681
# Epoch 32/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7356 - categorical_crossentropy: 0.7356 - categorical_accuracy: 0.6958 - val_loss: 1.1813 - val_categorical_crossentropy: 1.1813 - val_categorical_accuracy: 0.4043
# Epoch 33/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7227 - categorical_crossentropy: 0.7227 - categorical_accuracy: 0.7042 - val_loss: 1.1796 - val_categorical_crossentropy: 1.1796 - val_categorical_accuracy: 0.5106
# Epoch 34/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6884 - categorical_crossentropy: 0.6884 - categorical_accuracy: 0.7542 - val_loss: 1.1368 - val_categorical_crossentropy: 1.1368 - val_categorical_accuracy: 0.5319
# Epoch 35/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6996 - categorical_crossentropy: 0.6996 - categorical_accuracy: 0.7542 - val_loss: 1.1277 - val_categorical_crossentropy: 1.1277 - val_categorical_accuracy: 0.5106
# Epoch 36/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6815 - categorical_crossentropy: 0.6815 - categorical_accuracy: 0.7417 - val_loss: 1.1284 - val_categorical_crossentropy: 1.1284 - val_categorical_accuracy: 0.5106
# Epoch 37/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7066 - categorical_crossentropy: 0.7066 - categorical_accuracy: 0.7167 - val_loss: 1.0810 - val_categorical_crossentropy: 1.0810 - val_categorical_accuracy: 0.5319
# Epoch 38/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6712 - categorical_crossentropy: 0.6712 - categorical_accuracy: 0.7583 - val_loss: 1.0550 - val_categorical_crossentropy: 1.0550 - val_categorical_accuracy: 0.5319
# Epoch 39/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6706 - categorical_crossentropy: 0.6706 - categorical_accuracy: 0.7875 - val_loss: 1.0366 - val_categorical_crossentropy: 1.0366 - val_categorical_accuracy: 0.5319
# Epoch 40/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6898 - categorical_crossentropy: 0.6898 - categorical_accuracy: 0.7542 - val_loss: 1.0049 - val_categorical_crossentropy: 1.0049 - val_categorical_accuracy: 0.5319
# Epoch 41/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7011 - categorical_crossentropy: 0.7011 - categorical_accuracy: 0.7542 - val_loss: 0.9911 - val_categorical_crossentropy: 0.9911 - val_categorical_accuracy: 0.5319
# Epoch 42/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6627 - categorical_crossentropy: 0.6627 - categorical_accuracy: 0.7583 - val_loss: 0.9816 - val_categorical_crossentropy: 0.9816 - val_categorical_accuracy: 0.5106
# Epoch 43/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6810 - categorical_crossentropy: 0.6810 - categorical_accuracy: 0.7500 - val_loss: 0.9805 - val_categorical_crossentropy: 0.9805 - val_categorical_accuracy: 0.5319
# Epoch 44/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6669 - categorical_crossentropy: 0.6669 - categorical_accuracy: 0.7708 - val_loss: 0.9647 - val_categorical_crossentropy: 0.9647 - val_categorical_accuracy: 0.5319
# Epoch 45/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6594 - categorical_crossentropy: 0.6594 - categorical_accuracy: 0.7667 - val_loss: 0.9443 - val_categorical_crossentropy: 0.9443 - val_categorical_accuracy: 0.5106
# Epoch 46/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6541 - categorical_crossentropy: 0.6541 - categorical_accuracy: 0.7542 - val_loss: 0.9334 - val_categorical_crossentropy: 0.9334 - val_categorical_accuracy: 0.5745
# Epoch 47/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6602 - categorical_crossentropy: 0.6602 - categorical_accuracy: 0.7875 - val_loss: 0.9216 - val_categorical_crossentropy: 0.9216 - val_categorical_accuracy: 0.5532
# Epoch 48/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6374 - categorical_crossentropy: 0.6374 - categorical_accuracy: 0.7708 - val_loss: 0.9216 - val_categorical_crossentropy: 0.9216 - val_categorical_accuracy: 0.5957
# Epoch 49/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6731 - categorical_crossentropy: 0.6731 - categorical_accuracy: 0.7292 - val_loss: 0.9231 - val_categorical_crossentropy: 0.9231 - val_categorical_accuracy: 0.5957
# Epoch 50/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6517 - categorical_crossentropy: 0.6517 - categorical_accuracy: 0.7125 - val_loss: 0.9093 - val_categorical_crossentropy: 0.9093 - val_categorical_accuracy: 0.5957
# Epoch 51/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6697 - categorical_crossentropy: 0.6697 - categorical_accuracy: 0.7292 - val_loss: 0.9036 - val_categorical_crossentropy: 0.9036 - val_categorical_accuracy: 0.5745
# Epoch 52/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6590 - categorical_crossentropy: 0.6590 - categorical_accuracy: 0.7333 - val_loss: 0.8950 - val_categorical_crossentropy: 0.8950 - val_categorical_accuracy: 0.6170
# Epoch 53/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6400 - categorical_crossentropy: 0.6400 - categorical_accuracy: 0.7875 - val_loss: 0.8673 - val_categorical_crossentropy: 0.8673 - val_categorical_accuracy: 0.5957
# Epoch 54/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6432 - categorical_crossentropy: 0.6432 - categorical_accuracy: 0.7333 - val_loss: 0.8479 - val_categorical_crossentropy: 0.8479 - val_categorical_accuracy: 0.6809
# Epoch 55/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6458 - categorical_crossentropy: 0.6458 - categorical_accuracy: 0.7625 - val_loss: 0.8316 - val_categorical_crossentropy: 0.8316 - val_categorical_accuracy: 0.6809
# Epoch 56/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6070 - categorical_crossentropy: 0.6070 - categorical_accuracy: 0.7833 - val_loss: 0.8373 - val_categorical_crossentropy: 0.8373 - val_categorical_accuracy: 0.7021
# Epoch 57/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6337 - categorical_crossentropy: 0.6337 - categorical_accuracy: 0.7542 - val_loss: 0.8235 - val_categorical_crossentropy: 0.8235 - val_categorical_accuracy: 0.6596
# Epoch 58/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6259 - categorical_crossentropy: 0.6259 - categorical_accuracy: 0.7875 - val_loss: 0.8036 - val_categorical_crossentropy: 0.8036 - val_categorical_accuracy: 0.6383
# Epoch 59/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6359 - categorical_crossentropy: 0.6359 - categorical_accuracy: 0.7750 - val_loss: 0.8017 - val_categorical_crossentropy: 0.8017 - val_categorical_accuracy: 0.6596
# Epoch 60/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6221 - categorical_crossentropy: 0.6221 - categorical_accuracy: 0.7625 - val_loss: 0.8067 - val_categorical_crossentropy: 0.8067 - val_categorical_accuracy: 0.6596
# Epoch 61/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6026 - categorical_crossentropy: 0.6026 - categorical_accuracy: 0.7708 - val_loss: 0.8268 - val_categorical_crossentropy: 0.8268 - val_categorical_accuracy: 0.6383
# Epoch 62/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6128 - categorical_crossentropy: 0.6128 - categorical_accuracy: 0.7792 - val_loss: 0.8170 - val_categorical_crossentropy: 0.8170 - val_categorical_accuracy: 0.6596
# Epoch 63/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6242 - categorical_crossentropy: 0.6242 - categorical_accuracy: 0.7958 - val_loss: 0.8178 - val_categorical_crossentropy: 0.8178 - val_categorical_accuracy: 0.6809
# Epoch 64/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6160 - categorical_crossentropy: 0.6160 - categorical_accuracy: 0.8000 - val_loss: 0.8096 - val_categorical_crossentropy: 0.8096 - val_categorical_accuracy: 0.6809
# Epoch 65/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5980 - categorical_crossentropy: 0.5980 - categorical_accuracy: 0.7500 - val_loss: 0.8072 - val_categorical_crossentropy: 0.8072 - val_categorical_accuracy: 0.6809
# Epoch 66/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6100 - categorical_crossentropy: 0.6100 - categorical_accuracy: 0.7833 - val_loss: 0.7955 - val_categorical_crossentropy: 0.7955 - val_categorical_accuracy: 0.6809
# Epoch 67/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6190 - categorical_crossentropy: 0.6190 - categorical_accuracy: 0.7958 - val_loss: 0.8022 - val_categorical_crossentropy: 0.8022 - val_categorical_accuracy: 0.6596
# Epoch 68/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5700 - categorical_crossentropy: 0.5700 - categorical_accuracy: 0.8042 - val_loss: 0.8116 - val_categorical_crossentropy: 0.8116 - val_categorical_accuracy: 0.6383
# Epoch 69/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5727 - categorical_crossentropy: 0.5727 - categorical_accuracy: 0.8208 - val_loss: 0.8160 - val_categorical_crossentropy: 0.8160 - val_categorical_accuracy: 0.6383
# Epoch 70/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5954 - categorical_crossentropy: 0.5954 - categorical_accuracy: 0.7792 - val_loss: 0.8295 - val_categorical_crossentropy: 0.8295 - val_categorical_accuracy: 0.6596
# Epoch 71/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6150 - categorical_crossentropy: 0.6150 - categorical_accuracy: 0.7375 - val_loss: 0.8286 - val_categorical_crossentropy: 0.8286 - val_categorical_accuracy: 0.6809
# Epoch 72/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6031 - categorical_crossentropy: 0.6031 - categorical_accuracy: 0.7917 - val_loss: 0.7971 - val_categorical_crossentropy: 0.7971 - val_categorical_accuracy: 0.7021
# Epoch 73/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5703 - categorical_crossentropy: 0.5703 - categorical_accuracy: 0.8000 - val_loss: 0.7852 - val_categorical_crossentropy: 0.7852 - val_categorical_accuracy: 0.6596
# Epoch 74/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5834 - categorical_crossentropy: 0.5834 - categorical_accuracy: 0.7750 - val_loss: 0.7874 - val_categorical_crossentropy: 0.7874 - val_categorical_accuracy: 0.6809
# Epoch 75/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5927 - categorical_crossentropy: 0.5927 - categorical_accuracy: 0.8125 - val_loss: 0.7834 - val_categorical_crossentropy: 0.7834 - val_categorical_accuracy: 0.7021
# Epoch 76/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5941 - categorical_crossentropy: 0.5941 - categorical_accuracy: 0.7917 - val_loss: 0.8135 - val_categorical_crossentropy: 0.8135 - val_categorical_accuracy: 0.7021
# Epoch 77/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5917 - categorical_crossentropy: 0.5917 - categorical_accuracy: 0.8125 - val_loss: 0.8257 - val_categorical_crossentropy: 0.8257 - val_categorical_accuracy: 0.7021
# Epoch 78/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5952 - categorical_crossentropy: 0.5952 - categorical_accuracy: 0.7833 - val_loss: 0.8170 - val_categorical_crossentropy: 0.8170 - val_categorical_accuracy: 0.7021
# Epoch 79/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5817 - categorical_crossentropy: 0.5817 - categorical_accuracy: 0.7917 - val_loss: 0.7965 - val_categorical_crossentropy: 0.7965 - val_categorical_accuracy: 0.7021
# Epoch 80/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5546 - categorical_crossentropy: 0.5546 - categorical_accuracy: 0.8417 - val_loss: 0.7828 - val_categorical_crossentropy: 0.7828 - val_categorical_accuracy: 0.7234
# Epoch 81/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5770 - categorical_crossentropy: 0.5770 - categorical_accuracy: 0.7958 - val_loss: 0.7761 - val_categorical_crossentropy: 0.7761 - val_categorical_accuracy: 0.7447
# Epoch 82/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5776 - categorical_crossentropy: 0.5776 - categorical_accuracy: 0.7958 - val_loss: 0.7671 - val_categorical_crossentropy: 0.7671 - val_categorical_accuracy: 0.7447
# Epoch 83/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5646 - categorical_crossentropy: 0.5646 - categorical_accuracy: 0.8083 - val_loss: 0.7592 - val_categorical_crossentropy: 0.7592 - val_categorical_accuracy: 0.7234
# Epoch 84/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5725 - categorical_crossentropy: 0.5725 - categorical_accuracy: 0.8125 - val_loss: 0.7569 - val_categorical_crossentropy: 0.7569 - val_categorical_accuracy: 0.7234
# Epoch 85/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5788 - categorical_crossentropy: 0.5788 - categorical_accuracy: 0.7833 - val_loss: 0.7585 - val_categorical_crossentropy: 0.7585 - val_categorical_accuracy: 0.7234
# Epoch 86/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5935 - categorical_crossentropy: 0.5935 - categorical_accuracy: 0.7917 - val_loss: 0.7604 - val_categorical_crossentropy: 0.7604 - val_categorical_accuracy: 0.7234
# Epoch 87/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5758 - categorical_crossentropy: 0.5758 - categorical_accuracy: 0.8292 - val_loss: 0.7593 - val_categorical_crossentropy: 0.7593 - val_categorical_accuracy: 0.7234
# Epoch 88/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5697 - categorical_crossentropy: 0.5697 - categorical_accuracy: 0.8042 - val_loss: 0.7660 - val_categorical_crossentropy: 0.7660 - val_categorical_accuracy: 0.7234
# Epoch 89/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5587 - categorical_crossentropy: 0.5587 - categorical_accuracy: 0.8208 - val_loss: 0.7808 - val_categorical_crossentropy: 0.7808 - val_categorical_accuracy: 0.7234
# Epoch 90/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5562 - categorical_crossentropy: 0.5562 - categorical_accuracy: 0.7917 - val_loss: 0.7903 - val_categorical_crossentropy: 0.7903 - val_categorical_accuracy: 0.7234
# Epoch 91/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5369 - categorical_crossentropy: 0.5369 - categorical_accuracy: 0.8208 - val_loss: 0.7775 - val_categorical_crossentropy: 0.7775 - val_categorical_accuracy: 0.7234
# Epoch 92/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5702 - categorical_crossentropy: 0.5702 - categorical_accuracy: 0.7875 - val_loss: 0.7841 - val_categorical_crossentropy: 0.7841 - val_categorical_accuracy: 0.7021
# Epoch 93/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5984 - categorical_crossentropy: 0.5984 - categorical_accuracy: 0.7833 - val_loss: 0.7885 - val_categorical_crossentropy: 0.7885 - val_categorical_accuracy: 0.7021
# Epoch 94/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5432 - categorical_crossentropy: 0.5432 - categorical_accuracy: 0.8167 - val_loss: 0.7801 - val_categorical_crossentropy: 0.7801 - val_categorical_accuracy: 0.7021
# Epoch 95/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5658 - categorical_crossentropy: 0.5658 - categorical_accuracy: 0.8042 - val_loss: 0.7566 - val_categorical_crossentropy: 0.7566 - val_categorical_accuracy: 0.7447
# Epoch 96/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5329 - categorical_crossentropy: 0.5329 - categorical_accuracy: 0.8375 - val_loss: 0.7388 - val_categorical_crossentropy: 0.7388 - val_categorical_accuracy: 0.7234
# Epoch 97/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5431 - categorical_crossentropy: 0.5431 - categorical_accuracy: 0.8083 - val_loss: 0.7359 - val_categorical_crossentropy: 0.7359 - val_categorical_accuracy: 0.7234
# Epoch 98/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5400 - categorical_crossentropy: 0.5400 - categorical_accuracy: 0.8083 - val_loss: 0.7600 - val_categorical_crossentropy: 0.7600 - val_categorical_accuracy: 0.7234
# Epoch 99/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5572 - categorical_crossentropy: 0.5572 - categorical_accuracy: 0.8125 - val_loss: 0.7619 - val_categorical_crossentropy: 0.7619 - val_categorical_accuracy: 0.7234
# Epoch 100/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5424 - categorical_crossentropy: 0.5424 - categorical_accuracy: 0.8292 - val_loss: 0.7384 - val_categorical_crossentropy: 0.7384 - val_categorical_accuracy: 0.7234
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# Train on 8 steps, validate on 2 steps
# Epoch 1/100
# 8/8 [==============================] - 0s 57ms/step - loss: 0.5244 - categorical_crossentropy: 0.5244 - categorical_accuracy: 0.8458 - val_loss: 0.7503 - val_categorical_crossentropy: 0.7503 - val_categorical_accuracy: 0.7660
# Epoch 2/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5428 - categorical_crossentropy: 0.5428 - categorical_accuracy: 0.8167 - val_loss: 0.7602 - val_categorical_crossentropy: 0.7602 - val_categorical_accuracy: 0.7447
# Epoch 3/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5417 - categorical_crossentropy: 0.5417 - categorical_accuracy: 0.8167 - val_loss: 0.7539 - val_categorical_crossentropy: 0.7539 - val_categorical_accuracy: 0.7660
# Epoch 4/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5460 - categorical_crossentropy: 0.5460 - categorical_accuracy: 0.8458 - val_loss: 0.7288 - val_categorical_crossentropy: 0.7288 - val_categorical_accuracy: 0.7660
# Epoch 5/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5263 - categorical_crossentropy: 0.5263 - categorical_accuracy: 0.8167 - val_loss: 0.7395 - val_categorical_crossentropy: 0.7395 - val_categorical_accuracy: 0.7447
# Epoch 6/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5216 - categorical_crossentropy: 0.5216 - categorical_accuracy: 0.8500 - val_loss: 0.7464 - val_categorical_crossentropy: 0.7464 - val_categorical_accuracy: 0.7234
# Epoch 7/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5402 - categorical_crossentropy: 0.5402 - categorical_accuracy: 0.8125 - val_loss: 0.7578 - val_categorical_crossentropy: 0.7578 - val_categorical_accuracy: 0.7447
# Epoch 8/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5196 - categorical_crossentropy: 0.5196 - categorical_accuracy: 0.8500 - val_loss: 0.7516 - val_categorical_crossentropy: 0.7516 - val_categorical_accuracy: 0.7447
# Epoch 9/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5213 - categorical_crossentropy: 0.5213 - categorical_accuracy: 0.8208 - val_loss: 0.7361 - val_categorical_crossentropy: 0.7361 - val_categorical_accuracy: 0.7447
# Epoch 10/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5240 - categorical_crossentropy: 0.5240 - categorical_accuracy: 0.8167 - val_loss: 0.7283 - val_categorical_crossentropy: 0.7283 - val_categorical_accuracy: 0.7021
# Epoch 11/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5226 - categorical_crossentropy: 0.5226 - categorical_accuracy: 0.8042 - val_loss: 0.7210 - val_categorical_crossentropy: 0.7210 - val_categorical_accuracy: 0.7234
# Epoch 12/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5410 - categorical_crossentropy: 0.5410 - categorical_accuracy: 0.8292 - val_loss: 0.7616 - val_categorical_crossentropy: 0.7616 - val_categorical_accuracy: 0.7234
# Epoch 13/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5146 - categorical_crossentropy: 0.5146 - categorical_accuracy: 0.8542 - val_loss: 0.7562 - val_categorical_crossentropy: 0.7562 - val_categorical_accuracy: 0.7234
# Epoch 14/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5071 - categorical_crossentropy: 0.5071 - categorical_accuracy: 0.8292 - val_loss: 0.7255 - val_categorical_crossentropy: 0.7255 - val_categorical_accuracy: 0.6809
# Epoch 15/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5208 - categorical_crossentropy: 0.5208 - categorical_accuracy: 0.8333 - val_loss: 0.7161 - val_categorical_crossentropy: 0.7161 - val_categorical_accuracy: 0.6809
# Epoch 16/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5603 - categorical_crossentropy: 0.5603 - categorical_accuracy: 0.7667 - val_loss: 0.7319 - val_categorical_crossentropy: 0.7319 - val_categorical_accuracy: 0.6809
# Epoch 17/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5268 - categorical_crossentropy: 0.5268 - categorical_accuracy: 0.8083 - val_loss: 0.7386 - val_categorical_crossentropy: 0.7386 - val_categorical_accuracy: 0.7234
# Epoch 18/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5139 - categorical_crossentropy: 0.5139 - categorical_accuracy: 0.8167 - val_loss: 0.7421 - val_categorical_crossentropy: 0.7421 - val_categorical_accuracy: 0.7234
# Epoch 19/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4982 - categorical_crossentropy: 0.4982 - categorical_accuracy: 0.8333 - val_loss: 0.7443 - val_categorical_crossentropy: 0.7443 - val_categorical_accuracy: 0.7234
# Epoch 20/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5224 - categorical_crossentropy: 0.5224 - categorical_accuracy: 0.8250 - val_loss: 0.7421 - val_categorical_crossentropy: 0.7421 - val_categorical_accuracy: 0.7021
# Epoch 21/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5058 - categorical_crossentropy: 0.5058 - categorical_accuracy: 0.8208 - val_loss: 0.7454 - val_categorical_crossentropy: 0.7454 - val_categorical_accuracy: 0.7447
# Epoch 22/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5099 - categorical_crossentropy: 0.5099 - categorical_accuracy: 0.8083 - val_loss: 0.7519 - val_categorical_crossentropy: 0.7519 - val_categorical_accuracy: 0.7021
# Epoch 23/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5107 - categorical_crossentropy: 0.5107 - categorical_accuracy: 0.8375 - val_loss: 0.7545 - val_categorical_crossentropy: 0.7545 - val_categorical_accuracy: 0.7021
# Epoch 24/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5257 - categorical_crossentropy: 0.5257 - categorical_accuracy: 0.8042 - val_loss: 0.7485 - val_categorical_crossentropy: 0.7485 - val_categorical_accuracy: 0.7021
# Epoch 25/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4819 - categorical_crossentropy: 0.4819 - categorical_accuracy: 0.8625 - val_loss: 0.7436 - val_categorical_crossentropy: 0.7436 - val_categorical_accuracy: 0.7021
# Epoch 26/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5134 - categorical_crossentropy: 0.5134 - categorical_accuracy: 0.8458 - val_loss: 0.7540 - val_categorical_crossentropy: 0.7540 - val_categorical_accuracy: 0.7021
# Epoch 27/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4935 - categorical_crossentropy: 0.4935 - categorical_accuracy: 0.8625 - val_loss: 0.7485 - val_categorical_crossentropy: 0.7485 - val_categorical_accuracy: 0.7234
# Epoch 28/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4927 - categorical_crossentropy: 0.4927 - categorical_accuracy: 0.8500 - val_loss: 0.7424 - val_categorical_crossentropy: 0.7424 - val_categorical_accuracy: 0.6809
# Epoch 29/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5127 - categorical_crossentropy: 0.5127 - categorical_accuracy: 0.8292 - val_loss: 0.7647 - val_categorical_crossentropy: 0.7647 - val_categorical_accuracy: 0.7021
# Epoch 30/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5035 - categorical_crossentropy: 0.5035 - categorical_accuracy: 0.8250 - val_loss: 0.7698 - val_categorical_crossentropy: 0.7698 - val_categorical_accuracy: 0.7234
# Epoch 31/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5044 - categorical_crossentropy: 0.5044 - categorical_accuracy: 0.8000 - val_loss: 0.7502 - val_categorical_crossentropy: 0.7502 - val_categorical_accuracy: 0.7021
# Epoch 32/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4909 - categorical_crossentropy: 0.4909 - categorical_accuracy: 0.8458 - val_loss: 0.7556 - val_categorical_crossentropy: 0.7556 - val_categorical_accuracy: 0.7021
# Epoch 33/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4896 - categorical_crossentropy: 0.4896 - categorical_accuracy: 0.8583 - val_loss: 0.7599 - val_categorical_crossentropy: 0.7599 - val_categorical_accuracy: 0.7021
# Epoch 34/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5017 - categorical_crossentropy: 0.5017 - categorical_accuracy: 0.8083 - val_loss: 0.7437 - val_categorical_crossentropy: 0.7437 - val_categorical_accuracy: 0.7021
# Epoch 35/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5025 - categorical_crossentropy: 0.5025 - categorical_accuracy: 0.8583 - val_loss: 0.7265 - val_categorical_crossentropy: 0.7265 - val_categorical_accuracy: 0.7447
# Epoch 36/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4721 - categorical_crossentropy: 0.4721 - categorical_accuracy: 0.8667 - val_loss: 0.7421 - val_categorical_crossentropy: 0.7421 - val_categorical_accuracy: 0.7234
# Epoch 37/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5042 - categorical_crossentropy: 0.5042 - categorical_accuracy: 0.8417 - val_loss: 0.7507 - val_categorical_crossentropy: 0.7507 - val_categorical_accuracy: 0.7021
# Epoch 38/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5044 - categorical_crossentropy: 0.5044 - categorical_accuracy: 0.8292 - val_loss: 0.7538 - val_categorical_crossentropy: 0.7538 - val_categorical_accuracy: 0.7021
# Epoch 39/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5020 - categorical_crossentropy: 0.5020 - categorical_accuracy: 0.8583 - val_loss: 0.7418 - val_categorical_crossentropy: 0.7418 - val_categorical_accuracy: 0.7021
# Epoch 40/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5080 - categorical_crossentropy: 0.5080 - categorical_accuracy: 0.8250 - val_loss: 0.7406 - val_categorical_crossentropy: 0.7406 - val_categorical_accuracy: 0.7021
# Epoch 41/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4865 - categorical_crossentropy: 0.4865 - categorical_accuracy: 0.7958 - val_loss: 0.7434 - val_categorical_crossentropy: 0.7434 - val_categorical_accuracy: 0.6809
# Epoch 42/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4966 - categorical_crossentropy: 0.4966 - categorical_accuracy: 0.8250 - val_loss: 0.7487 - val_categorical_crossentropy: 0.7487 - val_categorical_accuracy: 0.6809
# Epoch 43/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4797 - categorical_crossentropy: 0.4797 - categorical_accuracy: 0.8417 - val_loss: 0.7486 - val_categorical_crossentropy: 0.7486 - val_categorical_accuracy: 0.6809
# Epoch 44/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4772 - categorical_crossentropy: 0.4772 - categorical_accuracy: 0.8417 - val_loss: 0.7509 - val_categorical_crossentropy: 0.7509 - val_categorical_accuracy: 0.7021
# Epoch 45/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4820 - categorical_crossentropy: 0.4820 - categorical_accuracy: 0.8375 - val_loss: 0.7530 - val_categorical_crossentropy: 0.7530 - val_categorical_accuracy: 0.7021
# Epoch 46/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5087 - categorical_crossentropy: 0.5087 - categorical_accuracy: 0.8167 - val_loss: 0.7476 - val_categorical_crossentropy: 0.7476 - val_categorical_accuracy: 0.7021
# Epoch 47/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4712 - categorical_crossentropy: 0.4712 - categorical_accuracy: 0.8500 - val_loss: 0.7297 - val_categorical_crossentropy: 0.7297 - val_categorical_accuracy: 0.7021
# Epoch 48/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4636 - categorical_crossentropy: 0.4636 - categorical_accuracy: 0.8667 - val_loss: 0.7329 - val_categorical_crossentropy: 0.7329 - val_categorical_accuracy: 0.7234
# Epoch 49/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4782 - categorical_crossentropy: 0.4782 - categorical_accuracy: 0.8625 - val_loss: 0.7432 - val_categorical_crossentropy: 0.7432 - val_categorical_accuracy: 0.7234
# Epoch 50/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4598 - categorical_crossentropy: 0.4598 - categorical_accuracy: 0.8458 - val_loss: 0.7366 - val_categorical_crossentropy: 0.7366 - val_categorical_accuracy: 0.7021
# Epoch 51/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4814 - categorical_crossentropy: 0.4814 - categorical_accuracy: 0.8667 - val_loss: 0.7348 - val_categorical_crossentropy: 0.7348 - val_categorical_accuracy: 0.7021
# Epoch 52/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4811 - categorical_crossentropy: 0.4811 - categorical_accuracy: 0.8417 - val_loss: 0.7580 - val_categorical_crossentropy: 0.7580 - val_categorical_accuracy: 0.7021
# Epoch 53/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4831 - categorical_crossentropy: 0.4831 - categorical_accuracy: 0.8542 - val_loss: 0.7437 - val_categorical_crossentropy: 0.7437 - val_categorical_accuracy: 0.7021
# Epoch 54/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4916 - categorical_crossentropy: 0.4916 - categorical_accuracy: 0.8292 - val_loss: 0.7279 - val_categorical_crossentropy: 0.7279 - val_categorical_accuracy: 0.7234
# Epoch 55/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4794 - categorical_crossentropy: 0.4794 - categorical_accuracy: 0.8458 - val_loss: 0.7438 - val_categorical_crossentropy: 0.7438 - val_categorical_accuracy: 0.7021
# Epoch 56/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4631 - categorical_crossentropy: 0.4631 - categorical_accuracy: 0.8625 - val_loss: 0.7630 - val_categorical_crossentropy: 0.7630 - val_categorical_accuracy: 0.7234
# Epoch 57/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4613 - categorical_crossentropy: 0.4613 - categorical_accuracy: 0.8500 - val_loss: 0.7352 - val_categorical_crossentropy: 0.7352 - val_categorical_accuracy: 0.7234
# Epoch 58/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4657 - categorical_crossentropy: 0.4657 - categorical_accuracy: 0.8708 - val_loss: 0.7320 - val_categorical_crossentropy: 0.7320 - val_categorical_accuracy: 0.7021
# Epoch 59/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4720 - categorical_crossentropy: 0.4720 - categorical_accuracy: 0.8375 - val_loss: 0.7406 - val_categorical_crossentropy: 0.7406 - val_categorical_accuracy: 0.7021
# Epoch 60/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4576 - categorical_crossentropy: 0.4576 - categorical_accuracy: 0.8542 - val_loss: 0.7592 - val_categorical_crossentropy: 0.7592 - val_categorical_accuracy: 0.7447
# Epoch 61/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4582 - categorical_crossentropy: 0.4582 - categorical_accuracy: 0.8708 - val_loss: 0.7385 - val_categorical_crossentropy: 0.7385 - val_categorical_accuracy: 0.7234
# Epoch 62/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4737 - categorical_crossentropy: 0.4737 - categorical_accuracy: 0.8625 - val_loss: 0.7201 - val_categorical_crossentropy: 0.7201 - val_categorical_accuracy: 0.7021
# Epoch 63/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4336 - categorical_crossentropy: 0.4336 - categorical_accuracy: 0.8708 - val_loss: 0.7094 - val_categorical_crossentropy: 0.7094 - val_categorical_accuracy: 0.7021
# Epoch 64/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4582 - categorical_crossentropy: 0.4582 - categorical_accuracy: 0.8542 - val_loss: 0.7156 - val_categorical_crossentropy: 0.7156 - val_categorical_accuracy: 0.6809
# Epoch 65/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4514 - categorical_crossentropy: 0.4514 - categorical_accuracy: 0.8667 - val_loss: 0.7089 - val_categorical_crossentropy: 0.7089 - val_categorical_accuracy: 0.7021
# Epoch 66/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4548 - categorical_crossentropy: 0.4548 - categorical_accuracy: 0.8625 - val_loss: 0.7074 - val_categorical_crossentropy: 0.7074 - val_categorical_accuracy: 0.7021
# Epoch 67/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4574 - categorical_crossentropy: 0.4574 - categorical_accuracy: 0.8583 - val_loss: 0.7303 - val_categorical_crossentropy: 0.7303 - val_categorical_accuracy: 0.7234
# Epoch 68/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4694 - categorical_crossentropy: 0.4694 - categorical_accuracy: 0.8583 - val_loss: 0.7602 - val_categorical_crossentropy: 0.7602 - val_categorical_accuracy: 0.7234
# Epoch 69/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4420 - categorical_crossentropy: 0.4420 - categorical_accuracy: 0.8875 - val_loss: 0.7258 - val_categorical_crossentropy: 0.7258 - val_categorical_accuracy: 0.7447
# Epoch 70/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4629 - categorical_crossentropy: 0.4629 - categorical_accuracy: 0.8708 - val_loss: 0.7184 - val_categorical_crossentropy: 0.7184 - val_categorical_accuracy: 0.7234
# Epoch 71/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4588 - categorical_crossentropy: 0.4588 - categorical_accuracy: 0.8500 - val_loss: 0.7328 - val_categorical_crossentropy: 0.7328 - val_categorical_accuracy: 0.7234
# Epoch 72/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4501 - categorical_crossentropy: 0.4501 - categorical_accuracy: 0.8458 - val_loss: 0.7088 - val_categorical_crossentropy: 0.7088 - val_categorical_accuracy: 0.7660
# Epoch 73/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4603 - categorical_crossentropy: 0.4603 - categorical_accuracy: 0.8625 - val_loss: 0.7225 - val_categorical_crossentropy: 0.7225 - val_categorical_accuracy: 0.7447
# Epoch 74/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4542 - categorical_crossentropy: 0.4542 - categorical_accuracy: 0.8208 - val_loss: 0.7283 - val_categorical_crossentropy: 0.7283 - val_categorical_accuracy: 0.7234
# Epoch 75/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4762 - categorical_crossentropy: 0.4762 - categorical_accuracy: 0.8250 - val_loss: 0.7235 - val_categorical_crossentropy: 0.7235 - val_categorical_accuracy: 0.7660
# Epoch 76/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4276 - categorical_crossentropy: 0.4276 - categorical_accuracy: 0.8875 - val_loss: 0.7078 - val_categorical_crossentropy: 0.7078 - val_categorical_accuracy: 0.7447
# Epoch 77/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4621 - categorical_crossentropy: 0.4621 - categorical_accuracy: 0.8292 - val_loss: 0.7160 - val_categorical_crossentropy: 0.7160 - val_categorical_accuracy: 0.7447
# Epoch 78/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4568 - categorical_crossentropy: 0.4568 - categorical_accuracy: 0.8542 - val_loss: 0.7146 - val_categorical_crossentropy: 0.7146 - val_categorical_accuracy: 0.7447
# Epoch 79/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4623 - categorical_crossentropy: 0.4623 - categorical_accuracy: 0.8500 - val_loss: 0.6885 - val_categorical_crossentropy: 0.6885 - val_categorical_accuracy: 0.7234
# Epoch 80/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4625 - categorical_crossentropy: 0.4625 - categorical_accuracy: 0.8458 - val_loss: 0.6672 - val_categorical_crossentropy: 0.6672 - val_categorical_accuracy: 0.7872
# Epoch 81/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4424 - categorical_crossentropy: 0.4424 - categorical_accuracy: 0.8625 - val_loss: 0.6960 - val_categorical_crossentropy: 0.6960 - val_categorical_accuracy: 0.7447
# Epoch 82/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4443 - categorical_crossentropy: 0.4443 - categorical_accuracy: 0.8458 - val_loss: 0.7017 - val_categorical_crossentropy: 0.7017 - val_categorical_accuracy: 0.7660
# Epoch 83/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4198 - categorical_crossentropy: 0.4198 - categorical_accuracy: 0.9000 - val_loss: 0.7096 - val_categorical_crossentropy: 0.7096 - val_categorical_accuracy: 0.7021
# Epoch 84/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4764 - categorical_crossentropy: 0.4764 - categorical_accuracy: 0.8417 - val_loss: 0.7104 - val_categorical_crossentropy: 0.7104 - val_categorical_accuracy: 0.7660
# Epoch 85/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4512 - categorical_crossentropy: 0.4512 - categorical_accuracy: 0.8542 - val_loss: 0.7068 - val_categorical_crossentropy: 0.7068 - val_categorical_accuracy: 0.6383
# Epoch 86/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4481 - categorical_crossentropy: 0.4481 - categorical_accuracy: 0.8833 - val_loss: 0.7013 - val_categorical_crossentropy: 0.7013 - val_categorical_accuracy: 0.6596
# Epoch 87/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4488 - categorical_crossentropy: 0.4488 - categorical_accuracy: 0.8542 - val_loss: 0.6882 - val_categorical_crossentropy: 0.6882 - val_categorical_accuracy: 0.7447
# Epoch 88/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4403 - categorical_crossentropy: 0.4403 - categorical_accuracy: 0.8625 - val_loss: 0.6803 - val_categorical_crossentropy: 0.6803 - val_categorical_accuracy: 0.7447
# Epoch 89/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4353 - categorical_crossentropy: 0.4353 - categorical_accuracy: 0.8708 - val_loss: 0.6684 - val_categorical_crossentropy: 0.6684 - val_categorical_accuracy: 0.7447
# Epoch 90/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4594 - categorical_crossentropy: 0.4594 - categorical_accuracy: 0.8417 - val_loss: 0.6494 - val_categorical_crossentropy: 0.6494 - val_categorical_accuracy: 0.7872
# Epoch 91/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4439 - categorical_crossentropy: 0.4439 - categorical_accuracy: 0.8583 - val_loss: 0.6497 - val_categorical_crossentropy: 0.6497 - val_categorical_accuracy: 0.7660
# Epoch 92/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4310 - categorical_crossentropy: 0.4310 - categorical_accuracy: 0.8583 - val_loss: 0.6499 - val_categorical_crossentropy: 0.6499 - val_categorical_accuracy: 0.7872
# Epoch 93/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4094 - categorical_crossentropy: 0.4094 - categorical_accuracy: 0.8542 - val_loss: 0.6606 - val_categorical_crossentropy: 0.6606 - val_categorical_accuracy: 0.7234
# Epoch 94/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4441 - categorical_crossentropy: 0.4441 - categorical_accuracy: 0.8500 - val_loss: 0.6574 - val_categorical_crossentropy: 0.6574 - val_categorical_accuracy: 0.7660
# Epoch 95/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4444 - categorical_crossentropy: 0.4444 - categorical_accuracy: 0.8625 - val_loss: 0.6589 - val_categorical_crossentropy: 0.6589 - val_categorical_accuracy: 0.7660
# Epoch 96/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4423 - categorical_crossentropy: 0.4423 - categorical_accuracy: 0.8542 - val_loss: 0.6709 - val_categorical_crossentropy: 0.6709 - val_categorical_accuracy: 0.7660
# Epoch 97/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4244 - categorical_crossentropy: 0.4244 - categorical_accuracy: 0.8875 - val_loss: 0.6621 - val_categorical_crossentropy: 0.6621 - val_categorical_accuracy: 0.7021
# Epoch 98/100
# ...
# Epoch 36/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3294 - categorical_crossentropy: 0.3294 - categorical_accuracy: 0.9125 - val_loss: 0.5450 - val_categorical_crossentropy: 0.5450 - val_categorical_accuracy: 0.8085
# Epoch 37/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3210 - categorical_crossentropy: 0.3210 - categorical_accuracy: 0.9167 - val_loss: 0.5616 - val_categorical_crossentropy: 0.5616 - val_categorical_accuracy: 0.7660
# Epoch 38/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3025 - categorical_crossentropy: 0.3025 - categorical_accuracy: 0.9250 - val_loss: 0.5666 - val_categorical_crossentropy: 0.5666 - val_categorical_accuracy: 0.8085
# Epoch 39/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2982 - categorical_crossentropy: 0.2982 - categorical_accuracy: 0.9250 - val_loss: 0.5655 - val_categorical_crossentropy: 0.5655 - val_categorical_accuracy: 0.7872
# Epoch 40/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2799 - categorical_crossentropy: 0.2799 - categorical_accuracy: 0.9375 - val_loss: 0.5428 - val_categorical_crossentropy: 0.5428 - val_categorical_accuracy: 0.8085
# Epoch 41/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3032 - categorical_crossentropy: 0.3032 - categorical_accuracy: 0.9333 - val_loss: 0.5553 - val_categorical_crossentropy: 0.5553 - val_categorical_accuracy: 0.7660
# Epoch 42/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3347 - categorical_crossentropy: 0.3347 - categorical_accuracy: 0.9042 - val_loss: 0.5741 - val_categorical_crossentropy: 0.5741 - val_categorical_accuracy: 0.7872
# Epoch 43/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3330 - categorical_crossentropy: 0.3330 - categorical_accuracy: 0.8875 - val_loss: 0.5572 - val_categorical_crossentropy: 0.5572 - val_categorical_accuracy: 0.7872
# Epoch 44/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3090 - categorical_crossentropy: 0.3090 - categorical_accuracy: 0.9083 - val_loss: 0.5652 - val_categorical_crossentropy: 0.5652 - val_categorical_accuracy: 0.7872
# Epoch 45/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2883 - categorical_crossentropy: 0.2883 - categorical_accuracy: 0.9292 - val_loss: 0.5521 - val_categorical_crossentropy: 0.5521 - val_categorical_accuracy: 0.8085
# Epoch 46/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3093 - categorical_crossentropy: 0.3093 - categorical_accuracy: 0.9208 - val_loss: 0.5460 - val_categorical_crossentropy: 0.5460 - val_categorical_accuracy: 0.8085
# Epoch 47/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3106 - categorical_crossentropy: 0.3106 - categorical_accuracy: 0.9125 - val_loss: 0.5304 - val_categorical_crossentropy: 0.5304 - val_categorical_accuracy: 0.8085
# Epoch 48/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3083 - categorical_crossentropy: 0.3083 - categorical_accuracy: 0.9167 - val_loss: 0.5406 - val_categorical_crossentropy: 0.5406 - val_categorical_accuracy: 0.8085
# Epoch 49/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3034 - categorical_crossentropy: 0.3034 - categorical_accuracy: 0.9167 - val_loss: 0.5522 - val_categorical_crossentropy: 0.5522 - val_categorical_accuracy: 0.7872
# Epoch 50/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2924 - categorical_crossentropy: 0.2924 - categorical_accuracy: 0.9250 - val_loss: 0.5364 - val_categorical_crossentropy: 0.5364 - val_categorical_accuracy: 0.8085
# Epoch 51/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2838 - categorical_crossentropy: 0.2838 - categorical_accuracy: 0.9292 - val_loss: 0.5254 - val_categorical_crossentropy: 0.5254 - val_categorical_accuracy: 0.7872
# Epoch 52/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2808 - categorical_crossentropy: 0.2808 - categorical_accuracy: 0.9417 - val_loss: 0.5355 - val_categorical_crossentropy: 0.5355 - val_categorical_accuracy: 0.7872
# Epoch 53/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2696 - categorical_crossentropy: 0.2696 - categorical_accuracy: 0.9417 - val_loss: 0.5300 - val_categorical_crossentropy: 0.5300 - val_categorical_accuracy: 0.7872
# Epoch 54/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2781 - categorical_crossentropy: 0.2781 - categorical_accuracy: 0.9292 - val_loss: 0.5236 - val_categorical_crossentropy: 0.5236 - val_categorical_accuracy: 0.7872
# Epoch 55/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2809 - categorical_crossentropy: 0.2809 - categorical_accuracy: 0.9167 - val_loss: 0.5187 - val_categorical_crossentropy: 0.5187 - val_categorical_accuracy: 0.8085
# Epoch 56/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3061 - categorical_crossentropy: 0.3061 - categorical_accuracy: 0.9375 - val_loss: 0.5183 - val_categorical_crossentropy: 0.5183 - val_categorical_accuracy: 0.7872
# Epoch 57/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2887 - categorical_crossentropy: 0.2887 - categorical_accuracy: 0.9125 - val_loss: 0.5588 - val_categorical_crossentropy: 0.5588 - val_categorical_accuracy: 0.8085
# Epoch 58/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2818 - categorical_crossentropy: 0.2818 - categorical_accuracy: 0.9292 - val_loss: 0.5677 - val_categorical_crossentropy: 0.5677 - val_categorical_accuracy: 0.7660
# Epoch 59/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2857 - categorical_crossentropy: 0.2857 - categorical_accuracy: 0.9250 - val_loss: 0.5779 - val_categorical_crossentropy: 0.5779 - val_categorical_accuracy: 0.7660
# Epoch 60/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2672 - categorical_crossentropy: 0.2672 - categorical_accuracy: 0.9375 - val_loss: 0.5742 - val_categorical_crossentropy: 0.5742 - val_categorical_accuracy: 0.8085
# Epoch 61/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2725 - categorical_crossentropy: 0.2725 - categorical_accuracy: 0.9375 - val_loss: 0.5567 - val_categorical_crossentropy: 0.5567 - val_categorical_accuracy: 0.7872
# Epoch 62/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3030 - categorical_crossentropy: 0.3030 - categorical_accuracy: 0.9042 - val_loss: 0.5529 - val_categorical_crossentropy: 0.5529 - val_categorical_accuracy: 0.7660
# Epoch 63/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2790 - categorical_crossentropy: 0.2790 - categorical_accuracy: 0.9292 - val_loss: 0.5539 - val_categorical_crossentropy: 0.5539 - val_categorical_accuracy: 0.7872
# Epoch 64/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2619 - categorical_crossentropy: 0.2619 - categorical_accuracy: 0.9417 - val_loss: 0.5426 - val_categorical_crossentropy: 0.5426 - val_categorical_accuracy: 0.7872
# Epoch 65/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2855 - categorical_crossentropy: 0.2855 - categorical_accuracy: 0.9208 - val_loss: 0.5553 - val_categorical_crossentropy: 0.5553 - val_categorical_accuracy: 0.7234
# Epoch 66/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2929 - categorical_crossentropy: 0.2929 - categorical_accuracy: 0.9042 - val_loss: 0.5566 - val_categorical_crossentropy: 0.5566 - val_categorical_accuracy: 0.7872
# Epoch 67/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2826 - categorical_crossentropy: 0.2826 - categorical_accuracy: 0.9417 - val_loss: 0.5629 - val_categorical_crossentropy: 0.5629 - val_categorical_accuracy: 0.7660
# Epoch 68/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3012 - categorical_crossentropy: 0.3012 - categorical_accuracy: 0.9125 - val_loss: 0.5686 - val_categorical_crossentropy: 0.5686 - val_categorical_accuracy: 0.7872
# Epoch 69/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2720 - categorical_crossentropy: 0.2720 - categorical_accuracy: 0.9292 - val_loss: 0.5517 - val_categorical_crossentropy: 0.5517 - val_categorical_accuracy: 0.7872
# Epoch 70/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2642 - categorical_crossentropy: 0.2642 - categorical_accuracy: 0.9292 - val_loss: 0.5384 - val_categorical_crossentropy: 0.5384 - val_categorical_accuracy: 0.7872
# Epoch 71/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3073 - categorical_crossentropy: 0.3073 - categorical_accuracy: 0.9208 - val_loss: 0.5506 - val_categorical_crossentropy: 0.5506 - val_categorical_accuracy: 0.8085
# Epoch 72/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2461 - categorical_crossentropy: 0.2461 - categorical_accuracy: 0.9542 - val_loss: 0.5554 - val_categorical_crossentropy: 0.5554 - val_categorical_accuracy: 0.7872
# Epoch 73/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2419 - categorical_crossentropy: 0.2419 - categorical_accuracy: 0.9667 - val_loss: 0.5427 - val_categorical_crossentropy: 0.5427 - val_categorical_accuracy: 0.7872
# Epoch 74/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2929 - categorical_crossentropy: 0.2929 - categorical_accuracy: 0.9208 - val_loss: 0.5317 - val_categorical_crossentropy: 0.5317 - val_categorical_accuracy: 0.7872
# Epoch 75/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2514 - categorical_crossentropy: 0.2514 - categorical_accuracy: 0.9292 - val_loss: 0.5259 - val_categorical_crossentropy: 0.5259 - val_categorical_accuracy: 0.7660
# Epoch 76/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2638 - categorical_crossentropy: 0.2638 - categorical_accuracy: 0.9292 - val_loss: 0.5488 - val_categorical_crossentropy: 0.5488 - val_categorical_accuracy: 0.7872
# Epoch 77/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2546 - categorical_crossentropy: 0.2546 - categorical_accuracy: 0.9333 - val_loss: 0.5498 - val_categorical_crossentropy: 0.5498 - val_categorical_accuracy: 0.7447
# Epoch 78/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2667 - categorical_crossentropy: 0.2667 - categorical_accuracy: 0.9458 - val_loss: 0.5515 - val_categorical_crossentropy: 0.5515 - val_categorical_accuracy: 0.7447
# Epoch 79/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2635 - categorical_crossentropy: 0.2635 - categorical_accuracy: 0.9417 - val_loss: 0.5282 - val_categorical_crossentropy: 0.5282 - val_categorical_accuracy: 0.7447
# Epoch 80/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2792 - categorical_crossentropy: 0.2792 - categorical_accuracy: 0.9125 - val_loss: 0.5383 - val_categorical_crossentropy: 0.5383 - val_categorical_accuracy: 0.7447
# Epoch 81/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2399 - categorical_crossentropy: 0.2399 - categorical_accuracy: 0.9292 - val_loss: 0.5477 - val_categorical_crossentropy: 0.5477 - val_categorical_accuracy: 0.7872
# Epoch 82/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2559 - categorical_crossentropy: 0.2559 - categorical_accuracy: 0.9208 - val_loss: 0.5314 - val_categorical_crossentropy: 0.5314 - val_categorical_accuracy: 0.7872
# Epoch 83/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2547 - categorical_crossentropy: 0.2547 - categorical_accuracy: 0.9417 - val_loss: 0.5351 - val_categorical_crossentropy: 0.5351 - val_categorical_accuracy: 0.7660
# Epoch 84/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2586 - categorical_crossentropy: 0.2586 - categorical_accuracy: 0.9250 - val_loss: 0.5605 - val_categorical_crossentropy: 0.5605 - val_categorical_accuracy: 0.7872
# Epoch 85/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2469 - categorical_crossentropy: 0.2469 - categorical_accuracy: 0.9333 - val_loss: 0.5900 - val_categorical_crossentropy: 0.5900 - val_categorical_accuracy: 0.7660
# Epoch 86/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2532 - categorical_crossentropy: 0.2532 - categorical_accuracy: 0.9417 - val_loss: 0.6326 - val_categorical_crossentropy: 0.6326 - val_categorical_accuracy: 0.7660
# Epoch 87/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2664 - categorical_crossentropy: 0.2664 - categorical_accuracy: 0.9292 - val_loss: 0.5616 - val_categorical_crossentropy: 0.5616 - val_categorical_accuracy: 0.7660
# Epoch 88/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2355 - categorical_crossentropy: 0.2355 - categorical_accuracy: 0.9458 - val_loss: 0.5472 - val_categorical_crossentropy: 0.5472 - val_categorical_accuracy: 0.8085
# Epoch 89/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2589 - categorical_crossentropy: 0.2589 - categorical_accuracy: 0.9208 - val_loss: 0.5403 - val_categorical_crossentropy: 0.5403 - val_categorical_accuracy: 0.8298
# Epoch 90/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2812 - categorical_crossentropy: 0.2812 - categorical_accuracy: 0.9167 - val_loss: 0.5402 - val_categorical_crossentropy: 0.5402 - val_categorical_accuracy: 0.7872
# Epoch 91/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2609 - categorical_crossentropy: 0.2609 - categorical_accuracy: 0.9417 - val_loss: 0.5166 - val_categorical_crossentropy: 0.5166 - val_categorical_accuracy: 0.7660
# Epoch 92/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2776 - categorical_crossentropy: 0.2776 - categorical_accuracy: 0.9208 - val_loss: 0.5062 - val_categorical_crossentropy: 0.5062 - val_categorical_accuracy: 0.7660
# Epoch 93/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2498 - categorical_crossentropy: 0.2498 - categorical_accuracy: 0.9417 - val_loss: 0.5158 - val_categorical_crossentropy: 0.5158 - val_categorical_accuracy: 0.7872
# Epoch 94/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2328 - categorical_crossentropy: 0.2328 - categorical_accuracy: 0.9625 - val_loss: 0.5116 - val_categorical_crossentropy: 0.5116 - val_categorical_accuracy: 0.7234
# Epoch 95/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2433 - categorical_crossentropy: 0.2433 - categorical_accuracy: 0.9375 - val_loss: 0.5257 - val_categorical_crossentropy: 0.5257 - val_categorical_accuracy: 0.7660
# Epoch 96/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2489 - categorical_crossentropy: 0.2489 - categorical_accuracy: 0.9417 - val_loss: 0.5290 - val_categorical_crossentropy: 0.5290 - val_categorical_accuracy: 0.7872
# Epoch 97/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2356 - categorical_crossentropy: 0.2356 - categorical_accuracy: 0.9375 - val_loss: 0.5505 - val_categorical_crossentropy: 0.5505 - val_categorical_accuracy: 0.7660
# Epoch 98/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2562 - categorical_crossentropy: 0.2562 - categorical_accuracy: 0.9208 - val_loss: 0.5413 - val_categorical_crossentropy: 0.5413 - val_categorical_accuracy: 0.7660
# Epoch 99/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2409 - categorical_crossentropy: 0.2409 - categorical_accuracy: 0.9458 - val_loss: 0.5388 - val_categorical_crossentropy: 0.5388 - val_categorical_accuracy: 0.7660
# Epoch 100/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2342 - categorical_crossentropy: 0.2342 - categorical_accuracy: 0.9458 - val_loss: 0.5639 - val_categorical_crossentropy: 0.5639 - val_categorical_accuracy: 0.7447
# # Evaluate on test data
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4688 - categorical_crossentropy: 0.4688 - categorical_accuracy: 0.8368
# test loss, test acc: [0.4687746398978763, 0.4687746, 0.8368056]
# [[0.64139336 0.7048611 ]
#  [1.1849792  0.50694442]
#  [0.50497353 0.7951389 ]
#  [0.9695695  0.58680558]
#  [1.27921605 0.43055555]
#  [1.16837561 0.48958334]
#  [0.52182579 0.81597221]
#  [0.67239505 0.7326389 ]
#  [0.46877459 0.83680558]]
