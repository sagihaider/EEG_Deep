# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_Single_Trial_Classification_EEGNet_NSL_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 247, done.
# remote: Total 247 (delta 0), reused 0 (delta 0), pack-reused 247
# Receiving objects: 100% (247/247), 1.07 GiB | 40.12 MiB/s, done.
# Resolving deltas: 100% (104/104), done.
# Checking out files: 100% (70/70), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting neural_structured_learning
#   Downloading https://files.pythonhosted.org/packages/08/2e/22b1385d7d601ad0c81457a5b66b3bb6f3c400348c62ea3f07a5fc1b13bc/neural_structured_learning-1.1.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 4.6MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.3.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.4)
# Installing collected packages: neural-structured-learning
# Successfully installed neural-structured-learning-1.1.0

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()
cols = 2
rows = 9
acc_all = zeros([rows, cols])
X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])


for x in range(1,10):
  fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_tr = mat['cleanRawEEGData']
  y_tr = mat['cleanClassLabels']
  
  print(np.shape(r_X_tr))
  print(np.shape(y_tr))

  for t in range(r_X_tr.shape[0]):
    tril = r_X_tr[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_tr[t,:,:] = tril_filtered 
    
  # split data of each subject in training and validation
  X_train      = X_tr[0:240,:,500:1250]
  Y_train      = y_tr[0:240]
  X_val       = X_tr[241:,:,500:1250]
  Y_val       = y_tr[241:]

  print(np.shape(X_train))
  print(np.shape(Y_train))
  print(np.shape(X_val))
  print(np.shape(Y_val))
  
  # convert labels to one-hot encodings.
  Y_train      = np_utils.to_categorical(Y_train-1)
  Y_val       = np_utils.to_categorical(Y_val-1)

  kernels, chans, samples = 1, 22, 750
  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
  X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
  print('X_train shape:', X_train.shape)
  print(X_train.shape[0], 'train samples')
  print(X_val.shape[0], 'val samples')

  # Load test data         
  fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
  print(fName)
  mat = spio.loadmat(fName)
  r_X_ts = mat['cleanRawEEGData']
  y_ts = mat['cleanClassLabels']

  print(np.shape(r_X_ts))
  print(np.shape(y_ts))

  for t in range(r_X_ts.shape[0]):
    tril = r_X_ts[t,:,:]
    # tril = tril.transpose()
    tril_filtered = butter_bandpass_filter(tril, 
                                              lowcut=4, 
                                              highcut=40, 
                                              fs=250,
                                              order=4)
    # tril_filtered = tril_filtered.transpose()
    X_ts[t,:,:] = tril_filtered 

  X_test      = X_ts[:,:,500:1250]
  Y_test      = y_ts[:]
  print(np.shape(X_test))
  print(np.shape(Y_test))

  #convert labels to one-hot encodings.
  Y_test      = np_utils.to_categorical(Y_test-1)

  # convert data to NCHW (trials, kernels, channels, samples) format. Data 
  # contains 22 channels and 500 time-points. Set the number of kernels to 1.
  X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

  print('X_train shape:', X_test.shape)
  print(X_test.shape[0], 'train samples')

  # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
  # model configurations may do better, but this is a good starting point)
  model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                 dropoutRate = 0.5, kernLength = 25, F1 = 8, 
                 D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

  adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
  adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
  # compile the model and set the optimizers
  adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
  batch_size = 32

  X_train = tf.cast(X_train, tf.float32)
  X_test = tf.cast(X_test, tf.float32)
  X_val = tf.cast(X_val, tf.float32)


  train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
  val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
  test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)

  val_steps = X_val.shape[0] // batch_size

  
  # adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=500, verbose=1)

  history = adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=500, verbose=1)

  # Plot training & validation accuracy values
  plt.plot(history.history['categorical_accuracy'])
  plt.plot(history.history['val_categorical_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  figName = 'Accuracy_A0' + str(x) + '.png'  
  plt.savefig(figName)

  print('\n# Evaluate on test data')
  results = adv_model.evaluate(test_data)
  print('test loss, test acc:', results)

  acc_all[x - 1, 0] = results[1]
  acc_all[x - 1, 1] = results[2]

  from keras import backend as K 
  # Do some code, e.g. train and save model
  K.clear_session()


print(acc_all)
# Out:
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288, 1)
# (240, 22, 750)
# (240, 1)
# (47, 22, 750)
# (47, 1)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/500
# 8/8 [==============================] - 0s 53ms/step - loss: 1.4017 - categorical_crossentropy: 1.4017 - categorical_accuracy: 0.2958 - val_loss: 1.3825 - val_categorical_crossentropy: 1.3825 - val_categorical_accuracy: 0.2553
# Epoch 2/500
# 8/8 [==============================] - 0s 16ms/step - loss: 1.3697 - categorical_crossentropy: 1.3697 - categorical_accuracy: 0.3250 - val_loss: 1.3801 - val_categorical_crossentropy: 1.3801 - val_categorical_accuracy: 0.2553
# Epoch 3/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3437 - categorical_crossentropy: 1.3437 - categorical_accuracy: 0.3958 - val_loss: 1.3776 - val_categorical_crossentropy: 1.3776 - val_categorical_accuracy: 0.3191
# Epoch 4/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3400 - categorical_crossentropy: 1.3400 - categorical_accuracy: 0.3708 - val_loss: 1.3735 - val_categorical_crossentropy: 1.3735 - val_categorical_accuracy: 0.4043
# Epoch 5/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3145 - categorical_crossentropy: 1.3145 - categorical_accuracy: 0.3833 - val_loss: 1.3675 - val_categorical_crossentropy: 1.3675 - val_categorical_accuracy: 0.4894
# Epoch 6/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.2798 - categorical_crossentropy: 1.2798 - categorical_accuracy: 0.4375 - val_loss: 1.3578 - val_categorical_crossentropy: 1.3578 - val_categorical_accuracy: 0.5957
# Epoch 7/500
# 8/8 [==============================] - 0s 16ms/step - loss: 1.2426 - categorical_crossentropy: 1.2426 - categorical_accuracy: 0.4458 - val_loss: 1.3428 - val_categorical_crossentropy: 1.3428 - val_categorical_accuracy: 0.5319
# Epoch 8/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1861 - categorical_crossentropy: 1.1861 - categorical_accuracy: 0.5375 - val_loss: 1.3197 - val_categorical_crossentropy: 1.3197 - val_categorical_accuracy: 0.4255
# Epoch 9/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.1303 - categorical_crossentropy: 1.1303 - categorical_accuracy: 0.5125 - val_loss: 1.2911 - val_categorical_crossentropy: 1.2911 - val_categorical_accuracy: 0.4255
# Epoch 10/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0680 - categorical_crossentropy: 1.0680 - categorical_accuracy: 0.5250 - val_loss: 1.2640 - val_categorical_crossentropy: 1.2640 - val_categorical_accuracy: 0.5532
# Epoch 11/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0041 - categorical_crossentropy: 1.0041 - categorical_accuracy: 0.5583 - val_loss: 1.2403 - val_categorical_crossentropy: 1.2403 - val_categorical_accuracy: 0.5532
# Epoch 12/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9582 - categorical_crossentropy: 0.9582 - categorical_accuracy: 0.6458 - val_loss: 1.2207 - val_categorical_crossentropy: 1.2207 - val_categorical_accuracy: 0.4043
# Epoch 13/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9191 - categorical_crossentropy: 0.9191 - categorical_accuracy: 0.6125 - val_loss: 1.2149 - val_categorical_crossentropy: 1.2149 - val_categorical_accuracy: 0.3830
# Epoch 14/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9049 - categorical_crossentropy: 0.9049 - categorical_accuracy: 0.5792 - val_loss: 1.2189 - val_categorical_crossentropy: 1.2189 - val_categorical_accuracy: 0.2979
# Epoch 15/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8554 - categorical_crossentropy: 0.8554 - categorical_accuracy: 0.6792 - val_loss: 1.2217 - val_categorical_crossentropy: 1.2217 - val_categorical_accuracy: 0.2766
# Epoch 16/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8593 - categorical_crossentropy: 0.8593 - categorical_accuracy: 0.6500 - val_loss: 1.2284 - val_categorical_crossentropy: 1.2284 - val_categorical_accuracy: 0.2766
# Epoch 17/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8563 - categorical_crossentropy: 0.8563 - categorical_accuracy: 0.6625 - val_loss: 1.2434 - val_categorical_crossentropy: 1.2434 - val_categorical_accuracy: 0.2766
# Epoch 18/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8137 - categorical_crossentropy: 0.8137 - categorical_accuracy: 0.6750 - val_loss: 1.2485 - val_categorical_crossentropy: 1.2485 - val_categorical_accuracy: 0.2766
# Epoch 19/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8282 - categorical_crossentropy: 0.8282 - categorical_accuracy: 0.6542 - val_loss: 1.2582 - val_categorical_crossentropy: 1.2582 - val_categorical_accuracy: 0.2766
# Epoch 20/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8188 - categorical_crossentropy: 0.8188 - categorical_accuracy: 0.6708 - val_loss: 1.2707 - val_categorical_crossentropy: 1.2707 - val_categorical_accuracy: 0.2979
# Epoch 21/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8056 - categorical_crossentropy: 0.8056 - categorical_accuracy: 0.7250 - val_loss: 1.2600 - val_categorical_crossentropy: 1.2600 - val_categorical_accuracy: 0.2979
# Epoch 22/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7871 - categorical_crossentropy: 0.7871 - categorical_accuracy: 0.7083 - val_loss: 1.2676 - val_categorical_crossentropy: 1.2676 - val_categorical_accuracy: 0.2979
# Epoch 23/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7724 - categorical_crossentropy: 0.7724 - categorical_accuracy: 0.7125 - val_loss: 1.2443 - val_categorical_crossentropy: 1.2443 - val_categorical_accuracy: 0.2979
# Epoch 24/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7931 - categorical_crossentropy: 0.7931 - categorical_accuracy: 0.6792 - val_loss: 1.2127 - val_categorical_crossentropy: 1.2127 - val_categorical_accuracy: 0.3404
# Epoch 25/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7464 - categorical_crossentropy: 0.7464 - categorical_accuracy: 0.7292 - val_loss: 1.1943 - val_categorical_crossentropy: 1.1943 - val_categorical_accuracy: 0.3830
# Epoch 26/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7647 - categorical_crossentropy: 0.7647 - categorical_accuracy: 0.7042 - val_loss: 1.2060 - val_categorical_crossentropy: 1.2060 - val_categorical_accuracy: 0.3830
# Epoch 27/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7745 - categorical_crossentropy: 0.7745 - categorical_accuracy: 0.6625 - val_loss: 1.2213 - val_categorical_crossentropy: 1.2213 - val_categorical_accuracy: 0.3404
# Epoch 28/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7748 - categorical_crossentropy: 0.7748 - categorical_accuracy: 0.7000 - val_loss: 1.1981 - val_categorical_crossentropy: 1.1981 - val_categorical_accuracy: 0.4255
# Epoch 29/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7704 - categorical_crossentropy: 0.7704 - categorical_accuracy: 0.6750 - val_loss: 1.1728 - val_categorical_crossentropy: 1.1728 - val_categorical_accuracy: 0.4043
# Epoch 30/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7343 - categorical_crossentropy: 0.7343 - categorical_accuracy: 0.7250 - val_loss: 1.1435 - val_categorical_crossentropy: 1.1435 - val_categorical_accuracy: 0.4043
# Epoch 31/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7518 - categorical_crossentropy: 0.7518 - categorical_accuracy: 0.7083 - val_loss: 1.1281 - val_categorical_crossentropy: 1.1281 - val_categorical_accuracy: 0.4468
# Epoch 32/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7353 - categorical_crossentropy: 0.7353 - categorical_accuracy: 0.7083 - val_loss: 1.1172 - val_categorical_crossentropy: 1.1172 - val_categorical_accuracy: 0.4468
# Epoch 33/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7655 - categorical_crossentropy: 0.7655 - categorical_accuracy: 0.7000 - val_loss: 1.0961 - val_categorical_crossentropy: 1.0961 - val_categorical_accuracy: 0.4681
# Epoch 34/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7241 - categorical_crossentropy: 0.7241 - categorical_accuracy: 0.7125 - val_loss: 1.0864 - val_categorical_crossentropy: 1.0864 - val_categorical_accuracy: 0.4681
# Epoch 35/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7268 - categorical_crossentropy: 0.7268 - categorical_accuracy: 0.7208 - val_loss: 1.0723 - val_categorical_crossentropy: 1.0723 - val_categorical_accuracy: 0.4255
# Epoch 36/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7012 - categorical_crossentropy: 0.7012 - categorical_accuracy: 0.7208 - val_loss: 1.0485 - val_categorical_crossentropy: 1.0485 - val_categorical_accuracy: 0.4255
# Epoch 37/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6844 - categorical_crossentropy: 0.6844 - categorical_accuracy: 0.8125 - val_loss: 1.0404 - val_categorical_crossentropy: 1.0404 - val_categorical_accuracy: 0.4468
# Epoch 38/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7002 - categorical_crossentropy: 0.7002 - categorical_accuracy: 0.7125 - val_loss: 1.0412 - val_categorical_crossentropy: 1.0412 - val_categorical_accuracy: 0.4468
# Epoch 39/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6944 - categorical_crossentropy: 0.6944 - categorical_accuracy: 0.7625 - val_loss: 1.0187 - val_categorical_crossentropy: 1.0187 - val_categorical_accuracy: 0.5319
# Epoch 40/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6806 - categorical_crossentropy: 0.6806 - categorical_accuracy: 0.7625 - val_loss: 0.9819 - val_categorical_crossentropy: 0.9819 - val_categorical_accuracy: 0.5319
# Epoch 41/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6845 - categorical_crossentropy: 0.6845 - categorical_accuracy: 0.7542 - val_loss: 0.9793 - val_categorical_crossentropy: 0.9793 - val_categorical_accuracy: 0.5106
# Epoch 42/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6840 - categorical_crossentropy: 0.6840 - categorical_accuracy: 0.7042 - val_loss: 0.9554 - val_categorical_crossentropy: 0.9554 - val_categorical_accuracy: 0.5532
# Epoch 43/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6818 - categorical_crossentropy: 0.6818 - categorical_accuracy: 0.7458 - val_loss: 0.9250 - val_categorical_crossentropy: 0.9250 - val_categorical_accuracy: 0.5745
# Epoch 44/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6841 - categorical_crossentropy: 0.6841 - categorical_accuracy: 0.7333 - val_loss: 0.9183 - val_categorical_crossentropy: 0.9183 - val_categorical_accuracy: 0.5532
# Epoch 45/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6755 - categorical_crossentropy: 0.6755 - categorical_accuracy: 0.7333 - val_loss: 0.9060 - val_categorical_crossentropy: 0.9060 - val_categorical_accuracy: 0.5957
# Epoch 46/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6877 - categorical_crossentropy: 0.6877 - categorical_accuracy: 0.7417 - val_loss: 0.8914 - val_categorical_crossentropy: 0.8914 - val_categorical_accuracy: 0.6596
# Epoch 47/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6918 - categorical_crossentropy: 0.6918 - categorical_accuracy: 0.7208 - val_loss: 0.8857 - val_categorical_crossentropy: 0.8857 - val_categorical_accuracy: 0.6596
# Epoch 48/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6494 - categorical_crossentropy: 0.6494 - categorical_accuracy: 0.7583 - val_loss: 0.8831 - val_categorical_crossentropy: 0.8831 - val_categorical_accuracy: 0.6809
# Epoch 49/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6497 - categorical_crossentropy: 0.6497 - categorical_accuracy: 0.7875 - val_loss: 0.8720 - val_categorical_crossentropy: 0.8720 - val_categorical_accuracy: 0.7021
# Epoch 50/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6457 - categorical_crossentropy: 0.6457 - categorical_accuracy: 0.7792 - val_loss: 0.8562 - val_categorical_crossentropy: 0.8562 - val_categorical_accuracy: 0.6809
# Epoch 51/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6478 - categorical_crossentropy: 0.6478 - categorical_accuracy: 0.7500 - val_loss: 0.8501 - val_categorical_crossentropy: 0.8501 - val_categorical_accuracy: 0.7021
# Epoch 52/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6488 - categorical_crossentropy: 0.6488 - categorical_accuracy: 0.7625 - val_loss: 0.8697 - val_categorical_crossentropy: 0.8697 - val_categorical_accuracy: 0.6809
# Epoch 53/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6252 - categorical_crossentropy: 0.6252 - categorical_accuracy: 0.8083 - val_loss: 0.8705 - val_categorical_crossentropy: 0.8705 - val_categorical_accuracy: 0.7021
# Epoch 54/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6575 - categorical_crossentropy: 0.6575 - categorical_accuracy: 0.7375 - val_loss: 0.8495 - val_categorical_crossentropy: 0.8495 - val_categorical_accuracy: 0.7021
# Epoch 55/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6463 - categorical_crossentropy: 0.6463 - categorical_accuracy: 0.8083 - val_loss: 0.8417 - val_categorical_crossentropy: 0.8417 - val_categorical_accuracy: 0.7234
# Epoch 56/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6337 - categorical_crossentropy: 0.6337 - categorical_accuracy: 0.7708 - val_loss: 0.8335 - val_categorical_crossentropy: 0.8335 - val_categorical_accuracy: 0.6596
# Epoch 57/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6428 - categorical_crossentropy: 0.6428 - categorical_accuracy: 0.7833 - val_loss: 0.8163 - val_categorical_crossentropy: 0.8163 - val_categorical_accuracy: 0.7021
# Epoch 58/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6293 - categorical_crossentropy: 0.6293 - categorical_accuracy: 0.7958 - val_loss: 0.8152 - val_categorical_crossentropy: 0.8152 - val_categorical_accuracy: 0.7234
# Epoch 59/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6454 - categorical_crossentropy: 0.6454 - categorical_accuracy: 0.7875 - val_loss: 0.8101 - val_categorical_crossentropy: 0.8101 - val_categorical_accuracy: 0.7021
# Epoch 60/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6418 - categorical_crossentropy: 0.6418 - categorical_accuracy: 0.7542 - val_loss: 0.8008 - val_categorical_crossentropy: 0.8008 - val_categorical_accuracy: 0.7234
# Epoch 61/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6301 - categorical_crossentropy: 0.6301 - categorical_accuracy: 0.7667 - val_loss: 0.7866 - val_categorical_crossentropy: 0.7866 - val_categorical_accuracy: 0.7234
# Epoch 62/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6392 - categorical_crossentropy: 0.6392 - categorical_accuracy: 0.7708 - val_loss: 0.7781 - val_categorical_crossentropy: 0.7781 - val_categorical_accuracy: 0.7234
# Epoch 63/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6150 - categorical_crossentropy: 0.6150 - categorical_accuracy: 0.7833 - val_loss: 0.7845 - val_categorical_crossentropy: 0.7845 - val_categorical_accuracy: 0.7234
# Epoch 64/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6400 - categorical_crossentropy: 0.6400 - categorical_accuracy: 0.7500 - val_loss: 0.7879 - val_categorical_crossentropy: 0.7879 - val_categorical_accuracy: 0.7021
# Epoch 65/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5979 - categorical_crossentropy: 0.5979 - categorical_accuracy: 0.8000 - val_loss: 0.8013 - val_categorical_crossentropy: 0.8013 - val_categorical_accuracy: 0.7234
# Epoch 66/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6004 - categorical_crossentropy: 0.6004 - categorical_accuracy: 0.8042 - val_loss: 0.8077 - val_categorical_crossentropy: 0.8077 - val_categorical_accuracy: 0.7234
# Epoch 67/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6099 - categorical_crossentropy: 0.6099 - categorical_accuracy: 0.7667 - val_loss: 0.8098 - val_categorical_crossentropy: 0.8098 - val_categorical_accuracy: 0.7234
# Epoch 68/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6375 - categorical_crossentropy: 0.6375 - categorical_accuracy: 0.7625 - val_loss: 0.8148 - val_categorical_crossentropy: 0.8148 - val_categorical_accuracy: 0.6809
# Epoch 69/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6063 - categorical_crossentropy: 0.6063 - categorical_accuracy: 0.7625 - val_loss: 0.8023 - val_categorical_crossentropy: 0.8023 - val_categorical_accuracy: 0.7021
# Epoch 70/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6159 - categorical_crossentropy: 0.6159 - categorical_accuracy: 0.8000 - val_loss: 0.7933 - val_categorical_crossentropy: 0.7933 - val_categorical_accuracy: 0.7021
# Epoch 71/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6205 - categorical_crossentropy: 0.6205 - categorical_accuracy: 0.7833 - val_loss: 0.7809 - val_categorical_crossentropy: 0.7809 - val_categorical_accuracy: 0.7021
# Epoch 72/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6187 - categorical_crossentropy: 0.6187 - categorical_accuracy: 0.7917 - val_loss: 0.7727 - val_categorical_crossentropy: 0.7727 - val_categorical_accuracy: 0.7234
# Epoch 73/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5879 - categorical_crossentropy: 0.5879 - categorical_accuracy: 0.7917 - val_loss: 0.7759 - val_categorical_crossentropy: 0.7759 - val_categorical_accuracy: 0.7447
# Epoch 74/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5941 - categorical_crossentropy: 0.5941 - categorical_accuracy: 0.7875 - val_loss: 0.7872 - val_categorical_crossentropy: 0.7872 - val_categorical_accuracy: 0.7021
# Epoch 75/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6059 - categorical_crossentropy: 0.6059 - categorical_accuracy: 0.7792 - val_loss: 0.7825 - val_categorical_crossentropy: 0.7825 - val_categorical_accuracy: 0.7021
# Epoch 76/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6173 - categorical_crossentropy: 0.6173 - categorical_accuracy: 0.7500 - val_loss: 0.7832 - val_categorical_crossentropy: 0.7832 - val_categorical_accuracy: 0.7234
# Epoch 77/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6095 - categorical_crossentropy: 0.6095 - categorical_accuracy: 0.7708 - val_loss: 0.7785 - val_categorical_crossentropy: 0.7785 - val_categorical_accuracy: 0.7234
# Epoch 78/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6078 - categorical_crossentropy: 0.6078 - categorical_accuracy: 0.7667 - val_loss: 0.7664 - val_categorical_crossentropy: 0.7664 - val_categorical_accuracy: 0.7234
# Epoch 79/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6088 - categorical_crossentropy: 0.6088 - categorical_accuracy: 0.8083 - val_loss: 0.7768 - val_categorical_crossentropy: 0.7768 - val_categorical_accuracy: 0.7447
# Epoch 80/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5715 - categorical_crossentropy: 0.5715 - categorical_accuracy: 0.7667 - val_loss: 0.7821 - val_categorical_crossentropy: 0.7821 - val_categorical_accuracy: 0.7234
# Epoch 81/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5752 - categorical_crossentropy: 0.5752 - categorical_accuracy: 0.8125 - val_loss: 0.7770 - val_categorical_crossentropy: 0.7770 - val_categorical_accuracy: 0.7234
# Epoch 82/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5819 - categorical_crossentropy: 0.5819 - categorical_accuracy: 0.8042 - val_loss: 0.7826 - val_categorical_crossentropy: 0.7826 - val_categorical_accuracy: 0.7234
# Epoch 83/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5780 - categorical_crossentropy: 0.5780 - categorical_accuracy: 0.8042 - val_loss: 0.7854 - val_categorical_crossentropy: 0.7854 - val_categorical_accuracy: 0.7447
# Epoch 84/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5743 - categorical_crossentropy: 0.5743 - categorical_accuracy: 0.8042 - val_loss: 0.7803 - val_categorical_crossentropy: 0.7803 - val_categorical_accuracy: 0.7447
# Epoch 85/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5680 - categorical_crossentropy: 0.5680 - categorical_accuracy: 0.8250 - val_loss: 0.7824 - val_categorical_crossentropy: 0.7824 - val_categorical_accuracy: 0.7447
# Epoch 86/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5496 - categorical_crossentropy: 0.5496 - categorical_accuracy: 0.8292 - val_loss: 0.8074 - val_categorical_crossentropy: 0.8074 - val_categorical_accuracy: 0.7021
# Epoch 87/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5773 - categorical_crossentropy: 0.5773 - categorical_accuracy: 0.8208 - val_loss: 0.8101 - val_categorical_crossentropy: 0.8101 - val_categorical_accuracy: 0.7021
# Epoch 88/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5626 - categorical_crossentropy: 0.5626 - categorical_accuracy: 0.8000 - val_loss: 0.7862 - val_categorical_crossentropy: 0.7862 - val_categorical_accuracy: 0.7021
# Epoch 89/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5511 - categorical_crossentropy: 0.5511 - categorical_accuracy: 0.8083 - val_loss: 0.7822 - val_categorical_crossentropy: 0.7822 - val_categorical_accuracy: 0.7021
# Epoch 90/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5778 - categorical_crossentropy: 0.5778 - categorical_accuracy: 0.7792 - val_loss: 0.7827 - val_categorical_crossentropy: 0.7827 - val_categorical_accuracy: 0.7021
# Epoch 91/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5837 - categorical_crossentropy: 0.5837 - categorical_accuracy: 0.7875 - val_loss: 0.7807 - val_categorical_crossentropy: 0.7807 - val_categorical_accuracy: 0.7447
# Epoch 92/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5678 - categorical_crossentropy: 0.5678 - categorical_accuracy: 0.7667 - val_loss: 0.7936 - val_categorical_crossentropy: 0.7936 - val_categorical_accuracy: 0.7234
# Epoch 93/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5660 - categorical_crossentropy: 0.5660 - categorical_accuracy: 0.8042 - val_loss: 0.8045 - val_categorical_crossentropy: 0.8045 - val_categorical_accuracy: 0.7021
# Epoch 94/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5667 - categorical_crossentropy: 0.5667 - categorical_accuracy: 0.7708 - val_loss: 0.7960 - val_categorical_crossentropy: 0.7960 - val_categorical_accuracy: 0.7021
# Epoch 95/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5501 - categorical_crossentropy: 0.5501 - categorical_accuracy: 0.8042 - val_loss: 0.7936 - val_categorical_crossentropy: 0.7936 - val_categorical_accuracy: 0.7234
# Epoch 96/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5351 - categorical_crossentropy: 0.5351 - categorical_accuracy: 0.8083 - val_loss: 0.7836 - val_categorical_crossentropy: 0.7836 - val_categorical_accuracy: 0.7021
# Epoch 97/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5619 - categorical_crossentropy: 0.5619 - categorical_accuracy: 0.8000 - val_loss: 0.7841 - val_categorical_crossentropy: 0.7841 - val_categorical_accuracy: 0.7234
# Epoch 98/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5483 - categorical_crossentropy: 0.5483 - categorical_accuracy: 0.8250 - val_loss: 0.7883 - val_categorical_crossentropy: 0.7883 - val_categorical_accuracy: 0.7234
# Epoch 99/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5517 - categorical_crossentropy: 0.5517 - categorical_accuracy: 0.8333 - val_loss: 0.7836 - val_categorical_crossentropy: 0.7836 - val_categorical_accuracy: 0.7234
# Epoch 100/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5692 - categorical_crossentropy: 0.5692 - categorical_accuracy: 0.7958 - val_loss: 0.7678 - val_categorical_crossentropy: 0.7678 - val_categorical_accuracy: 0.7021
# Epoch 101/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5781 - categorical_crossentropy: 0.5781 - categorical_accuracy: 0.8208 - val_loss: 0.7489 - val_categorical_crossentropy: 0.7489 - val_categorical_accuracy: 0.7447
# Epoch 102/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5244 - categorical_crossentropy: 0.5244 - categorical_accuracy: 0.8250 - val_loss: 0.7558 - val_categorical_crossentropy: 0.7558 - val_categorical_accuracy: 0.7234
# Epoch 103/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5665 - categorical_crossentropy: 0.5665 - categorical_accuracy: 0.8250 - val_loss: 0.7722 - val_categorical_crossentropy: 0.7722 - val_categorical_accuracy: 0.7234
# Epoch 104/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5539 - categorical_crossentropy: 0.5539 - categorical_accuracy: 0.8000 - val_loss: 0.7637 - val_categorical_crossentropy: 0.7637 - val_categorical_accuracy: 0.7234
# Epoch 105/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5588 - categorical_crossentropy: 0.5588 - categorical_accuracy: 0.8167 - val_loss: 0.7570 - val_categorical_crossentropy: 0.7570 - val_categorical_accuracy: 0.7660
# Epoch 106/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5300 - categorical_crossentropy: 0.5300 - categorical_accuracy: 0.8125 - val_loss: 0.7459 - val_categorical_crossentropy: 0.7459 - val_categorical_accuracy: 0.7447
# Epoch 107/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5330 - categorical_crossentropy: 0.5330 - categorical_accuracy: 0.8375 - val_loss: 0.7391 - val_categorical_crossentropy: 0.7391 - val_categorical_accuracy: 0.7234
# Epoch 108/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5247 - categorical_crossentropy: 0.5247 - categorical_accuracy: 0.8125 - val_loss: 0.7509 - val_categorical_crossentropy: 0.7509 - val_categorical_accuracy: 0.7447
# Epoch 109/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5227 - categorical_crossentropy: 0.5227 - categorical_accuracy: 0.8292 - val_loss: 0.7692 - val_categorical_crossentropy: 0.7692 - val_categorical_accuracy: 0.7447
# Epoch 110/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5526 - categorical_crossentropy: 0.5526 - categorical_accuracy: 0.8125 - val_loss: 0.7695 - val_categorical_crossentropy: 0.7695 - val_categorical_accuracy: 0.7447
# Epoch 111/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5334 - categorical_crossentropy: 0.5334 - categorical_accuracy: 0.8083 - val_loss: 0.7784 - val_categorical_crossentropy: 0.7784 - val_categorical_accuracy: 0.7234
# Epoch 112/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5248 - categorical_crossentropy: 0.5248 - categorical_accuracy: 0.8167 - val_loss: 0.7792 - val_categorical_crossentropy: 0.7792 - val_categorical_accuracy: 0.7234
# Epoch 113/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5264 - categorical_crossentropy: 0.5264 - categorical_accuracy: 0.8250 - val_loss: 0.7726 - val_categorical_crossentropy: 0.7726 - val_categorical_accuracy: 0.7234
# Epoch 114/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5370 - categorical_crossentropy: 0.5370 - categorical_accuracy: 0.8375 - val_loss: 0.7647 - val_categorical_crossentropy: 0.7647 - val_categorical_accuracy: 0.7447
# Epoch 115/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5364 - categorical_crossentropy: 0.5364 - categorical_accuracy: 0.8042 - val_loss: 0.7481 - val_categorical_crossentropy: 0.7481 - val_categorical_accuracy: 0.7447
# Epoch 116/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5369 - categorical_crossentropy: 0.5369 - categorical_accuracy: 0.8250 - val_loss: 0.7294 - val_categorical_crossentropy: 0.7294 - val_categorical_accuracy: 0.7447
# Epoch 117/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5199 - categorical_crossentropy: 0.5199 - categorical_accuracy: 0.8333 - val_loss: 0.7284 - val_categorical_crossentropy: 0.7284 - val_categorical_accuracy: 0.7660
# Epoch 118/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5166 - categorical_crossentropy: 0.5166 - categorical_accuracy: 0.8208 - val_loss: 0.7320 - val_categorical_crossentropy: 0.7320 - val_categorical_accuracy: 0.7447
# Epoch 119/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5374 - categorical_crossentropy: 0.5374 - categorical_accuracy: 0.8167 - val_loss: 0.7352 - val_categorical_crossentropy: 0.7352 - val_categorical_accuracy: 0.7234
# Epoch 120/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5442 - categorical_crossentropy: 0.5442 - categorical_accuracy: 0.8167 - val_loss: 0.7144 - val_categorical_crossentropy: 0.7144 - val_categorical_accuracy: 0.7234
# Epoch 121/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5432 - categorical_crossentropy: 0.5432 - categorical_accuracy: 0.8250 - val_loss: 0.7247 - val_categorical_crossentropy: 0.7247 - val_categorical_accuracy: 0.7447
# Epoch 122/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5429 - categorical_crossentropy: 0.5429 - categorical_accuracy: 0.8083 - val_loss: 0.7207 - val_categorical_crossentropy: 0.7207 - val_categorical_accuracy: 0.7447
# Epoch 123/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5148 - categorical_crossentropy: 0.5148 - categorical_accuracy: 0.8250 - val_loss: 0.7228 - val_categorical_crossentropy: 0.7228 - val_categorical_accuracy: 0.7660
# Epoch 124/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5495 - categorical_crossentropy: 0.5495 - categorical_accuracy: 0.7958 - val_loss: 0.7245 - val_categorical_crossentropy: 0.7245 - val_categorical_accuracy: 0.7660
# Epoch 125/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5084 - categorical_crossentropy: 0.5084 - categorical_accuracy: 0.8292 - val_loss: 0.7157 - val_categorical_crossentropy: 0.7157 - val_categorical_accuracy: 0.7660
# Epoch 126/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5322 - categorical_crossentropy: 0.5322 - categorical_accuracy: 0.8375 - val_loss: 0.7270 - val_categorical_crossentropy: 0.7270 - val_categorical_accuracy: 0.7447
# Epoch 127/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5160 - categorical_crossentropy: 0.5160 - categorical_accuracy: 0.8583 - val_loss: 0.7474 - val_categorical_crossentropy: 0.7474 - val_categorical_accuracy: 0.7447
# Epoch 128/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4974 - categorical_crossentropy: 0.4974 - categorical_accuracy: 0.8333 - val_loss: 0.7327 - val_categorical_crossentropy: 0.7327 - val_categorical_accuracy: 0.7234
# Epoch 129/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5246 - categorical_crossentropy: 0.5246 - categorical_accuracy: 0.8208 - val_loss: 0.7401 - val_categorical_crossentropy: 0.7401 - val_categorical_accuracy: 0.7234
# Epoch 130/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5073 - categorical_crossentropy: 0.5073 - categorical_accuracy: 0.8417 - val_loss: 0.7397 - val_categorical_crossentropy: 0.7397 - val_categorical_accuracy: 0.7447
# Epoch 131/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4945 - categorical_crossentropy: 0.4945 - categorical_accuracy: 0.8375 - val_loss: 0.7356 - val_categorical_crossentropy: 0.7356 - val_categorical_accuracy: 0.7447
# Epoch 132/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5363 - categorical_crossentropy: 0.5363 - categorical_accuracy: 0.8125 - val_loss: 0.7282 - val_categorical_crossentropy: 0.7282 - val_categorical_accuracy: 0.7234
# Epoch 133/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5166 - categorical_crossentropy: 0.5166 - categorical_accuracy: 0.8208 - val_loss: 0.7087 - val_categorical_crossentropy: 0.7087 - val_categorical_accuracy: 0.7447
# Epoch 134/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5031 - categorical_crossentropy: 0.5031 - categorical_accuracy: 0.8333 - val_loss: 0.7130 - val_categorical_crossentropy: 0.7130 - val_categorical_accuracy: 0.7447
# Epoch 135/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5003 - categorical_crossentropy: 0.5003 - categorical_accuracy: 0.8542 - val_loss: 0.7178 - val_categorical_crossentropy: 0.7178 - val_categorical_accuracy: 0.7447
# Epoch 136/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4786 - categorical_crossentropy: 0.4786 - categorical_accuracy: 0.8417 - val_loss: 0.7230 - val_categorical_crossentropy: 0.7230 - val_categorical_accuracy: 0.7447
# Epoch 137/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4773 - categorical_crossentropy: 0.4773 - categorical_accuracy: 0.8417 - val_loss: 0.7341 - val_categorical_crossentropy: 0.7341 - val_categorical_accuracy: 0.7447
# Epoch 138/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4910 - categorical_crossentropy: 0.4910 - categorical_accuracy: 0.8625 - val_loss: 0.7385 - val_categorical_crossentropy: 0.7385 - val_categorical_accuracy: 0.7021
# Epoch 139/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5024 - categorical_crossentropy: 0.5024 - categorical_accuracy: 0.8375 - val_loss: 0.7421 - val_categorical_crossentropy: 0.7421 - val_categorical_accuracy: 0.7021
# Epoch 140/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5194 - categorical_crossentropy: 0.5194 - categorical_accuracy: 0.8125 - val_loss: 0.7454 - val_categorical_crossentropy: 0.7454 - val_categorical_accuracy: 0.7234
# Epoch 141/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5036 - categorical_crossentropy: 0.5036 - categorical_accuracy: 0.8333 - val_loss: 0.7356 - val_categorical_crossentropy: 0.7356 - val_categorical_accuracy: 0.7447
# Epoch 142/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4710 - categorical_crossentropy: 0.4710 - categorical_accuracy: 0.8292 - val_loss: 0.7359 - val_categorical_crossentropy: 0.7359 - val_categorical_accuracy: 0.7660
# Epoch 143/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4980 - categorical_crossentropy: 0.4980 - categorical_accuracy: 0.8375 - val_loss: 0.7395 - val_categorical_crossentropy: 0.7395 - val_categorical_accuracy: 0.7660
# Epoch 144/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4817 - categorical_crossentropy: 0.4817 - categorical_accuracy: 0.8417 - val_loss: 0.7350 - val_categorical_crossentropy: 0.7350 - val_categorical_accuracy: 0.7021
# Epoch 145/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4843 - categorical_crossentropy: 0.4843 - categorical_accuracy: 0.8458 - val_loss: 0.7449 - val_categorical_crossentropy: 0.7449 - val_categorical_accuracy: 0.7234
# Epoch 146/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5025 - categorical_crossentropy: 0.5025 - categorical_accuracy: 0.8375 - val_loss: 0.7532 - val_categorical_crossentropy: 0.7532 - val_categorical_accuracy: 0.7447
# Epoch 147/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5041 - categorical_crossentropy: 0.5041 - categorical_accuracy: 0.8333 - val_loss: 0.7332 - val_categorical_crossentropy: 0.7332 - val_categorical_accuracy: 0.7447
# Epoch 148/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4715 - categorical_crossentropy: 0.4715 - categorical_accuracy: 0.8583 - val_loss: 0.7336 - val_categorical_crossentropy: 0.7336 - val_categorical_accuracy: 0.7447
# Epoch 149/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4816 - categorical_crossentropy: 0.4816 - categorical_accuracy: 0.8458 - val_loss: 0.7481 - val_categorical_crossentropy: 0.7481 - val_categorical_accuracy: 0.7234
# Epoch 150/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5450 - categorical_crossentropy: 0.5450 - categorical_accuracy: 0.7792 - val_loss: 0.7370 - val_categorical_crossentropy: 0.7370 - val_categorical_accuracy: 0.7447
# Epoch 151/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4906 - categorical_crossentropy: 0.4906 - categorical_accuracy: 0.8333 - val_loss: 0.7636 - val_categorical_crossentropy: 0.7636 - val_categorical_accuracy: 0.7447
# Epoch 152/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4804 - categorical_crossentropy: 0.4804 - categorical_accuracy: 0.8500 - val_loss: 0.7462 - val_categorical_crossentropy: 0.7462 - val_categorical_accuracy: 0.7447
# Epoch 153/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4858 - categorical_crossentropy: 0.4858 - categorical_accuracy: 0.8500 - val_loss: 0.7271 - val_categorical_crossentropy: 0.7271 - val_categorical_accuracy: 0.7234
# Epoch 154/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4485 - categorical_crossentropy: 0.4485 - categorical_accuracy: 0.8417 - val_loss: 0.7317 - val_categorical_crossentropy: 0.7317 - val_categorical_accuracy: 0.7447
# Epoch 155/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5049 - categorical_crossentropy: 0.5049 - categorical_accuracy: 0.8042 - val_loss: 0.7345 - val_categorical_crossentropy: 0.7345 - val_categorical_accuracy: 0.7234
# Epoch 156/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4791 - categorical_crossentropy: 0.4791 - categorical_accuracy: 0.8583 - val_loss: 0.7395 - val_categorical_crossentropy: 0.7395 - val_categorical_accuracy: 0.7234
# Epoch 157/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4783 - categorical_crossentropy: 0.4783 - categorical_accuracy: 0.8542 - val_loss: 0.7297 - val_categorical_crossentropy: 0.7297 - val_categorical_accuracy: 0.7660
# Epoch 158/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4740 - categorical_crossentropy: 0.4740 - categorical_accuracy: 0.8333 - val_loss: 0.7180 - val_categorical_crossentropy: 0.7180 - val_categorical_accuracy: 0.7660
# Epoch 159/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4777 - categorical_crossentropy: 0.4777 - categorical_accuracy: 0.8792 - val_loss: 0.7159 - val_categorical_crossentropy: 0.7159 - val_categorical_accuracy: 0.7660
# Epoch 160/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5122 - categorical_crossentropy: 0.5122 - categorical_accuracy: 0.8208 - val_loss: 0.7147 - val_categorical_crossentropy: 0.7147 - val_categorical_accuracy: 0.7447
# Epoch 161/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4776 - categorical_crossentropy: 0.4776 - categorical_accuracy: 0.8250 - val_loss: 0.7196 - val_categorical_crossentropy: 0.7196 - val_categorical_accuracy: 0.7447
# Epoch 162/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4701 - categorical_crossentropy: 0.4701 - categorical_accuracy: 0.8417 - val_loss: 0.7326 - val_categorical_crossentropy: 0.7326 - val_categorical_accuracy: 0.7021
# Epoch 163/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4768 - categorical_crossentropy: 0.4768 - categorical_accuracy: 0.8542 - val_loss: 0.7286 - val_categorical_crossentropy: 0.7286 - val_categorical_accuracy: 0.7447
# Epoch 164/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4420 - categorical_crossentropy: 0.4420 - categorical_accuracy: 0.8708 - val_loss: 0.7262 - val_categorical_crossentropy: 0.7262 - val_categorical_accuracy: 0.7660
# Epoch 165/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4684 - categorical_crossentropy: 0.4684 - categorical_accuracy: 0.8625 - val_loss: 0.7151 - val_categorical_crossentropy: 0.7151 - val_categorical_accuracy: 0.7447
# Epoch 166/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4488 - categorical_crossentropy: 0.4488 - categorical_accuracy: 0.8667 - val_loss: 0.7071 - val_categorical_crossentropy: 0.7071 - val_categorical_accuracy: 0.7447
# Epoch 167/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4652 - categorical_crossentropy: 0.4652 - categorical_accuracy: 0.8208 - val_loss: 0.6998 - val_categorical_crossentropy: 0.6998 - val_categorical_accuracy: 0.7660
# Epoch 168/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4805 - categorical_crossentropy: 0.4805 - categorical_accuracy: 0.8625 - val_loss: 0.7046 - val_categorical_crossentropy: 0.7046 - val_categorical_accuracy: 0.7447
# Epoch 169/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4633 - categorical_crossentropy: 0.4633 - categorical_accuracy: 0.8792 - val_loss: 0.7251 - val_categorical_crossentropy: 0.7251 - val_categorical_accuracy: 0.7447
# Epoch 170/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4875 - categorical_crossentropy: 0.4875 - categorical_accuracy: 0.8208 - val_loss: 0.7197 - val_categorical_crossentropy: 0.7197 - val_categorical_accuracy: 0.7447
# Epoch 171/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4543 - categorical_crossentropy: 0.4543 - categorical_accuracy: 0.8500 - val_loss: 0.7196 - val_categorical_crossentropy: 0.7196 - val_categorical_accuracy: 0.7447
# Epoch 172/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4808 - categorical_crossentropy: 0.4808 - categorical_accuracy: 0.8625 - val_loss: 0.7220 - val_categorical_crossentropy: 0.7220 - val_categorical_accuracy: 0.7234
# Epoch 173/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4814 - categorical_crossentropy: 0.4814 - categorical_accuracy: 0.8375 - val_loss: 0.7377 - val_categorical_crossentropy: 0.7377 - val_categorical_accuracy: 0.7447
# Epoch 174/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4431 - categorical_crossentropy: 0.4431 - categorical_accuracy: 0.8417 - val_loss: 0.7155 - val_categorical_crossentropy: 0.7155 - val_categorical_accuracy: 0.7660
# Epoch 175/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4816 - categorical_crossentropy: 0.4816 - categorical_accuracy: 0.8625 - val_loss: 0.7293 - val_categorical_crossentropy: 0.7293 - val_categorical_accuracy: 0.7234
# Epoch 176/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4871 - categorical_crossentropy: 0.4871 - categorical_accuracy: 0.8375 - val_loss: 0.7099 - val_categorical_crossentropy: 0.7099 - val_categorical_accuracy: 0.7660
# Epoch 177/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4798 - categorical_crossentropy: 0.4798 - categorical_accuracy: 0.8125 - val_loss: 0.6981 - val_categorical_crossentropy: 0.6981 - val_categorical_accuracy: 0.7660
# Epoch 178/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4491 - categorical_crossentropy: 0.4491 - categorical_accuracy: 0.8750 - val_loss: 0.7017 - val_categorical_crossentropy: 0.7017 - val_categorical_accuracy: 0.7872
# Epoch 179/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4478 - categorical_crossentropy: 0.4478 - categorical_accuracy: 0.8500 - val_loss: 0.6982 - val_categorical_crossentropy: 0.6982 - val_categorical_accuracy: 0.7872
# Epoch 180/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4374 - categorical_crossentropy: 0.4374 - categorical_accuracy: 0.8708 - val_loss: 0.7195 - val_categorical_crossentropy: 0.7195 - val_categorical_accuracy: 0.7660
# Epoch 181/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4393 - categorical_crossentropy: 0.4393 - categorical_accuracy: 0.8667 - val_loss: 0.7203 - val_categorical_crossentropy: 0.7203 - val_categorical_accuracy: 0.7660
# Epoch 182/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4814 - categorical_crossentropy: 0.4814 - categorical_accuracy: 0.8042 - val_loss: 0.7055 - val_categorical_crossentropy: 0.7055 - val_categorical_accuracy: 0.7660
# Epoch 183/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4344 - categorical_crossentropy: 0.4344 - categorical_accuracy: 0.8833 - val_loss: 0.7121 - val_categorical_crossentropy: 0.7121 - val_categorical_accuracy: 0.7021
# Epoch 184/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4084 - categorical_crossentropy: 0.4084 - categorical_accuracy: 0.8958 - val_loss: 0.7152 - val_categorical_crossentropy: 0.7152 - val_categorical_accuracy: 0.7234
# Epoch 185/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4336 - categorical_crossentropy: 0.4336 - categorical_accuracy: 0.8458 - val_loss: 0.7390 - val_categorical_crossentropy: 0.7390 - val_categorical_accuracy: 0.7447
# Epoch 186/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4089 - categorical_crossentropy: 0.4089 - categorical_accuracy: 0.8667 - val_loss: 0.7420 - val_categorical_crossentropy: 0.7420 - val_categorical_accuracy: 0.7447
# Epoch 187/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4270 - categorical_crossentropy: 0.4270 - categorical_accuracy: 0.8583 - val_loss: 0.7097 - val_categorical_crossentropy: 0.7097 - val_categorical_accuracy: 0.7660
# Epoch 188/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4385 - categorical_crossentropy: 0.4385 - categorical_accuracy: 0.8625 - val_loss: 0.7341 - val_categorical_crossentropy: 0.7341 - val_categorical_accuracy: 0.7447
# Epoch 189/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4296 - categorical_crossentropy: 0.4296 - categorical_accuracy: 0.8792 - val_loss: 0.7157 - val_categorical_crossentropy: 0.7157 - val_categorical_accuracy: 0.7660
# Epoch 190/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4352 - categorical_crossentropy: 0.4352 - categorical_accuracy: 0.8458 - val_loss: 0.7094 - val_categorical_crossentropy: 0.7094 - val_categorical_accuracy: 0.7447
# Epoch 191/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4348 - categorical_crossentropy: 0.4348 - categorical_accuracy: 0.8583 - val_loss: 0.6970 - val_categorical_crossentropy: 0.6970 - val_categorical_accuracy: 0.7660
# Epoch 192/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4282 - categorical_crossentropy: 0.4282 - categorical_accuracy: 0.8625 - val_loss: 0.6841 - val_categorical_crossentropy: 0.6841 - val_categorical_accuracy: 0.7660
# Epoch 193/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4156 - categorical_crossentropy: 0.4156 - categorical_accuracy: 0.8625 - val_loss: 0.7185 - val_categorical_crossentropy: 0.7185 - val_categorical_accuracy: 0.7660
# Epoch 194/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4547 - categorical_crossentropy: 0.4547 - categorical_accuracy: 0.8375 - val_loss: 0.7161 - val_categorical_crossentropy: 0.7161 - val_categorical_accuracy: 0.7660
# Epoch 195/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4138 - categorical_crossentropy: 0.4138 - categorical_accuracy: 0.8625 - val_loss: 0.7177 - val_categorical_crossentropy: 0.7177 - val_categorical_accuracy: 0.7447
# Epoch 196/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4337 - categorical_crossentropy: 0.4337 - categorical_accuracy: 0.8708 - val_loss: 0.6999 - val_categorical_crossentropy: 0.6999 - val_categorical_accuracy: 0.7660
# Epoch 197/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4284 - categorical_crossentropy: 0.4284 - categorical_accuracy: 0.8583 - val_loss: 0.6993 - val_categorical_crossentropy: 0.6993 - val_categorical_accuracy: 0.7447
# Epoch 198/500
# ...
# Epoch 437/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1547 - categorical_crossentropy: 0.1547 - categorical_accuracy: 0.9625 - val_loss: 0.5378 - val_categorical_crossentropy: 0.5378 - val_categorical_accuracy: 0.8085
# Epoch 438/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1330 - categorical_crossentropy: 0.1330 - categorical_accuracy: 0.9750 - val_loss: 0.5471 - val_categorical_crossentropy: 0.5471 - val_categorical_accuracy: 0.8085
# Epoch 439/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1455 - categorical_crossentropy: 0.1455 - categorical_accuracy: 0.9625 - val_loss: 0.5068 - val_categorical_crossentropy: 0.5068 - val_categorical_accuracy: 0.7872
# Epoch 440/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1607 - categorical_crossentropy: 0.1607 - categorical_accuracy: 0.9542 - val_loss: 0.5550 - val_categorical_crossentropy: 0.5550 - val_categorical_accuracy: 0.7660
# Epoch 441/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1341 - categorical_crossentropy: 0.1341 - categorical_accuracy: 0.9500 - val_loss: 0.5310 - val_categorical_crossentropy: 0.5310 - val_categorical_accuracy: 0.7872
# Epoch 442/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1408 - categorical_crossentropy: 0.1408 - categorical_accuracy: 0.9792 - val_loss: 0.5471 - val_categorical_crossentropy: 0.5471 - val_categorical_accuracy: 0.7872
# Epoch 443/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1372 - categorical_crossentropy: 0.1372 - categorical_accuracy: 0.9667 - val_loss: 0.5246 - val_categorical_crossentropy: 0.5246 - val_categorical_accuracy: 0.7660
# Epoch 444/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1459 - categorical_crossentropy: 0.1459 - categorical_accuracy: 0.9500 - val_loss: 0.5379 - val_categorical_crossentropy: 0.5379 - val_categorical_accuracy: 0.7234
# Epoch 445/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1450 - categorical_crossentropy: 0.1450 - categorical_accuracy: 0.9542 - val_loss: 0.5825 - val_categorical_crossentropy: 0.5825 - val_categorical_accuracy: 0.7447
# Epoch 446/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1433 - categorical_crossentropy: 0.1433 - categorical_accuracy: 0.9625 - val_loss: 0.5458 - val_categorical_crossentropy: 0.5458 - val_categorical_accuracy: 0.7447
# Epoch 447/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1571 - categorical_crossentropy: 0.1571 - categorical_accuracy: 0.9583 - val_loss: 0.5484 - val_categorical_crossentropy: 0.5484 - val_categorical_accuracy: 0.7447
# Epoch 448/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1487 - categorical_crossentropy: 0.1487 - categorical_accuracy: 0.9583 - val_loss: 0.5513 - val_categorical_crossentropy: 0.5513 - val_categorical_accuracy: 0.7872
# Epoch 449/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1606 - categorical_crossentropy: 0.1606 - categorical_accuracy: 0.9583 - val_loss: 0.5139 - val_categorical_crossentropy: 0.5139 - val_categorical_accuracy: 0.7234
# Epoch 450/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1607 - categorical_crossentropy: 0.1607 - categorical_accuracy: 0.9667 - val_loss: 0.5414 - val_categorical_crossentropy: 0.5414 - val_categorical_accuracy: 0.7660
# Epoch 451/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1595 - categorical_crossentropy: 0.1595 - categorical_accuracy: 0.9667 - val_loss: 0.5618 - val_categorical_crossentropy: 0.5618 - val_categorical_accuracy: 0.7872
# Epoch 452/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1429 - categorical_crossentropy: 0.1429 - categorical_accuracy: 0.9542 - val_loss: 0.6048 - val_categorical_crossentropy: 0.6048 - val_categorical_accuracy: 0.7660
# Epoch 453/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1459 - categorical_crossentropy: 0.1459 - categorical_accuracy: 0.9625 - val_loss: 0.5393 - val_categorical_crossentropy: 0.5393 - val_categorical_accuracy: 0.7872
# Epoch 454/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1555 - categorical_crossentropy: 0.1555 - categorical_accuracy: 0.9625 - val_loss: 0.4920 - val_categorical_crossentropy: 0.4920 - val_categorical_accuracy: 0.7872
# Epoch 455/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1549 - categorical_crossentropy: 0.1549 - categorical_accuracy: 0.9542 - val_loss: 0.5285 - val_categorical_crossentropy: 0.5285 - val_categorical_accuracy: 0.7660
# Epoch 456/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1642 - categorical_crossentropy: 0.1642 - categorical_accuracy: 0.9625 - val_loss: 0.5163 - val_categorical_crossentropy: 0.5163 - val_categorical_accuracy: 0.7234
# Epoch 457/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1571 - categorical_crossentropy: 0.1571 - categorical_accuracy: 0.9583 - val_loss: 0.4920 - val_categorical_crossentropy: 0.4920 - val_categorical_accuracy: 0.7447
# Epoch 458/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1530 - categorical_crossentropy: 0.1530 - categorical_accuracy: 0.9583 - val_loss: 0.5015 - val_categorical_crossentropy: 0.5015 - val_categorical_accuracy: 0.7660
# Epoch 459/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1573 - categorical_crossentropy: 0.1573 - categorical_accuracy: 0.9542 - val_loss: 0.5318 - val_categorical_crossentropy: 0.5318 - val_categorical_accuracy: 0.7447
# Epoch 460/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1437 - categorical_crossentropy: 0.1437 - categorical_accuracy: 0.9667 - val_loss: 0.5687 - val_categorical_crossentropy: 0.5687 - val_categorical_accuracy: 0.7447
# Epoch 461/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1432 - categorical_crossentropy: 0.1432 - categorical_accuracy: 0.9750 - val_loss: 0.5205 - val_categorical_crossentropy: 0.5205 - val_categorical_accuracy: 0.7872
# Epoch 462/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1370 - categorical_crossentropy: 0.1370 - categorical_accuracy: 0.9708 - val_loss: 0.5100 - val_categorical_crossentropy: 0.5100 - val_categorical_accuracy: 0.7872
# Epoch 463/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1196 - categorical_crossentropy: 0.1196 - categorical_accuracy: 0.9833 - val_loss: 0.4983 - val_categorical_crossentropy: 0.4983 - val_categorical_accuracy: 0.7872
# Epoch 464/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1459 - categorical_crossentropy: 0.1459 - categorical_accuracy: 0.9500 - val_loss: 0.4927 - val_categorical_crossentropy: 0.4927 - val_categorical_accuracy: 0.7660
# Epoch 465/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1320 - categorical_crossentropy: 0.1320 - categorical_accuracy: 0.9667 - val_loss: 0.4934 - val_categorical_crossentropy: 0.4934 - val_categorical_accuracy: 0.7660
# Epoch 466/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1313 - categorical_crossentropy: 0.1313 - categorical_accuracy: 0.9750 - val_loss: 0.5079 - val_categorical_crossentropy: 0.5079 - val_categorical_accuracy: 0.7660
# Epoch 467/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1303 - categorical_crossentropy: 0.1303 - categorical_accuracy: 0.9667 - val_loss: 0.5416 - val_categorical_crossentropy: 0.5416 - val_categorical_accuracy: 0.8085
# Epoch 468/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1322 - categorical_crossentropy: 0.1322 - categorical_accuracy: 0.9625 - val_loss: 0.5461 - val_categorical_crossentropy: 0.5461 - val_categorical_accuracy: 0.8085
# Epoch 469/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1473 - categorical_crossentropy: 0.1473 - categorical_accuracy: 0.9583 - val_loss: 0.5115 - val_categorical_crossentropy: 0.5115 - val_categorical_accuracy: 0.7660
# Epoch 470/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1524 - categorical_crossentropy: 0.1524 - categorical_accuracy: 0.9667 - val_loss: 0.4998 - val_categorical_crossentropy: 0.4998 - val_categorical_accuracy: 0.7234
# Epoch 471/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1361 - categorical_crossentropy: 0.1361 - categorical_accuracy: 0.9750 - val_loss: 0.4774 - val_categorical_crossentropy: 0.4774 - val_categorical_accuracy: 0.7872
# Epoch 472/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1396 - categorical_crossentropy: 0.1396 - categorical_accuracy: 0.9542 - val_loss: 0.5038 - val_categorical_crossentropy: 0.5038 - val_categorical_accuracy: 0.8085
# Epoch 473/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1678 - categorical_crossentropy: 0.1678 - categorical_accuracy: 0.9500 - val_loss: 0.5742 - val_categorical_crossentropy: 0.5742 - val_categorical_accuracy: 0.7660
# Epoch 474/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1229 - categorical_crossentropy: 0.1229 - categorical_accuracy: 0.9750 - val_loss: 0.5252 - val_categorical_crossentropy: 0.5252 - val_categorical_accuracy: 0.7872
# Epoch 475/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1540 - categorical_crossentropy: 0.1540 - categorical_accuracy: 0.9458 - val_loss: 0.5664 - val_categorical_crossentropy: 0.5664 - val_categorical_accuracy: 0.7447
# Epoch 476/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1529 - categorical_crossentropy: 0.1529 - categorical_accuracy: 0.9667 - val_loss: 0.5497 - val_categorical_crossentropy: 0.5497 - val_categorical_accuracy: 0.7872
# Epoch 477/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1319 - categorical_crossentropy: 0.1319 - categorical_accuracy: 0.9583 - val_loss: 0.5020 - val_categorical_crossentropy: 0.5020 - val_categorical_accuracy: 0.7872
# Epoch 478/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1304 - categorical_crossentropy: 0.1304 - categorical_accuracy: 0.9750 - val_loss: 0.4974 - val_categorical_crossentropy: 0.4974 - val_categorical_accuracy: 0.7872
# Epoch 479/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1241 - categorical_crossentropy: 0.1241 - categorical_accuracy: 0.9792 - val_loss: 0.5354 - val_categorical_crossentropy: 0.5354 - val_categorical_accuracy: 0.7660
# Epoch 480/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1288 - categorical_crossentropy: 0.1288 - categorical_accuracy: 0.9667 - val_loss: 0.5955 - val_categorical_crossentropy: 0.5955 - val_categorical_accuracy: 0.7660
# Epoch 481/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1114 - categorical_crossentropy: 0.1114 - categorical_accuracy: 0.9708 - val_loss: 0.5260 - val_categorical_crossentropy: 0.5260 - val_categorical_accuracy: 0.7872
# Epoch 482/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1614 - categorical_crossentropy: 0.1614 - categorical_accuracy: 0.9458 - val_loss: 0.5061 - val_categorical_crossentropy: 0.5061 - val_categorical_accuracy: 0.7660
# Epoch 483/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1292 - categorical_crossentropy: 0.1292 - categorical_accuracy: 0.9625 - val_loss: 0.5738 - val_categorical_crossentropy: 0.5738 - val_categorical_accuracy: 0.7660
# Epoch 484/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1336 - categorical_crossentropy: 0.1336 - categorical_accuracy: 0.9625 - val_loss: 0.5595 - val_categorical_crossentropy: 0.5595 - val_categorical_accuracy: 0.7447
# Epoch 485/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1277 - categorical_crossentropy: 0.1277 - categorical_accuracy: 0.9625 - val_loss: 0.5141 - val_categorical_crossentropy: 0.5141 - val_categorical_accuracy: 0.7872
# Epoch 486/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1239 - categorical_crossentropy: 0.1239 - categorical_accuracy: 0.9750 - val_loss: 0.5476 - val_categorical_crossentropy: 0.5476 - val_categorical_accuracy: 0.8298
# Epoch 487/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1320 - categorical_crossentropy: 0.1320 - categorical_accuracy: 0.9583 - val_loss: 0.5485 - val_categorical_crossentropy: 0.5485 - val_categorical_accuracy: 0.8298
# Epoch 488/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1439 - categorical_crossentropy: 0.1439 - categorical_accuracy: 0.9542 - val_loss: 0.5789 - val_categorical_crossentropy: 0.5789 - val_categorical_accuracy: 0.7872
# Epoch 489/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1580 - categorical_crossentropy: 0.1580 - categorical_accuracy: 0.9542 - val_loss: 0.5865 - val_categorical_crossentropy: 0.5865 - val_categorical_accuracy: 0.7660
# Epoch 490/500
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1664 - categorical_crossentropy: 0.1664 - categorical_accuracy: 0.9500 - val_loss: 0.4907 - val_categorical_crossentropy: 0.4907 - val_categorical_accuracy: 0.7660
# Epoch 491/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1275 - categorical_crossentropy: 0.1275 - categorical_accuracy: 0.9708 - val_loss: 0.5032 - val_categorical_crossentropy: 0.5032 - val_categorical_accuracy: 0.8085
# Epoch 492/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1686 - categorical_crossentropy: 0.1686 - categorical_accuracy: 0.9583 - val_loss: 0.4955 - val_categorical_crossentropy: 0.4955 - val_categorical_accuracy: 0.7872
# Epoch 493/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1124 - categorical_crossentropy: 0.1124 - categorical_accuracy: 0.9833 - val_loss: 0.5459 - val_categorical_crossentropy: 0.5459 - val_categorical_accuracy: 0.7872
# Epoch 494/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1328 - categorical_crossentropy: 0.1328 - categorical_accuracy: 0.9583 - val_loss: 0.5173 - val_categorical_crossentropy: 0.5173 - val_categorical_accuracy: 0.7872
# Epoch 495/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1300 - categorical_crossentropy: 0.1300 - categorical_accuracy: 0.9792 - val_loss: 0.5500 - val_categorical_crossentropy: 0.5500 - val_categorical_accuracy: 0.8085
# Epoch 496/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1258 - categorical_crossentropy: 0.1258 - categorical_accuracy: 0.9625 - val_loss: 0.5275 - val_categorical_crossentropy: 0.5275 - val_categorical_accuracy: 0.7872
# Epoch 497/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1312 - categorical_crossentropy: 0.1312 - categorical_accuracy: 0.9667 - val_loss: 0.5589 - val_categorical_crossentropy: 0.5589 - val_categorical_accuracy: 0.7660
# Epoch 498/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1114 - categorical_crossentropy: 0.1114 - categorical_accuracy: 0.9792 - val_loss: 0.5755 - val_categorical_crossentropy: 0.5755 - val_categorical_accuracy: 0.7660
# Epoch 499/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1431 - categorical_crossentropy: 0.1431 - categorical_accuracy: 0.9583 - val_loss: 0.5713 - val_categorical_crossentropy: 0.5713 - val_categorical_accuracy: 0.7872
# Epoch 500/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1259 - categorical_crossentropy: 0.1259 - categorical_accuracy: 0.9708 - val_loss: 0.6026 - val_categorical_crossentropy: 0.6026 - val_categorical_accuracy: 0.7234
# # Evaluate on test data
# 9/9 [==============================] - 0s 13ms/step - loss: 0.5958 - categorical_crossentropy: 0.5958 - categorical_accuracy: 0.7951
# test loss, test acc: [0.5957680013444688, 0.595768, 0.7951389]
# [[0.57638109 0.75      ]
#  [1.21075809 0.5       ]
#  [0.346636   0.88541669]
#  [0.84437674 0.64583331]
#  [1.26167142 0.4513889 ]
#  [1.31117749 0.49652779]
#  [0.4443692  0.8576389 ]
#  [0.57123053 0.77777779]
#  [0.59576797 0.7951389 ]]
