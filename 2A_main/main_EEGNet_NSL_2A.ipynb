# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/2A_main/main_EEGNet_NSL_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (109/109), done.
# Receiving objects: 100% (422/422), 1.69 GiB | 33.28 MiB/s, done.
# remote: Total 422 (delta 67), reused 0 (delta 0), pack-reused 313
# Resolving deltas: 100% (195/195), done.
# Checking out files: 100% (98/98), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting neural_structured_learning
#   Downloading https://files.pythonhosted.org/packages/08/2e/22b1385d7d601ad0c81457a5b66b3bb6f3c400348c62ea3f07a5fc1b13bc/neural_structured_learning-1.1.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 6.6MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.5)
# Installing collected packages: neural-structured-learning
# Successfully installed neural-structured-learning-1.1.0
# Using TensorFlow backend.

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()

# Initialize parameter
h_cut = [24]
drop_out = [0.25]
k_len = [32, 64, 128]
n_epochs = 100

out_f_name = 'acc_NSL_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_accuracy = zeros([nsub, nfilt,ndrop,nkl])

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])

for sub_idx, x in enumerate(range(1,2)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
      y_tr = y_tr.flatten() 
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered 

      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, 
                                               highcut=40, fs=250, order=4)  
        
      # tril_filtered = tril_filtered.transpose()
      X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          print(id_kl, id_d)
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

          adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
          adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
          # compile the model and set the optimizers
          adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
          batch_size = 32

          X_train = tf.cast(X_train, tf.float32)
          X_test = tf.cast(X_test, tf.float32)
          X_val = tf.cast(X_val, tf.float32)


          train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
          val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
          test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)

          val_steps = X_val.shape[0] // batch_size

  
          # adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=500, verbose=1)

          history = adv_model.fit(train_data, validation_data=val_data, 
                                  validation_steps=None, epochs=n_epochs, verbose=1)
          
          print('\n# Evaluate on test data')
          results = adv_model.evaluate(test_data)
          print('test loss, test acc:', results)

          loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          categorical_accuracy[sub_idx,h_indx,id_d, id_kl] = results[2]

          del model

#           del train_data, val_data, test_data

# #           from keras import backend as K 
#           K.clear_session()

np.save(out_f_name, categorical_accuracy)
# Out:
# acc_NSL_EEGNet_epochs_100_filter_[24]_drop_[0.25]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288,)
# (240, 22, 750)
# (240,)
# (47, 22, 750)
# (47,)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# 0 0
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.3862 - categorical_crossentropy: 1.3862 - categorical_accuracy: 0.2833 - val_loss: 1.3871 - val_categorical_crossentropy: 1.3871 - val_categorical_accuracy: 0.2128
# Epoch 2/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3377 - categorical_crossentropy: 1.3377 - categorical_accuracy: 0.3417 - val_loss: 1.3843 - val_categorical_crossentropy: 1.3843 - val_categorical_accuracy: 0.2553
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2800 - categorical_crossentropy: 1.2800 - categorical_accuracy: 0.4917 - val_loss: 1.3784 - val_categorical_crossentropy: 1.3784 - val_categorical_accuracy: 0.3830
# Epoch 4/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.2017 - categorical_crossentropy: 1.2017 - categorical_accuracy: 0.5667 - val_loss: 1.3647 - val_categorical_crossentropy: 1.3647 - val_categorical_accuracy: 0.4255
# Epoch 5/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.1155 - categorical_crossentropy: 1.1155 - categorical_accuracy: 0.6667 - val_loss: 1.3418 - val_categorical_crossentropy: 1.3418 - val_categorical_accuracy: 0.3830
# Epoch 6/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0300 - categorical_crossentropy: 1.0300 - categorical_accuracy: 0.6667 - val_loss: 1.3133 - val_categorical_crossentropy: 1.3133 - val_categorical_accuracy: 0.4468
# Epoch 7/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9576 - categorical_crossentropy: 0.9576 - categorical_accuracy: 0.6667 - val_loss: 1.2852 - val_categorical_crossentropy: 1.2852 - val_categorical_accuracy: 0.5106
# Epoch 8/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9232 - categorical_crossentropy: 0.9232 - categorical_accuracy: 0.6542 - val_loss: 1.2640 - val_categorical_crossentropy: 1.2640 - val_categorical_accuracy: 0.4681
# Epoch 9/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8898 - categorical_crossentropy: 0.8898 - categorical_accuracy: 0.6583 - val_loss: 1.2534 - val_categorical_crossentropy: 1.2534 - val_categorical_accuracy: 0.4681
# Epoch 10/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8423 - categorical_crossentropy: 0.8423 - categorical_accuracy: 0.6625 - val_loss: 1.2465 - val_categorical_crossentropy: 1.2465 - val_categorical_accuracy: 0.4468
# Epoch 11/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8365 - categorical_crossentropy: 0.8365 - categorical_accuracy: 0.6750 - val_loss: 1.2433 - val_categorical_crossentropy: 1.2433 - val_categorical_accuracy: 0.3830
# Epoch 12/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7895 - categorical_crossentropy: 0.7895 - categorical_accuracy: 0.6958 - val_loss: 1.2384 - val_categorical_crossentropy: 1.2384 - val_categorical_accuracy: 0.3617
# Epoch 13/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7898 - categorical_crossentropy: 0.7898 - categorical_accuracy: 0.6958 - val_loss: 1.2339 - val_categorical_crossentropy: 1.2339 - val_categorical_accuracy: 0.3404
# Epoch 14/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7642 - categorical_crossentropy: 0.7642 - categorical_accuracy: 0.7250 - val_loss: 1.2288 - val_categorical_crossentropy: 1.2288 - val_categorical_accuracy: 0.3404
# Epoch 15/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7468 - categorical_crossentropy: 0.7468 - categorical_accuracy: 0.7500 - val_loss: 1.2244 - val_categorical_crossentropy: 1.2244 - val_categorical_accuracy: 0.3191
# Epoch 16/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7331 - categorical_crossentropy: 0.7331 - categorical_accuracy: 0.7292 - val_loss: 1.2265 - val_categorical_crossentropy: 1.2265 - val_categorical_accuracy: 0.3191
# Epoch 17/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7383 - categorical_crossentropy: 0.7383 - categorical_accuracy: 0.7167 - val_loss: 1.2373 - val_categorical_crossentropy: 1.2373 - val_categorical_accuracy: 0.3191
# Epoch 18/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7184 - categorical_crossentropy: 0.7184 - categorical_accuracy: 0.7083 - val_loss: 1.2373 - val_categorical_crossentropy: 1.2373 - val_categorical_accuracy: 0.3191
# Epoch 19/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7121 - categorical_crossentropy: 0.7121 - categorical_accuracy: 0.7583 - val_loss: 1.2347 - val_categorical_crossentropy: 1.2347 - val_categorical_accuracy: 0.3191
# Epoch 20/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7039 - categorical_crossentropy: 0.7039 - categorical_accuracy: 0.7333 - val_loss: 1.2354 - val_categorical_crossentropy: 1.2354 - val_categorical_accuracy: 0.3191
# Epoch 21/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6860 - categorical_crossentropy: 0.6860 - categorical_accuracy: 0.7833 - val_loss: 1.2342 - val_categorical_crossentropy: 1.2342 - val_categorical_accuracy: 0.3191
# Epoch 22/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6805 - categorical_crossentropy: 0.6805 - categorical_accuracy: 0.7250 - val_loss: 1.2289 - val_categorical_crossentropy: 1.2289 - val_categorical_accuracy: 0.3191
# Epoch 23/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6698 - categorical_crossentropy: 0.6698 - categorical_accuracy: 0.7750 - val_loss: 1.2172 - val_categorical_crossentropy: 1.2172 - val_categorical_accuracy: 0.3191
# Epoch 24/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6762 - categorical_crossentropy: 0.6762 - categorical_accuracy: 0.7500 - val_loss: 1.2112 - val_categorical_crossentropy: 1.2112 - val_categorical_accuracy: 0.3191
# Epoch 25/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6548 - categorical_crossentropy: 0.6548 - categorical_accuracy: 0.7750 - val_loss: 1.2120 - val_categorical_crossentropy: 1.2120 - val_categorical_accuracy: 0.3191
# Epoch 26/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6552 - categorical_crossentropy: 0.6552 - categorical_accuracy: 0.7500 - val_loss: 1.1909 - val_categorical_crossentropy: 1.1909 - val_categorical_accuracy: 0.3191
# Epoch 27/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6496 - categorical_crossentropy: 0.6496 - categorical_accuracy: 0.7958 - val_loss: 1.1699 - val_categorical_crossentropy: 1.1699 - val_categorical_accuracy: 0.3404
# Epoch 28/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6443 - categorical_crossentropy: 0.6443 - categorical_accuracy: 0.8083 - val_loss: 1.1383 - val_categorical_crossentropy: 1.1383 - val_categorical_accuracy: 0.3404
# Epoch 29/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6526 - categorical_crossentropy: 0.6526 - categorical_accuracy: 0.7875 - val_loss: 1.1267 - val_categorical_crossentropy: 1.1267 - val_categorical_accuracy: 0.3404
# Epoch 30/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6444 - categorical_crossentropy: 0.6444 - categorical_accuracy: 0.8000 - val_loss: 1.1242 - val_categorical_crossentropy: 1.1242 - val_categorical_accuracy: 0.3830
# Epoch 31/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6443 - categorical_crossentropy: 0.6443 - categorical_accuracy: 0.7833 - val_loss: 1.1275 - val_categorical_crossentropy: 1.1275 - val_categorical_accuracy: 0.4255
# Epoch 32/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6370 - categorical_crossentropy: 0.6370 - categorical_accuracy: 0.7625 - val_loss: 1.1242 - val_categorical_crossentropy: 1.1242 - val_categorical_accuracy: 0.4468
# Epoch 33/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6258 - categorical_crossentropy: 0.6258 - categorical_accuracy: 0.7625 - val_loss: 1.1289 - val_categorical_crossentropy: 1.1289 - val_categorical_accuracy: 0.4681
# Epoch 34/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6174 - categorical_crossentropy: 0.6174 - categorical_accuracy: 0.8125 - val_loss: 1.1286 - val_categorical_crossentropy: 1.1286 - val_categorical_accuracy: 0.4681
# Epoch 35/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6201 - categorical_crossentropy: 0.6201 - categorical_accuracy: 0.8375 - val_loss: 1.1299 - val_categorical_crossentropy: 1.1299 - val_categorical_accuracy: 0.4468
# Epoch 36/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6235 - categorical_crossentropy: 0.6235 - categorical_accuracy: 0.8125 - val_loss: 1.1177 - val_categorical_crossentropy: 1.1177 - val_categorical_accuracy: 0.4681
# Epoch 37/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5897 - categorical_crossentropy: 0.5897 - categorical_accuracy: 0.8083 - val_loss: 1.1251 - val_categorical_crossentropy: 1.1251 - val_categorical_accuracy: 0.4468
# Epoch 38/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5904 - categorical_crossentropy: 0.5904 - categorical_accuracy: 0.8250 - val_loss: 1.1114 - val_categorical_crossentropy: 1.1114 - val_categorical_accuracy: 0.4681
# Epoch 39/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5883 - categorical_crossentropy: 0.5883 - categorical_accuracy: 0.8333 - val_loss: 1.0780 - val_categorical_crossentropy: 1.0780 - val_categorical_accuracy: 0.4894
# Epoch 40/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5845 - categorical_crossentropy: 0.5845 - categorical_accuracy: 0.8292 - val_loss: 1.0638 - val_categorical_crossentropy: 1.0638 - val_categorical_accuracy: 0.5106
# Epoch 41/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5715 - categorical_crossentropy: 0.5715 - categorical_accuracy: 0.8125 - val_loss: 1.0407 - val_categorical_crossentropy: 1.0407 - val_categorical_accuracy: 0.5106
# Epoch 42/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5818 - categorical_crossentropy: 0.5818 - categorical_accuracy: 0.8083 - val_loss: 1.0195 - val_categorical_crossentropy: 1.0195 - val_categorical_accuracy: 0.5106
# Epoch 43/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5941 - categorical_crossentropy: 0.5941 - categorical_accuracy: 0.8167 - val_loss: 1.0125 - val_categorical_crossentropy: 1.0125 - val_categorical_accuracy: 0.5319
# Epoch 44/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5804 - categorical_crossentropy: 0.5804 - categorical_accuracy: 0.8083 - val_loss: 1.0046 - val_categorical_crossentropy: 1.0046 - val_categorical_accuracy: 0.5319
# Epoch 45/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5582 - categorical_crossentropy: 0.5582 - categorical_accuracy: 0.8375 - val_loss: 0.9915 - val_categorical_crossentropy: 0.9915 - val_categorical_accuracy: 0.5532
# Epoch 46/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5626 - categorical_crossentropy: 0.5626 - categorical_accuracy: 0.7917 - val_loss: 0.9780 - val_categorical_crossentropy: 0.9780 - val_categorical_accuracy: 0.5745
# Epoch 47/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5695 - categorical_crossentropy: 0.5695 - categorical_accuracy: 0.8083 - val_loss: 0.9479 - val_categorical_crossentropy: 0.9479 - val_categorical_accuracy: 0.5745
# Epoch 48/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5735 - categorical_crossentropy: 0.5735 - categorical_accuracy: 0.8167 - val_loss: 0.9328 - val_categorical_crossentropy: 0.9328 - val_categorical_accuracy: 0.5745
# Epoch 49/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5448 - categorical_crossentropy: 0.5448 - categorical_accuracy: 0.8417 - val_loss: 0.9215 - val_categorical_crossentropy: 0.9215 - val_categorical_accuracy: 0.6170
# Epoch 50/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5467 - categorical_crossentropy: 0.5467 - categorical_accuracy: 0.8417 - val_loss: 0.9121 - val_categorical_crossentropy: 0.9121 - val_categorical_accuracy: 0.5745
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5524 - categorical_crossentropy: 0.5524 - categorical_accuracy: 0.8292 - val_loss: 0.9175 - val_categorical_crossentropy: 0.9175 - val_categorical_accuracy: 0.5957
# Epoch 52/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5519 - categorical_crossentropy: 0.5519 - categorical_accuracy: 0.8417 - val_loss: 0.9071 - val_categorical_crossentropy: 0.9071 - val_categorical_accuracy: 0.5957
# Epoch 53/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5331 - categorical_crossentropy: 0.5331 - categorical_accuracy: 0.8667 - val_loss: 0.9113 - val_categorical_crossentropy: 0.9113 - val_categorical_accuracy: 0.5957
# Epoch 54/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5408 - categorical_crossentropy: 0.5408 - categorical_accuracy: 0.8542 - val_loss: 0.8963 - val_categorical_crossentropy: 0.8963 - val_categorical_accuracy: 0.5957
# Epoch 55/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5241 - categorical_crossentropy: 0.5241 - categorical_accuracy: 0.8375 - val_loss: 0.8896 - val_categorical_crossentropy: 0.8896 - val_categorical_accuracy: 0.5745
# Epoch 56/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5419 - categorical_crossentropy: 0.5419 - categorical_accuracy: 0.8333 - val_loss: 0.8943 - val_categorical_crossentropy: 0.8943 - val_categorical_accuracy: 0.5957
# Epoch 57/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5300 - categorical_crossentropy: 0.5300 - categorical_accuracy: 0.8292 - val_loss: 0.8776 - val_categorical_crossentropy: 0.8776 - val_categorical_accuracy: 0.6170
# Epoch 58/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5553 - categorical_crossentropy: 0.5553 - categorical_accuracy: 0.8250 - val_loss: 0.8754 - val_categorical_crossentropy: 0.8754 - val_categorical_accuracy: 0.6383
# Epoch 59/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5362 - categorical_crossentropy: 0.5362 - categorical_accuracy: 0.8625 - val_loss: 0.8479 - val_categorical_crossentropy: 0.8479 - val_categorical_accuracy: 0.6809
# Epoch 60/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5176 - categorical_crossentropy: 0.5176 - categorical_accuracy: 0.8667 - val_loss: 0.8376 - val_categorical_crossentropy: 0.8376 - val_categorical_accuracy: 0.7021
# Epoch 61/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5114 - categorical_crossentropy: 0.5114 - categorical_accuracy: 0.8667 - val_loss: 0.8440 - val_categorical_crossentropy: 0.8440 - val_categorical_accuracy: 0.7021
# Epoch 62/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5157 - categorical_crossentropy: 0.5157 - categorical_accuracy: 0.8667 - val_loss: 0.8458 - val_categorical_crossentropy: 0.8458 - val_categorical_accuracy: 0.6170
# Epoch 63/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5192 - categorical_crossentropy: 0.5192 - categorical_accuracy: 0.8667 - val_loss: 0.8647 - val_categorical_crossentropy: 0.8647 - val_categorical_accuracy: 0.6383
# Epoch 64/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4995 - categorical_crossentropy: 0.4995 - categorical_accuracy: 0.8750 - val_loss: 0.8744 - val_categorical_crossentropy: 0.8744 - val_categorical_accuracy: 0.6383
# Epoch 65/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5269 - categorical_crossentropy: 0.5269 - categorical_accuracy: 0.8500 - val_loss: 0.8835 - val_categorical_crossentropy: 0.8835 - val_categorical_accuracy: 0.6383
# Epoch 66/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5038 - categorical_crossentropy: 0.5038 - categorical_accuracy: 0.8583 - val_loss: 0.8811 - val_categorical_crossentropy: 0.8811 - val_categorical_accuracy: 0.5957
# Epoch 67/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4869 - categorical_crossentropy: 0.4869 - categorical_accuracy: 0.8708 - val_loss: 0.8524 - val_categorical_crossentropy: 0.8524 - val_categorical_accuracy: 0.6170
# Epoch 68/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4924 - categorical_crossentropy: 0.4924 - categorical_accuracy: 0.8667 - val_loss: 0.8588 - val_categorical_crossentropy: 0.8588 - val_categorical_accuracy: 0.6383
# Epoch 69/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5280 - categorical_crossentropy: 0.5280 - categorical_accuracy: 0.8250 - val_loss: 0.8491 - val_categorical_crossentropy: 0.8491 - val_categorical_accuracy: 0.6596
# Epoch 70/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4890 - categorical_crossentropy: 0.4890 - categorical_accuracy: 0.8625 - val_loss: 0.8624 - val_categorical_crossentropy: 0.8624 - val_categorical_accuracy: 0.5745
# Epoch 71/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4997 - categorical_crossentropy: 0.4997 - categorical_accuracy: 0.8750 - val_loss: 0.8563 - val_categorical_crossentropy: 0.8563 - val_categorical_accuracy: 0.6596
# Epoch 72/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5036 - categorical_crossentropy: 0.5036 - categorical_accuracy: 0.8708 - val_loss: 0.8341 - val_categorical_crossentropy: 0.8341 - val_categorical_accuracy: 0.6383
# Epoch 73/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4968 - categorical_crossentropy: 0.4968 - categorical_accuracy: 0.8667 - val_loss: 0.8259 - val_categorical_crossentropy: 0.8259 - val_categorical_accuracy: 0.6809
# Epoch 74/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4804 - categorical_crossentropy: 0.4804 - categorical_accuracy: 0.8583 - val_loss: 0.8136 - val_categorical_crossentropy: 0.8136 - val_categorical_accuracy: 0.6809
# Epoch 75/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4819 - categorical_crossentropy: 0.4819 - categorical_accuracy: 0.8667 - val_loss: 0.8206 - val_categorical_crossentropy: 0.8206 - val_categorical_accuracy: 0.6596
# Epoch 76/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4619 - categorical_crossentropy: 0.4619 - categorical_accuracy: 0.8833 - val_loss: 0.8156 - val_categorical_crossentropy: 0.8156 - val_categorical_accuracy: 0.6596
# Epoch 77/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4676 - categorical_crossentropy: 0.4676 - categorical_accuracy: 0.9000 - val_loss: 0.8005 - val_categorical_crossentropy: 0.8005 - val_categorical_accuracy: 0.7021
# Epoch 78/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4696 - categorical_crossentropy: 0.4696 - categorical_accuracy: 0.8875 - val_loss: 0.8122 - val_categorical_crossentropy: 0.8122 - val_categorical_accuracy: 0.6809
# Epoch 79/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4747 - categorical_crossentropy: 0.4747 - categorical_accuracy: 0.8625 - val_loss: 0.8077 - val_categorical_crossentropy: 0.8077 - val_categorical_accuracy: 0.6809
# Epoch 80/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4628 - categorical_crossentropy: 0.4628 - categorical_accuracy: 0.8792 - val_loss: 0.8079 - val_categorical_crossentropy: 0.8079 - val_categorical_accuracy: 0.6383
# Epoch 81/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4656 - categorical_crossentropy: 0.4656 - categorical_accuracy: 0.8917 - val_loss: 0.8245 - val_categorical_crossentropy: 0.8245 - val_categorical_accuracy: 0.6383
# Epoch 82/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4563 - categorical_crossentropy: 0.4563 - categorical_accuracy: 0.8708 - val_loss: 0.8136 - val_categorical_crossentropy: 0.8136 - val_categorical_accuracy: 0.6596
# Epoch 83/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4662 - categorical_crossentropy: 0.4662 - categorical_accuracy: 0.8625 - val_loss: 0.8126 - val_categorical_crossentropy: 0.8126 - val_categorical_accuracy: 0.6809
# Epoch 84/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4644 - categorical_crossentropy: 0.4644 - categorical_accuracy: 0.8542 - val_loss: 0.8013 - val_categorical_crossentropy: 0.8013 - val_categorical_accuracy: 0.6809
# Epoch 85/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4684 - categorical_crossentropy: 0.4684 - categorical_accuracy: 0.8625 - val_loss: 0.8051 - val_categorical_crossentropy: 0.8051 - val_categorical_accuracy: 0.7234
# Epoch 86/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4426 - categorical_crossentropy: 0.4426 - categorical_accuracy: 0.9083 - val_loss: 0.8184 - val_categorical_crossentropy: 0.8184 - val_categorical_accuracy: 0.6809
# Epoch 87/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4759 - categorical_crossentropy: 0.4759 - categorical_accuracy: 0.8792 - val_loss: 0.7999 - val_categorical_crossentropy: 0.7999 - val_categorical_accuracy: 0.6809
# Epoch 88/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4379 - categorical_crossentropy: 0.4379 - categorical_accuracy: 0.8833 - val_loss: 0.8005 - val_categorical_crossentropy: 0.8005 - val_categorical_accuracy: 0.7021
# Epoch 89/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4394 - categorical_crossentropy: 0.4394 - categorical_accuracy: 0.8958 - val_loss: 0.8278 - val_categorical_crossentropy: 0.8278 - val_categorical_accuracy: 0.6596
# Epoch 90/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4502 - categorical_crossentropy: 0.4502 - categorical_accuracy: 0.8875 - val_loss: 0.8240 - val_categorical_crossentropy: 0.8240 - val_categorical_accuracy: 0.6596
# Epoch 91/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4419 - categorical_crossentropy: 0.4419 - categorical_accuracy: 0.9042 - val_loss: 0.8167 - val_categorical_crossentropy: 0.8167 - val_categorical_accuracy: 0.6383
# Epoch 92/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4389 - categorical_crossentropy: 0.4389 - categorical_accuracy: 0.8875 - val_loss: 0.8188 - val_categorical_crossentropy: 0.8188 - val_categorical_accuracy: 0.6383
# Epoch 93/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4316 - categorical_crossentropy: 0.4316 - categorical_accuracy: 0.8917 - val_loss: 0.7966 - val_categorical_crossentropy: 0.7966 - val_categorical_accuracy: 0.6596
# Epoch 94/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4341 - categorical_crossentropy: 0.4341 - categorical_accuracy: 0.8833 - val_loss: 0.7839 - val_categorical_crossentropy: 0.7839 - val_categorical_accuracy: 0.6809
# Epoch 95/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4319 - categorical_crossentropy: 0.4319 - categorical_accuracy: 0.8667 - val_loss: 0.8054 - val_categorical_crossentropy: 0.8054 - val_categorical_accuracy: 0.6596
# Epoch 96/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4314 - categorical_crossentropy: 0.4314 - categorical_accuracy: 0.8917 - val_loss: 0.8148 - val_categorical_crossentropy: 0.8148 - val_categorical_accuracy: 0.7021
# Epoch 97/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4291 - categorical_crossentropy: 0.4291 - categorical_accuracy: 0.9042 - val_loss: 0.8032 - val_categorical_crossentropy: 0.8032 - val_categorical_accuracy: 0.7021
# Epoch 98/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4258 - categorical_crossentropy: 0.4258 - categorical_accuracy: 0.8917 - val_loss: 0.7880 - val_categorical_crossentropy: 0.7880 - val_categorical_accuracy: 0.7660
# Epoch 99/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4322 - categorical_crossentropy: 0.4322 - categorical_accuracy: 0.8875 - val_loss: 0.8035 - val_categorical_crossentropy: 0.8035 - val_categorical_accuracy: 0.7234
# Epoch 100/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4171 - categorical_crossentropy: 0.4171 - categorical_accuracy: 0.9000 - val_loss: 0.8111 - val_categorical_crossentropy: 0.8111 - val_categorical_accuracy: 0.6809
#
# # Evaluate on test data
# 9/9 [==============================] - 0s 14ms/step - loss: 2.9705 - categorical_crossentropy: 2.9705 - categorical_accuracy: 0.2361
# test loss, test acc: [2.970523860719469, 2.9705238, 0.2361111]
# 1 0
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/100
# 8/8 [==============================] - 1s 70ms/step - loss: 1.4005 - categorical_crossentropy: 1.4005 - categorical_accuracy: 0.2708 - val_loss: 1.3869 - val_categorical_crossentropy: 1.3869 - val_categorical_accuracy: 0.2340
# Epoch 2/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.3636 - categorical_crossentropy: 1.3636 - categorical_accuracy: 0.3750 - val_loss: 1.3859 - val_categorical_crossentropy: 1.3859 - val_categorical_accuracy: 0.2766
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3401 - categorical_crossentropy: 1.3401 - categorical_accuracy: 0.3958 - val_loss: 1.3843 - val_categorical_crossentropy: 1.3843 - val_categorical_accuracy: 0.2979
# Epoch 4/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.3173 - categorical_crossentropy: 1.3173 - categorical_accuracy: 0.4625 - val_loss: 1.3811 - val_categorical_crossentropy: 1.3811 - val_categorical_accuracy: 0.3830
# Epoch 5/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.2713 - categorical_crossentropy: 1.2713 - categorical_accuracy: 0.5667 - val_loss: 1.3733 - val_categorical_crossentropy: 1.3733 - val_categorical_accuracy: 0.4468
# Epoch 6/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2183 - categorical_crossentropy: 1.2183 - categorical_accuracy: 0.7125 - val_loss: 1.3558 - val_categorical_crossentropy: 1.3558 - val_categorical_accuracy: 0.4681
# Epoch 7/100
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1298 - categorical_crossentropy: 1.1298 - categorical_accuracy: 0.7125 - val_loss: 1.3259 - val_categorical_crossentropy: 1.3259 - val_categorical_accuracy: 0.5319
# Epoch 8/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0494 - categorical_crossentropy: 1.0494 - categorical_accuracy: 0.7042 - val_loss: 1.2820 - val_categorical_crossentropy: 1.2820 - val_categorical_accuracy: 0.5106
# Epoch 9/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9739 - categorical_crossentropy: 0.9739 - categorical_accuracy: 0.7042 - val_loss: 1.2360 - val_categorical_crossentropy: 1.2360 - val_categorical_accuracy: 0.5745
# Epoch 10/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9141 - categorical_crossentropy: 0.9141 - categorical_accuracy: 0.6833 - val_loss: 1.1940 - val_categorical_crossentropy: 1.1940 - val_categorical_accuracy: 0.6383
# Epoch 11/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8911 - categorical_crossentropy: 0.8911 - categorical_accuracy: 0.6875 - val_loss: 1.1672 - val_categorical_crossentropy: 1.1672 - val_categorical_accuracy: 0.5532
# Epoch 12/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8487 - categorical_crossentropy: 0.8487 - categorical_accuracy: 0.6833 - val_loss: 1.1493 - val_categorical_crossentropy: 1.1493 - val_categorical_accuracy: 0.5957
# Epoch 13/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8256 - categorical_crossentropy: 0.8256 - categorical_accuracy: 0.7125 - val_loss: 1.1315 - val_categorical_crossentropy: 1.1315 - val_categorical_accuracy: 0.5532
# Epoch 14/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8091 - categorical_crossentropy: 0.8091 - categorical_accuracy: 0.7125 - val_loss: 1.1266 - val_categorical_crossentropy: 1.1266 - val_categorical_accuracy: 0.5106
# Epoch 15/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7909 - categorical_crossentropy: 0.7909 - categorical_accuracy: 0.7542 - val_loss: 1.1211 - val_categorical_crossentropy: 1.1211 - val_categorical_accuracy: 0.4894
# Epoch 16/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7831 - categorical_crossentropy: 0.7831 - categorical_accuracy: 0.7125 - val_loss: 1.1168 - val_categorical_crossentropy: 1.1168 - val_categorical_accuracy: 0.4468
# Epoch 17/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7537 - categorical_crossentropy: 0.7537 - categorical_accuracy: 0.7375 - val_loss: 1.1215 - val_categorical_crossentropy: 1.1215 - val_categorical_accuracy: 0.4894
# Epoch 18/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7462 - categorical_crossentropy: 0.7462 - categorical_accuracy: 0.7750 - val_loss: 1.1089 - val_categorical_crossentropy: 1.1089 - val_categorical_accuracy: 0.4894
# Epoch 19/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7329 - categorical_crossentropy: 0.7329 - categorical_accuracy: 0.7250 - val_loss: 1.0978 - val_categorical_crossentropy: 1.0978 - val_categorical_accuracy: 0.4894
# Epoch 20/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7212 - categorical_crossentropy: 0.7212 - categorical_accuracy: 0.7500 - val_loss: 1.0983 - val_categorical_crossentropy: 1.0983 - val_categorical_accuracy: 0.4468
# Epoch 21/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7187 - categorical_crossentropy: 0.7187 - categorical_accuracy: 0.7458 - val_loss: 1.0990 - val_categorical_crossentropy: 1.0990 - val_categorical_accuracy: 0.4468
# Epoch 22/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7027 - categorical_crossentropy: 0.7027 - categorical_accuracy: 0.7833 - val_loss: 1.0990 - val_categorical_crossentropy: 1.0990 - val_categorical_accuracy: 0.4468
# Epoch 23/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6861 - categorical_crossentropy: 0.6861 - categorical_accuracy: 0.7625 - val_loss: 1.1038 - val_categorical_crossentropy: 1.1038 - val_categorical_accuracy: 0.4681
# Epoch 24/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6689 - categorical_crossentropy: 0.6689 - categorical_accuracy: 0.8250 - val_loss: 1.1142 - val_categorical_crossentropy: 1.1142 - val_categorical_accuracy: 0.4468
# Epoch 25/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6715 - categorical_crossentropy: 0.6715 - categorical_accuracy: 0.8000 - val_loss: 1.1022 - val_categorical_crossentropy: 1.1022 - val_categorical_accuracy: 0.4681
# Epoch 26/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6739 - categorical_crossentropy: 0.6739 - categorical_accuracy: 0.7875 - val_loss: 1.0848 - val_categorical_crossentropy: 1.0848 - val_categorical_accuracy: 0.4681
# Epoch 27/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6521 - categorical_crossentropy: 0.6521 - categorical_accuracy: 0.7792 - val_loss: 1.0757 - val_categorical_crossentropy: 1.0757 - val_categorical_accuracy: 0.4894
# Epoch 28/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6494 - categorical_crossentropy: 0.6494 - categorical_accuracy: 0.7875 - val_loss: 1.0718 - val_categorical_crossentropy: 1.0718 - val_categorical_accuracy: 0.4894
# Epoch 29/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6469 - categorical_crossentropy: 0.6469 - categorical_accuracy: 0.8042 - val_loss: 1.0672 - val_categorical_crossentropy: 1.0672 - val_categorical_accuracy: 0.4681
# Epoch 30/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6341 - categorical_crossentropy: 0.6341 - categorical_accuracy: 0.8083 - val_loss: 1.0432 - val_categorical_crossentropy: 1.0432 - val_categorical_accuracy: 0.5106
# Epoch 31/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6325 - categorical_crossentropy: 0.6325 - categorical_accuracy: 0.8333 - val_loss: 1.0356 - val_categorical_crossentropy: 1.0356 - val_categorical_accuracy: 0.4894
# Epoch 32/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6174 - categorical_crossentropy: 0.6174 - categorical_accuracy: 0.8167 - val_loss: 1.0565 - val_categorical_crossentropy: 1.0565 - val_categorical_accuracy: 0.4894
# Epoch 33/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6018 - categorical_crossentropy: 0.6018 - categorical_accuracy: 0.8083 - val_loss: 1.0632 - val_categorical_crossentropy: 1.0632 - val_categorical_accuracy: 0.4894
# Epoch 34/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6210 - categorical_crossentropy: 0.6210 - categorical_accuracy: 0.8250 - val_loss: 1.0423 - val_categorical_crossentropy: 1.0423 - val_categorical_accuracy: 0.5106
# Epoch 35/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6010 - categorical_crossentropy: 0.6010 - categorical_accuracy: 0.8208 - val_loss: 1.0320 - val_categorical_crossentropy: 1.0320 - val_categorical_accuracy: 0.5106
# Epoch 36/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6014 - categorical_crossentropy: 0.6014 - categorical_accuracy: 0.8500 - val_loss: 1.0091 - val_categorical_crossentropy: 1.0091 - val_categorical_accuracy: 0.4894
# Epoch 37/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5953 - categorical_crossentropy: 0.5953 - categorical_accuracy: 0.8333 - val_loss: 0.9988 - val_categorical_crossentropy: 0.9988 - val_categorical_accuracy: 0.4681
# Epoch 38/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5923 - categorical_crossentropy: 0.5923 - categorical_accuracy: 0.8458 - val_loss: 1.0013 - val_categorical_crossentropy: 1.0013 - val_categorical_accuracy: 0.5106
# Epoch 39/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5846 - categorical_crossentropy: 0.5846 - categorical_accuracy: 0.8208 - val_loss: 0.9990 - val_categorical_crossentropy: 0.9990 - val_categorical_accuracy: 0.4894
# Epoch 40/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5643 - categorical_crossentropy: 0.5643 - categorical_accuracy: 0.8458 - val_loss: 1.0042 - val_categorical_crossentropy: 1.0042 - val_categorical_accuracy: 0.4894
# Epoch 41/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5685 - categorical_crossentropy: 0.5685 - categorical_accuracy: 0.8333 - val_loss: 0.9761 - val_categorical_crossentropy: 0.9761 - val_categorical_accuracy: 0.5319
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5730 - categorical_crossentropy: 0.5730 - categorical_accuracy: 0.8667 - val_loss: 0.9517 - val_categorical_crossentropy: 0.9517 - val_categorical_accuracy: 0.4894
# Epoch 43/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5560 - categorical_crossentropy: 0.5560 - categorical_accuracy: 0.8792 - val_loss: 0.9372 - val_categorical_crossentropy: 0.9372 - val_categorical_accuracy: 0.5532
# Epoch 44/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5583 - categorical_crossentropy: 0.5583 - categorical_accuracy: 0.8708 - val_loss: 0.9305 - val_categorical_crossentropy: 0.9305 - val_categorical_accuracy: 0.5319
# Epoch 45/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5579 - categorical_crossentropy: 0.5579 - categorical_accuracy: 0.8417 - val_loss: 0.9178 - val_categorical_crossentropy: 0.9178 - val_categorical_accuracy: 0.5745
# Epoch 46/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5402 - categorical_crossentropy: 0.5402 - categorical_accuracy: 0.8708 - val_loss: 0.9117 - val_categorical_crossentropy: 0.9117 - val_categorical_accuracy: 0.5745
# Epoch 47/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5387 - categorical_crossentropy: 0.5387 - categorical_accuracy: 0.8500 - val_loss: 0.9186 - val_categorical_crossentropy: 0.9186 - val_categorical_accuracy: 0.5319
# Epoch 48/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5213 - categorical_crossentropy: 0.5213 - categorical_accuracy: 0.8833 - val_loss: 0.9322 - val_categorical_crossentropy: 0.9322 - val_categorical_accuracy: 0.5106
# Epoch 49/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5403 - categorical_crossentropy: 0.5403 - categorical_accuracy: 0.8750 - val_loss: 0.9355 - val_categorical_crossentropy: 0.9355 - val_categorical_accuracy: 0.5319
# Epoch 50/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5348 - categorical_crossentropy: 0.5348 - categorical_accuracy: 0.8708 - val_loss: 0.9293 - val_categorical_crossentropy: 0.9293 - val_categorical_accuracy: 0.5745
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5319 - categorical_crossentropy: 0.5319 - categorical_accuracy: 0.8667 - val_loss: 0.9247 - val_categorical_crossentropy: 0.9247 - val_categorical_accuracy: 0.5319
# Epoch 52/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5394 - categorical_crossentropy: 0.5394 - categorical_accuracy: 0.8667 - val_loss: 0.9163 - val_categorical_crossentropy: 0.9163 - val_categorical_accuracy: 0.5532
# Epoch 53/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5311 - categorical_crossentropy: 0.5311 - categorical_accuracy: 0.8583 - val_loss: 0.9168 - val_categorical_crossentropy: 0.9168 - val_categorical_accuracy: 0.5532
# Epoch 54/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5058 - categorical_crossentropy: 0.5058 - categorical_accuracy: 0.8792 - val_loss: 0.8910 - val_categorical_crossentropy: 0.8910 - val_categorical_accuracy: 0.5957
# Epoch 55/100
# 1/8 [==>...........................] - ETA: 0s - loss: 0.5916 - categorical_crossentropy: 0.5916 - categorical_accuracy: 0.8750
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7faccb8a3cf8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 758, in __del__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 753, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-236532e2ef79> in <module>()
#     131
#     132           history = adv_model.fit(train_data, validation_data=val_data,
# --> 133                                   validation_steps=None, epochs=n_epochs, verbose=1)
#     134
#     135           print('\n# Evaluate on test data')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     298           else:
#     299             actual_inputs = ins()
# --> 300           batch_outs = f(actual_inputs)
#     301         except errors.OutOfRangeError:
#     302           if is_dataset:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
