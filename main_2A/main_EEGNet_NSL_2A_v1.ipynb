# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_2A/main_EEGNet_NSL_2A_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 497 (delta 10), reused 0 (delta 0), pack-reused 477
# Receiving objects: 100% (497/497), 1.69 GiB | 48.44 MiB/s, done.
# Resolving deltas: 100% (240/240), done.
# Checking out files: 100% (95/95), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf

# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Requirement already satisfied: neural_structured_learning in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.5)

# %%
from numpy import zeros
K.clear_session()

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])


# Initialize parameter
h_cut = [40]
drop_out = [0.5]
k_len = [15, 30, 60]
n_epochs = 500

out_f_name = 'acc_NSL_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_accuracy = zeros([nsub, nfilt,ndrop,nkl])

for sub_idx, x in enumerate(range(1,10)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered
      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250,order=4)
        # tril_filtered = tril_filtered.transpose()
        X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test = X_test.reshape(X_test.shape[0], kernels, chans, samples)
      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

          adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
          adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
          # compile the model and set the optimizers
          adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
          batch_size = 32

          X_train = tf.cast(X_train, tf.float32)
          X_test = tf.cast(X_test, tf.float32)
          X_val = tf.cast(X_val, tf.float32)

          train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
          val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
          test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)
          val_steps = X_val.shape[0] // batch_size
          
          history = adv_model.fit(train_data, validation_data=val_data, 
                                  validation_steps=None, epochs=n_epochs, verbose=1)
          
          print('\n# Evaluate on test data')
          results = adv_model.evaluate(test_data)
          print('test loss, test acc:', results)

          # loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          # categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          categorical_accuracy[sub_idx,h_indx,id_d, id_kl] = results[2]

          # from keras import backend as K 
          # Do some code, e.g. train and save model
          # K.clear_session()


np.save(out_f_name, categorical_accuracy)
# Out:
# acc_NSL_EEGNet_epochs_500_filter_[40]_drop_[0.5]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288, 1)
# (240, 22, 750)
# (240, 1)
# (47, 22, 750)
# (47, 1)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/neural_structured_learning/keras/adversarial_regularization.py:167: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/500
# 8/8 [==============================] - 2s 247ms/step - loss: 1.4032 - categorical_crossentropy: 1.4032 - categorical_accuracy: 0.2750 - val_loss: 1.3894 - val_categorical_crossentropy: 1.3894 - val_categorical_accuracy: 0.2128
# Epoch 2/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3854 - categorical_crossentropy: 1.3854 - categorical_accuracy: 0.2583 - val_loss: 1.3879 - val_categorical_crossentropy: 1.3879 - val_categorical_accuracy: 0.2553
# Epoch 3/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3655 - categorical_crossentropy: 1.3655 - categorical_accuracy: 0.3083 - val_loss: 1.3869 - val_categorical_crossentropy: 1.3869 - val_categorical_accuracy: 0.2766
# Epoch 4/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3458 - categorical_crossentropy: 1.3458 - categorical_accuracy: 0.3750 - val_loss: 1.3854 - val_categorical_crossentropy: 1.3854 - val_categorical_accuracy: 0.2553
# Epoch 5/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3442 - categorical_crossentropy: 1.3442 - categorical_accuracy: 0.3208 - val_loss: 1.3834 - val_categorical_crossentropy: 1.3834 - val_categorical_accuracy: 0.2766
# Epoch 6/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3384 - categorical_crossentropy: 1.3384 - categorical_accuracy: 0.3125 - val_loss: 1.3806 - val_categorical_crossentropy: 1.3806 - val_categorical_accuracy: 0.3617
# Epoch 7/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3131 - categorical_crossentropy: 1.3131 - categorical_accuracy: 0.3667 - val_loss: 1.3766 - val_categorical_crossentropy: 1.3766 - val_categorical_accuracy: 0.3830
# Epoch 8/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.2888 - categorical_crossentropy: 1.2888 - categorical_accuracy: 0.4750 - val_loss: 1.3709 - val_categorical_crossentropy: 1.3709 - val_categorical_accuracy: 0.3617
# Epoch 9/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.2617 - categorical_crossentropy: 1.2617 - categorical_accuracy: 0.4958 - val_loss: 1.3623 - val_categorical_crossentropy: 1.3623 - val_categorical_accuracy: 0.4043
# Epoch 10/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.2361 - categorical_crossentropy: 1.2361 - categorical_accuracy: 0.5000 - val_loss: 1.3500 - val_categorical_crossentropy: 1.3500 - val_categorical_accuracy: 0.4043
# Epoch 11/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1934 - categorical_crossentropy: 1.1934 - categorical_accuracy: 0.5708 - val_loss: 1.3312 - val_categorical_crossentropy: 1.3312 - val_categorical_accuracy: 0.4043
# Epoch 12/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1776 - categorical_crossentropy: 1.1776 - categorical_accuracy: 0.5708 - val_loss: 1.3089 - val_categorical_crossentropy: 1.3089 - val_categorical_accuracy: 0.4255
# Epoch 13/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1384 - categorical_crossentropy: 1.1384 - categorical_accuracy: 0.5833 - val_loss: 1.2869 - val_categorical_crossentropy: 1.2869 - val_categorical_accuracy: 0.4681
# Epoch 14/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0954 - categorical_crossentropy: 1.0954 - categorical_accuracy: 0.5833 - val_loss: 1.2594 - val_categorical_crossentropy: 1.2594 - val_categorical_accuracy: 0.5106
# Epoch 15/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0513 - categorical_crossentropy: 1.0513 - categorical_accuracy: 0.6375 - val_loss: 1.2347 - val_categorical_crossentropy: 1.2347 - val_categorical_accuracy: 0.4681
# Epoch 16/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0338 - categorical_crossentropy: 1.0338 - categorical_accuracy: 0.6000 - val_loss: 1.2233 - val_categorical_crossentropy: 1.2233 - val_categorical_accuracy: 0.4468
# Epoch 17/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9739 - categorical_crossentropy: 0.9739 - categorical_accuracy: 0.6375 - val_loss: 1.2223 - val_categorical_crossentropy: 1.2223 - val_categorical_accuracy: 0.3830
# Epoch 18/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9247 - categorical_crossentropy: 0.9247 - categorical_accuracy: 0.6208 - val_loss: 1.2347 - val_categorical_crossentropy: 1.2347 - val_categorical_accuracy: 0.3830
# Epoch 19/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9300 - categorical_crossentropy: 0.9300 - categorical_accuracy: 0.6458 - val_loss: 1.2542 - val_categorical_crossentropy: 1.2542 - val_categorical_accuracy: 0.2979
# Epoch 20/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9022 - categorical_crossentropy: 0.9022 - categorical_accuracy: 0.6083 - val_loss: 1.2717 - val_categorical_crossentropy: 1.2717 - val_categorical_accuracy: 0.2766
# Epoch 21/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8783 - categorical_crossentropy: 0.8783 - categorical_accuracy: 0.6500 - val_loss: 1.2977 - val_categorical_crossentropy: 1.2977 - val_categorical_accuracy: 0.2766
# Epoch 22/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8671 - categorical_crossentropy: 0.8671 - categorical_accuracy: 0.6250 - val_loss: 1.3135 - val_categorical_crossentropy: 1.3135 - val_categorical_accuracy: 0.2766
# Epoch 23/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8579 - categorical_crossentropy: 0.8579 - categorical_accuracy: 0.6583 - val_loss: 1.3284 - val_categorical_crossentropy: 1.3284 - val_categorical_accuracy: 0.2766
# Epoch 24/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8388 - categorical_crossentropy: 0.8388 - categorical_accuracy: 0.6667 - val_loss: 1.3410 - val_categorical_crossentropy: 1.3410 - val_categorical_accuracy: 0.2553
# Epoch 25/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8549 - categorical_crossentropy: 0.8549 - categorical_accuracy: 0.6167 - val_loss: 1.3469 - val_categorical_crossentropy: 1.3469 - val_categorical_accuracy: 0.2553
# Epoch 26/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7986 - categorical_crossentropy: 0.7986 - categorical_accuracy: 0.6917 - val_loss: 1.3728 - val_categorical_crossentropy: 1.3728 - val_categorical_accuracy: 0.2553
# Epoch 27/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7973 - categorical_crossentropy: 0.7973 - categorical_accuracy: 0.7167 - val_loss: 1.3816 - val_categorical_crossentropy: 1.3816 - val_categorical_accuracy: 0.2766
# Epoch 28/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8016 - categorical_crossentropy: 0.8016 - categorical_accuracy: 0.6833 - val_loss: 1.4065 - val_categorical_crossentropy: 1.4065 - val_categorical_accuracy: 0.2553
# Epoch 29/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8161 - categorical_crossentropy: 0.8161 - categorical_accuracy: 0.6792 - val_loss: 1.4019 - val_categorical_crossentropy: 1.4019 - val_categorical_accuracy: 0.2766
# Epoch 30/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8033 - categorical_crossentropy: 0.8033 - categorical_accuracy: 0.6667 - val_loss: 1.3752 - val_categorical_crossentropy: 1.3752 - val_categorical_accuracy: 0.2766
# Epoch 31/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7787 - categorical_crossentropy: 0.7787 - categorical_accuracy: 0.6833 - val_loss: 1.3490 - val_categorical_crossentropy: 1.3490 - val_categorical_accuracy: 0.2979
# Epoch 32/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8163 - categorical_crossentropy: 0.8163 - categorical_accuracy: 0.6625 - val_loss: 1.3508 - val_categorical_crossentropy: 1.3508 - val_categorical_accuracy: 0.2979
# Epoch 33/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7893 - categorical_crossentropy: 0.7893 - categorical_accuracy: 0.6750 - val_loss: 1.3584 - val_categorical_crossentropy: 1.3584 - val_categorical_accuracy: 0.2766
# Epoch 34/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7694 - categorical_crossentropy: 0.7694 - categorical_accuracy: 0.6917 - val_loss: 1.3481 - val_categorical_crossentropy: 1.3481 - val_categorical_accuracy: 0.2979
# Epoch 35/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7414 - categorical_crossentropy: 0.7414 - categorical_accuracy: 0.6917 - val_loss: 1.3308 - val_categorical_crossentropy: 1.3308 - val_categorical_accuracy: 0.3191
# Epoch 36/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7625 - categorical_crossentropy: 0.7625 - categorical_accuracy: 0.6833 - val_loss: 1.2887 - val_categorical_crossentropy: 1.2887 - val_categorical_accuracy: 0.3830
# Epoch 37/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7437 - categorical_crossentropy: 0.7437 - categorical_accuracy: 0.7500 - val_loss: 1.2357 - val_categorical_crossentropy: 1.2357 - val_categorical_accuracy: 0.4043
# Epoch 38/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7654 - categorical_crossentropy: 0.7654 - categorical_accuracy: 0.6958 - val_loss: 1.2035 - val_categorical_crossentropy: 1.2035 - val_categorical_accuracy: 0.4043
# Epoch 39/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7690 - categorical_crossentropy: 0.7690 - categorical_accuracy: 0.6750 - val_loss: 1.1464 - val_categorical_crossentropy: 1.1464 - val_categorical_accuracy: 0.4255
# Epoch 40/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7296 - categorical_crossentropy: 0.7296 - categorical_accuracy: 0.7250 - val_loss: 1.1041 - val_categorical_crossentropy: 1.1041 - val_categorical_accuracy: 0.4255
# Epoch 41/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7543 - categorical_crossentropy: 0.7543 - categorical_accuracy: 0.7000 - val_loss: 1.0623 - val_categorical_crossentropy: 1.0623 - val_categorical_accuracy: 0.4468
# Epoch 42/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7327 - categorical_crossentropy: 0.7327 - categorical_accuracy: 0.7042 - val_loss: 1.0604 - val_categorical_crossentropy: 1.0604 - val_categorical_accuracy: 0.4255
# Epoch 43/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7272 - categorical_crossentropy: 0.7272 - categorical_accuracy: 0.7208 - val_loss: 1.0834 - val_categorical_crossentropy: 1.0834 - val_categorical_accuracy: 0.4255
# Epoch 44/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7400 - categorical_crossentropy: 0.7400 - categorical_accuracy: 0.7292 - val_loss: 1.0592 - val_categorical_crossentropy: 1.0592 - val_categorical_accuracy: 0.4468
# Epoch 45/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7232 - categorical_crossentropy: 0.7232 - categorical_accuracy: 0.6917 - val_loss: 1.0275 - val_categorical_crossentropy: 1.0275 - val_categorical_accuracy: 0.4468
# Epoch 46/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7272 - categorical_crossentropy: 0.7272 - categorical_accuracy: 0.7208 - val_loss: 0.9852 - val_categorical_crossentropy: 0.9852 - val_categorical_accuracy: 0.4894
# Epoch 47/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7136 - categorical_crossentropy: 0.7136 - categorical_accuracy: 0.7042 - val_loss: 0.9471 - val_categorical_crossentropy: 0.9471 - val_categorical_accuracy: 0.5106
# Epoch 48/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7023 - categorical_crossentropy: 0.7023 - categorical_accuracy: 0.7500 - val_loss: 0.9346 - val_categorical_crossentropy: 0.9346 - val_categorical_accuracy: 0.5957
# Epoch 49/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6903 - categorical_crossentropy: 0.6903 - categorical_accuracy: 0.7417 - val_loss: 0.9304 - val_categorical_crossentropy: 0.9304 - val_categorical_accuracy: 0.5532
# Epoch 50/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7088 - categorical_crossentropy: 0.7088 - categorical_accuracy: 0.7125 - val_loss: 0.9270 - val_categorical_crossentropy: 0.9270 - val_categorical_accuracy: 0.5319
# Epoch 51/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7021 - categorical_crossentropy: 0.7021 - categorical_accuracy: 0.7167 - val_loss: 0.8970 - val_categorical_crossentropy: 0.8970 - val_categorical_accuracy: 0.5745
# Epoch 52/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7186 - categorical_crossentropy: 0.7186 - categorical_accuracy: 0.7375 - val_loss: 0.8746 - val_categorical_crossentropy: 0.8746 - val_categorical_accuracy: 0.6596
# Epoch 53/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6988 - categorical_crossentropy: 0.6988 - categorical_accuracy: 0.7333 - val_loss: 0.8651 - val_categorical_crossentropy: 0.8651 - val_categorical_accuracy: 0.6596
# Epoch 54/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7202 - categorical_crossentropy: 0.7202 - categorical_accuracy: 0.7375 - val_loss: 0.8843 - val_categorical_crossentropy: 0.8843 - val_categorical_accuracy: 0.5957
# Epoch 55/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6722 - categorical_crossentropy: 0.6722 - categorical_accuracy: 0.7542 - val_loss: 0.8843 - val_categorical_crossentropy: 0.8843 - val_categorical_accuracy: 0.5957
# Epoch 56/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6892 - categorical_crossentropy: 0.6892 - categorical_accuracy: 0.7542 - val_loss: 0.8643 - val_categorical_crossentropy: 0.8643 - val_categorical_accuracy: 0.6596
# Epoch 57/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6653 - categorical_crossentropy: 0.6653 - categorical_accuracy: 0.7458 - val_loss: 0.8951 - val_categorical_crossentropy: 0.8951 - val_categorical_accuracy: 0.5532
# Epoch 58/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6996 - categorical_crossentropy: 0.6996 - categorical_accuracy: 0.7250 - val_loss: 0.8961 - val_categorical_crossentropy: 0.8961 - val_categorical_accuracy: 0.5532
# Epoch 59/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6770 - categorical_crossentropy: 0.6770 - categorical_accuracy: 0.7333 - val_loss: 0.8647 - val_categorical_crossentropy: 0.8647 - val_categorical_accuracy: 0.6383
# Epoch 60/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6649 - categorical_crossentropy: 0.6649 - categorical_accuracy: 0.7708 - val_loss: 0.8534 - val_categorical_crossentropy: 0.8534 - val_categorical_accuracy: 0.6809
# Epoch 61/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6715 - categorical_crossentropy: 0.6715 - categorical_accuracy: 0.7292 - val_loss: 0.8433 - val_categorical_crossentropy: 0.8433 - val_categorical_accuracy: 0.7234
# Epoch 62/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6868 - categorical_crossentropy: 0.6868 - categorical_accuracy: 0.7333 - val_loss: 0.8398 - val_categorical_crossentropy: 0.8398 - val_categorical_accuracy: 0.7021
# Epoch 63/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6888 - categorical_crossentropy: 0.6888 - categorical_accuracy: 0.7375 - val_loss: 0.8299 - val_categorical_crossentropy: 0.8299 - val_categorical_accuracy: 0.6596
# Epoch 64/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6580 - categorical_crossentropy: 0.6580 - categorical_accuracy: 0.7417 - val_loss: 0.8551 - val_categorical_crossentropy: 0.8551 - val_categorical_accuracy: 0.5745
# Epoch 65/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6640 - categorical_crossentropy: 0.6640 - categorical_accuracy: 0.7333 - val_loss: 0.8636 - val_categorical_crossentropy: 0.8636 - val_categorical_accuracy: 0.5532
# Epoch 66/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6678 - categorical_crossentropy: 0.6678 - categorical_accuracy: 0.7583 - val_loss: 0.8600 - val_categorical_crossentropy: 0.8600 - val_categorical_accuracy: 0.6170
# Epoch 67/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6477 - categorical_crossentropy: 0.6477 - categorical_accuracy: 0.7750 - val_loss: 0.8235 - val_categorical_crossentropy: 0.8235 - val_categorical_accuracy: 0.7021
# Epoch 68/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6680 - categorical_crossentropy: 0.6680 - categorical_accuracy: 0.7333 - val_loss: 0.8105 - val_categorical_crossentropy: 0.8105 - val_categorical_accuracy: 0.7021
# Epoch 69/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6646 - categorical_crossentropy: 0.6646 - categorical_accuracy: 0.7417 - val_loss: 0.7881 - val_categorical_crossentropy: 0.7881 - val_categorical_accuracy: 0.7234
# Epoch 70/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6290 - categorical_crossentropy: 0.6290 - categorical_accuracy: 0.7625 - val_loss: 0.7970 - val_categorical_crossentropy: 0.7970 - val_categorical_accuracy: 0.7234
# Epoch 71/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6524 - categorical_crossentropy: 0.6524 - categorical_accuracy: 0.7917 - val_loss: 0.8047 - val_categorical_crossentropy: 0.8047 - val_categorical_accuracy: 0.6596
# Epoch 72/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6205 - categorical_crossentropy: 0.6205 - categorical_accuracy: 0.7625 - val_loss: 0.8070 - val_categorical_crossentropy: 0.8070 - val_categorical_accuracy: 0.6809
# Epoch 73/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6578 - categorical_crossentropy: 0.6578 - categorical_accuracy: 0.7375 - val_loss: 0.7958 - val_categorical_crossentropy: 0.7958 - val_categorical_accuracy: 0.7021
# Epoch 74/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6050 - categorical_crossentropy: 0.6050 - categorical_accuracy: 0.7625 - val_loss: 0.8051 - val_categorical_crossentropy: 0.8051 - val_categorical_accuracy: 0.7872
# Epoch 75/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6554 - categorical_crossentropy: 0.6554 - categorical_accuracy: 0.7583 - val_loss: 0.8168 - val_categorical_crossentropy: 0.8168 - val_categorical_accuracy: 0.7234
# Epoch 76/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6480 - categorical_crossentropy: 0.6480 - categorical_accuracy: 0.7750 - val_loss: 0.7901 - val_categorical_crossentropy: 0.7901 - val_categorical_accuracy: 0.6596
# Epoch 77/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6432 - categorical_crossentropy: 0.6432 - categorical_accuracy: 0.7583 - val_loss: 0.7758 - val_categorical_crossentropy: 0.7758 - val_categorical_accuracy: 0.7234
# Epoch 78/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6375 - categorical_crossentropy: 0.6375 - categorical_accuracy: 0.7583 - val_loss: 0.8086 - val_categorical_crossentropy: 0.8086 - val_categorical_accuracy: 0.6383
# Epoch 79/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6163 - categorical_crossentropy: 0.6163 - categorical_accuracy: 0.7875 - val_loss: 0.7911 - val_categorical_crossentropy: 0.7911 - val_categorical_accuracy: 0.7021
# Epoch 80/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6287 - categorical_crossentropy: 0.6287 - categorical_accuracy: 0.7708 - val_loss: 0.7792 - val_categorical_crossentropy: 0.7792 - val_categorical_accuracy: 0.6596
# Epoch 81/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6353 - categorical_crossentropy: 0.6353 - categorical_accuracy: 0.7958 - val_loss: 0.7767 - val_categorical_crossentropy: 0.7767 - val_categorical_accuracy: 0.6809
# Epoch 82/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6112 - categorical_crossentropy: 0.6112 - categorical_accuracy: 0.7500 - val_loss: 0.7675 - val_categorical_crossentropy: 0.7675 - val_categorical_accuracy: 0.6596
# Epoch 83/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6023 - categorical_crossentropy: 0.6023 - categorical_accuracy: 0.7708 - val_loss: 0.7769 - val_categorical_crossentropy: 0.7769 - val_categorical_accuracy: 0.7021
# Epoch 84/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6469 - categorical_crossentropy: 0.6469 - categorical_accuracy: 0.7292 - val_loss: 0.7780 - val_categorical_crossentropy: 0.7780 - val_categorical_accuracy: 0.7234
# Epoch 85/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6140 - categorical_crossentropy: 0.6140 - categorical_accuracy: 0.7583 - val_loss: 0.7750 - val_categorical_crossentropy: 0.7750 - val_categorical_accuracy: 0.7234
# Epoch 86/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6415 - categorical_crossentropy: 0.6415 - categorical_accuracy: 0.7500 - val_loss: 0.7737 - val_categorical_crossentropy: 0.7737 - val_categorical_accuracy: 0.7234
# Epoch 87/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6483 - categorical_crossentropy: 0.6483 - categorical_accuracy: 0.7333 - val_loss: 0.7618 - val_categorical_crossentropy: 0.7618 - val_categorical_accuracy: 0.7021
# Epoch 88/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6311 - categorical_crossentropy: 0.6311 - categorical_accuracy: 0.7667 - val_loss: 0.7799 - val_categorical_crossentropy: 0.7799 - val_categorical_accuracy: 0.7234
# Epoch 89/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6202 - categorical_crossentropy: 0.6202 - categorical_accuracy: 0.7625 - val_loss: 0.7772 - val_categorical_crossentropy: 0.7772 - val_categorical_accuracy: 0.7234
# Epoch 90/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6348 - categorical_crossentropy: 0.6348 - categorical_accuracy: 0.7458 - val_loss: 0.7852 - val_categorical_crossentropy: 0.7852 - val_categorical_accuracy: 0.7234
# Epoch 91/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6469 - categorical_crossentropy: 0.6469 - categorical_accuracy: 0.7833 - val_loss: 0.7858 - val_categorical_crossentropy: 0.7858 - val_categorical_accuracy: 0.7021
# Epoch 92/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6014 - categorical_crossentropy: 0.6014 - categorical_accuracy: 0.7708 - val_loss: 0.7927 - val_categorical_crossentropy: 0.7927 - val_categorical_accuracy: 0.6809
# Epoch 93/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5981 - categorical_crossentropy: 0.5981 - categorical_accuracy: 0.7667 - val_loss: 0.7656 - val_categorical_crossentropy: 0.7656 - val_categorical_accuracy: 0.7021
# Epoch 94/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6105 - categorical_crossentropy: 0.6105 - categorical_accuracy: 0.7958 - val_loss: 0.7754 - val_categorical_crossentropy: 0.7754 - val_categorical_accuracy: 0.6809
# Epoch 95/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6282 - categorical_crossentropy: 0.6282 - categorical_accuracy: 0.7417 - val_loss: 0.7944 - val_categorical_crossentropy: 0.7944 - val_categorical_accuracy: 0.6809
# Epoch 96/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5896 - categorical_crossentropy: 0.5896 - categorical_accuracy: 0.7583 - val_loss: 0.8036 - val_categorical_crossentropy: 0.8036 - val_categorical_accuracy: 0.7021
# Epoch 97/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6152 - categorical_crossentropy: 0.6152 - categorical_accuracy: 0.7792 - val_loss: 0.7984 - val_categorical_crossentropy: 0.7984 - val_categorical_accuracy: 0.7021
# Epoch 98/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6185 - categorical_crossentropy: 0.6185 - categorical_accuracy: 0.7375 - val_loss: 0.7908 - val_categorical_crossentropy: 0.7908 - val_categorical_accuracy: 0.7021
# Epoch 99/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5975 - categorical_crossentropy: 0.5975 - categorical_accuracy: 0.7875 - val_loss: 0.7995 - val_categorical_crossentropy: 0.7995 - val_categorical_accuracy: 0.7021
# Epoch 100/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6219 - categorical_crossentropy: 0.6219 - categorical_accuracy: 0.7583 - val_loss: 0.7891 - val_categorical_crossentropy: 0.7891 - val_categorical_accuracy: 0.6809
# Epoch 101/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5577 - categorical_crossentropy: 0.5577 - categorical_accuracy: 0.8083 - val_loss: 0.7830 - val_categorical_crossentropy: 0.7830 - val_categorical_accuracy: 0.7021
# Epoch 102/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5878 - categorical_crossentropy: 0.5878 - categorical_accuracy: 0.8042 - val_loss: 0.7879 - val_categorical_crossentropy: 0.7879 - val_categorical_accuracy: 0.7447
# Epoch 103/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5929 - categorical_crossentropy: 0.5929 - categorical_accuracy: 0.7792 - val_loss: 0.7814 - val_categorical_crossentropy: 0.7814 - val_categorical_accuracy: 0.7660
# Epoch 104/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6109 - categorical_crossentropy: 0.6109 - categorical_accuracy: 0.7583 - val_loss: 0.7524 - val_categorical_crossentropy: 0.7524 - val_categorical_accuracy: 0.7872
# Epoch 105/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5650 - categorical_crossentropy: 0.5650 - categorical_accuracy: 0.8000 - val_loss: 0.7480 - val_categorical_crossentropy: 0.7480 - val_categorical_accuracy: 0.7660
# Epoch 106/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5609 - categorical_crossentropy: 0.5609 - categorical_accuracy: 0.8250 - val_loss: 0.7620 - val_categorical_crossentropy: 0.7620 - val_categorical_accuracy: 0.7021
# Epoch 107/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5930 - categorical_crossentropy: 0.5930 - categorical_accuracy: 0.7708 - val_loss: 0.7581 - val_categorical_crossentropy: 0.7581 - val_categorical_accuracy: 0.7872
# Epoch 108/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5755 - categorical_crossentropy: 0.5755 - categorical_accuracy: 0.7917 - val_loss: 0.7453 - val_categorical_crossentropy: 0.7453 - val_categorical_accuracy: 0.7660
# Epoch 109/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5699 - categorical_crossentropy: 0.5699 - categorical_accuracy: 0.8000 - val_loss: 0.7325 - val_categorical_crossentropy: 0.7325 - val_categorical_accuracy: 0.7447
# Epoch 110/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5818 - categorical_crossentropy: 0.5818 - categorical_accuracy: 0.7708 - val_loss: 0.7334 - val_categorical_crossentropy: 0.7334 - val_categorical_accuracy: 0.7660
# Epoch 111/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5961 - categorical_crossentropy: 0.5961 - categorical_accuracy: 0.7708 - val_loss: 0.7524 - val_categorical_crossentropy: 0.7524 - val_categorical_accuracy: 0.7660
# Epoch 112/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5912 - categorical_crossentropy: 0.5912 - categorical_accuracy: 0.8125 - val_loss: 0.7524 - val_categorical_crossentropy: 0.7524 - val_categorical_accuracy: 0.7660
# Epoch 113/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5431 - categorical_crossentropy: 0.5431 - categorical_accuracy: 0.8417 - val_loss: 0.7462 - val_categorical_crossentropy: 0.7462 - val_categorical_accuracy: 0.7872
# Epoch 114/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5764 - categorical_crossentropy: 0.5764 - categorical_accuracy: 0.7583 - val_loss: 0.7623 - val_categorical_crossentropy: 0.7623 - val_categorical_accuracy: 0.7660
# Epoch 115/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6002 - categorical_crossentropy: 0.6002 - categorical_accuracy: 0.7625 - val_loss: 0.7944 - val_categorical_crossentropy: 0.7944 - val_categorical_accuracy: 0.7234
# Epoch 116/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5526 - categorical_crossentropy: 0.5526 - categorical_accuracy: 0.7917 - val_loss: 0.7898 - val_categorical_crossentropy: 0.7898 - val_categorical_accuracy: 0.7447
# Epoch 117/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5608 - categorical_crossentropy: 0.5608 - categorical_accuracy: 0.7625 - val_loss: 0.7777 - val_categorical_crossentropy: 0.7777 - val_categorical_accuracy: 0.7447
# Epoch 118/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5643 - categorical_crossentropy: 0.5643 - categorical_accuracy: 0.8042 - val_loss: 0.7636 - val_categorical_crossentropy: 0.7636 - val_categorical_accuracy: 0.7021
# Epoch 119/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5281 - categorical_crossentropy: 0.5281 - categorical_accuracy: 0.8333 - val_loss: 0.7705 - val_categorical_crossentropy: 0.7705 - val_categorical_accuracy: 0.7021
# Epoch 120/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5674 - categorical_crossentropy: 0.5674 - categorical_accuracy: 0.7792 - val_loss: 0.7742 - val_categorical_crossentropy: 0.7742 - val_categorical_accuracy: 0.7447
# Epoch 121/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5354 - categorical_crossentropy: 0.5354 - categorical_accuracy: 0.8208 - val_loss: 0.7888 - val_categorical_crossentropy: 0.7888 - val_categorical_accuracy: 0.7021
# Epoch 122/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5174 - categorical_crossentropy: 0.5174 - categorical_accuracy: 0.8167 - val_loss: 0.7740 - val_categorical_crossentropy: 0.7740 - val_categorical_accuracy: 0.7660
# Epoch 123/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5524 - categorical_crossentropy: 0.5524 - categorical_accuracy: 0.8167 - val_loss: 0.7748 - val_categorical_crossentropy: 0.7748 - val_categorical_accuracy: 0.7021
# Epoch 124/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5463 - categorical_crossentropy: 0.5463 - categorical_accuracy: 0.8167 - val_loss: 0.7789 - val_categorical_crossentropy: 0.7789 - val_categorical_accuracy: 0.7660
# Epoch 125/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5452 - categorical_crossentropy: 0.5452 - categorical_accuracy: 0.8083 - val_loss: 0.7446 - val_categorical_crossentropy: 0.7446 - val_categorical_accuracy: 0.7447
# Epoch 126/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5533 - categorical_crossentropy: 0.5533 - categorical_accuracy: 0.7708 - val_loss: 0.7531 - val_categorical_crossentropy: 0.7531 - val_categorical_accuracy: 0.7447
# Epoch 127/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5553 - categorical_crossentropy: 0.5553 - categorical_accuracy: 0.7833 - val_loss: 0.7406 - val_categorical_crossentropy: 0.7406 - val_categorical_accuracy: 0.7234
# Epoch 128/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5227 - categorical_crossentropy: 0.5227 - categorical_accuracy: 0.8333 - val_loss: 0.7573 - val_categorical_crossentropy: 0.7573 - val_categorical_accuracy: 0.6809
# Epoch 129/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5550 - categorical_crossentropy: 0.5550 - categorical_accuracy: 0.7833 - val_loss: 0.7608 - val_categorical_crossentropy: 0.7608 - val_categorical_accuracy: 0.7447
# Epoch 130/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5051 - categorical_crossentropy: 0.5051 - categorical_accuracy: 0.8292 - val_loss: 0.7799 - val_categorical_crossentropy: 0.7799 - val_categorical_accuracy: 0.7447
# Epoch 131/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5279 - categorical_crossentropy: 0.5279 - categorical_accuracy: 0.8125 - val_loss: 0.7844 - val_categorical_crossentropy: 0.7844 - val_categorical_accuracy: 0.6809
# Epoch 132/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5202 - categorical_crossentropy: 0.5202 - categorical_accuracy: 0.8375 - val_loss: 0.7982 - val_categorical_crossentropy: 0.7982 - val_categorical_accuracy: 0.7021
# Epoch 133/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5056 - categorical_crossentropy: 0.5056 - categorical_accuracy: 0.8125 - val_loss: 0.7997 - val_categorical_crossentropy: 0.7997 - val_categorical_accuracy: 0.7234
# Epoch 134/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5068 - categorical_crossentropy: 0.5068 - categorical_accuracy: 0.8458 - val_loss: 0.7795 - val_categorical_crossentropy: 0.7795 - val_categorical_accuracy: 0.6596
# Epoch 135/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5163 - categorical_crossentropy: 0.5163 - categorical_accuracy: 0.8542 - val_loss: 0.7683 - val_categorical_crossentropy: 0.7683 - val_categorical_accuracy: 0.7234
# Epoch 136/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5147 - categorical_crossentropy: 0.5147 - categorical_accuracy: 0.8208 - val_loss: 0.7675 - val_categorical_crossentropy: 0.7675 - val_categorical_accuracy: 0.7234
# Epoch 137/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5531 - categorical_crossentropy: 0.5531 - categorical_accuracy: 0.8042 - val_loss: 0.7818 - val_categorical_crossentropy: 0.7818 - val_categorical_accuracy: 0.6383
# Epoch 138/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5144 - categorical_crossentropy: 0.5144 - categorical_accuracy: 0.8292 - val_loss: 0.7941 - val_categorical_crossentropy: 0.7941 - val_categorical_accuracy: 0.5745
# Epoch 139/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5171 - categorical_crossentropy: 0.5171 - categorical_accuracy: 0.8208 - val_loss: 0.7723 - val_categorical_crossentropy: 0.7723 - val_categorical_accuracy: 0.6596
# Epoch 140/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4961 - categorical_crossentropy: 0.4961 - categorical_accuracy: 0.8417 - val_loss: 0.8089 - val_categorical_crossentropy: 0.8089 - val_categorical_accuracy: 0.5957
# Epoch 141/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4979 - categorical_crossentropy: 0.4979 - categorical_accuracy: 0.8250 - val_loss: 0.7927 - val_categorical_crossentropy: 0.7927 - val_categorical_accuracy: 0.6383
# Epoch 142/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5000 - categorical_crossentropy: 0.5000 - categorical_accuracy: 0.8292 - val_loss: 0.8102 - val_categorical_crossentropy: 0.8102 - val_categorical_accuracy: 0.5957
# Epoch 143/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5228 - categorical_crossentropy: 0.5228 - categorical_accuracy: 0.7875 - val_loss: 0.7744 - val_categorical_crossentropy: 0.7744 - val_categorical_accuracy: 0.7021
# Epoch 144/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5106 - categorical_crossentropy: 0.5106 - categorical_accuracy: 0.8083 - val_loss: 0.7827 - val_categorical_crossentropy: 0.7827 - val_categorical_accuracy: 0.6383
# Epoch 145/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5013 - categorical_crossentropy: 0.5013 - categorical_accuracy: 0.8375 - val_loss: 0.7862 - val_categorical_crossentropy: 0.7862 - val_categorical_accuracy: 0.5957
# Epoch 146/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4961 - categorical_crossentropy: 0.4961 - categorical_accuracy: 0.8417 - val_loss: 0.7999 - val_categorical_crossentropy: 0.7999 - val_categorical_accuracy: 0.6383
# Epoch 147/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4951 - categorical_crossentropy: 0.4951 - categorical_accuracy: 0.8333 - val_loss: 0.7677 - val_categorical_crossentropy: 0.7677 - val_categorical_accuracy: 0.6809
# Epoch 148/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4760 - categorical_crossentropy: 0.4760 - categorical_accuracy: 0.8667 - val_loss: 0.7958 - val_categorical_crossentropy: 0.7958 - val_categorical_accuracy: 0.6383
# Epoch 149/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4861 - categorical_crossentropy: 0.4861 - categorical_accuracy: 0.8333 - val_loss: 0.7254 - val_categorical_crossentropy: 0.7254 - val_categorical_accuracy: 0.6809
# Epoch 150/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4775 - categorical_crossentropy: 0.4775 - categorical_accuracy: 0.8458 - val_loss: 0.7670 - val_categorical_crossentropy: 0.7670 - val_categorical_accuracy: 0.6170
# Epoch 151/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4890 - categorical_crossentropy: 0.4890 - categorical_accuracy: 0.8333 - val_loss: 0.7425 - val_categorical_crossentropy: 0.7425 - val_categorical_accuracy: 0.6596
# Epoch 152/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4579 - categorical_crossentropy: 0.4579 - categorical_accuracy: 0.8458 - val_loss: 0.8246 - val_categorical_crossentropy: 0.8246 - val_categorical_accuracy: 0.6383
# Epoch 153/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4938 - categorical_crossentropy: 0.4938 - categorical_accuracy: 0.8292 - val_loss: 0.7486 - val_categorical_crossentropy: 0.7486 - val_categorical_accuracy: 0.7021
# Epoch 154/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4722 - categorical_crossentropy: 0.4722 - categorical_accuracy: 0.8542 - val_loss: 0.7641 - val_categorical_crossentropy: 0.7641 - val_categorical_accuracy: 0.6809
# Epoch 155/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4523 - categorical_crossentropy: 0.4523 - categorical_accuracy: 0.8750 - val_loss: 0.7208 - val_categorical_crossentropy: 0.7208 - val_categorical_accuracy: 0.7021
# Epoch 156/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5065 - categorical_crossentropy: 0.5065 - categorical_accuracy: 0.8083 - val_loss: 0.7644 - val_categorical_crossentropy: 0.7644 - val_categorical_accuracy: 0.6383
# Epoch 157/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4855 - categorical_crossentropy: 0.4855 - categorical_accuracy: 0.8125 - val_loss: 0.6946 - val_categorical_crossentropy: 0.6946 - val_categorical_accuracy: 0.7447
# Epoch 158/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4647 - categorical_crossentropy: 0.4647 - categorical_accuracy: 0.8583 - val_loss: 0.7305 - val_categorical_crossentropy: 0.7305 - val_categorical_accuracy: 0.7021
# Epoch 159/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5002 - categorical_crossentropy: 0.5002 - categorical_accuracy: 0.8167 - val_loss: 0.7381 - val_categorical_crossentropy: 0.7381 - val_categorical_accuracy: 0.6809
# Epoch 160/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4673 - categorical_crossentropy: 0.4673 - categorical_accuracy: 0.8375 - val_loss: 0.7517 - val_categorical_crossentropy: 0.7517 - val_categorical_accuracy: 0.7021
# Epoch 161/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5357 - categorical_crossentropy: 0.5357 - categorical_accuracy: 0.7792 - val_loss: 0.7393 - val_categorical_crossentropy: 0.7393 - val_categorical_accuracy: 0.6809
# Epoch 162/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4670 - categorical_crossentropy: 0.4670 - categorical_accuracy: 0.8625 - val_loss: 0.7755 - val_categorical_crossentropy: 0.7755 - val_categorical_accuracy: 0.6809
# Epoch 163/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4861 - categorical_crossentropy: 0.4861 - categorical_accuracy: 0.8375 - val_loss: 0.7263 - val_categorical_crossentropy: 0.7263 - val_categorical_accuracy: 0.7021
# Epoch 164/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4930 - categorical_crossentropy: 0.4930 - categorical_accuracy: 0.7958 - val_loss: 0.7693 - val_categorical_crossentropy: 0.7693 - val_categorical_accuracy: 0.6596
# Epoch 165/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5005 - categorical_crossentropy: 0.5005 - categorical_accuracy: 0.8125 - val_loss: 0.7300 - val_categorical_crossentropy: 0.7300 - val_categorical_accuracy: 0.7021
# Epoch 166/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4641 - categorical_crossentropy: 0.4641 - categorical_accuracy: 0.8458 - val_loss: 0.7296 - val_categorical_crossentropy: 0.7296 - val_categorical_accuracy: 0.6596
# Epoch 167/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5090 - categorical_crossentropy: 0.5090 - categorical_accuracy: 0.8208 - val_loss: 0.7097 - val_categorical_crossentropy: 0.7097 - val_categorical_accuracy: 0.6809
# Epoch 168/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4686 - categorical_crossentropy: 0.4686 - categorical_accuracy: 0.8583 - val_loss: 0.6941 - val_categorical_crossentropy: 0.6941 - val_categorical_accuracy: 0.6596
# Epoch 169/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4758 - categorical_crossentropy: 0.4758 - categorical_accuracy: 0.8500 - val_loss: 0.6678 - val_categorical_crossentropy: 0.6678 - val_categorical_accuracy: 0.7021
# Epoch 170/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4985 - categorical_crossentropy: 0.4985 - categorical_accuracy: 0.8167 - val_loss: 0.6972 - val_categorical_crossentropy: 0.6972 - val_categorical_accuracy: 0.7021
# Epoch 171/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4676 - categorical_crossentropy: 0.4676 - categorical_accuracy: 0.8417 - val_loss: 0.7312 - val_categorical_crossentropy: 0.7312 - val_categorical_accuracy: 0.6809
# Epoch 172/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5080 - categorical_crossentropy: 0.5080 - categorical_accuracy: 0.7958 - val_loss: 0.6672 - val_categorical_crossentropy: 0.6672 - val_categorical_accuracy: 0.6596
# Epoch 173/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4455 - categorical_crossentropy: 0.4455 - categorical_accuracy: 0.8583 - val_loss: 0.6631 - val_categorical_crossentropy: 0.6631 - val_categorical_accuracy: 0.7234
# Epoch 174/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4447 - categorical_crossentropy: 0.4447 - categorical_accuracy: 0.8917 - val_loss: 0.6944 - val_categorical_crossentropy: 0.6944 - val_categorical_accuracy: 0.7234
# Epoch 175/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4644 - categorical_crossentropy: 0.4644 - categorical_accuracy: 0.8542 - val_loss: 0.6738 - val_categorical_crossentropy: 0.6738 - val_categorical_accuracy: 0.6596
# Epoch 176/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4498 - categorical_crossentropy: 0.4498 - categorical_accuracy: 0.8583 - val_loss: 0.6959 - val_categorical_crossentropy: 0.6959 - val_categorical_accuracy: 0.7021
# Epoch 177/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4660 - categorical_crossentropy: 0.4660 - categorical_accuracy: 0.8458 - val_loss: 0.6753 - val_categorical_crossentropy: 0.6753 - val_categorical_accuracy: 0.7234
# Epoch 178/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4587 - categorical_crossentropy: 0.4587 - categorical_accuracy: 0.8292 - val_loss: 0.6805 - val_categorical_crossentropy: 0.6805 - val_categorical_accuracy: 0.7021
# Epoch 179/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4610 - categorical_crossentropy: 0.4610 - categorical_accuracy: 0.8208 - val_loss: 0.6984 - val_categorical_crossentropy: 0.6984 - val_categorical_accuracy: 0.7234
# Epoch 180/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4543 - categorical_crossentropy: 0.4543 - categorical_accuracy: 0.8708 - val_loss: 0.6528 - val_categorical_crossentropy: 0.6528 - val_categorical_accuracy: 0.7234
# Epoch 181/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4834 - categorical_crossentropy: 0.4834 - categorical_accuracy: 0.8542 - val_loss: 0.7166 - val_categorical_crossentropy: 0.7166 - val_categorical_accuracy: 0.7021
# Epoch 182/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4431 - categorical_crossentropy: 0.4431 - categorical_accuracy: 0.8417 - val_loss: 0.7408 - val_categorical_crossentropy: 0.7408 - val_categorical_accuracy: 0.7021
# Epoch 183/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4329 - categorical_crossentropy: 0.4329 - categorical_accuracy: 0.8542 - val_loss: 0.7467 - val_categorical_crossentropy: 0.7467 - val_categorical_accuracy: 0.6809
# Epoch 184/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4557 - categorical_crossentropy: 0.4557 - categorical_accuracy: 0.8208 - val_loss: 0.7097 - val_categorical_crossentropy: 0.7097 - val_categorical_accuracy: 0.7234
# Epoch 185/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4290 - categorical_crossentropy: 0.4290 - categorical_accuracy: 0.8500 - val_loss: 0.6996 - val_categorical_crossentropy: 0.6996 - val_categorical_accuracy: 0.6809
# Epoch 186/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4326 - categorical_crossentropy: 0.4326 - categorical_accuracy: 0.8667 - val_loss: 0.6996 - val_categorical_crossentropy: 0.6996 - val_categorical_accuracy: 0.7021
# Epoch 187/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4196 - categorical_crossentropy: 0.4196 - categorical_accuracy: 0.8667 - val_loss: 0.7094 - val_categorical_crossentropy: 0.7094 - val_categorical_accuracy: 0.6596
# Epoch 188/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4443 - categorical_crossentropy: 0.4443 - categorical_accuracy: 0.8500 - val_loss: 0.7231 - val_categorical_crossentropy: 0.7231 - val_categorical_accuracy: 0.6383
# Epoch 189/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4366 - categorical_crossentropy: 0.4366 - categorical_accuracy: 0.8583 - val_loss: 0.6872 - val_categorical_crossentropy: 0.6872 - val_categorical_accuracy: 0.6809
# Epoch 190/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4309 - categorical_crossentropy: 0.4309 - categorical_accuracy: 0.8833 - val_loss: 0.6745 - val_categorical_crossentropy: 0.6745 - val_categorical_accuracy: 0.7021
# Epoch 191/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4475 - categorical_crossentropy: 0.4475 - categorical_accuracy: 0.8333 - val_loss: 0.6923 - val_categorical_crossentropy: 0.6923 - val_categorical_accuracy: 0.6809
# Epoch 192/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4668 - categorical_crossentropy: 0.4668 - categorical_accuracy: 0.8167 - val_loss: 0.6974 - val_categorical_crossentropy: 0.6974 - val_categorical_accuracy: 0.6596
# Epoch 193/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4244 - categorical_crossentropy: 0.4244 - categorical_accuracy: 0.8583 - val_loss: 0.6698 - val_categorical_crossentropy: 0.6698 - val_categorical_accuracy: 0.6809
# Epoch 194/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4368 - categorical_crossentropy: 0.4368 - categorical_accuracy: 0.8542 - val_loss: 0.6962 - val_categorical_crossentropy: 0.6962 - val_categorical_accuracy: 0.6809
# Epoch 195/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4293 - categorical_crossentropy: 0.4293 - categorical_accuracy: 0.8792 - val_loss: 0.6627 - val_categorical_crossentropy: 0.6627 - val_categorical_accuracy: 0.6383
# ...
# Epoch 436/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1182 - categorical_crossentropy: 0.1182 - categorical_accuracy: 0.9625 - val_loss: 0.5135 - val_categorical_crossentropy: 0.5135 - val_categorical_accuracy: 0.7872
# Epoch 437/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1074 - categorical_crossentropy: 0.1074 - categorical_accuracy: 0.9667 - val_loss: 0.4848 - val_categorical_crossentropy: 0.4848 - val_categorical_accuracy: 0.8085
# Epoch 438/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0978 - categorical_crossentropy: 0.0978 - categorical_accuracy: 0.9833 - val_loss: 0.4844 - val_categorical_crossentropy: 0.4844 - val_categorical_accuracy: 0.7660
# Epoch 439/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1177 - categorical_crossentropy: 0.1177 - categorical_accuracy: 0.9875 - val_loss: 0.5330 - val_categorical_crossentropy: 0.5330 - val_categorical_accuracy: 0.8298
# Epoch 440/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1205 - categorical_crossentropy: 0.1205 - categorical_accuracy: 0.9750 - val_loss: 0.5368 - val_categorical_crossentropy: 0.5368 - val_categorical_accuracy: 0.7660
# Epoch 441/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1071 - categorical_crossentropy: 0.1071 - categorical_accuracy: 0.9750 - val_loss: 0.5739 - val_categorical_crossentropy: 0.5739 - val_categorical_accuracy: 0.7234
# Epoch 442/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1252 - categorical_crossentropy: 0.1252 - categorical_accuracy: 0.9583 - val_loss: 0.5277 - val_categorical_crossentropy: 0.5277 - val_categorical_accuracy: 0.7872
# Epoch 443/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1044 - categorical_crossentropy: 0.1044 - categorical_accuracy: 0.9750 - val_loss: 0.4948 - val_categorical_crossentropy: 0.4948 - val_categorical_accuracy: 0.8298
# Epoch 444/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1047 - categorical_crossentropy: 0.1047 - categorical_accuracy: 0.9792 - val_loss: 0.5872 - val_categorical_crossentropy: 0.5872 - val_categorical_accuracy: 0.7660
# Epoch 445/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0955 - categorical_crossentropy: 0.0955 - categorical_accuracy: 0.9875 - val_loss: 0.5811 - val_categorical_crossentropy: 0.5811 - val_categorical_accuracy: 0.7660
# Epoch 446/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1150 - categorical_crossentropy: 0.1150 - categorical_accuracy: 0.9750 - val_loss: 0.5312 - val_categorical_crossentropy: 0.5312 - val_categorical_accuracy: 0.8085
# Epoch 447/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1095 - categorical_crossentropy: 0.1095 - categorical_accuracy: 0.9667 - val_loss: 0.5596 - val_categorical_crossentropy: 0.5596 - val_categorical_accuracy: 0.7872
# Epoch 448/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0970 - categorical_crossentropy: 0.0970 - categorical_accuracy: 0.9833 - val_loss: 0.5289 - val_categorical_crossentropy: 0.5289 - val_categorical_accuracy: 0.8298
# Epoch 449/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1189 - categorical_crossentropy: 0.1189 - categorical_accuracy: 0.9833 - val_loss: 0.4979 - val_categorical_crossentropy: 0.4979 - val_categorical_accuracy: 0.8085
# Epoch 450/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1075 - categorical_crossentropy: 0.1075 - categorical_accuracy: 0.9750 - val_loss: 0.5566 - val_categorical_crossentropy: 0.5566 - val_categorical_accuracy: 0.7234
# Epoch 451/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1196 - categorical_crossentropy: 0.1196 - categorical_accuracy: 0.9708 - val_loss: 0.5491 - val_categorical_crossentropy: 0.5491 - val_categorical_accuracy: 0.7660
# Epoch 452/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1074 - categorical_crossentropy: 0.1074 - categorical_accuracy: 0.9833 - val_loss: 0.5578 - val_categorical_crossentropy: 0.5578 - val_categorical_accuracy: 0.7872
# Epoch 453/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1085 - categorical_crossentropy: 0.1085 - categorical_accuracy: 0.9792 - val_loss: 0.5508 - val_categorical_crossentropy: 0.5508 - val_categorical_accuracy: 0.7660
# Epoch 454/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1075 - categorical_crossentropy: 0.1075 - categorical_accuracy: 0.9833 - val_loss: 0.6344 - val_categorical_crossentropy: 0.6344 - val_categorical_accuracy: 0.7447
# Epoch 455/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1008 - categorical_crossentropy: 0.1008 - categorical_accuracy: 0.9750 - val_loss: 0.5863 - val_categorical_crossentropy: 0.5863 - val_categorical_accuracy: 0.8085
# Epoch 456/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1060 - categorical_crossentropy: 0.1060 - categorical_accuracy: 0.9708 - val_loss: 0.5196 - val_categorical_crossentropy: 0.5196 - val_categorical_accuracy: 0.8085
# Epoch 457/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1288 - categorical_crossentropy: 0.1288 - categorical_accuracy: 0.9708 - val_loss: 0.5283 - val_categorical_crossentropy: 0.5283 - val_categorical_accuracy: 0.7872
# Epoch 458/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1038 - categorical_crossentropy: 0.1038 - categorical_accuracy: 0.9833 - val_loss: 0.5208 - val_categorical_crossentropy: 0.5208 - val_categorical_accuracy: 0.7872
# Epoch 459/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1000 - categorical_crossentropy: 0.1000 - categorical_accuracy: 0.9833 - val_loss: 0.5092 - val_categorical_crossentropy: 0.5092 - val_categorical_accuracy: 0.8298
# Epoch 460/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0913 - categorical_crossentropy: 0.0913 - categorical_accuracy: 0.9875 - val_loss: 0.5026 - val_categorical_crossentropy: 0.5026 - val_categorical_accuracy: 0.8085
# Epoch 461/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0880 - categorical_crossentropy: 0.0880 - categorical_accuracy: 0.9833 - val_loss: 0.5121 - val_categorical_crossentropy: 0.5121 - val_categorical_accuracy: 0.7872
# Epoch 462/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0973 - categorical_crossentropy: 0.0973 - categorical_accuracy: 0.9708 - val_loss: 0.5321 - val_categorical_crossentropy: 0.5321 - val_categorical_accuracy: 0.8085
# Epoch 463/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0871 - categorical_crossentropy: 0.0871 - categorical_accuracy: 0.9917 - val_loss: 0.5834 - val_categorical_crossentropy: 0.5834 - val_categorical_accuracy: 0.7872
# Epoch 464/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0967 - categorical_crossentropy: 0.0967 - categorical_accuracy: 0.9833 - val_loss: 0.6247 - val_categorical_crossentropy: 0.6247 - val_categorical_accuracy: 0.7872
# Epoch 465/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1095 - categorical_crossentropy: 0.1095 - categorical_accuracy: 0.9792 - val_loss: 0.5569 - val_categorical_crossentropy: 0.5569 - val_categorical_accuracy: 0.7872
# Epoch 466/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0931 - categorical_crossentropy: 0.0931 - categorical_accuracy: 0.9833 - val_loss: 0.5073 - val_categorical_crossentropy: 0.5073 - val_categorical_accuracy: 0.8085
# Epoch 467/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0982 - categorical_crossentropy: 0.0982 - categorical_accuracy: 0.9792 - val_loss: 0.5070 - val_categorical_crossentropy: 0.5070 - val_categorical_accuracy: 0.8298
# Epoch 468/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0921 - categorical_crossentropy: 0.0921 - categorical_accuracy: 0.9792 - val_loss: 0.5491 - val_categorical_crossentropy: 0.5491 - val_categorical_accuracy: 0.7872
# Epoch 469/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0956 - categorical_crossentropy: 0.0956 - categorical_accuracy: 0.9792 - val_loss: 0.5585 - val_categorical_crossentropy: 0.5585 - val_categorical_accuracy: 0.7872
# Epoch 470/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0926 - categorical_crossentropy: 0.0926 - categorical_accuracy: 0.9833 - val_loss: 0.5460 - val_categorical_crossentropy: 0.5460 - val_categorical_accuracy: 0.8085
# Epoch 471/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1041 - categorical_crossentropy: 0.1041 - categorical_accuracy: 0.9750 - val_loss: 0.5267 - val_categorical_crossentropy: 0.5267 - val_categorical_accuracy: 0.8085
# Epoch 472/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1178 - categorical_crossentropy: 0.1178 - categorical_accuracy: 0.9792 - val_loss: 0.5773 - val_categorical_crossentropy: 0.5773 - val_categorical_accuracy: 0.7660
# Epoch 473/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1131 - categorical_crossentropy: 0.1131 - categorical_accuracy: 0.9792 - val_loss: 0.5565 - val_categorical_crossentropy: 0.5565 - val_categorical_accuracy: 0.7660
# Epoch 474/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0932 - categorical_crossentropy: 0.0932 - categorical_accuracy: 0.9958 - val_loss: 0.5560 - val_categorical_crossentropy: 0.5560 - val_categorical_accuracy: 0.7872
# Epoch 475/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0804 - categorical_crossentropy: 0.0804 - categorical_accuracy: 0.9958 - val_loss: 0.5470 - val_categorical_crossentropy: 0.5470 - val_categorical_accuracy: 0.7872
# Epoch 476/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0949 - categorical_crossentropy: 0.0949 - categorical_accuracy: 0.9708 - val_loss: 0.5431 - val_categorical_crossentropy: 0.5431 - val_categorical_accuracy: 0.7447
# Epoch 477/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0852 - categorical_crossentropy: 0.0852 - categorical_accuracy: 0.9917 - val_loss: 0.5549 - val_categorical_crossentropy: 0.5549 - val_categorical_accuracy: 0.7872
# Epoch 478/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1045 - categorical_crossentropy: 0.1045 - categorical_accuracy: 0.9833 - val_loss: 0.5612 - val_categorical_crossentropy: 0.5612 - val_categorical_accuracy: 0.7660
# Epoch 479/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0857 - categorical_crossentropy: 0.0857 - categorical_accuracy: 0.9875 - val_loss: 0.5500 - val_categorical_crossentropy: 0.5500 - val_categorical_accuracy: 0.7447
# Epoch 480/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0966 - categorical_crossentropy: 0.0966 - categorical_accuracy: 0.9958 - val_loss: 0.5460 - val_categorical_crossentropy: 0.5460 - val_categorical_accuracy: 0.7872
# Epoch 481/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0981 - categorical_crossentropy: 0.0981 - categorical_accuracy: 0.9792 - val_loss: 0.5747 - val_categorical_crossentropy: 0.5747 - val_categorical_accuracy: 0.8085
# Epoch 482/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0916 - categorical_crossentropy: 0.0916 - categorical_accuracy: 0.9958 - val_loss: 0.5644 - val_categorical_crossentropy: 0.5644 - val_categorical_accuracy: 0.7660
# Epoch 483/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0822 - categorical_crossentropy: 0.0822 - categorical_accuracy: 0.9917 - val_loss: 0.5284 - val_categorical_crossentropy: 0.5284 - val_categorical_accuracy: 0.7872
# Epoch 484/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0973 - categorical_crossentropy: 0.0973 - categorical_accuracy: 0.9792 - val_loss: 0.5304 - val_categorical_crossentropy: 0.5304 - val_categorical_accuracy: 0.7660
# Epoch 485/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1054 - categorical_crossentropy: 0.1054 - categorical_accuracy: 0.9750 - val_loss: 0.5438 - val_categorical_crossentropy: 0.5438 - val_categorical_accuracy: 0.7660
# Epoch 486/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0954 - categorical_crossentropy: 0.0954 - categorical_accuracy: 0.9833 - val_loss: 0.5175 - val_categorical_crossentropy: 0.5175 - val_categorical_accuracy: 0.7447
# Epoch 487/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0683 - categorical_crossentropy: 0.0683 - categorical_accuracy: 0.9917 - val_loss: 0.5177 - val_categorical_crossentropy: 0.5177 - val_categorical_accuracy: 0.8085
# Epoch 488/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0905 - categorical_crossentropy: 0.0905 - categorical_accuracy: 0.9667 - val_loss: 0.6074 - val_categorical_crossentropy: 0.6074 - val_categorical_accuracy: 0.7660
# Epoch 489/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0908 - categorical_crossentropy: 0.0908 - categorical_accuracy: 0.9833 - val_loss: 0.6179 - val_categorical_crossentropy: 0.6179 - val_categorical_accuracy: 0.7234
# Epoch 490/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1002 - categorical_crossentropy: 0.1002 - categorical_accuracy: 0.9833 - val_loss: 0.5352 - val_categorical_crossentropy: 0.5352 - val_categorical_accuracy: 0.7660
# Epoch 491/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1105 - categorical_crossentropy: 0.1105 - categorical_accuracy: 0.9708 - val_loss: 0.5405 - val_categorical_crossentropy: 0.5405 - val_categorical_accuracy: 0.7872
# Epoch 492/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1055 - categorical_crossentropy: 0.1055 - categorical_accuracy: 0.9708 - val_loss: 0.5616 - val_categorical_crossentropy: 0.5616 - val_categorical_accuracy: 0.7660
# Epoch 493/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0994 - categorical_crossentropy: 0.0994 - categorical_accuracy: 0.9792 - val_loss: 0.5280 - val_categorical_crossentropy: 0.5280 - val_categorical_accuracy: 0.8298
# Epoch 494/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1098 - categorical_crossentropy: 0.1098 - categorical_accuracy: 0.9667 - val_loss: 0.5527 - val_categorical_crossentropy: 0.5527 - val_categorical_accuracy: 0.8085
# Epoch 495/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1272 - categorical_crossentropy: 0.1272 - categorical_accuracy: 0.9500 - val_loss: 0.6519 - val_categorical_crossentropy: 0.6519 - val_categorical_accuracy: 0.7234
# Epoch 496/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1051 - categorical_crossentropy: 0.1051 - categorical_accuracy: 0.9708 - val_loss: 0.6555 - val_categorical_crossentropy: 0.6555 - val_categorical_accuracy: 0.7447
# Epoch 497/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0807 - categorical_crossentropy: 0.0807 - categorical_accuracy: 0.9917 - val_loss: 0.5794 - val_categorical_crossentropy: 0.5794 - val_categorical_accuracy: 0.7660
# Epoch 498/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0977 - categorical_crossentropy: 0.0977 - categorical_accuracy: 0.9750 - val_loss: 0.5733 - val_categorical_crossentropy: 0.5733 - val_categorical_accuracy: 0.7872
# Epoch 499/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1080 - categorical_crossentropy: 0.1080 - categorical_accuracy: 0.9667 - val_loss: 0.5779 - val_categorical_crossentropy: 0.5779 - val_categorical_accuracy: 0.8085
# Epoch 500/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1026 - categorical_crossentropy: 0.1026 - categorical_accuracy: 0.9875 - val_loss: 0.5934 - val_categorical_crossentropy: 0.5934 - val_categorical_accuracy: 0.7872
#
# # Evaluate on test data
# 9/9 [==============================] - 1s 102ms/step - loss: 0.5929 - categorical_crossentropy: 0.5929 - categorical_accuracy: 0.7743
# test loss, test acc: [0.5928612351417542, 0.59286124, 0.7743056]
