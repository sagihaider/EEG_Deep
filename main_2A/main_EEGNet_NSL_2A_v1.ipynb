# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_2A/main_EEGNet_NSL_2A_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 477, done.
# remote: Total 477 (delta 0), reused 0 (delta 0), pack-reused 477
# Receiving objects: 100% (477/477), 1.69 GiB | 32.58 MiB/s, done.
# Resolving deltas: 100% (230/230), done.
# Checking out files: 100% (92/92), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf

# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting neural_structured_learning
#   Downloading https://files.pythonhosted.org/packages/08/2e/22b1385d7d601ad0c81457a5b66b3bb6f3c400348c62ea3f07a5fc1b13bc/neural_structured_learning-1.1.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 6.5MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.5)
# Installing collected packages: neural-structured-learning
# Successfully installed neural-structured-learning-1.1.0

# %%
from numpy import zeros
K.clear_session()

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])


# Initialize parameter
h_cut = [24]
drop_out = [0.25]
k_len = [15, 30, 60]
n_epochs = 100

out_f_name = 'acc_NSL_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_accuracy = zeros([nsub, nfilt,ndrop,nkl])

for sub_idx, x in enumerate(range(1,10)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered
      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250,order=4)
        # tril_filtered = tril_filtered.transpose()
        X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test = X_test.reshape(X_test.shape[0], kernels, chans, samples)
      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

          adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
          adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
          # compile the model and set the optimizers
          adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
          batch_size = 32

          X_train = tf.cast(X_train, tf.float32)
          X_test = tf.cast(X_test, tf.float32)
          X_val = tf.cast(X_val, tf.float32)

          train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
          val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
          test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)
          val_steps = X_val.shape[0] // batch_size
          
          history = adv_model.fit(train_data, validation_data=val_data, 
                                  validation_steps=None, epochs=500, verbose=1)
          
          print('\n# Evaluate on test data')
          results = adv_model.evaluate(test_data)
          print('test loss, test acc:', results)

          # loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          # categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          categorical_accuracy[sub_idx,h_indx,id_d, id_kl] = results[2]

          # from keras import backend as K 
          # Do some code, e.g. train and save model
          # K.clear_session()


np.save(out_f_name, categorical_accuracy)
# Out:
# acc_NSL_EEGNet_epochs_100_filter_[24]_drop_[0.25]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288, 1)
# (240, 22, 750)
# (240, 1)
# (47, 22, 750)
# (47, 1)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/500
# 8/8 [==============================] - 0s 62ms/step - loss: 1.4166 - categorical_crossentropy: 1.4166 - categorical_accuracy: 0.2417 - val_loss: 1.3869 - val_categorical_crossentropy: 1.3869 - val_categorical_accuracy: 0.2979
# Epoch 2/500
# 8/8 [==============================] - 0s 20ms/step - loss: 1.3537 - categorical_crossentropy: 1.3537 - categorical_accuracy: 0.3625 - val_loss: 1.3860 - val_categorical_crossentropy: 1.3860 - val_categorical_accuracy: 0.2766
# Epoch 3/500
# 8/8 [==============================] - 0s 19ms/step - loss: 1.3326 - categorical_crossentropy: 1.3326 - categorical_accuracy: 0.3917 - val_loss: 1.3859 - val_categorical_crossentropy: 1.3859 - val_categorical_accuracy: 0.3404
# Epoch 4/500
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3120 - categorical_crossentropy: 1.3120 - categorical_accuracy: 0.4042 - val_loss: 1.3852 - val_categorical_crossentropy: 1.3852 - val_categorical_accuracy: 0.3191
# Epoch 5/500
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2932 - categorical_crossentropy: 1.2932 - categorical_accuracy: 0.4833 - val_loss: 1.3834 - val_categorical_crossentropy: 1.3834 - val_categorical_accuracy: 0.3404
# Epoch 6/500
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2626 - categorical_crossentropy: 1.2626 - categorical_accuracy: 0.4833 - val_loss: 1.3806 - val_categorical_crossentropy: 1.3806 - val_categorical_accuracy: 0.2766
# Epoch 7/500
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2223 - categorical_crossentropy: 1.2223 - categorical_accuracy: 0.5708 - val_loss: 1.3766 - val_categorical_crossentropy: 1.3766 - val_categorical_accuracy: 0.2553
# Epoch 8/500
# 8/8 [==============================] - 0s 16ms/step - loss: 1.1844 - categorical_crossentropy: 1.1844 - categorical_accuracy: 0.6167 - val_loss: 1.3715 - val_categorical_crossentropy: 1.3715 - val_categorical_accuracy: 0.2766
# Epoch 9/500
# 8/8 [==============================] - 0s 16ms/step - loss: 1.1193 - categorical_crossentropy: 1.1193 - categorical_accuracy: 0.6458 - val_loss: 1.3637 - val_categorical_crossentropy: 1.3637 - val_categorical_accuracy: 0.2766
# Epoch 10/500
# 8/8 [==============================] - 0s 17ms/step - loss: 1.0646 - categorical_crossentropy: 1.0646 - categorical_accuracy: 0.6708 - val_loss: 1.3534 - val_categorical_crossentropy: 1.3534 - val_categorical_accuracy: 0.3404
# Epoch 11/500
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0062 - categorical_crossentropy: 1.0062 - categorical_accuracy: 0.7042 - val_loss: 1.3493 - val_categorical_crossentropy: 1.3493 - val_categorical_accuracy: 0.3191
# Epoch 12/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9397 - categorical_crossentropy: 0.9397 - categorical_accuracy: 0.7292 - val_loss: 1.3604 - val_categorical_crossentropy: 1.3604 - val_categorical_accuracy: 0.2553
# Epoch 13/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8890 - categorical_crossentropy: 0.8890 - categorical_accuracy: 0.7333 - val_loss: 1.3789 - val_categorical_crossentropy: 1.3789 - val_categorical_accuracy: 0.2553
# Epoch 14/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8654 - categorical_crossentropy: 0.8654 - categorical_accuracy: 0.7333 - val_loss: 1.4095 - val_categorical_crossentropy: 1.4095 - val_categorical_accuracy: 0.2553
# Epoch 15/500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8383 - categorical_crossentropy: 0.8383 - categorical_accuracy: 0.7417 - val_loss: 1.4487 - val_categorical_crossentropy: 1.4487 - val_categorical_accuracy: 0.2553
# Epoch 16/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8208 - categorical_crossentropy: 0.8208 - categorical_accuracy: 0.7250 - val_loss: 1.4833 - val_categorical_crossentropy: 1.4833 - val_categorical_accuracy: 0.2553
# Epoch 17/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8000 - categorical_crossentropy: 0.8000 - categorical_accuracy: 0.7542 - val_loss: 1.5069 - val_categorical_crossentropy: 1.5069 - val_categorical_accuracy: 0.2553
# Epoch 18/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7751 - categorical_crossentropy: 0.7751 - categorical_accuracy: 0.7708 - val_loss: 1.5390 - val_categorical_crossentropy: 1.5390 - val_categorical_accuracy: 0.2553
# Epoch 19/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7708 - categorical_crossentropy: 0.7708 - categorical_accuracy: 0.7500 - val_loss: 1.5877 - val_categorical_crossentropy: 1.5877 - val_categorical_accuracy: 0.2553
# Epoch 20/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7562 - categorical_crossentropy: 0.7562 - categorical_accuracy: 0.7458 - val_loss: 1.6186 - val_categorical_crossentropy: 1.6186 - val_categorical_accuracy: 0.2553
# Epoch 21/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7354 - categorical_crossentropy: 0.7354 - categorical_accuracy: 0.7458 - val_loss: 1.6453 - val_categorical_crossentropy: 1.6453 - val_categorical_accuracy: 0.2553
# Epoch 22/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7237 - categorical_crossentropy: 0.7237 - categorical_accuracy: 0.7667 - val_loss: 1.6853 - val_categorical_crossentropy: 1.6853 - val_categorical_accuracy: 0.2766
# Epoch 23/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7232 - categorical_crossentropy: 0.7232 - categorical_accuracy: 0.7625 - val_loss: 1.7224 - val_categorical_crossentropy: 1.7224 - val_categorical_accuracy: 0.3404
# Epoch 24/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7173 - categorical_crossentropy: 0.7173 - categorical_accuracy: 0.7875 - val_loss: 1.7347 - val_categorical_crossentropy: 1.7347 - val_categorical_accuracy: 0.3830
# Epoch 25/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7055 - categorical_crossentropy: 0.7055 - categorical_accuracy: 0.7667 - val_loss: 1.7416 - val_categorical_crossentropy: 1.7416 - val_categorical_accuracy: 0.3404
# Epoch 26/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6898 - categorical_crossentropy: 0.6898 - categorical_accuracy: 0.7875 - val_loss: 1.7438 - val_categorical_crossentropy: 1.7438 - val_categorical_accuracy: 0.4468
# Epoch 27/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6850 - categorical_crossentropy: 0.6850 - categorical_accuracy: 0.7667 - val_loss: 1.7683 - val_categorical_crossentropy: 1.7683 - val_categorical_accuracy: 0.4468
# Epoch 28/500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6878 - categorical_crossentropy: 0.6878 - categorical_accuracy: 0.7667 - val_loss: 1.7837 - val_categorical_crossentropy: 1.7837 - val_categorical_accuracy: 0.4255
# Epoch 29/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6615 - categorical_crossentropy: 0.6615 - categorical_accuracy: 0.8083 - val_loss: 1.7827 - val_categorical_crossentropy: 1.7827 - val_categorical_accuracy: 0.4468
# Epoch 30/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6774 - categorical_crossentropy: 0.6774 - categorical_accuracy: 0.7875 - val_loss: 1.7786 - val_categorical_crossentropy: 1.7786 - val_categorical_accuracy: 0.4043
# Epoch 31/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6642 - categorical_crossentropy: 0.6642 - categorical_accuracy: 0.7750 - val_loss: 1.7569 - val_categorical_crossentropy: 1.7569 - val_categorical_accuracy: 0.4468
# Epoch 32/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6650 - categorical_crossentropy: 0.6650 - categorical_accuracy: 0.7875 - val_loss: 1.7522 - val_categorical_crossentropy: 1.7522 - val_categorical_accuracy: 0.4468
# Epoch 33/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6369 - categorical_crossentropy: 0.6369 - categorical_accuracy: 0.8250 - val_loss: 1.7473 - val_categorical_crossentropy: 1.7473 - val_categorical_accuracy: 0.4255
# Epoch 34/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6417 - categorical_crossentropy: 0.6417 - categorical_accuracy: 0.8083 - val_loss: 1.7427 - val_categorical_crossentropy: 1.7427 - val_categorical_accuracy: 0.4468
# Epoch 35/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6224 - categorical_crossentropy: 0.6224 - categorical_accuracy: 0.8042 - val_loss: 1.7312 - val_categorical_crossentropy: 1.7312 - val_categorical_accuracy: 0.4681
# Epoch 36/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6306 - categorical_crossentropy: 0.6306 - categorical_accuracy: 0.8333 - val_loss: 1.7011 - val_categorical_crossentropy: 1.7011 - val_categorical_accuracy: 0.4681
# Epoch 37/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6018 - categorical_crossentropy: 0.6018 - categorical_accuracy: 0.8417 - val_loss: 1.6574 - val_categorical_crossentropy: 1.6574 - val_categorical_accuracy: 0.4681
# Epoch 38/500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6062 - categorical_crossentropy: 0.6062 - categorical_accuracy: 0.8375 - val_loss: 1.6164 - val_categorical_crossentropy: 1.6164 - val_categorical_accuracy: 0.2979
# Epoch 39/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6155 - categorical_crossentropy: 0.6155 - categorical_accuracy: 0.8375 - val_loss: 1.5862 - val_categorical_crossentropy: 1.5862 - val_categorical_accuracy: 0.4468
# Epoch 40/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6104 - categorical_crossentropy: 0.6104 - categorical_accuracy: 0.8125 - val_loss: 1.5613 - val_categorical_crossentropy: 1.5613 - val_categorical_accuracy: 0.4468
# Epoch 41/500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5951 - categorical_crossentropy: 0.5951 - categorical_accuracy: 0.8500 - val_loss: 1.5557 - val_categorical_crossentropy: 1.5557 - val_categorical_accuracy: 0.4468
# Epoch 42/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6100 - categorical_crossentropy: 0.6100 - categorical_accuracy: 0.8167 - val_loss: 1.5284 - val_categorical_crossentropy: 1.5284 - val_categorical_accuracy: 0.4468
# Epoch 43/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6162 - categorical_crossentropy: 0.6162 - categorical_accuracy: 0.7917 - val_loss: 1.4352 - val_categorical_crossentropy: 1.4352 - val_categorical_accuracy: 0.4681
# Epoch 44/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6058 - categorical_crossentropy: 0.6058 - categorical_accuracy: 0.8167 - val_loss: 1.3700 - val_categorical_crossentropy: 1.3700 - val_categorical_accuracy: 0.4681
# Epoch 45/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6097 - categorical_crossentropy: 0.6097 - categorical_accuracy: 0.8292 - val_loss: 1.3156 - val_categorical_crossentropy: 1.3156 - val_categorical_accuracy: 0.4681
# Epoch 46/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5999 - categorical_crossentropy: 0.5999 - categorical_accuracy: 0.8042 - val_loss: 1.3334 - val_categorical_crossentropy: 1.3334 - val_categorical_accuracy: 0.4043
# Epoch 47/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5862 - categorical_crossentropy: 0.5862 - categorical_accuracy: 0.8375 - val_loss: 1.2963 - val_categorical_crossentropy: 1.2963 - val_categorical_accuracy: 0.4894
# Epoch 48/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5863 - categorical_crossentropy: 0.5863 - categorical_accuracy: 0.8125 - val_loss: 1.2483 - val_categorical_crossentropy: 1.2483 - val_categorical_accuracy: 0.5106
# Epoch 49/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5763 - categorical_crossentropy: 0.5763 - categorical_accuracy: 0.8375 - val_loss: 1.2049 - val_categorical_crossentropy: 1.2049 - val_categorical_accuracy: 0.4468
# Epoch 50/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5716 - categorical_crossentropy: 0.5716 - categorical_accuracy: 0.8500 - val_loss: 1.1122 - val_categorical_crossentropy: 1.1122 - val_categorical_accuracy: 0.5106
# Epoch 51/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5887 - categorical_crossentropy: 0.5887 - categorical_accuracy: 0.8125 - val_loss: 1.0629 - val_categorical_crossentropy: 1.0629 - val_categorical_accuracy: 0.5106
# Epoch 52/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5778 - categorical_crossentropy: 0.5778 - categorical_accuracy: 0.8125 - val_loss: 1.0298 - val_categorical_crossentropy: 1.0298 - val_categorical_accuracy: 0.5106
# Epoch 53/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5918 - categorical_crossentropy: 0.5918 - categorical_accuracy: 0.8083 - val_loss: 1.0511 - val_categorical_crossentropy: 1.0511 - val_categorical_accuracy: 0.5106
# Epoch 54/500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5794 - categorical_crossentropy: 0.5794 - categorical_accuracy: 0.8292 - val_loss: 1.0304 - val_categorical_crossentropy: 1.0304 - val_categorical_accuracy: 0.5319
# Epoch 55/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5584 - categorical_crossentropy: 0.5584 - categorical_accuracy: 0.8417 - val_loss: 1.0316 - val_categorical_crossentropy: 1.0316 - val_categorical_accuracy: 0.5319
# Epoch 56/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5467 - categorical_crossentropy: 0.5467 - categorical_accuracy: 0.8833 - val_loss: 0.9903 - val_categorical_crossentropy: 0.9903 - val_categorical_accuracy: 0.5745
# Epoch 57/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5591 - categorical_crossentropy: 0.5591 - categorical_accuracy: 0.8458 - val_loss: 0.9491 - val_categorical_crossentropy: 0.9491 - val_categorical_accuracy: 0.5745
# Epoch 58/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5515 - categorical_crossentropy: 0.5515 - categorical_accuracy: 0.8667 - val_loss: 0.8999 - val_categorical_crossentropy: 0.8999 - val_categorical_accuracy: 0.5745
# Epoch 59/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5546 - categorical_crossentropy: 0.5546 - categorical_accuracy: 0.8542 - val_loss: 0.8959 - val_categorical_crossentropy: 0.8959 - val_categorical_accuracy: 0.6170
# Epoch 60/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5695 - categorical_crossentropy: 0.5695 - categorical_accuracy: 0.8042 - val_loss: 0.8843 - val_categorical_crossentropy: 0.8843 - val_categorical_accuracy: 0.5957
# Epoch 61/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5451 - categorical_crossentropy: 0.5451 - categorical_accuracy: 0.8458 - val_loss: 0.8426 - val_categorical_crossentropy: 0.8426 - val_categorical_accuracy: 0.5957
# Epoch 62/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5384 - categorical_crossentropy: 0.5384 - categorical_accuracy: 0.8375 - val_loss: 0.8668 - val_categorical_crossentropy: 0.8668 - val_categorical_accuracy: 0.5745
# Epoch 63/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5454 - categorical_crossentropy: 0.5454 - categorical_accuracy: 0.8500 - val_loss: 0.8685 - val_categorical_crossentropy: 0.8685 - val_categorical_accuracy: 0.5957
# Epoch 64/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5144 - categorical_crossentropy: 0.5144 - categorical_accuracy: 0.8708 - val_loss: 0.8723 - val_categorical_crossentropy: 0.8723 - val_categorical_accuracy: 0.6170
# Epoch 65/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5472 - categorical_crossentropy: 0.5472 - categorical_accuracy: 0.8250 - val_loss: 0.8757 - val_categorical_crossentropy: 0.8757 - val_categorical_accuracy: 0.5745
# Epoch 66/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5443 - categorical_crossentropy: 0.5443 - categorical_accuracy: 0.8500 - val_loss: 0.8700 - val_categorical_crossentropy: 0.8700 - val_categorical_accuracy: 0.5957
# Epoch 67/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5251 - categorical_crossentropy: 0.5251 - categorical_accuracy: 0.8458 - val_loss: 0.8551 - val_categorical_crossentropy: 0.8551 - val_categorical_accuracy: 0.5957
# Epoch 68/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5199 - categorical_crossentropy: 0.5199 - categorical_accuracy: 0.8542 - val_loss: 0.8450 - val_categorical_crossentropy: 0.8450 - val_categorical_accuracy: 0.6383
# Epoch 69/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5326 - categorical_crossentropy: 0.5326 - categorical_accuracy: 0.8417 - val_loss: 0.8334 - val_categorical_crossentropy: 0.8334 - val_categorical_accuracy: 0.5957
# Epoch 70/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5219 - categorical_crossentropy: 0.5219 - categorical_accuracy: 0.8500 - val_loss: 0.8329 - val_categorical_crossentropy: 0.8329 - val_categorical_accuracy: 0.6383
# Epoch 71/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5394 - categorical_crossentropy: 0.5394 - categorical_accuracy: 0.8667 - val_loss: 0.8143 - val_categorical_crossentropy: 0.8143 - val_categorical_accuracy: 0.7021
# Epoch 72/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5117 - categorical_crossentropy: 0.5117 - categorical_accuracy: 0.8667 - val_loss: 0.8159 - val_categorical_crossentropy: 0.8159 - val_categorical_accuracy: 0.6809
# Epoch 73/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5153 - categorical_crossentropy: 0.5153 - categorical_accuracy: 0.8708 - val_loss: 0.8163 - val_categorical_crossentropy: 0.8163 - val_categorical_accuracy: 0.6170
# Epoch 74/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5106 - categorical_crossentropy: 0.5106 - categorical_accuracy: 0.8750 - val_loss: 0.8160 - val_categorical_crossentropy: 0.8160 - val_categorical_accuracy: 0.6596
# Epoch 75/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5160 - categorical_crossentropy: 0.5160 - categorical_accuracy: 0.8500 - val_loss: 0.8198 - val_categorical_crossentropy: 0.8198 - val_categorical_accuracy: 0.6809
# Epoch 76/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5095 - categorical_crossentropy: 0.5095 - categorical_accuracy: 0.8500 - val_loss: 0.8138 - val_categorical_crossentropy: 0.8138 - val_categorical_accuracy: 0.7021
# Epoch 77/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5232 - categorical_crossentropy: 0.5232 - categorical_accuracy: 0.8500 - val_loss: 0.8135 - val_categorical_crossentropy: 0.8135 - val_categorical_accuracy: 0.6809
# Epoch 78/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5218 - categorical_crossentropy: 0.5218 - categorical_accuracy: 0.8250 - val_loss: 0.8085 - val_categorical_crossentropy: 0.8085 - val_categorical_accuracy: 0.6383
# Epoch 79/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5004 - categorical_crossentropy: 0.5004 - categorical_accuracy: 0.8625 - val_loss: 0.8040 - val_categorical_crossentropy: 0.8040 - val_categorical_accuracy: 0.7021
# Epoch 80/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5065 - categorical_crossentropy: 0.5065 - categorical_accuracy: 0.8375 - val_loss: 0.8137 - val_categorical_crossentropy: 0.8137 - val_categorical_accuracy: 0.6809
# Epoch 81/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4949 - categorical_crossentropy: 0.4949 - categorical_accuracy: 0.8583 - val_loss: 0.7982 - val_categorical_crossentropy: 0.7982 - val_categorical_accuracy: 0.6809
# Epoch 82/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5108 - categorical_crossentropy: 0.5108 - categorical_accuracy: 0.8792 - val_loss: 0.8134 - val_categorical_crossentropy: 0.8134 - val_categorical_accuracy: 0.5957
# Epoch 83/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4786 - categorical_crossentropy: 0.4786 - categorical_accuracy: 0.8917 - val_loss: 0.8203 - val_categorical_crossentropy: 0.8203 - val_categorical_accuracy: 0.6383
# Epoch 84/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4961 - categorical_crossentropy: 0.4961 - categorical_accuracy: 0.8708 - val_loss: 0.8188 - val_categorical_crossentropy: 0.8188 - val_categorical_accuracy: 0.6809
# Epoch 85/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5050 - categorical_crossentropy: 0.5050 - categorical_accuracy: 0.8792 - val_loss: 0.8510 - val_categorical_crossentropy: 0.8510 - val_categorical_accuracy: 0.6170
# Epoch 86/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5005 - categorical_crossentropy: 0.5005 - categorical_accuracy: 0.8208 - val_loss: 0.8521 - val_categorical_crossentropy: 0.8521 - val_categorical_accuracy: 0.6383
# Epoch 87/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5057 - categorical_crossentropy: 0.5057 - categorical_accuracy: 0.8875 - val_loss: 0.8215 - val_categorical_crossentropy: 0.8215 - val_categorical_accuracy: 0.5957
# Epoch 88/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5071 - categorical_crossentropy: 0.5071 - categorical_accuracy: 0.8500 - val_loss: 0.7914 - val_categorical_crossentropy: 0.7914 - val_categorical_accuracy: 0.6383
# Epoch 89/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5043 - categorical_crossentropy: 0.5043 - categorical_accuracy: 0.8583 - val_loss: 0.8003 - val_categorical_crossentropy: 0.8003 - val_categorical_accuracy: 0.6170
# Epoch 90/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4880 - categorical_crossentropy: 0.4880 - categorical_accuracy: 0.8792 - val_loss: 0.8024 - val_categorical_crossentropy: 0.8024 - val_categorical_accuracy: 0.6809
# Epoch 91/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4757 - categorical_crossentropy: 0.4757 - categorical_accuracy: 0.8750 - val_loss: 0.7965 - val_categorical_crossentropy: 0.7965 - val_categorical_accuracy: 0.7021
# Epoch 92/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4715 - categorical_crossentropy: 0.4715 - categorical_accuracy: 0.8792 - val_loss: 0.8086 - val_categorical_crossentropy: 0.8086 - val_categorical_accuracy: 0.6596
# Epoch 93/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4627 - categorical_crossentropy: 0.4627 - categorical_accuracy: 0.8792 - val_loss: 0.8379 - val_categorical_crossentropy: 0.8379 - val_categorical_accuracy: 0.6170
# Epoch 94/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4790 - categorical_crossentropy: 0.4790 - categorical_accuracy: 0.8750 - val_loss: 0.8356 - val_categorical_crossentropy: 0.8356 - val_categorical_accuracy: 0.6596
# Epoch 95/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4691 - categorical_crossentropy: 0.4691 - categorical_accuracy: 0.8833 - val_loss: 0.8311 - val_categorical_crossentropy: 0.8311 - val_categorical_accuracy: 0.6170
# Epoch 96/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4805 - categorical_crossentropy: 0.4805 - categorical_accuracy: 0.8833 - val_loss: 0.8441 - val_categorical_crossentropy: 0.8441 - val_categorical_accuracy: 0.6170
# Epoch 97/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4629 - categorical_crossentropy: 0.4629 - categorical_accuracy: 0.8958 - val_loss: 0.8163 - val_categorical_crossentropy: 0.8163 - val_categorical_accuracy: 0.6170
# Epoch 98/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4712 - categorical_crossentropy: 0.4712 - categorical_accuracy: 0.8750 - val_loss: 0.8215 - val_categorical_crossentropy: 0.8215 - val_categorical_accuracy: 0.5957
# Epoch 99/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4547 - categorical_crossentropy: 0.4547 - categorical_accuracy: 0.8917 - val_loss: 0.8226 - val_categorical_crossentropy: 0.8226 - val_categorical_accuracy: 0.6383
# Epoch 100/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4918 - categorical_crossentropy: 0.4918 - categorical_accuracy: 0.8458 - val_loss: 0.8385 - val_categorical_crossentropy: 0.8385 - val_categorical_accuracy: 0.6170
# Epoch 101/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4641 - categorical_crossentropy: 0.4641 - categorical_accuracy: 0.8792 - val_loss: 0.8359 - val_categorical_crossentropy: 0.8359 - val_categorical_accuracy: 0.6383
# Epoch 102/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4505 - categorical_crossentropy: 0.4505 - categorical_accuracy: 0.9042 - val_loss: 0.8055 - val_categorical_crossentropy: 0.8055 - val_categorical_accuracy: 0.6596
# Epoch 103/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4655 - categorical_crossentropy: 0.4655 - categorical_accuracy: 0.8500 - val_loss: 0.8585 - val_categorical_crossentropy: 0.8585 - val_categorical_accuracy: 0.5957
# Epoch 104/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4670 - categorical_crossentropy: 0.4670 - categorical_accuracy: 0.8667 - val_loss: 0.8482 - val_categorical_crossentropy: 0.8482 - val_categorical_accuracy: 0.6170
# Epoch 105/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4665 - categorical_crossentropy: 0.4665 - categorical_accuracy: 0.8875 - val_loss: 0.8321 - val_categorical_crossentropy: 0.8321 - val_categorical_accuracy: 0.6383
# Epoch 106/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4538 - categorical_crossentropy: 0.4538 - categorical_accuracy: 0.8958 - val_loss: 0.8291 - val_categorical_crossentropy: 0.8291 - val_categorical_accuracy: 0.6170
# Epoch 107/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4466 - categorical_crossentropy: 0.4466 - categorical_accuracy: 0.8875 - val_loss: 0.8141 - val_categorical_crossentropy: 0.8141 - val_categorical_accuracy: 0.6596
# Epoch 108/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4634 - categorical_crossentropy: 0.4634 - categorical_accuracy: 0.9000 - val_loss: 0.8590 - val_categorical_crossentropy: 0.8590 - val_categorical_accuracy: 0.6170
# Epoch 109/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4381 - categorical_crossentropy: 0.4381 - categorical_accuracy: 0.8917 - val_loss: 0.8467 - val_categorical_crossentropy: 0.8467 - val_categorical_accuracy: 0.6170
# Epoch 110/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4637 - categorical_crossentropy: 0.4637 - categorical_accuracy: 0.8667 - val_loss: 0.8663 - val_categorical_crossentropy: 0.8663 - val_categorical_accuracy: 0.5745
# Epoch 111/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4436 - categorical_crossentropy: 0.4436 - categorical_accuracy: 0.8875 - val_loss: 0.8385 - val_categorical_crossentropy: 0.8385 - val_categorical_accuracy: 0.6383
# Epoch 112/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4536 - categorical_crossentropy: 0.4536 - categorical_accuracy: 0.8917 - val_loss: 0.8075 - val_categorical_crossentropy: 0.8075 - val_categorical_accuracy: 0.6170
# Epoch 113/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4249 - categorical_crossentropy: 0.4249 - categorical_accuracy: 0.9125 - val_loss: 0.8001 - val_categorical_crossentropy: 0.8001 - val_categorical_accuracy: 0.5957
# Epoch 114/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4379 - categorical_crossentropy: 0.4379 - categorical_accuracy: 0.8792 - val_loss: 0.8125 - val_categorical_crossentropy: 0.8125 - val_categorical_accuracy: 0.6596
# Epoch 115/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4600 - categorical_crossentropy: 0.4600 - categorical_accuracy: 0.8875 - val_loss: 0.7804 - val_categorical_crossentropy: 0.7804 - val_categorical_accuracy: 0.6809
# Epoch 116/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4420 - categorical_crossentropy: 0.4420 - categorical_accuracy: 0.8833 - val_loss: 0.7726 - val_categorical_crossentropy: 0.7726 - val_categorical_accuracy: 0.7021
# Epoch 117/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4474 - categorical_crossentropy: 0.4474 - categorical_accuracy: 0.8667 - val_loss: 0.7334 - val_categorical_crossentropy: 0.7334 - val_categorical_accuracy: 0.7660
# Epoch 118/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4455 - categorical_crossentropy: 0.4455 - categorical_accuracy: 0.8958 - val_loss: 0.7882 - val_categorical_crossentropy: 0.7882 - val_categorical_accuracy: 0.6596
# Epoch 119/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4434 - categorical_crossentropy: 0.4434 - categorical_accuracy: 0.8958 - val_loss: 0.7786 - val_categorical_crossentropy: 0.7786 - val_categorical_accuracy: 0.7234
# Epoch 120/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4359 - categorical_crossentropy: 0.4359 - categorical_accuracy: 0.8542 - val_loss: 0.7449 - val_categorical_crossentropy: 0.7449 - val_categorical_accuracy: 0.7447
# Epoch 121/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4146 - categorical_crossentropy: 0.4146 - categorical_accuracy: 0.9125 - val_loss: 0.7620 - val_categorical_crossentropy: 0.7620 - val_categorical_accuracy: 0.7021
# Epoch 122/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4209 - categorical_crossentropy: 0.4209 - categorical_accuracy: 0.9000 - val_loss: 0.8650 - val_categorical_crossentropy: 0.8650 - val_categorical_accuracy: 0.6596
# Epoch 123/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4499 - categorical_crossentropy: 0.4499 - categorical_accuracy: 0.8750 - val_loss: 0.7744 - val_categorical_crossentropy: 0.7744 - val_categorical_accuracy: 0.7234
# Epoch 124/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4094 - categorical_crossentropy: 0.4094 - categorical_accuracy: 0.9000 - val_loss: 0.7469 - val_categorical_crossentropy: 0.7469 - val_categorical_accuracy: 0.6809
# Epoch 125/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4179 - categorical_crossentropy: 0.4179 - categorical_accuracy: 0.8958 - val_loss: 0.8072 - val_categorical_crossentropy: 0.8072 - val_categorical_accuracy: 0.6596
# Epoch 126/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4171 - categorical_crossentropy: 0.4171 - categorical_accuracy: 0.8667 - val_loss: 0.7560 - val_categorical_crossentropy: 0.7560 - val_categorical_accuracy: 0.7234
# Epoch 127/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4164 - categorical_crossentropy: 0.4164 - categorical_accuracy: 0.8917 - val_loss: 0.7776 - val_categorical_crossentropy: 0.7776 - val_categorical_accuracy: 0.7447
# Epoch 128/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4142 - categorical_crossentropy: 0.4142 - categorical_accuracy: 0.8917 - val_loss: 0.7898 - val_categorical_crossentropy: 0.7898 - val_categorical_accuracy: 0.7021
# Epoch 129/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4138 - categorical_crossentropy: 0.4138 - categorical_accuracy: 0.8875 - val_loss: 0.7472 - val_categorical_crossentropy: 0.7472 - val_categorical_accuracy: 0.7021
# Epoch 130/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4158 - categorical_crossentropy: 0.4158 - categorical_accuracy: 0.8875 - val_loss: 0.7188 - val_categorical_crossentropy: 0.7188 - val_categorical_accuracy: 0.7447
# Epoch 131/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3969 - categorical_crossentropy: 0.3969 - categorical_accuracy: 0.9000 - val_loss: 0.7241 - val_categorical_crossentropy: 0.7241 - val_categorical_accuracy: 0.7234
# Epoch 132/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3929 - categorical_crossentropy: 0.3929 - categorical_accuracy: 0.9167 - val_loss: 0.7398 - val_categorical_crossentropy: 0.7398 - val_categorical_accuracy: 0.7234
# Epoch 133/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3961 - categorical_crossentropy: 0.3961 - categorical_accuracy: 0.9250 - val_loss: 0.7277 - val_categorical_crossentropy: 0.7277 - val_categorical_accuracy: 0.7234
# Epoch 134/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3873 - categorical_crossentropy: 0.3873 - categorical_accuracy: 0.9167 - val_loss: 0.7288 - val_categorical_crossentropy: 0.7288 - val_categorical_accuracy: 0.7234
# Epoch 135/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3858 - categorical_crossentropy: 0.3858 - categorical_accuracy: 0.9208 - val_loss: 0.7354 - val_categorical_crossentropy: 0.7354 - val_categorical_accuracy: 0.7447
# Epoch 136/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3918 - categorical_crossentropy: 0.3918 - categorical_accuracy: 0.9083 - val_loss: 0.7441 - val_categorical_crossentropy: 0.7441 - val_categorical_accuracy: 0.6383
# Epoch 137/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3955 - categorical_crossentropy: 0.3955 - categorical_accuracy: 0.8958 - val_loss: 0.7740 - val_categorical_crossentropy: 0.7740 - val_categorical_accuracy: 0.7447
# Epoch 138/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3831 - categorical_crossentropy: 0.3831 - categorical_accuracy: 0.8958 - val_loss: 0.7455 - val_categorical_crossentropy: 0.7455 - val_categorical_accuracy: 0.7021
# Epoch 139/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3800 - categorical_crossentropy: 0.3800 - categorical_accuracy: 0.9000 - val_loss: 0.7413 - val_categorical_crossentropy: 0.7413 - val_categorical_accuracy: 0.6809
# Epoch 140/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3871 - categorical_crossentropy: 0.3871 - categorical_accuracy: 0.9083 - val_loss: 0.7519 - val_categorical_crossentropy: 0.7519 - val_categorical_accuracy: 0.7021
# Epoch 141/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3864 - categorical_crossentropy: 0.3864 - categorical_accuracy: 0.9125 - val_loss: 0.7437 - val_categorical_crossentropy: 0.7437 - val_categorical_accuracy: 0.7234
# Epoch 142/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4128 - categorical_crossentropy: 0.4128 - categorical_accuracy: 0.9083 - val_loss: 0.7599 - val_categorical_crossentropy: 0.7599 - val_categorical_accuracy: 0.6809
# Epoch 143/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3993 - categorical_crossentropy: 0.3993 - categorical_accuracy: 0.9042 - val_loss: 0.7436 - val_categorical_crossentropy: 0.7436 - val_categorical_accuracy: 0.6596
# Epoch 144/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3582 - categorical_crossentropy: 0.3582 - categorical_accuracy: 0.9375 - val_loss: 0.7631 - val_categorical_crossentropy: 0.7631 - val_categorical_accuracy: 0.7234
# Epoch 145/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3752 - categorical_crossentropy: 0.3752 - categorical_accuracy: 0.9042 - val_loss: 0.7541 - val_categorical_crossentropy: 0.7541 - val_categorical_accuracy: 0.6809
# Epoch 146/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3673 - categorical_crossentropy: 0.3673 - categorical_accuracy: 0.9375 - val_loss: 0.7874 - val_categorical_crossentropy: 0.7874 - val_categorical_accuracy: 0.7021
# Epoch 147/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3804 - categorical_crossentropy: 0.3804 - categorical_accuracy: 0.9042 - val_loss: 0.7633 - val_categorical_crossentropy: 0.7633 - val_categorical_accuracy: 0.6383
# Epoch 148/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3499 - categorical_crossentropy: 0.3499 - categorical_accuracy: 0.9292 - val_loss: 0.7371 - val_categorical_crossentropy: 0.7371 - val_categorical_accuracy: 0.6596
# Epoch 149/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3756 - categorical_crossentropy: 0.3756 - categorical_accuracy: 0.9167 - val_loss: 0.7609 - val_categorical_crossentropy: 0.7609 - val_categorical_accuracy: 0.6383
# Epoch 150/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3619 - categorical_crossentropy: 0.3619 - categorical_accuracy: 0.9292 - val_loss: 0.7481 - val_categorical_crossentropy: 0.7481 - val_categorical_accuracy: 0.6170
# Epoch 151/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3546 - categorical_crossentropy: 0.3546 - categorical_accuracy: 0.9208 - val_loss: 0.7294 - val_categorical_crossentropy: 0.7294 - val_categorical_accuracy: 0.6383
# Epoch 152/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3785 - categorical_crossentropy: 0.3785 - categorical_accuracy: 0.9208 - val_loss: 0.7551 - val_categorical_crossentropy: 0.7551 - val_categorical_accuracy: 0.6383
# Epoch 153/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3504 - categorical_crossentropy: 0.3504 - categorical_accuracy: 0.9333 - val_loss: 0.7943 - val_categorical_crossentropy: 0.7943 - val_categorical_accuracy: 0.7021
# Epoch 154/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3834 - categorical_crossentropy: 0.3834 - categorical_accuracy: 0.8833 - val_loss: 0.7788 - val_categorical_crossentropy: 0.7788 - val_categorical_accuracy: 0.7021
# Epoch 155/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3876 - categorical_crossentropy: 0.3876 - categorical_accuracy: 0.9042 - val_loss: 0.7855 - val_categorical_crossentropy: 0.7855 - val_categorical_accuracy: 0.6596
# Epoch 156/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3555 - categorical_crossentropy: 0.3555 - categorical_accuracy: 0.9375 - val_loss: 0.7532 - val_categorical_crossentropy: 0.7532 - val_categorical_accuracy: 0.6596
# Epoch 157/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3338 - categorical_crossentropy: 0.3338 - categorical_accuracy: 0.9250 - val_loss: 0.7793 - val_categorical_crossentropy: 0.7793 - val_categorical_accuracy: 0.6383
# Epoch 158/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3474 - categorical_crossentropy: 0.3474 - categorical_accuracy: 0.9250 - val_loss: 0.7708 - val_categorical_crossentropy: 0.7708 - val_categorical_accuracy: 0.5745
# Epoch 159/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3495 - categorical_crossentropy: 0.3495 - categorical_accuracy: 0.9167 - val_loss: 0.7902 - val_categorical_crossentropy: 0.7902 - val_categorical_accuracy: 0.6809
# Epoch 160/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3608 - categorical_crossentropy: 0.3608 - categorical_accuracy: 0.9000 - val_loss: 0.7945 - val_categorical_crossentropy: 0.7945 - val_categorical_accuracy: 0.6170
# Epoch 161/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3593 - categorical_crossentropy: 0.3593 - categorical_accuracy: 0.9292 - val_loss: 0.7612 - val_categorical_crossentropy: 0.7612 - val_categorical_accuracy: 0.6170
# Epoch 162/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3522 - categorical_crossentropy: 0.3522 - categorical_accuracy: 0.9167 - val_loss: 0.7661 - val_categorical_crossentropy: 0.7661 - val_categorical_accuracy: 0.6170
# Epoch 163/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3452 - categorical_crossentropy: 0.3452 - categorical_accuracy: 0.9208 - val_loss: 0.7476 - val_categorical_crossentropy: 0.7476 - val_categorical_accuracy: 0.5957
# Epoch 164/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3447 - categorical_crossentropy: 0.3447 - categorical_accuracy: 0.9333 - val_loss: 0.7500 - val_categorical_crossentropy: 0.7500 - val_categorical_accuracy: 0.6170
# Epoch 165/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3388 - categorical_crossentropy: 0.3388 - categorical_accuracy: 0.9333 - val_loss: 0.7629 - val_categorical_crossentropy: 0.7629 - val_categorical_accuracy: 0.6383
# Epoch 166/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3214 - categorical_crossentropy: 0.3214 - categorical_accuracy: 0.9292 - val_loss: 0.7756 - val_categorical_crossentropy: 0.7756 - val_categorical_accuracy: 0.5745
# Epoch 167/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3266 - categorical_crossentropy: 0.3266 - categorical_accuracy: 0.9500 - val_loss: 0.7812 - val_categorical_crossentropy: 0.7812 - val_categorical_accuracy: 0.6383
# Epoch 168/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3334 - categorical_crossentropy: 0.3334 - categorical_accuracy: 0.9208 - val_loss: 0.7382 - val_categorical_crossentropy: 0.7382 - val_categorical_accuracy: 0.6383
# Epoch 169/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3446 - categorical_crossentropy: 0.3446 - categorical_accuracy: 0.9292 - val_loss: 0.7370 - val_categorical_crossentropy: 0.7370 - val_categorical_accuracy: 0.6383
# Epoch 170/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3459 - categorical_crossentropy: 0.3459 - categorical_accuracy: 0.9333 - val_loss: 0.7442 - val_categorical_crossentropy: 0.7442 - val_categorical_accuracy: 0.6170
# Epoch 171/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3325 - categorical_crossentropy: 0.3325 - categorical_accuracy: 0.9375 - val_loss: 0.7394 - val_categorical_crossentropy: 0.7394 - val_categorical_accuracy: 0.6596
# Epoch 172/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3549 - categorical_crossentropy: 0.3549 - categorical_accuracy: 0.9042 - val_loss: 0.7499 - val_categorical_crossentropy: 0.7499 - val_categorical_accuracy: 0.7021
# Epoch 173/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3177 - categorical_crossentropy: 0.3177 - categorical_accuracy: 0.9375 - val_loss: 0.8052 - val_categorical_crossentropy: 0.8052 - val_categorical_accuracy: 0.6383
# Epoch 174/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3131 - categorical_crossentropy: 0.3131 - categorical_accuracy: 0.9375 - val_loss: 0.7503 - val_categorical_crossentropy: 0.7503 - val_categorical_accuracy: 0.6170
# Epoch 175/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3349 - categorical_crossentropy: 0.3349 - categorical_accuracy: 0.9042 - val_loss: 0.7342 - val_categorical_crossentropy: 0.7342 - val_categorical_accuracy: 0.6383
# Epoch 176/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3191 - categorical_crossentropy: 0.3191 - categorical_accuracy: 0.9458 - val_loss: 0.7724 - val_categorical_crossentropy: 0.7724 - val_categorical_accuracy: 0.6596
# Epoch 177/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3309 - categorical_crossentropy: 0.3309 - categorical_accuracy: 0.9292 - val_loss: 0.7748 - val_categorical_crossentropy: 0.7748 - val_categorical_accuracy: 0.6383
# Epoch 178/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3081 - categorical_crossentropy: 0.3081 - categorical_accuracy: 0.9542 - val_loss: 0.7207 - val_categorical_crossentropy: 0.7207 - val_categorical_accuracy: 0.6596
# Epoch 179/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3265 - categorical_crossentropy: 0.3265 - categorical_accuracy: 0.9208 - val_loss: 0.7370 - val_categorical_crossentropy: 0.7370 - val_categorical_accuracy: 0.6809
# Epoch 180/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3540 - categorical_crossentropy: 0.3540 - categorical_accuracy: 0.9125 - val_loss: 0.7030 - val_categorical_crossentropy: 0.7030 - val_categorical_accuracy: 0.6809
# Epoch 181/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3368 - categorical_crossentropy: 0.3368 - categorical_accuracy: 0.9167 - val_loss: 0.7066 - val_categorical_crossentropy: 0.7066 - val_categorical_accuracy: 0.6383
# Epoch 182/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3074 - categorical_crossentropy: 0.3074 - categorical_accuracy: 0.9500 - val_loss: 0.7787 - val_categorical_crossentropy: 0.7787 - val_categorical_accuracy: 0.6170
# Epoch 183/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3104 - categorical_crossentropy: 0.3104 - categorical_accuracy: 0.9417 - val_loss: 0.7299 - val_categorical_crossentropy: 0.7299 - val_categorical_accuracy: 0.6383
# Epoch 184/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3089 - categorical_crossentropy: 0.3089 - categorical_accuracy: 0.9500 - val_loss: 0.8002 - val_categorical_crossentropy: 0.8002 - val_categorical_accuracy: 0.6170
# Epoch 185/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3156 - categorical_crossentropy: 0.3156 - categorical_accuracy: 0.9083 - val_loss: 0.7719 - val_categorical_crossentropy: 0.7719 - val_categorical_accuracy: 0.6383
# Epoch 186/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3175 - categorical_crossentropy: 0.3175 - categorical_accuracy: 0.9542 - val_loss: 0.7944 - val_categorical_crossentropy: 0.7944 - val_categorical_accuracy: 0.6170
# Epoch 187/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3123 - categorical_crossentropy: 0.3123 - categorical_accuracy: 0.9375 - val_loss: 0.7734 - val_categorical_crossentropy: 0.7734 - val_categorical_accuracy: 0.5745
# Epoch 188/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3014 - categorical_crossentropy: 0.3014 - categorical_accuracy: 0.9375 - val_loss: 0.7508 - val_categorical_crossentropy: 0.7508 - val_categorical_accuracy: 0.5745
# Epoch 189/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3105 - categorical_crossentropy: 0.3105 - categorical_accuracy: 0.9167 - val_loss: 0.7493 - val_categorical_crossentropy: 0.7493 - val_categorical_accuracy: 0.6383
# Epoch 190/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3166 - categorical_crossentropy: 0.3166 - categorical_accuracy: 0.9208 - val_loss: 0.7597 - val_categorical_crossentropy: 0.7597 - val_categorical_accuracy: 0.6170
# Epoch 191/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3093 - categorical_crossentropy: 0.3093 - categorical_accuracy: 0.9458 - val_loss: 0.7697 - val_categorical_crossentropy: 0.7697 - val_categorical_accuracy: 0.5745
# Epoch 192/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3024 - categorical_crossentropy: 0.3024 - categorical_accuracy: 0.9417 - val_loss: 0.7807 - val_categorical_crossentropy: 0.7807 - val_categorical_accuracy: 0.5957
# Epoch 193/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3061 - categorical_crossentropy: 0.3061 - categorical_accuracy: 0.9250 - val_loss: 0.7485 - val_categorical_crossentropy: 0.7485 - val_categorical_accuracy: 0.5957
# Epoch 194/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2782 - categorical_crossentropy: 0.2782 - categorical_accuracy: 0.9333 - val_loss: 0.7158 - val_categorical_crossentropy: 0.7158 - val_categorical_accuracy: 0.5957
# Epoch 195/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2897 - categorical_crossentropy: 0.2897 - categorical_accuracy: 0.9458 - val_loss: 0.7204 - val_categorical_crossentropy: 0.7204 - val_categorical_accuracy: 0.6383
# Epoch 196/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2703 - categorical_crossentropy: 0.2703 - categorical_accuracy: 0.9500 - val_loss: 0.7563 - val_categorical_crossentropy: 0.7563 - val_categorical_accuracy: 0.5745
# Epoch 197/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2989 - categorical_crossentropy: 0.2989 - categorical_accuracy: 0.9208 - val_loss: 0.7585 - val_categorical_crossentropy: 0.7585 - val_categorical_accuracy: 0.6170
# Epoch 198/500
# ...
# Epoch 88/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4400 - categorical_crossentropy: 0.4400 - categorical_accuracy: 0.8875 - val_loss: 0.7942 - val_categorical_crossentropy: 0.7942 - val_categorical_accuracy: 0.6596
# Epoch 89/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4642 - categorical_crossentropy: 0.4642 - categorical_accuracy: 0.8792 - val_loss: 0.7784 - val_categorical_crossentropy: 0.7784 - val_categorical_accuracy: 0.7234
# Epoch 90/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4325 - categorical_crossentropy: 0.4325 - categorical_accuracy: 0.9208 - val_loss: 0.7798 - val_categorical_crossentropy: 0.7798 - val_categorical_accuracy: 0.6809
# Epoch 91/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4519 - categorical_crossentropy: 0.4519 - categorical_accuracy: 0.8875 - val_loss: 0.7792 - val_categorical_crossentropy: 0.7792 - val_categorical_accuracy: 0.6809
# Epoch 92/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4309 - categorical_crossentropy: 0.4309 - categorical_accuracy: 0.9000 - val_loss: 0.7641 - val_categorical_crossentropy: 0.7641 - val_categorical_accuracy: 0.7021
# Epoch 93/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4375 - categorical_crossentropy: 0.4375 - categorical_accuracy: 0.9125 - val_loss: 0.7870 - val_categorical_crossentropy: 0.7870 - val_categorical_accuracy: 0.6596
# Epoch 94/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4200 - categorical_crossentropy: 0.4200 - categorical_accuracy: 0.9167 - val_loss: 0.7759 - val_categorical_crossentropy: 0.7759 - val_categorical_accuracy: 0.6596
# Epoch 95/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4385 - categorical_crossentropy: 0.4385 - categorical_accuracy: 0.8917 - val_loss: 0.7755 - val_categorical_crossentropy: 0.7755 - val_categorical_accuracy: 0.6809
# Epoch 96/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4283 - categorical_crossentropy: 0.4283 - categorical_accuracy: 0.8917 - val_loss: 0.7812 - val_categorical_crossentropy: 0.7812 - val_categorical_accuracy: 0.7234
# Epoch 97/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4139 - categorical_crossentropy: 0.4139 - categorical_accuracy: 0.8958 - val_loss: 0.7878 - val_categorical_crossentropy: 0.7878 - val_categorical_accuracy: 0.6383
# Epoch 98/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4386 - categorical_crossentropy: 0.4386 - categorical_accuracy: 0.9083 - val_loss: 0.7770 - val_categorical_crossentropy: 0.7770 - val_categorical_accuracy: 0.7021
# Epoch 99/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4216 - categorical_crossentropy: 0.4216 - categorical_accuracy: 0.9292 - val_loss: 0.8043 - val_categorical_crossentropy: 0.8043 - val_categorical_accuracy: 0.6383
# Epoch 100/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4199 - categorical_crossentropy: 0.4199 - categorical_accuracy: 0.8917 - val_loss: 0.7789 - val_categorical_crossentropy: 0.7789 - val_categorical_accuracy: 0.7021
# Epoch 101/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4091 - categorical_crossentropy: 0.4091 - categorical_accuracy: 0.9000 - val_loss: 0.7619 - val_categorical_crossentropy: 0.7619 - val_categorical_accuracy: 0.7021
# Epoch 102/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4224 - categorical_crossentropy: 0.4224 - categorical_accuracy: 0.9083 - val_loss: 0.7817 - val_categorical_crossentropy: 0.7817 - val_categorical_accuracy: 0.6809
# Epoch 103/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4263 - categorical_crossentropy: 0.4263 - categorical_accuracy: 0.8875 - val_loss: 0.7482 - val_categorical_crossentropy: 0.7482 - val_categorical_accuracy: 0.7234
# Epoch 104/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4190 - categorical_crossentropy: 0.4190 - categorical_accuracy: 0.9000 - val_loss: 0.7723 - val_categorical_crossentropy: 0.7723 - val_categorical_accuracy: 0.7021
# Epoch 105/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4120 - categorical_crossentropy: 0.4120 - categorical_accuracy: 0.8875 - val_loss: 0.7856 - val_categorical_crossentropy: 0.7856 - val_categorical_accuracy: 0.7021
# Epoch 106/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4190 - categorical_crossentropy: 0.4190 - categorical_accuracy: 0.8917 - val_loss: 0.7493 - val_categorical_crossentropy: 0.7493 - val_categorical_accuracy: 0.7021
# Epoch 107/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4307 - categorical_crossentropy: 0.4307 - categorical_accuracy: 0.8833 - val_loss: 0.7887 - val_categorical_crossentropy: 0.7887 - val_categorical_accuracy: 0.6809
# Epoch 108/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4148 - categorical_crossentropy: 0.4148 - categorical_accuracy: 0.9000 - val_loss: 0.7767 - val_categorical_crossentropy: 0.7767 - val_categorical_accuracy: 0.6809
# Epoch 109/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4108 - categorical_crossentropy: 0.4108 - categorical_accuracy: 0.9125 - val_loss: 0.7687 - val_categorical_crossentropy: 0.7687 - val_categorical_accuracy: 0.7021
# Epoch 110/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4132 - categorical_crossentropy: 0.4132 - categorical_accuracy: 0.9042 - val_loss: 0.8042 - val_categorical_crossentropy: 0.8042 - val_categorical_accuracy: 0.7021
# Epoch 111/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3937 - categorical_crossentropy: 0.3937 - categorical_accuracy: 0.9167 - val_loss: 0.7608 - val_categorical_crossentropy: 0.7608 - val_categorical_accuracy: 0.7021
# Epoch 112/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4108 - categorical_crossentropy: 0.4108 - categorical_accuracy: 0.8917 - val_loss: 0.7942 - val_categorical_crossentropy: 0.7942 - val_categorical_accuracy: 0.6596
# Epoch 113/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3936 - categorical_crossentropy: 0.3936 - categorical_accuracy: 0.9167 - val_loss: 0.7635 - val_categorical_crossentropy: 0.7635 - val_categorical_accuracy: 0.7021
# Epoch 114/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3943 - categorical_crossentropy: 0.3943 - categorical_accuracy: 0.9042 - val_loss: 0.7938 - val_categorical_crossentropy: 0.7938 - val_categorical_accuracy: 0.6809
# Epoch 115/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3963 - categorical_crossentropy: 0.3963 - categorical_accuracy: 0.9083 - val_loss: 0.7900 - val_categorical_crossentropy: 0.7900 - val_categorical_accuracy: 0.7234
# Epoch 116/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3815 - categorical_crossentropy: 0.3815 - categorical_accuracy: 0.9083 - val_loss: 0.7783 - val_categorical_crossentropy: 0.7783 - val_categorical_accuracy: 0.7234
# Epoch 117/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3907 - categorical_crossentropy: 0.3907 - categorical_accuracy: 0.9125 - val_loss: 0.7971 - val_categorical_crossentropy: 0.7971 - val_categorical_accuracy: 0.6809
# Epoch 118/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4123 - categorical_crossentropy: 0.4123 - categorical_accuracy: 0.9083 - val_loss: 0.7922 - val_categorical_crossentropy: 0.7922 - val_categorical_accuracy: 0.7021
# Epoch 119/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4087 - categorical_crossentropy: 0.4087 - categorical_accuracy: 0.9208 - val_loss: 0.7930 - val_categorical_crossentropy: 0.7930 - val_categorical_accuracy: 0.7234
# Epoch 120/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3898 - categorical_crossentropy: 0.3898 - categorical_accuracy: 0.9167 - val_loss: 0.7901 - val_categorical_crossentropy: 0.7901 - val_categorical_accuracy: 0.7234
# Epoch 121/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3783 - categorical_crossentropy: 0.3783 - categorical_accuracy: 0.9125 - val_loss: 0.7789 - val_categorical_crossentropy: 0.7789 - val_categorical_accuracy: 0.7021
# Epoch 122/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3864 - categorical_crossentropy: 0.3864 - categorical_accuracy: 0.9208 - val_loss: 0.7828 - val_categorical_crossentropy: 0.7828 - val_categorical_accuracy: 0.7021
# Epoch 123/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3774 - categorical_crossentropy: 0.3774 - categorical_accuracy: 0.9167 - val_loss: 0.7833 - val_categorical_crossentropy: 0.7833 - val_categorical_accuracy: 0.7021
# Epoch 124/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4004 - categorical_crossentropy: 0.4004 - categorical_accuracy: 0.8917 - val_loss: 0.8022 - val_categorical_crossentropy: 0.8022 - val_categorical_accuracy: 0.7021
# Epoch 125/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3774 - categorical_crossentropy: 0.3774 - categorical_accuracy: 0.9167 - val_loss: 0.7984 - val_categorical_crossentropy: 0.7984 - val_categorical_accuracy: 0.7021
# Epoch 126/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3723 - categorical_crossentropy: 0.3723 - categorical_accuracy: 0.9333 - val_loss: 0.7582 - val_categorical_crossentropy: 0.7582 - val_categorical_accuracy: 0.6809
# Epoch 127/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3706 - categorical_crossentropy: 0.3706 - categorical_accuracy: 0.9292 - val_loss: 0.7875 - val_categorical_crossentropy: 0.7875 - val_categorical_accuracy: 0.6809
# Epoch 128/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3621 - categorical_crossentropy: 0.3621 - categorical_accuracy: 0.9458 - val_loss: 0.8016 - val_categorical_crossentropy: 0.8016 - val_categorical_accuracy: 0.6383
# Epoch 129/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3864 - categorical_crossentropy: 0.3864 - categorical_accuracy: 0.9167 - val_loss: 0.7979 - val_categorical_crossentropy: 0.7979 - val_categorical_accuracy: 0.5957
# Epoch 130/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3721 - categorical_crossentropy: 0.3721 - categorical_accuracy: 0.8958 - val_loss: 0.8170 - val_categorical_crossentropy: 0.8170 - val_categorical_accuracy: 0.6809
# Epoch 131/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3766 - categorical_crossentropy: 0.3766 - categorical_accuracy: 0.9167 - val_loss: 0.7790 - val_categorical_crossentropy: 0.7790 - val_categorical_accuracy: 0.6809
# Epoch 132/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3800 - categorical_crossentropy: 0.3800 - categorical_accuracy: 0.8958 - val_loss: 0.8170 - val_categorical_crossentropy: 0.8170 - val_categorical_accuracy: 0.6596
# Epoch 133/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3355 - categorical_crossentropy: 0.3355 - categorical_accuracy: 0.9583 - val_loss: 0.8262 - val_categorical_crossentropy: 0.8262 - val_categorical_accuracy: 0.6596
# Epoch 134/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3758 - categorical_crossentropy: 0.3758 - categorical_accuracy: 0.8875 - val_loss: 0.8102 - val_categorical_crossentropy: 0.8102 - val_categorical_accuracy: 0.6596
# Epoch 135/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3483 - categorical_crossentropy: 0.3483 - categorical_accuracy: 0.9333 - val_loss: 0.8427 - val_categorical_crossentropy: 0.8427 - val_categorical_accuracy: 0.6383
# Epoch 136/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3668 - categorical_crossentropy: 0.3668 - categorical_accuracy: 0.9292 - val_loss: 0.8381 - val_categorical_crossentropy: 0.8381 - val_categorical_accuracy: 0.6596
# Epoch 137/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3644 - categorical_crossentropy: 0.3644 - categorical_accuracy: 0.9125 - val_loss: 0.8335 - val_categorical_crossentropy: 0.8335 - val_categorical_accuracy: 0.7021
# Epoch 138/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3485 - categorical_crossentropy: 0.3485 - categorical_accuracy: 0.9250 - val_loss: 0.8133 - val_categorical_crossentropy: 0.8133 - val_categorical_accuracy: 0.6809
# Epoch 139/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3492 - categorical_crossentropy: 0.3492 - categorical_accuracy: 0.9542 - val_loss: 0.8360 - val_categorical_crossentropy: 0.8360 - val_categorical_accuracy: 0.6809
# Epoch 140/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3336 - categorical_crossentropy: 0.3336 - categorical_accuracy: 0.9375 - val_loss: 0.8159 - val_categorical_crossentropy: 0.8159 - val_categorical_accuracy: 0.5532
# Epoch 141/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3183 - categorical_crossentropy: 0.3183 - categorical_accuracy: 0.9583 - val_loss: 0.8667 - val_categorical_crossentropy: 0.8667 - val_categorical_accuracy: 0.5745
# Epoch 142/500
# 5/8 [=================>............] - ETA: 0s - loss: 0.3359 - categorical_crossentropy: 0.3359 - categorical_accuracy: 0.9500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f5fd8903e847> in <module>()
#     123
#     124           history = adv_model.fit(train_data, validation_data=val_data,
# --> 125                                   validation_steps=None, epochs=500, verbose=1)
#     126
#     127           print('\n# Evaluate on test data')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     298           else:
#     299             actual_inputs = ins()
# --> 300           batch_outs = f(actual_inputs)
#     301         except errors.OutOfRangeError:
#     302           if is_dataset:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
