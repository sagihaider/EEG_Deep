# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_2A/main_EEGNet_NSL_2A_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 481 (delta 0), reused 0 (delta 0), pack-reused 477
# Receiving objects: 100% (481/481), 1.69 GiB | 43.42 MiB/s, done.
# Resolving deltas: 100% (230/230), done.
# Checking out files: 100% (93/93), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf

# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting neural_structured_learning
#   Downloading https://files.pythonhosted.org/packages/08/2e/22b1385d7d601ad0c81457a5b66b3bb6f3c400348c62ea3f07a5fc1b13bc/neural_structured_learning-1.1.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 4.7MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.5)
# Installing collected packages: neural-structured-learning
# Successfully installed neural-structured-learning-1.1.0

# %%
from numpy import zeros
K.clear_session()

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])


# Initialize parameter
h_cut = [24]
drop_out = [0.25]
k_len = [15, 30, 60]
n_epochs = 100

out_f_name = 'acc_NSL_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_accuracy = zeros([nsub, nfilt,ndrop,nkl])

for sub_idx, x in enumerate(range(1,10)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered
      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250,order=4)
        # tril_filtered = tril_filtered.transpose()
        X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test = X_test.reshape(X_test.shape[0], kernels, chans, samples)
      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

          adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
          adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
          # compile the model and set the optimizers
          adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
          batch_size = 32

          X_train = tf.cast(X_train, tf.float32)
          X_test = tf.cast(X_test, tf.float32)
          X_val = tf.cast(X_val, tf.float32)

          train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
          val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
          test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)
          val_steps = X_val.shape[0] // batch_size
          
          history = adv_model.fit(train_data, validation_data=val_data, 
                                  validation_steps=None, epochs=n_epochs, verbose=1)
          
          print('\n# Evaluate on test data')
          results = adv_model.evaluate(test_data)
          print('test loss, test acc:', results)

          # loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          # categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          categorical_accuracy[sub_idx,h_indx,id_d, id_kl] = results[2]

          # from keras import backend as K 
          # Do some code, e.g. train and save model
          # K.clear_session()


np.save(out_f_name, categorical_accuracy)
# Out:
# acc_NSL_EEGNet_epochs_100_filter_[24]_drop_[0.25]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288, 1)
# (240, 22, 750)
# (240, 1)
# (47, 22, 750)
# (47, 1)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/neural_structured_learning/keras/adversarial_regularization.py:167: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/500
# 8/8 [==============================] - 6s 810ms/step - loss: 1.4086 - categorical_crossentropy: 1.4086 - categorical_accuracy: 0.2583 - val_loss: 1.3880 - val_categorical_crossentropy: 1.3880 - val_categorical_accuracy: 0.2979
# Epoch 2/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3597 - categorical_crossentropy: 1.3597 - categorical_accuracy: 0.3333 - val_loss: 1.3852 - val_categorical_crossentropy: 1.3852 - val_categorical_accuracy: 0.2979
# Epoch 3/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3281 - categorical_crossentropy: 1.3281 - categorical_accuracy: 0.4208 - val_loss: 1.3813 - val_categorical_crossentropy: 1.3813 - val_categorical_accuracy: 0.2979
# Epoch 4/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.2863 - categorical_crossentropy: 1.2863 - categorical_accuracy: 0.5250 - val_loss: 1.3750 - val_categorical_crossentropy: 1.3750 - val_categorical_accuracy: 0.4255
# Epoch 5/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.2260 - categorical_crossentropy: 1.2260 - categorical_accuracy: 0.6125 - val_loss: 1.3658 - val_categorical_crossentropy: 1.3658 - val_categorical_accuracy: 0.4255
# Epoch 6/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.1596 - categorical_crossentropy: 1.1596 - categorical_accuracy: 0.6542 - val_loss: 1.3553 - val_categorical_crossentropy: 1.3553 - val_categorical_accuracy: 0.2979
# Epoch 7/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0697 - categorical_crossentropy: 1.0697 - categorical_accuracy: 0.7083 - val_loss: 1.3474 - val_categorical_crossentropy: 1.3474 - val_categorical_accuracy: 0.2553
# Epoch 8/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0044 - categorical_crossentropy: 1.0044 - categorical_accuracy: 0.6458 - val_loss: 1.3457 - val_categorical_crossentropy: 1.3457 - val_categorical_accuracy: 0.2553
# Epoch 9/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9450 - categorical_crossentropy: 0.9450 - categorical_accuracy: 0.7125 - val_loss: 1.3571 - val_categorical_crossentropy: 1.3571 - val_categorical_accuracy: 0.2553
# Epoch 10/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9084 - categorical_crossentropy: 0.9084 - categorical_accuracy: 0.6750 - val_loss: 1.3791 - val_categorical_crossentropy: 1.3791 - val_categorical_accuracy: 0.2553
# Epoch 11/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8735 - categorical_crossentropy: 0.8735 - categorical_accuracy: 0.6875 - val_loss: 1.4028 - val_categorical_crossentropy: 1.4028 - val_categorical_accuracy: 0.2553
# Epoch 12/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8345 - categorical_crossentropy: 0.8345 - categorical_accuracy: 0.6875 - val_loss: 1.4228 - val_categorical_crossentropy: 1.4228 - val_categorical_accuracy: 0.2553
# Epoch 13/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8390 - categorical_crossentropy: 0.8390 - categorical_accuracy: 0.6583 - val_loss: 1.4558 - val_categorical_crossentropy: 1.4558 - val_categorical_accuracy: 0.2553
# Epoch 14/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8039 - categorical_crossentropy: 0.8039 - categorical_accuracy: 0.7208 - val_loss: 1.4887 - val_categorical_crossentropy: 1.4887 - val_categorical_accuracy: 0.2553
# Epoch 15/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7859 - categorical_crossentropy: 0.7859 - categorical_accuracy: 0.7292 - val_loss: 1.5269 - val_categorical_crossentropy: 1.5269 - val_categorical_accuracy: 0.2553
# Epoch 16/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7775 - categorical_crossentropy: 0.7775 - categorical_accuracy: 0.7167 - val_loss: 1.5677 - val_categorical_crossentropy: 1.5677 - val_categorical_accuracy: 0.2553
# Epoch 17/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7518 - categorical_crossentropy: 0.7518 - categorical_accuracy: 0.7167 - val_loss: 1.5921 - val_categorical_crossentropy: 1.5921 - val_categorical_accuracy: 0.2553
# Epoch 18/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7605 - categorical_crossentropy: 0.7605 - categorical_accuracy: 0.7292 - val_loss: 1.5975 - val_categorical_crossentropy: 1.5975 - val_categorical_accuracy: 0.2553
# Epoch 19/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7530 - categorical_crossentropy: 0.7530 - categorical_accuracy: 0.7500 - val_loss: 1.6122 - val_categorical_crossentropy: 1.6122 - val_categorical_accuracy: 0.2553
# Epoch 20/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7413 - categorical_crossentropy: 0.7413 - categorical_accuracy: 0.7250 - val_loss: 1.6465 - val_categorical_crossentropy: 1.6465 - val_categorical_accuracy: 0.2553
# Epoch 21/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7190 - categorical_crossentropy: 0.7190 - categorical_accuracy: 0.7542 - val_loss: 1.6852 - val_categorical_crossentropy: 1.6852 - val_categorical_accuracy: 0.2553
# Epoch 22/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7321 - categorical_crossentropy: 0.7321 - categorical_accuracy: 0.7625 - val_loss: 1.7077 - val_categorical_crossentropy: 1.7077 - val_categorical_accuracy: 0.2553
# Epoch 23/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7278 - categorical_crossentropy: 0.7278 - categorical_accuracy: 0.7625 - val_loss: 1.7358 - val_categorical_crossentropy: 1.7358 - val_categorical_accuracy: 0.2553
# Epoch 24/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7157 - categorical_crossentropy: 0.7157 - categorical_accuracy: 0.7833 - val_loss: 1.7557 - val_categorical_crossentropy: 1.7557 - val_categorical_accuracy: 0.2553
# Epoch 25/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7161 - categorical_crossentropy: 0.7161 - categorical_accuracy: 0.7708 - val_loss: 1.7821 - val_categorical_crossentropy: 1.7821 - val_categorical_accuracy: 0.2553
# Epoch 26/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7161 - categorical_crossentropy: 0.7161 - categorical_accuracy: 0.7250 - val_loss: 1.8213 - val_categorical_crossentropy: 1.8213 - val_categorical_accuracy: 0.2553
# Epoch 27/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7006 - categorical_crossentropy: 0.7006 - categorical_accuracy: 0.7333 - val_loss: 1.8543 - val_categorical_crossentropy: 1.8543 - val_categorical_accuracy: 0.2553
# Epoch 28/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6920 - categorical_crossentropy: 0.6920 - categorical_accuracy: 0.7792 - val_loss: 1.8707 - val_categorical_crossentropy: 1.8707 - val_categorical_accuracy: 0.2553
# Epoch 29/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6916 - categorical_crossentropy: 0.6916 - categorical_accuracy: 0.7875 - val_loss: 1.8924 - val_categorical_crossentropy: 1.8924 - val_categorical_accuracy: 0.2766
# Epoch 30/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6653 - categorical_crossentropy: 0.6653 - categorical_accuracy: 0.8250 - val_loss: 1.8750 - val_categorical_crossentropy: 1.8750 - val_categorical_accuracy: 0.2766
# Epoch 31/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6624 - categorical_crossentropy: 0.6624 - categorical_accuracy: 0.7792 - val_loss: 1.8236 - val_categorical_crossentropy: 1.8236 - val_categorical_accuracy: 0.2766
# Epoch 32/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6546 - categorical_crossentropy: 0.6546 - categorical_accuracy: 0.8000 - val_loss: 1.8352 - val_categorical_crossentropy: 1.8352 - val_categorical_accuracy: 0.3404
# Epoch 33/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6428 - categorical_crossentropy: 0.6428 - categorical_accuracy: 0.8042 - val_loss: 1.8512 - val_categorical_crossentropy: 1.8512 - val_categorical_accuracy: 0.3830
# Epoch 34/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6531 - categorical_crossentropy: 0.6531 - categorical_accuracy: 0.7958 - val_loss: 1.8622 - val_categorical_crossentropy: 1.8622 - val_categorical_accuracy: 0.3830
# Epoch 35/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6137 - categorical_crossentropy: 0.6137 - categorical_accuracy: 0.8208 - val_loss: 1.8318 - val_categorical_crossentropy: 1.8318 - val_categorical_accuracy: 0.4043
# Epoch 36/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6394 - categorical_crossentropy: 0.6394 - categorical_accuracy: 0.7958 - val_loss: 1.8161 - val_categorical_crossentropy: 1.8161 - val_categorical_accuracy: 0.4043
# Epoch 37/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6281 - categorical_crossentropy: 0.6281 - categorical_accuracy: 0.8250 - val_loss: 1.8275 - val_categorical_crossentropy: 1.8275 - val_categorical_accuracy: 0.4255
# Epoch 38/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6305 - categorical_crossentropy: 0.6305 - categorical_accuracy: 0.7875 - val_loss: 1.8070 - val_categorical_crossentropy: 1.8070 - val_categorical_accuracy: 0.4043
# Epoch 39/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6170 - categorical_crossentropy: 0.6170 - categorical_accuracy: 0.8083 - val_loss: 1.7390 - val_categorical_crossentropy: 1.7390 - val_categorical_accuracy: 0.3617
# Epoch 40/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6265 - categorical_crossentropy: 0.6265 - categorical_accuracy: 0.8042 - val_loss: 1.7136 - val_categorical_crossentropy: 1.7136 - val_categorical_accuracy: 0.3830
# Epoch 41/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6249 - categorical_crossentropy: 0.6249 - categorical_accuracy: 0.7958 - val_loss: 1.6887 - val_categorical_crossentropy: 1.6887 - val_categorical_accuracy: 0.4468
# Epoch 42/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6107 - categorical_crossentropy: 0.6107 - categorical_accuracy: 0.8167 - val_loss: 1.6872 - val_categorical_crossentropy: 1.6872 - val_categorical_accuracy: 0.4468
# Epoch 43/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6001 - categorical_crossentropy: 0.6001 - categorical_accuracy: 0.8125 - val_loss: 1.6518 - val_categorical_crossentropy: 1.6518 - val_categorical_accuracy: 0.4255
# Epoch 44/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6000 - categorical_crossentropy: 0.6000 - categorical_accuracy: 0.8250 - val_loss: 1.5514 - val_categorical_crossentropy: 1.5514 - val_categorical_accuracy: 0.4468
# Epoch 45/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6032 - categorical_crossentropy: 0.6032 - categorical_accuracy: 0.8292 - val_loss: 1.5154 - val_categorical_crossentropy: 1.5154 - val_categorical_accuracy: 0.4043
# Epoch 46/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6014 - categorical_crossentropy: 0.6014 - categorical_accuracy: 0.7958 - val_loss: 1.4546 - val_categorical_crossentropy: 1.4546 - val_categorical_accuracy: 0.4468
# Epoch 47/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6217 - categorical_crossentropy: 0.6217 - categorical_accuracy: 0.8000 - val_loss: 1.3737 - val_categorical_crossentropy: 1.3737 - val_categorical_accuracy: 0.4681
# Epoch 48/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6015 - categorical_crossentropy: 0.6015 - categorical_accuracy: 0.8292 - val_loss: 1.3856 - val_categorical_crossentropy: 1.3856 - val_categorical_accuracy: 0.5106
# Epoch 49/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5751 - categorical_crossentropy: 0.5751 - categorical_accuracy: 0.8458 - val_loss: 1.3724 - val_categorical_crossentropy: 1.3724 - val_categorical_accuracy: 0.4681
# Epoch 50/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5833 - categorical_crossentropy: 0.5833 - categorical_accuracy: 0.8167 - val_loss: 1.2598 - val_categorical_crossentropy: 1.2598 - val_categorical_accuracy: 0.4894
# Epoch 51/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5529 - categorical_crossentropy: 0.5529 - categorical_accuracy: 0.8333 - val_loss: 1.2508 - val_categorical_crossentropy: 1.2508 - val_categorical_accuracy: 0.5106
# Epoch 52/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5912 - categorical_crossentropy: 0.5912 - categorical_accuracy: 0.8208 - val_loss: 1.2634 - val_categorical_crossentropy: 1.2634 - val_categorical_accuracy: 0.4681
# Epoch 53/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5903 - categorical_crossentropy: 0.5903 - categorical_accuracy: 0.8083 - val_loss: 1.1514 - val_categorical_crossentropy: 1.1514 - val_categorical_accuracy: 0.5532
# Epoch 54/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5621 - categorical_crossentropy: 0.5621 - categorical_accuracy: 0.8250 - val_loss: 1.0924 - val_categorical_crossentropy: 1.0924 - val_categorical_accuracy: 0.5532
# Epoch 55/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5687 - categorical_crossentropy: 0.5687 - categorical_accuracy: 0.8250 - val_loss: 1.0252 - val_categorical_crossentropy: 1.0252 - val_categorical_accuracy: 0.5106
# Epoch 56/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5480 - categorical_crossentropy: 0.5480 - categorical_accuracy: 0.8375 - val_loss: 0.9601 - val_categorical_crossentropy: 0.9601 - val_categorical_accuracy: 0.5532
# Epoch 57/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5574 - categorical_crossentropy: 0.5574 - categorical_accuracy: 0.8292 - val_loss: 1.0140 - val_categorical_crossentropy: 1.0140 - val_categorical_accuracy: 0.5319
# Epoch 58/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5504 - categorical_crossentropy: 0.5504 - categorical_accuracy: 0.8500 - val_loss: 1.0109 - val_categorical_crossentropy: 1.0109 - val_categorical_accuracy: 0.5106
# Epoch 59/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5558 - categorical_crossentropy: 0.5558 - categorical_accuracy: 0.8083 - val_loss: 0.9874 - val_categorical_crossentropy: 0.9874 - val_categorical_accuracy: 0.4681
# Epoch 60/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5616 - categorical_crossentropy: 0.5616 - categorical_accuracy: 0.8167 - val_loss: 0.9303 - val_categorical_crossentropy: 0.9303 - val_categorical_accuracy: 0.5319
# Epoch 61/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5480 - categorical_crossentropy: 0.5480 - categorical_accuracy: 0.8417 - val_loss: 0.9107 - val_categorical_crossentropy: 0.9107 - val_categorical_accuracy: 0.5532
# Epoch 62/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5610 - categorical_crossentropy: 0.5610 - categorical_accuracy: 0.8292 - val_loss: 0.9200 - val_categorical_crossentropy: 0.9200 - val_categorical_accuracy: 0.5319
# Epoch 63/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5423 - categorical_crossentropy: 0.5423 - categorical_accuracy: 0.8292 - val_loss: 0.9098 - val_categorical_crossentropy: 0.9098 - val_categorical_accuracy: 0.5745
# Epoch 64/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5333 - categorical_crossentropy: 0.5333 - categorical_accuracy: 0.8250 - val_loss: 0.9510 - val_categorical_crossentropy: 0.9510 - val_categorical_accuracy: 0.5745
# Epoch 65/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5308 - categorical_crossentropy: 0.5308 - categorical_accuracy: 0.8292 - val_loss: 0.9644 - val_categorical_crossentropy: 0.9644 - val_categorical_accuracy: 0.5532
# Epoch 66/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5477 - categorical_crossentropy: 0.5477 - categorical_accuracy: 0.8083 - val_loss: 0.9487 - val_categorical_crossentropy: 0.9487 - val_categorical_accuracy: 0.5319
# Epoch 67/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5539 - categorical_crossentropy: 0.5539 - categorical_accuracy: 0.8500 - val_loss: 0.8887 - val_categorical_crossentropy: 0.8887 - val_categorical_accuracy: 0.5745
# Epoch 68/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5257 - categorical_crossentropy: 0.5257 - categorical_accuracy: 0.8500 - val_loss: 0.8752 - val_categorical_crossentropy: 0.8752 - val_categorical_accuracy: 0.5745
# Epoch 69/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5117 - categorical_crossentropy: 0.5117 - categorical_accuracy: 0.8375 - val_loss: 0.8859 - val_categorical_crossentropy: 0.8859 - val_categorical_accuracy: 0.5745
# Epoch 70/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5208 - categorical_crossentropy: 0.5208 - categorical_accuracy: 0.8542 - val_loss: 0.9193 - val_categorical_crossentropy: 0.9193 - val_categorical_accuracy: 0.5532
# Epoch 71/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5109 - categorical_crossentropy: 0.5109 - categorical_accuracy: 0.8500 - val_loss: 0.9245 - val_categorical_crossentropy: 0.9245 - val_categorical_accuracy: 0.5745
# Epoch 72/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5317 - categorical_crossentropy: 0.5317 - categorical_accuracy: 0.8500 - val_loss: 0.8839 - val_categorical_crossentropy: 0.8839 - val_categorical_accuracy: 0.5319
# Epoch 73/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5005 - categorical_crossentropy: 0.5005 - categorical_accuracy: 0.8542 - val_loss: 0.8945 - val_categorical_crossentropy: 0.8945 - val_categorical_accuracy: 0.5532
# Epoch 74/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5034 - categorical_crossentropy: 0.5034 - categorical_accuracy: 0.8333 - val_loss: 0.8829 - val_categorical_crossentropy: 0.8829 - val_categorical_accuracy: 0.5745
# Epoch 75/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5260 - categorical_crossentropy: 0.5260 - categorical_accuracy: 0.8500 - val_loss: 0.8672 - val_categorical_crossentropy: 0.8672 - val_categorical_accuracy: 0.5745
# Epoch 76/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4973 - categorical_crossentropy: 0.4973 - categorical_accuracy: 0.8792 - val_loss: 0.8628 - val_categorical_crossentropy: 0.8628 - val_categorical_accuracy: 0.5957
# Epoch 77/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5212 - categorical_crossentropy: 0.5212 - categorical_accuracy: 0.8500 - val_loss: 0.8578 - val_categorical_crossentropy: 0.8578 - val_categorical_accuracy: 0.5957
# Epoch 78/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5042 - categorical_crossentropy: 0.5042 - categorical_accuracy: 0.8542 - val_loss: 0.8956 - val_categorical_crossentropy: 0.8956 - val_categorical_accuracy: 0.5319
# Epoch 79/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5069 - categorical_crossentropy: 0.5069 - categorical_accuracy: 0.8458 - val_loss: 0.9005 - val_categorical_crossentropy: 0.9005 - val_categorical_accuracy: 0.5319
# Epoch 80/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5118 - categorical_crossentropy: 0.5118 - categorical_accuracy: 0.8625 - val_loss: 0.8706 - val_categorical_crossentropy: 0.8706 - val_categorical_accuracy: 0.5532
# Epoch 81/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5088 - categorical_crossentropy: 0.5088 - categorical_accuracy: 0.8750 - val_loss: 0.8617 - val_categorical_crossentropy: 0.8617 - val_categorical_accuracy: 0.5745
# Epoch 82/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4963 - categorical_crossentropy: 0.4963 - categorical_accuracy: 0.8583 - val_loss: 0.8772 - val_categorical_crossentropy: 0.8772 - val_categorical_accuracy: 0.5319
# Epoch 83/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4982 - categorical_crossentropy: 0.4982 - categorical_accuracy: 0.8875 - val_loss: 0.9247 - val_categorical_crossentropy: 0.9247 - val_categorical_accuracy: 0.5532
# Epoch 84/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4784 - categorical_crossentropy: 0.4784 - categorical_accuracy: 0.8833 - val_loss: 0.9229 - val_categorical_crossentropy: 0.9229 - val_categorical_accuracy: 0.5106
# Epoch 85/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5089 - categorical_crossentropy: 0.5089 - categorical_accuracy: 0.8333 - val_loss: 0.8864 - val_categorical_crossentropy: 0.8864 - val_categorical_accuracy: 0.5532
# Epoch 86/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4530 - categorical_crossentropy: 0.4530 - categorical_accuracy: 0.9167 - val_loss: 0.8725 - val_categorical_crossentropy: 0.8725 - val_categorical_accuracy: 0.5532
# Epoch 87/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4705 - categorical_crossentropy: 0.4705 - categorical_accuracy: 0.8750 - val_loss: 0.8685 - val_categorical_crossentropy: 0.8685 - val_categorical_accuracy: 0.5957
# Epoch 88/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4551 - categorical_crossentropy: 0.4551 - categorical_accuracy: 0.8917 - val_loss: 0.8952 - val_categorical_crossentropy: 0.8952 - val_categorical_accuracy: 0.5745
# Epoch 89/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5091 - categorical_crossentropy: 0.5091 - categorical_accuracy: 0.8417 - val_loss: 0.9073 - val_categorical_crossentropy: 0.9073 - val_categorical_accuracy: 0.5106
# Epoch 90/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4753 - categorical_crossentropy: 0.4753 - categorical_accuracy: 0.8750 - val_loss: 0.8897 - val_categorical_crossentropy: 0.8897 - val_categorical_accuracy: 0.5106
# Epoch 91/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4764 - categorical_crossentropy: 0.4764 - categorical_accuracy: 0.8583 - val_loss: 0.8630 - val_categorical_crossentropy: 0.8630 - val_categorical_accuracy: 0.5745
# Epoch 92/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4835 - categorical_crossentropy: 0.4835 - categorical_accuracy: 0.8500 - val_loss: 0.8448 - val_categorical_crossentropy: 0.8448 - val_categorical_accuracy: 0.5957
# Epoch 93/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4592 - categorical_crossentropy: 0.4592 - categorical_accuracy: 0.9042 - val_loss: 0.8211 - val_categorical_crossentropy: 0.8211 - val_categorical_accuracy: 0.5957
# Epoch 94/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4773 - categorical_crossentropy: 0.4773 - categorical_accuracy: 0.9000 - val_loss: 0.8389 - val_categorical_crossentropy: 0.8389 - val_categorical_accuracy: 0.6170
# Epoch 95/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4690 - categorical_crossentropy: 0.4690 - categorical_accuracy: 0.8833 - val_loss: 0.8036 - val_categorical_crossentropy: 0.8036 - val_categorical_accuracy: 0.7021
# Epoch 96/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4567 - categorical_crossentropy: 0.4567 - categorical_accuracy: 0.8833 - val_loss: 0.8268 - val_categorical_crossentropy: 0.8268 - val_categorical_accuracy: 0.6383
# Epoch 97/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4443 - categorical_crossentropy: 0.4443 - categorical_accuracy: 0.9042 - val_loss: 0.8119 - val_categorical_crossentropy: 0.8119 - val_categorical_accuracy: 0.6809
# Epoch 98/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4762 - categorical_crossentropy: 0.4762 - categorical_accuracy: 0.8750 - val_loss: 0.8265 - val_categorical_crossentropy: 0.8265 - val_categorical_accuracy: 0.6383
# Epoch 99/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4544 - categorical_crossentropy: 0.4544 - categorical_accuracy: 0.8708 - val_loss: 0.8387 - val_categorical_crossentropy: 0.8387 - val_categorical_accuracy: 0.5957
# Epoch 100/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4434 - categorical_crossentropy: 0.4434 - categorical_accuracy: 0.8583 - val_loss: 0.8351 - val_categorical_crossentropy: 0.8351 - val_categorical_accuracy: 0.5957
# Epoch 101/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4712 - categorical_crossentropy: 0.4712 - categorical_accuracy: 0.8875 - val_loss: 0.8460 - val_categorical_crossentropy: 0.8460 - val_categorical_accuracy: 0.5957
# Epoch 102/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4732 - categorical_crossentropy: 0.4732 - categorical_accuracy: 0.8458 - val_loss: 0.8377 - val_categorical_crossentropy: 0.8377 - val_categorical_accuracy: 0.6170
# Epoch 103/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4478 - categorical_crossentropy: 0.4478 - categorical_accuracy: 0.8708 - val_loss: 0.8213 - val_categorical_crossentropy: 0.8213 - val_categorical_accuracy: 0.6383
# Epoch 104/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4435 - categorical_crossentropy: 0.4435 - categorical_accuracy: 0.8958 - val_loss: 0.8348 - val_categorical_crossentropy: 0.8348 - val_categorical_accuracy: 0.6170
# Epoch 105/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4599 - categorical_crossentropy: 0.4599 - categorical_accuracy: 0.8875 - val_loss: 0.8584 - val_categorical_crossentropy: 0.8584 - val_categorical_accuracy: 0.6383
# Epoch 106/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4414 - categorical_crossentropy: 0.4414 - categorical_accuracy: 0.9125 - val_loss: 0.8306 - val_categorical_crossentropy: 0.8306 - val_categorical_accuracy: 0.6383
# Epoch 107/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4368 - categorical_crossentropy: 0.4368 - categorical_accuracy: 0.8958 - val_loss: 0.8195 - val_categorical_crossentropy: 0.8195 - val_categorical_accuracy: 0.6170
# Epoch 108/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4658 - categorical_crossentropy: 0.4658 - categorical_accuracy: 0.8833 - val_loss: 0.8004 - val_categorical_crossentropy: 0.8004 - val_categorical_accuracy: 0.6383
# Epoch 109/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4533 - categorical_crossentropy: 0.4533 - categorical_accuracy: 0.8708 - val_loss: 0.8491 - val_categorical_crossentropy: 0.8491 - val_categorical_accuracy: 0.5957
# Epoch 110/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4349 - categorical_crossentropy: 0.4349 - categorical_accuracy: 0.8917 - val_loss: 0.8458 - val_categorical_crossentropy: 0.8458 - val_categorical_accuracy: 0.6170
# Epoch 111/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4418 - categorical_crossentropy: 0.4418 - categorical_accuracy: 0.8875 - val_loss: 0.8088 - val_categorical_crossentropy: 0.8088 - val_categorical_accuracy: 0.6809
# Epoch 112/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4392 - categorical_crossentropy: 0.4392 - categorical_accuracy: 0.8917 - val_loss: 0.8277 - val_categorical_crossentropy: 0.8277 - val_categorical_accuracy: 0.6383
# Epoch 113/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4370 - categorical_crossentropy: 0.4370 - categorical_accuracy: 0.8833 - val_loss: 0.8640 - val_categorical_crossentropy: 0.8640 - val_categorical_accuracy: 0.6170
# Epoch 114/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4435 - categorical_crossentropy: 0.4435 - categorical_accuracy: 0.8667 - val_loss: 0.8175 - val_categorical_crossentropy: 0.8175 - val_categorical_accuracy: 0.6596
# Epoch 115/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4340 - categorical_crossentropy: 0.4340 - categorical_accuracy: 0.8958 - val_loss: 0.8305 - val_categorical_crossentropy: 0.8305 - val_categorical_accuracy: 0.5957
# Epoch 116/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4303 - categorical_crossentropy: 0.4303 - categorical_accuracy: 0.8875 - val_loss: 0.8281 - val_categorical_crossentropy: 0.8281 - val_categorical_accuracy: 0.6170
# Epoch 117/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4573 - categorical_crossentropy: 0.4573 - categorical_accuracy: 0.8708 - val_loss: 0.8264 - val_categorical_crossentropy: 0.8264 - val_categorical_accuracy: 0.5957
# Epoch 118/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4238 - categorical_crossentropy: 0.4238 - categorical_accuracy: 0.9250 - val_loss: 0.8044 - val_categorical_crossentropy: 0.8044 - val_categorical_accuracy: 0.6596
# Epoch 119/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4551 - categorical_crossentropy: 0.4551 - categorical_accuracy: 0.8708 - val_loss: 0.8317 - val_categorical_crossentropy: 0.8317 - val_categorical_accuracy: 0.6383
# Epoch 120/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4107 - categorical_crossentropy: 0.4107 - categorical_accuracy: 0.9125 - val_loss: 0.8110 - val_categorical_crossentropy: 0.8110 - val_categorical_accuracy: 0.6596
# Epoch 121/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4347 - categorical_crossentropy: 0.4347 - categorical_accuracy: 0.8958 - val_loss: 0.8218 - val_categorical_crossentropy: 0.8218 - val_categorical_accuracy: 0.6596
# Epoch 122/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4129 - categorical_crossentropy: 0.4129 - categorical_accuracy: 0.9208 - val_loss: 0.8417 - val_categorical_crossentropy: 0.8417 - val_categorical_accuracy: 0.6170
# Epoch 123/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4111 - categorical_crossentropy: 0.4111 - categorical_accuracy: 0.8833 - val_loss: 0.8237 - val_categorical_crossentropy: 0.8237 - val_categorical_accuracy: 0.6383
# Epoch 124/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4306 - categorical_crossentropy: 0.4306 - categorical_accuracy: 0.8917 - val_loss: 0.8319 - val_categorical_crossentropy: 0.8319 - val_categorical_accuracy: 0.6383
# Epoch 125/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4132 - categorical_crossentropy: 0.4132 - categorical_accuracy: 0.9042 - val_loss: 0.8168 - val_categorical_crossentropy: 0.8168 - val_categorical_accuracy: 0.6170
# Epoch 126/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4102 - categorical_crossentropy: 0.4102 - categorical_accuracy: 0.9083 - val_loss: 0.7835 - val_categorical_crossentropy: 0.7835 - val_categorical_accuracy: 0.6809
# Epoch 127/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3856 - categorical_crossentropy: 0.3856 - categorical_accuracy: 0.9125 - val_loss: 0.8416 - val_categorical_crossentropy: 0.8416 - val_categorical_accuracy: 0.6383
# Epoch 128/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4113 - categorical_crossentropy: 0.4113 - categorical_accuracy: 0.9083 - val_loss: 0.8373 - val_categorical_crossentropy: 0.8373 - val_categorical_accuracy: 0.6596
# Epoch 129/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4090 - categorical_crossentropy: 0.4090 - categorical_accuracy: 0.8958 - val_loss: 0.9312 - val_categorical_crossentropy: 0.9312 - val_categorical_accuracy: 0.5745
# Epoch 130/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4034 - categorical_crossentropy: 0.4034 - categorical_accuracy: 0.9042 - val_loss: 0.8556 - val_categorical_crossentropy: 0.8556 - val_categorical_accuracy: 0.5532
# Epoch 131/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4094 - categorical_crossentropy: 0.4094 - categorical_accuracy: 0.8958 - val_loss: 0.9105 - val_categorical_crossentropy: 0.9105 - val_categorical_accuracy: 0.5532
# Epoch 132/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3830 - categorical_crossentropy: 0.3830 - categorical_accuracy: 0.9208 - val_loss: 0.8611 - val_categorical_crossentropy: 0.8611 - val_categorical_accuracy: 0.5957
# Epoch 133/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4294 - categorical_crossentropy: 0.4294 - categorical_accuracy: 0.8833 - val_loss: 0.8245 - val_categorical_crossentropy: 0.8245 - val_categorical_accuracy: 0.6170
# Epoch 134/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4130 - categorical_crossentropy: 0.4130 - categorical_accuracy: 0.8750 - val_loss: 0.8134 - val_categorical_crossentropy: 0.8134 - val_categorical_accuracy: 0.6596
# Epoch 135/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3885 - categorical_crossentropy: 0.3885 - categorical_accuracy: 0.9333 - val_loss: 0.8185 - val_categorical_crossentropy: 0.8185 - val_categorical_accuracy: 0.6383
# Epoch 136/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3930 - categorical_crossentropy: 0.3930 - categorical_accuracy: 0.9250 - val_loss: 0.8653 - val_categorical_crossentropy: 0.8653 - val_categorical_accuracy: 0.6383
# Epoch 137/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3829 - categorical_crossentropy: 0.3829 - categorical_accuracy: 0.9083 - val_loss: 0.8793 - val_categorical_crossentropy: 0.8793 - val_categorical_accuracy: 0.6170
# Epoch 138/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3842 - categorical_crossentropy: 0.3842 - categorical_accuracy: 0.8875 - val_loss: 0.8815 - val_categorical_crossentropy: 0.8815 - val_categorical_accuracy: 0.5532
# Epoch 139/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3823 - categorical_crossentropy: 0.3823 - categorical_accuracy: 0.9333 - val_loss: 0.8915 - val_categorical_crossentropy: 0.8915 - val_categorical_accuracy: 0.5319
# Epoch 140/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3699 - categorical_crossentropy: 0.3699 - categorical_accuracy: 0.9542 - val_loss: 0.8635 - val_categorical_crossentropy: 0.8635 - val_categorical_accuracy: 0.5745
# Epoch 141/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3855 - categorical_crossentropy: 0.3855 - categorical_accuracy: 0.9000 - val_loss: 0.8516 - val_categorical_crossentropy: 0.8516 - val_categorical_accuracy: 0.6170
# Epoch 142/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3693 - categorical_crossentropy: 0.3693 - categorical_accuracy: 0.9250 - val_loss: 0.8677 - val_categorical_crossentropy: 0.8677 - val_categorical_accuracy: 0.5957
# Epoch 143/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3748 - categorical_crossentropy: 0.3748 - categorical_accuracy: 0.9208 - val_loss: 0.8582 - val_categorical_crossentropy: 0.8582 - val_categorical_accuracy: 0.6170
# Epoch 144/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3761 - categorical_crossentropy: 0.3761 - categorical_accuracy: 0.9333 - val_loss: 0.8748 - val_categorical_crossentropy: 0.8748 - val_categorical_accuracy: 0.6596
# Epoch 145/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3735 - categorical_crossentropy: 0.3735 - categorical_accuracy: 0.9333 - val_loss: 0.8635 - val_categorical_crossentropy: 0.8635 - val_categorical_accuracy: 0.6383
# Epoch 146/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3732 - categorical_crossentropy: 0.3732 - categorical_accuracy: 0.9125 - val_loss: 0.7917 - val_categorical_crossentropy: 0.7917 - val_categorical_accuracy: 0.7447
# Epoch 147/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3828 - categorical_crossentropy: 0.3828 - categorical_accuracy: 0.9042 - val_loss: 0.8010 - val_categorical_crossentropy: 0.8010 - val_categorical_accuracy: 0.7021
# Epoch 148/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3727 - categorical_crossentropy: 0.3727 - categorical_accuracy: 0.9125 - val_loss: 0.8130 - val_categorical_crossentropy: 0.8130 - val_categorical_accuracy: 0.6596
# Epoch 149/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3867 - categorical_crossentropy: 0.3867 - categorical_accuracy: 0.9042 - val_loss: 0.8002 - val_categorical_crossentropy: 0.8002 - val_categorical_accuracy: 0.6383
# Epoch 150/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3711 - categorical_crossentropy: 0.3711 - categorical_accuracy: 0.9292 - val_loss: 0.8091 - val_categorical_crossentropy: 0.8091 - val_categorical_accuracy: 0.6170
# Epoch 151/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3917 - categorical_crossentropy: 0.3917 - categorical_accuracy: 0.8875 - val_loss: 0.7920 - val_categorical_crossentropy: 0.7920 - val_categorical_accuracy: 0.6809
# Epoch 152/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3632 - categorical_crossentropy: 0.3632 - categorical_accuracy: 0.9458 - val_loss: 0.7881 - val_categorical_crossentropy: 0.7881 - val_categorical_accuracy: 0.6596
# Epoch 153/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3904 - categorical_crossentropy: 0.3904 - categorical_accuracy: 0.9292 - val_loss: 0.8056 - val_categorical_crossentropy: 0.8056 - val_categorical_accuracy: 0.6383
# Epoch 154/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3751 - categorical_crossentropy: 0.3751 - categorical_accuracy: 0.9000 - val_loss: 0.8250 - val_categorical_crossentropy: 0.8250 - val_categorical_accuracy: 0.7234
# Epoch 155/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3658 - categorical_crossentropy: 0.3658 - categorical_accuracy: 0.9292 - val_loss: 0.8110 - val_categorical_crossentropy: 0.8110 - val_categorical_accuracy: 0.7660
# Epoch 156/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3646 - categorical_crossentropy: 0.3646 - categorical_accuracy: 0.9375 - val_loss: 0.8615 - val_categorical_crossentropy: 0.8615 - val_categorical_accuracy: 0.6596
# Epoch 157/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3638 - categorical_crossentropy: 0.3638 - categorical_accuracy: 0.9167 - val_loss: 0.8020 - val_categorical_crossentropy: 0.8020 - val_categorical_accuracy: 0.6809
# Epoch 158/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3766 - categorical_crossentropy: 0.3766 - categorical_accuracy: 0.9250 - val_loss: 0.7925 - val_categorical_crossentropy: 0.7925 - val_categorical_accuracy: 0.6809
# Epoch 159/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3608 - categorical_crossentropy: 0.3608 - categorical_accuracy: 0.9083 - val_loss: 0.8089 - val_categorical_crossentropy: 0.8089 - val_categorical_accuracy: 0.6809
# Epoch 160/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3529 - categorical_crossentropy: 0.3529 - categorical_accuracy: 0.9375 - val_loss: 0.8733 - val_categorical_crossentropy: 0.8733 - val_categorical_accuracy: 0.6596
# Epoch 161/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3538 - categorical_crossentropy: 0.3538 - categorical_accuracy: 0.9000 - val_loss: 0.7972 - val_categorical_crossentropy: 0.7972 - val_categorical_accuracy: 0.6596
# Epoch 162/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3512 - categorical_crossentropy: 0.3512 - categorical_accuracy: 0.9125 - val_loss: 0.8532 - val_categorical_crossentropy: 0.8532 - val_categorical_accuracy: 0.6383
# Epoch 163/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3781 - categorical_crossentropy: 0.3781 - categorical_accuracy: 0.8875 - val_loss: 0.7909 - val_categorical_crossentropy: 0.7909 - val_categorical_accuracy: 0.6809
# Epoch 164/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3575 - categorical_crossentropy: 0.3575 - categorical_accuracy: 0.9208 - val_loss: 0.8001 - val_categorical_crossentropy: 0.8001 - val_categorical_accuracy: 0.6809
# Epoch 165/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3609 - categorical_crossentropy: 0.3609 - categorical_accuracy: 0.9250 - val_loss: 0.8042 - val_categorical_crossentropy: 0.8042 - val_categorical_accuracy: 0.7021
# Epoch 166/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3681 - categorical_crossentropy: 0.3681 - categorical_accuracy: 0.9125 - val_loss: 0.7871 - val_categorical_crossentropy: 0.7871 - val_categorical_accuracy: 0.7234
# Epoch 167/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3402 - categorical_crossentropy: 0.3402 - categorical_accuracy: 0.9417 - val_loss: 0.8349 - val_categorical_crossentropy: 0.8349 - val_categorical_accuracy: 0.6596
# Epoch 168/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3450 - categorical_crossentropy: 0.3450 - categorical_accuracy: 0.9208 - val_loss: 0.7963 - val_categorical_crossentropy: 0.7963 - val_categorical_accuracy: 0.6170
# Epoch 169/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3288 - categorical_crossentropy: 0.3288 - categorical_accuracy: 0.9667 - val_loss: 0.8039 - val_categorical_crossentropy: 0.8039 - val_categorical_accuracy: 0.6383
# Epoch 170/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3546 - categorical_crossentropy: 0.3546 - categorical_accuracy: 0.9167 - val_loss: 0.8294 - val_categorical_crossentropy: 0.8294 - val_categorical_accuracy: 0.6383
# Epoch 171/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3418 - categorical_crossentropy: 0.3418 - categorical_accuracy: 0.9208 - val_loss: 0.8761 - val_categorical_crossentropy: 0.8761 - val_categorical_accuracy: 0.6596
# Epoch 172/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3355 - categorical_crossentropy: 0.3355 - categorical_accuracy: 0.9500 - val_loss: 0.8218 - val_categorical_crossentropy: 0.8218 - val_categorical_accuracy: 0.6383
# Epoch 173/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3277 - categorical_crossentropy: 0.3277 - categorical_accuracy: 0.9375 - val_loss: 0.8144 - val_categorical_crossentropy: 0.8144 - val_categorical_accuracy: 0.6809
# Epoch 174/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3362 - categorical_crossentropy: 0.3362 - categorical_accuracy: 0.9292 - val_loss: 0.8294 - val_categorical_crossentropy: 0.8294 - val_categorical_accuracy: 0.6596
# Epoch 175/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3248 - categorical_crossentropy: 0.3248 - categorical_accuracy: 0.9583 - val_loss: 0.7988 - val_categorical_crossentropy: 0.7988 - val_categorical_accuracy: 0.7021
# Epoch 176/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3491 - categorical_crossentropy: 0.3491 - categorical_accuracy: 0.9042 - val_loss: 0.8149 - val_categorical_crossentropy: 0.8149 - val_categorical_accuracy: 0.6809
# Epoch 177/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3235 - categorical_crossentropy: 0.3235 - categorical_accuracy: 0.9292 - val_loss: 0.8263 - val_categorical_crossentropy: 0.8263 - val_categorical_accuracy: 0.6596
# Epoch 178/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3410 - categorical_crossentropy: 0.3410 - categorical_accuracy: 0.9333 - val_loss: 0.8939 - val_categorical_crossentropy: 0.8939 - val_categorical_accuracy: 0.5745
# Epoch 179/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3517 - categorical_crossentropy: 0.3517 - categorical_accuracy: 0.9208 - val_loss: 0.8324 - val_categorical_crossentropy: 0.8324 - val_categorical_accuracy: 0.6596
# Epoch 180/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3275 - categorical_crossentropy: 0.3275 - categorical_accuracy: 0.9417 - val_loss: 0.8673 - val_categorical_crossentropy: 0.8673 - val_categorical_accuracy: 0.6809
# Epoch 181/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3419 - categorical_crossentropy: 0.3419 - categorical_accuracy: 0.9375 - val_loss: 0.8568 - val_categorical_crossentropy: 0.8568 - val_categorical_accuracy: 0.6809
# Epoch 182/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3128 - categorical_crossentropy: 0.3128 - categorical_accuracy: 0.9542 - val_loss: 0.8261 - val_categorical_crossentropy: 0.8261 - val_categorical_accuracy: 0.6809
# Epoch 183/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3325 - categorical_crossentropy: 0.3325 - categorical_accuracy: 0.9292 - val_loss: 0.8168 - val_categorical_crossentropy: 0.8168 - val_categorical_accuracy: 0.6383
# Epoch 184/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3426 - categorical_crossentropy: 0.3426 - categorical_accuracy: 0.9417 - val_loss: 0.8481 - val_categorical_crossentropy: 0.8481 - val_categorical_accuracy: 0.6170
# Epoch 185/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3429 - categorical_crossentropy: 0.3429 - categorical_accuracy: 0.9208 - val_loss: 0.8534 - val_categorical_crossentropy: 0.8534 - val_categorical_accuracy: 0.6170
# Epoch 186/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3443 - categorical_crossentropy: 0.3443 - categorical_accuracy: 0.9333 - val_loss: 0.7678 - val_categorical_crossentropy: 0.7678 - val_categorical_accuracy: 0.7021
# Epoch 187/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3257 - categorical_crossentropy: 0.3257 - categorical_accuracy: 0.9333 - val_loss: 0.7878 - val_categorical_crossentropy: 0.7878 - val_categorical_accuracy: 0.6596
# Epoch 188/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3127 - categorical_crossentropy: 0.3127 - categorical_accuracy: 0.9417 - val_loss: 0.7917 - val_categorical_crossentropy: 0.7917 - val_categorical_accuracy: 0.6596
# Epoch 189/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3453 - categorical_crossentropy: 0.3453 - categorical_accuracy: 0.9292 - val_loss: 0.8457 - val_categorical_crossentropy: 0.8457 - val_categorical_accuracy: 0.6383
# Epoch 190/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3233 - categorical_crossentropy: 0.3233 - categorical_accuracy: 0.9458 - val_loss: 0.7761 - val_categorical_crossentropy: 0.7761 - val_categorical_accuracy: 0.7447
# Epoch 191/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3229 - categorical_crossentropy: 0.3229 - categorical_accuracy: 0.9250 - val_loss: 0.7927 - val_categorical_crossentropy: 0.7927 - val_categorical_accuracy: 0.7021
# Epoch 192/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3200 - categorical_crossentropy: 0.3200 - categorical_accuracy: 0.9500 - val_loss: 0.8056 - val_categorical_crossentropy: 0.8056 - val_categorical_accuracy: 0.6809
# Epoch 193/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3075 - categorical_crossentropy: 0.3075 - categorical_accuracy: 0.9292 - val_loss: 0.8111 - val_categorical_crossentropy: 0.8111 - val_categorical_accuracy: 0.7021
# Epoch 194/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3128 - categorical_crossentropy: 0.3128 - categorical_accuracy: 0.9375 - val_loss: 0.8465 - val_categorical_crossentropy: 0.8465 - val_categorical_accuracy: 0.6809
# Epoch 195/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3123 - categorical_crossentropy: 0.3123 - categorical_accuracy: 0.9458 - val_loss: 0.7859 - val_categorical_crossentropy: 0.7859 - val_categorical_accuracy: 0.7234
# ...
# Epoch 196/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1887 - categorical_crossentropy: 0.1887 - categorical_accuracy: 0.9792 - val_loss: 0.6423 - val_categorical_crossentropy: 0.6423 - val_categorical_accuracy: 0.7234
# Epoch 197/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2091 - categorical_crossentropy: 0.2091 - categorical_accuracy: 0.9750 - val_loss: 0.6710 - val_categorical_crossentropy: 0.6710 - val_categorical_accuracy: 0.7021
# Epoch 198/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2128 - categorical_crossentropy: 0.2128 - categorical_accuracy: 0.9708 - val_loss: 0.6513 - val_categorical_crossentropy: 0.6513 - val_categorical_accuracy: 0.6809
# Epoch 199/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2066 - categorical_crossentropy: 0.2066 - categorical_accuracy: 0.9750 - val_loss: 0.6583 - val_categorical_crossentropy: 0.6583 - val_categorical_accuracy: 0.7021
# Epoch 200/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2105 - categorical_crossentropy: 0.2105 - categorical_accuracy: 0.9750 - val_loss: 0.6292 - val_categorical_crossentropy: 0.6292 - val_categorical_accuracy: 0.7021
# Epoch 201/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2199 - categorical_crossentropy: 0.2199 - categorical_accuracy: 0.9458 - val_loss: 0.6352 - val_categorical_crossentropy: 0.6352 - val_categorical_accuracy: 0.7021
# Epoch 202/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2098 - categorical_crossentropy: 0.2098 - categorical_accuracy: 0.9708 - val_loss: 0.7012 - val_categorical_crossentropy: 0.7012 - val_categorical_accuracy: 0.6809
# Epoch 203/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2210 - categorical_crossentropy: 0.2210 - categorical_accuracy: 0.9708 - val_loss: 0.6992 - val_categorical_crossentropy: 0.6992 - val_categorical_accuracy: 0.7021
# Epoch 204/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2206 - categorical_crossentropy: 0.2206 - categorical_accuracy: 0.9750 - val_loss: 0.6629 - val_categorical_crossentropy: 0.6629 - val_categorical_accuracy: 0.6383
# Epoch 205/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1927 - categorical_crossentropy: 0.1927 - categorical_accuracy: 0.9833 - val_loss: 0.7103 - val_categorical_crossentropy: 0.7103 - val_categorical_accuracy: 0.7021
# Epoch 206/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1914 - categorical_crossentropy: 0.1914 - categorical_accuracy: 0.9792 - val_loss: 0.6489 - val_categorical_crossentropy: 0.6489 - val_categorical_accuracy: 0.6809
# Epoch 207/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2187 - categorical_crossentropy: 0.2187 - categorical_accuracy: 0.9625 - val_loss: 0.6751 - val_categorical_crossentropy: 0.6751 - val_categorical_accuracy: 0.6809
# Epoch 208/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2015 - categorical_crossentropy: 0.2015 - categorical_accuracy: 0.9833 - val_loss: 0.6543 - val_categorical_crossentropy: 0.6543 - val_categorical_accuracy: 0.7021
# Epoch 209/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1812 - categorical_crossentropy: 0.1812 - categorical_accuracy: 0.9958 - val_loss: 0.6249 - val_categorical_crossentropy: 0.6249 - val_categorical_accuracy: 0.6809
# Epoch 210/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1975 - categorical_crossentropy: 0.1975 - categorical_accuracy: 0.9708 - val_loss: 0.6089 - val_categorical_crossentropy: 0.6089 - val_categorical_accuracy: 0.7021
# Epoch 211/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2074 - categorical_crossentropy: 0.2074 - categorical_accuracy: 0.9542 - val_loss: 0.6863 - val_categorical_crossentropy: 0.6863 - val_categorical_accuracy: 0.7021
# Epoch 212/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1886 - categorical_crossentropy: 0.1886 - categorical_accuracy: 0.9708 - val_loss: 0.6929 - val_categorical_crossentropy: 0.6929 - val_categorical_accuracy: 0.7021
# Epoch 213/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2266 - categorical_crossentropy: 0.2266 - categorical_accuracy: 0.9500 - val_loss: 0.6907 - val_categorical_crossentropy: 0.6907 - val_categorical_accuracy: 0.6809
# Epoch 214/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2039 - categorical_crossentropy: 0.2039 - categorical_accuracy: 0.9750 - val_loss: 0.6108 - val_categorical_crossentropy: 0.6108 - val_categorical_accuracy: 0.6809
# Epoch 215/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1851 - categorical_crossentropy: 0.1851 - categorical_accuracy: 0.9833 - val_loss: 0.6209 - val_categorical_crossentropy: 0.6209 - val_categorical_accuracy: 0.7234
# Epoch 216/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2000 - categorical_crossentropy: 0.2000 - categorical_accuracy: 0.9750 - val_loss: 0.6596 - val_categorical_crossentropy: 0.6596 - val_categorical_accuracy: 0.6809
# Epoch 217/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1979 - categorical_crossentropy: 0.1979 - categorical_accuracy: 0.9583 - val_loss: 0.6600 - val_categorical_crossentropy: 0.6600 - val_categorical_accuracy: 0.7234
# Epoch 218/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1866 - categorical_crossentropy: 0.1866 - categorical_accuracy: 0.9667 - val_loss: 0.6579 - val_categorical_crossentropy: 0.6579 - val_categorical_accuracy: 0.6809
# Epoch 219/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1748 - categorical_crossentropy: 0.1748 - categorical_accuracy: 0.9625 - val_loss: 0.6438 - val_categorical_crossentropy: 0.6438 - val_categorical_accuracy: 0.7021
# Epoch 220/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1981 - categorical_crossentropy: 0.1981 - categorical_accuracy: 0.9750 - val_loss: 0.6587 - val_categorical_crossentropy: 0.6587 - val_categorical_accuracy: 0.6596
# Epoch 221/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1893 - categorical_crossentropy: 0.1893 - categorical_accuracy: 0.9833 - val_loss: 0.6750 - val_categorical_crossentropy: 0.6750 - val_categorical_accuracy: 0.6596
# Epoch 222/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1901 - categorical_crossentropy: 0.1901 - categorical_accuracy: 0.9708 - val_loss: 0.6655 - val_categorical_crossentropy: 0.6655 - val_categorical_accuracy: 0.6809
# Epoch 223/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1880 - categorical_crossentropy: 0.1880 - categorical_accuracy: 0.9708 - val_loss: 0.6514 - val_categorical_crossentropy: 0.6514 - val_categorical_accuracy: 0.7021
# Epoch 224/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1859 - categorical_crossentropy: 0.1859 - categorical_accuracy: 0.9625 - val_loss: 0.6156 - val_categorical_crossentropy: 0.6156 - val_categorical_accuracy: 0.7021
# Epoch 225/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1835 - categorical_crossentropy: 0.1835 - categorical_accuracy: 0.9750 - val_loss: 0.6297 - val_categorical_crossentropy: 0.6297 - val_categorical_accuracy: 0.7021
# Epoch 226/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1834 - categorical_crossentropy: 0.1834 - categorical_accuracy: 0.9833 - val_loss: 0.6405 - val_categorical_crossentropy: 0.6405 - val_categorical_accuracy: 0.7234
# Epoch 227/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1917 - categorical_crossentropy: 0.1917 - categorical_accuracy: 0.9750 - val_loss: 0.6434 - val_categorical_crossentropy: 0.6434 - val_categorical_accuracy: 0.7234
# Epoch 228/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2016 - categorical_crossentropy: 0.2016 - categorical_accuracy: 0.9583 - val_loss: 0.5801 - val_categorical_crossentropy: 0.5801 - val_categorical_accuracy: 0.7447
# Epoch 229/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1724 - categorical_crossentropy: 0.1724 - categorical_accuracy: 0.9833 - val_loss: 0.6134 - val_categorical_crossentropy: 0.6134 - val_categorical_accuracy: 0.7660
# Epoch 230/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1639 - categorical_crossentropy: 0.1639 - categorical_accuracy: 0.9875 - val_loss: 0.6473 - val_categorical_crossentropy: 0.6473 - val_categorical_accuracy: 0.7447
# Epoch 231/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1876 - categorical_crossentropy: 0.1876 - categorical_accuracy: 0.9625 - val_loss: 0.6180 - val_categorical_crossentropy: 0.6180 - val_categorical_accuracy: 0.7234
# Epoch 232/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1793 - categorical_crossentropy: 0.1793 - categorical_accuracy: 0.9750 - val_loss: 0.6124 - val_categorical_crossentropy: 0.6124 - val_categorical_accuracy: 0.7234
# Epoch 233/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1955 - categorical_crossentropy: 0.1955 - categorical_accuracy: 0.9708 - val_loss: 0.6203 - val_categorical_crossentropy: 0.6203 - val_categorical_accuracy: 0.7021
# Epoch 234/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1869 - categorical_crossentropy: 0.1869 - categorical_accuracy: 0.9708 - val_loss: 0.6035 - val_categorical_crossentropy: 0.6035 - val_categorical_accuracy: 0.7021
# Epoch 235/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1817 - categorical_crossentropy: 0.1817 - categorical_accuracy: 0.9667 - val_loss: 0.5994 - val_categorical_crossentropy: 0.5994 - val_categorical_accuracy: 0.6809
# Epoch 236/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1678 - categorical_crossentropy: 0.1678 - categorical_accuracy: 0.9917 - val_loss: 0.6364 - val_categorical_crossentropy: 0.6364 - val_categorical_accuracy: 0.6596
# Epoch 237/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1882 - categorical_crossentropy: 0.1882 - categorical_accuracy: 0.9792 - val_loss: 0.6038 - val_categorical_crossentropy: 0.6038 - val_categorical_accuracy: 0.7234
# Epoch 238/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1769 - categorical_crossentropy: 0.1769 - categorical_accuracy: 0.9792 - val_loss: 0.6008 - val_categorical_crossentropy: 0.6008 - val_categorical_accuracy: 0.7234
# Epoch 239/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1735 - categorical_crossentropy: 0.1735 - categorical_accuracy: 0.9750 - val_loss: 0.6113 - val_categorical_crossentropy: 0.6113 - val_categorical_accuracy: 0.7021
# Epoch 240/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1526 - categorical_crossentropy: 0.1526 - categorical_accuracy: 0.9875 - val_loss: 0.6057 - val_categorical_crossentropy: 0.6057 - val_categorical_accuracy: 0.7021
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f5fd8903e847> in <module>()
#     123
#     124           history = adv_model.fit(train_data, validation_data=val_data,
# --> 125                                   validation_steps=None, epochs=500, verbose=1)
#     126
#     127           print('\n# Evaluate on test data')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     453     # Reinitialize dataset iterator for the next epoch.
#     454     if reset_dataset_after_each_epoch and epoch < epochs - 1:
# --> 455       _reinitialize_iterator(input_iterator, model._distribution_strategy)
#     456
#     457   callbacks._call_end_hook(mode)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in _reinitialize_iterator(iterator, distribution_strategy)
#     557         iterator, distribution_strategy)
#     558   else:
# --> 559     training_utils.initialize_iterator(iterator)
#     560
#     561
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_utils.py in initialize_iterator(iterator)
#    1565   if not context.executing_eagerly():
#    1566     init_op = iterator.initializer
# -> 1567     K.get_session((init_op,)).run(init_op)
#    1568
#    1569
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
