# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_2A/main_EEGNet_NSL_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 473 (delta 94), reused 3 (delta 1), pack-reused 313
# Receiving objects: 100% (473/473), 1.69 GiB | 41.63 MiB/s, done.
# Resolving deltas: 100% (222/222), done.
# Checking out files: 100% (92/92), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Requirement already satisfied: neural_structured_learning in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.5)
# Using TensorFlow backend.

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()

# Initialize parameter
h_cut = [40]
drop_out = [0.5]
k_len = [32, 64, 128]
n_epochs = 500

out_f_name = 'acc_NSL_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_accuracy = zeros([nsub, nfilt,ndrop,nkl])

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])

for sub_idx, x in enumerate(range(1,10)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
      y_tr = y_tr.flatten() 
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered 

      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, 
                                               highcut=40, fs=250, order=4)  
        
      # tril_filtered = tril_filtered.transpose()
      X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          print(id_kl, id_d)
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

          adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
          adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
          # compile the model and set the optimizers
          adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
          batch_size = 32

          X_train = tf.cast(X_train, tf.float32)
          X_test = tf.cast(X_test, tf.float32)
          X_val = tf.cast(X_val, tf.float32)


          train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
          val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
          test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)

          val_steps = X_val.shape[0] // batch_size

  
          # adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=500, verbose=1)

          history = adv_model.fit(train_data, validation_data=val_data, 
                                  validation_steps=None, epochs=n_epochs, verbose=1)
          
          print('\n# Evaluate on test data')
          results = adv_model.evaluate(test_data)
          print('test loss, test acc:', results)

          loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          categorical_accuracy[sub_idx,h_indx,id_d, id_kl] = results[2]

          del model

#           del train_data, val_data, test_data

          # from keras import backend as K 
          # K.clear_session()

np.save(out_f_name, categorical_accuracy)
# Out:
# acc_NSL_EEGNet_epochs_500_filter_[40]_drop_[0.5]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288,)
# (240, 22, 750)
# (240,)
# (47, 22, 750)
# (47,)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# 0 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/neural_structured_learning/keras/adversarial_regularization.py:167: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/500
# 8/8 [==============================] - 2s 243ms/step - loss: 1.4066 - categorical_crossentropy: 1.4066 - categorical_accuracy: 0.2458 - val_loss: 1.3852 - val_categorical_crossentropy: 1.3852 - val_categorical_accuracy: 0.3617
# Epoch 2/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3681 - categorical_crossentropy: 1.3681 - categorical_accuracy: 0.3167 - val_loss: 1.3853 - val_categorical_crossentropy: 1.3853 - val_categorical_accuracy: 0.3617
# Epoch 3/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3661 - categorical_crossentropy: 1.3661 - categorical_accuracy: 0.2958 - val_loss: 1.3852 - val_categorical_crossentropy: 1.3852 - val_categorical_accuracy: 0.3404
# Epoch 4/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3523 - categorical_crossentropy: 1.3523 - categorical_accuracy: 0.3458 - val_loss: 1.3847 - val_categorical_crossentropy: 1.3847 - val_categorical_accuracy: 0.3617
# Epoch 5/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3403 - categorical_crossentropy: 1.3403 - categorical_accuracy: 0.3417 - val_loss: 1.3835 - val_categorical_crossentropy: 1.3835 - val_categorical_accuracy: 0.3830
# Epoch 6/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3261 - categorical_crossentropy: 1.3261 - categorical_accuracy: 0.3750 - val_loss: 1.3800 - val_categorical_crossentropy: 1.3800 - val_categorical_accuracy: 0.3617
# Epoch 7/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3052 - categorical_crossentropy: 1.3052 - categorical_accuracy: 0.4625 - val_loss: 1.3743 - val_categorical_crossentropy: 1.3743 - val_categorical_accuracy: 0.3404
# Epoch 8/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.2713 - categorical_crossentropy: 1.2713 - categorical_accuracy: 0.5042 - val_loss: 1.3647 - val_categorical_crossentropy: 1.3647 - val_categorical_accuracy: 0.4468
# Epoch 9/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.2249 - categorical_crossentropy: 1.2249 - categorical_accuracy: 0.5375 - val_loss: 1.3494 - val_categorical_crossentropy: 1.3494 - val_categorical_accuracy: 0.4681
# Epoch 10/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1907 - categorical_crossentropy: 1.1907 - categorical_accuracy: 0.5958 - val_loss: 1.3263 - val_categorical_crossentropy: 1.3263 - val_categorical_accuracy: 0.4894
# Epoch 11/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1241 - categorical_crossentropy: 1.1241 - categorical_accuracy: 0.5875 - val_loss: 1.3016 - val_categorical_crossentropy: 1.3016 - val_categorical_accuracy: 0.4468
# Epoch 12/500
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0869 - categorical_crossentropy: 1.0869 - categorical_accuracy: 0.6125 - val_loss: 1.2762 - val_categorical_crossentropy: 1.2762 - val_categorical_accuracy: 0.3830
# Epoch 13/500
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0335 - categorical_crossentropy: 1.0335 - categorical_accuracy: 0.5958 - val_loss: 1.2387 - val_categorical_crossentropy: 1.2387 - val_categorical_accuracy: 0.4043
# Epoch 14/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9931 - categorical_crossentropy: 0.9931 - categorical_accuracy: 0.6458 - val_loss: 1.2185 - val_categorical_crossentropy: 1.2185 - val_categorical_accuracy: 0.3830
# Epoch 15/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9583 - categorical_crossentropy: 0.9583 - categorical_accuracy: 0.6083 - val_loss: 1.2163 - val_categorical_crossentropy: 1.2163 - val_categorical_accuracy: 0.4043
# Epoch 16/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9294 - categorical_crossentropy: 0.9294 - categorical_accuracy: 0.6042 - val_loss: 1.2217 - val_categorical_crossentropy: 1.2217 - val_categorical_accuracy: 0.3830
# Epoch 17/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8657 - categorical_crossentropy: 0.8657 - categorical_accuracy: 0.6833 - val_loss: 1.2155 - val_categorical_crossentropy: 1.2155 - val_categorical_accuracy: 0.3404
# Epoch 18/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8688 - categorical_crossentropy: 0.8688 - categorical_accuracy: 0.6667 - val_loss: 1.2206 - val_categorical_crossentropy: 1.2206 - val_categorical_accuracy: 0.3404
# Epoch 19/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8733 - categorical_crossentropy: 0.8733 - categorical_accuracy: 0.6375 - val_loss: 1.2381 - val_categorical_crossentropy: 1.2381 - val_categorical_accuracy: 0.2979
# Epoch 20/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8671 - categorical_crossentropy: 0.8671 - categorical_accuracy: 0.6375 - val_loss: 1.2281 - val_categorical_crossentropy: 1.2281 - val_categorical_accuracy: 0.2979
# Epoch 21/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8253 - categorical_crossentropy: 0.8253 - categorical_accuracy: 0.7000 - val_loss: 1.2083 - val_categorical_crossentropy: 1.2083 - val_categorical_accuracy: 0.3191
# Epoch 22/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8406 - categorical_crossentropy: 0.8406 - categorical_accuracy: 0.6250 - val_loss: 1.2251 - val_categorical_crossentropy: 1.2251 - val_categorical_accuracy: 0.2979
# Epoch 23/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8111 - categorical_crossentropy: 0.8111 - categorical_accuracy: 0.6750 - val_loss: 1.2437 - val_categorical_crossentropy: 1.2437 - val_categorical_accuracy: 0.2979
# Epoch 24/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8182 - categorical_crossentropy: 0.8182 - categorical_accuracy: 0.6583 - val_loss: 1.2397 - val_categorical_crossentropy: 1.2397 - val_categorical_accuracy: 0.2979
# Epoch 25/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8003 - categorical_crossentropy: 0.8003 - categorical_accuracy: 0.6917 - val_loss: 1.2275 - val_categorical_crossentropy: 1.2275 - val_categorical_accuracy: 0.3191
# Epoch 26/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7893 - categorical_crossentropy: 0.7893 - categorical_accuracy: 0.7042 - val_loss: 1.2227 - val_categorical_crossentropy: 1.2227 - val_categorical_accuracy: 0.3191
# Epoch 27/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7754 - categorical_crossentropy: 0.7754 - categorical_accuracy: 0.6917 - val_loss: 1.2227 - val_categorical_crossentropy: 1.2227 - val_categorical_accuracy: 0.3191
# Epoch 28/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8176 - categorical_crossentropy: 0.8176 - categorical_accuracy: 0.6625 - val_loss: 1.2120 - val_categorical_crossentropy: 1.2120 - val_categorical_accuracy: 0.3191
# Epoch 29/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7755 - categorical_crossentropy: 0.7755 - categorical_accuracy: 0.7083 - val_loss: 1.2131 - val_categorical_crossentropy: 1.2131 - val_categorical_accuracy: 0.3191
# Epoch 30/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7557 - categorical_crossentropy: 0.7557 - categorical_accuracy: 0.7083 - val_loss: 1.1992 - val_categorical_crossentropy: 1.1992 - val_categorical_accuracy: 0.3191
# Epoch 31/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7579 - categorical_crossentropy: 0.7579 - categorical_accuracy: 0.7167 - val_loss: 1.1863 - val_categorical_crossentropy: 1.1863 - val_categorical_accuracy: 0.3404
# Epoch 32/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7558 - categorical_crossentropy: 0.7558 - categorical_accuracy: 0.7375 - val_loss: 1.1451 - val_categorical_crossentropy: 1.1451 - val_categorical_accuracy: 0.4043
# Epoch 33/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7736 - categorical_crossentropy: 0.7736 - categorical_accuracy: 0.6750 - val_loss: 1.1093 - val_categorical_crossentropy: 1.1093 - val_categorical_accuracy: 0.4255
# Epoch 34/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7470 - categorical_crossentropy: 0.7470 - categorical_accuracy: 0.7083 - val_loss: 1.0822 - val_categorical_crossentropy: 1.0822 - val_categorical_accuracy: 0.4468
# Epoch 35/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7648 - categorical_crossentropy: 0.7648 - categorical_accuracy: 0.7250 - val_loss: 1.0760 - val_categorical_crossentropy: 1.0760 - val_categorical_accuracy: 0.4043
# Epoch 36/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7543 - categorical_crossentropy: 0.7543 - categorical_accuracy: 0.7167 - val_loss: 1.0547 - val_categorical_crossentropy: 1.0547 - val_categorical_accuracy: 0.4681
# Epoch 37/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7291 - categorical_crossentropy: 0.7291 - categorical_accuracy: 0.7542 - val_loss: 1.0341 - val_categorical_crossentropy: 1.0341 - val_categorical_accuracy: 0.4681
# Epoch 38/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7170 - categorical_crossentropy: 0.7170 - categorical_accuracy: 0.7375 - val_loss: 1.0239 - val_categorical_crossentropy: 1.0239 - val_categorical_accuracy: 0.5319
# Epoch 39/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7113 - categorical_crossentropy: 0.7113 - categorical_accuracy: 0.7292 - val_loss: 1.0238 - val_categorical_crossentropy: 1.0238 - val_categorical_accuracy: 0.4468
# Epoch 40/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7067 - categorical_crossentropy: 0.7067 - categorical_accuracy: 0.7542 - val_loss: 1.0213 - val_categorical_crossentropy: 1.0213 - val_categorical_accuracy: 0.4681
# Epoch 41/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7221 - categorical_crossentropy: 0.7221 - categorical_accuracy: 0.7375 - val_loss: 1.0042 - val_categorical_crossentropy: 1.0042 - val_categorical_accuracy: 0.5106
# Epoch 42/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6877 - categorical_crossentropy: 0.6877 - categorical_accuracy: 0.7542 - val_loss: 0.9988 - val_categorical_crossentropy: 0.9988 - val_categorical_accuracy: 0.5319
# Epoch 43/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6883 - categorical_crossentropy: 0.6883 - categorical_accuracy: 0.7583 - val_loss: 0.9853 - val_categorical_crossentropy: 0.9853 - val_categorical_accuracy: 0.4894
# Epoch 44/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7060 - categorical_crossentropy: 0.7060 - categorical_accuracy: 0.7625 - val_loss: 0.9582 - val_categorical_crossentropy: 0.9582 - val_categorical_accuracy: 0.5106
# Epoch 45/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7271 - categorical_crossentropy: 0.7271 - categorical_accuracy: 0.7125 - val_loss: 0.9411 - val_categorical_crossentropy: 0.9411 - val_categorical_accuracy: 0.5745
# Epoch 46/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6817 - categorical_crossentropy: 0.6817 - categorical_accuracy: 0.7625 - val_loss: 0.9291 - val_categorical_crossentropy: 0.9291 - val_categorical_accuracy: 0.6170
# Epoch 47/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6870 - categorical_crossentropy: 0.6870 - categorical_accuracy: 0.7875 - val_loss: 0.9133 - val_categorical_crossentropy: 0.9133 - val_categorical_accuracy: 0.6383
# Epoch 48/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6752 - categorical_crossentropy: 0.6752 - categorical_accuracy: 0.7792 - val_loss: 0.9021 - val_categorical_crossentropy: 0.9021 - val_categorical_accuracy: 0.5957
# Epoch 49/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7061 - categorical_crossentropy: 0.7061 - categorical_accuracy: 0.7542 - val_loss: 0.8936 - val_categorical_crossentropy: 0.8936 - val_categorical_accuracy: 0.6383
# Epoch 50/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6565 - categorical_crossentropy: 0.6565 - categorical_accuracy: 0.7667 - val_loss: 0.8867 - val_categorical_crossentropy: 0.8867 - val_categorical_accuracy: 0.6170
# Epoch 51/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6827 - categorical_crossentropy: 0.6827 - categorical_accuracy: 0.7625 - val_loss: 0.8779 - val_categorical_crossentropy: 0.8779 - val_categorical_accuracy: 0.6383
# Epoch 52/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6529 - categorical_crossentropy: 0.6529 - categorical_accuracy: 0.7792 - val_loss: 0.8750 - val_categorical_crossentropy: 0.8750 - val_categorical_accuracy: 0.6170
# Epoch 53/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6802 - categorical_crossentropy: 0.6802 - categorical_accuracy: 0.7458 - val_loss: 0.8727 - val_categorical_crossentropy: 0.8727 - val_categorical_accuracy: 0.6170
# Epoch 54/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6385 - categorical_crossentropy: 0.6385 - categorical_accuracy: 0.7542 - val_loss: 0.8746 - val_categorical_crossentropy: 0.8746 - val_categorical_accuracy: 0.6596
# Epoch 55/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6439 - categorical_crossentropy: 0.6439 - categorical_accuracy: 0.7917 - val_loss: 0.8873 - val_categorical_crossentropy: 0.8873 - val_categorical_accuracy: 0.6383
# Epoch 56/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6297 - categorical_crossentropy: 0.6297 - categorical_accuracy: 0.7917 - val_loss: 0.8805 - val_categorical_crossentropy: 0.8805 - val_categorical_accuracy: 0.6596
# Epoch 57/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6807 - categorical_crossentropy: 0.6807 - categorical_accuracy: 0.7750 - val_loss: 0.8750 - val_categorical_crossentropy: 0.8750 - val_categorical_accuracy: 0.6383
# Epoch 58/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6735 - categorical_crossentropy: 0.6735 - categorical_accuracy: 0.7667 - val_loss: 0.8617 - val_categorical_crossentropy: 0.8617 - val_categorical_accuracy: 0.6383
# Epoch 59/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6591 - categorical_crossentropy: 0.6591 - categorical_accuracy: 0.7667 - val_loss: 0.8464 - val_categorical_crossentropy: 0.8464 - val_categorical_accuracy: 0.6383
# Epoch 60/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6549 - categorical_crossentropy: 0.6549 - categorical_accuracy: 0.7750 - val_loss: 0.8422 - val_categorical_crossentropy: 0.8422 - val_categorical_accuracy: 0.6383
# Epoch 61/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6381 - categorical_crossentropy: 0.6381 - categorical_accuracy: 0.7750 - val_loss: 0.8316 - val_categorical_crossentropy: 0.8316 - val_categorical_accuracy: 0.6596
# Epoch 62/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6551 - categorical_crossentropy: 0.6551 - categorical_accuracy: 0.7500 - val_loss: 0.8246 - val_categorical_crossentropy: 0.8246 - val_categorical_accuracy: 0.6596
# Epoch 63/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6514 - categorical_crossentropy: 0.6514 - categorical_accuracy: 0.7875 - val_loss: 0.8300 - val_categorical_crossentropy: 0.8300 - val_categorical_accuracy: 0.6383
# Epoch 64/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6485 - categorical_crossentropy: 0.6485 - categorical_accuracy: 0.7750 - val_loss: 0.8366 - val_categorical_crossentropy: 0.8366 - val_categorical_accuracy: 0.6596
# Epoch 65/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6273 - categorical_crossentropy: 0.6273 - categorical_accuracy: 0.8208 - val_loss: 0.8305 - val_categorical_crossentropy: 0.8305 - val_categorical_accuracy: 0.6383
# Epoch 66/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6160 - categorical_crossentropy: 0.6160 - categorical_accuracy: 0.8083 - val_loss: 0.8327 - val_categorical_crossentropy: 0.8327 - val_categorical_accuracy: 0.6596
# Epoch 67/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6299 - categorical_crossentropy: 0.6299 - categorical_accuracy: 0.7792 - val_loss: 0.8302 - val_categorical_crossentropy: 0.8302 - val_categorical_accuracy: 0.6596
# Epoch 68/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6215 - categorical_crossentropy: 0.6215 - categorical_accuracy: 0.7458 - val_loss: 0.8258 - val_categorical_crossentropy: 0.8258 - val_categorical_accuracy: 0.6596
# Epoch 69/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6507 - categorical_crossentropy: 0.6507 - categorical_accuracy: 0.8000 - val_loss: 0.8059 - val_categorical_crossentropy: 0.8059 - val_categorical_accuracy: 0.6596
# Epoch 70/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5928 - categorical_crossentropy: 0.5928 - categorical_accuracy: 0.8000 - val_loss: 0.7910 - val_categorical_crossentropy: 0.7910 - val_categorical_accuracy: 0.6596
# Epoch 71/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5907 - categorical_crossentropy: 0.5907 - categorical_accuracy: 0.8083 - val_loss: 0.7929 - val_categorical_crossentropy: 0.7929 - val_categorical_accuracy: 0.7021
# Epoch 72/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5751 - categorical_crossentropy: 0.5751 - categorical_accuracy: 0.8083 - val_loss: 0.7874 - val_categorical_crossentropy: 0.7874 - val_categorical_accuracy: 0.6596
# Epoch 73/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5930 - categorical_crossentropy: 0.5930 - categorical_accuracy: 0.8083 - val_loss: 0.7814 - val_categorical_crossentropy: 0.7814 - val_categorical_accuracy: 0.7021
# Epoch 74/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6051 - categorical_crossentropy: 0.6051 - categorical_accuracy: 0.7708 - val_loss: 0.7862 - val_categorical_crossentropy: 0.7862 - val_categorical_accuracy: 0.7021
# Epoch 75/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5957 - categorical_crossentropy: 0.5957 - categorical_accuracy: 0.7875 - val_loss: 0.7801 - val_categorical_crossentropy: 0.7801 - val_categorical_accuracy: 0.7234
# Epoch 76/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6061 - categorical_crossentropy: 0.6061 - categorical_accuracy: 0.8042 - val_loss: 0.7892 - val_categorical_crossentropy: 0.7892 - val_categorical_accuracy: 0.6809
# Epoch 77/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6079 - categorical_crossentropy: 0.6079 - categorical_accuracy: 0.7833 - val_loss: 0.7790 - val_categorical_crossentropy: 0.7790 - val_categorical_accuracy: 0.6596
# Epoch 78/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5663 - categorical_crossentropy: 0.5663 - categorical_accuracy: 0.8250 - val_loss: 0.7780 - val_categorical_crossentropy: 0.7780 - val_categorical_accuracy: 0.7234
# Epoch 79/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5587 - categorical_crossentropy: 0.5587 - categorical_accuracy: 0.8208 - val_loss: 0.7928 - val_categorical_crossentropy: 0.7928 - val_categorical_accuracy: 0.7021
# Epoch 80/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6035 - categorical_crossentropy: 0.6035 - categorical_accuracy: 0.7667 - val_loss: 0.7938 - val_categorical_crossentropy: 0.7938 - val_categorical_accuracy: 0.6596
# Epoch 81/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5701 - categorical_crossentropy: 0.5701 - categorical_accuracy: 0.8292 - val_loss: 0.7970 - val_categorical_crossentropy: 0.7970 - val_categorical_accuracy: 0.7021
# Epoch 82/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5801 - categorical_crossentropy: 0.5801 - categorical_accuracy: 0.8458 - val_loss: 0.7678 - val_categorical_crossentropy: 0.7678 - val_categorical_accuracy: 0.7234
# Epoch 83/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5784 - categorical_crossentropy: 0.5784 - categorical_accuracy: 0.8125 - val_loss: 0.7712 - val_categorical_crossentropy: 0.7712 - val_categorical_accuracy: 0.7021
# Epoch 84/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5751 - categorical_crossentropy: 0.5751 - categorical_accuracy: 0.8625 - val_loss: 0.7708 - val_categorical_crossentropy: 0.7708 - val_categorical_accuracy: 0.7021
# Epoch 85/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5451 - categorical_crossentropy: 0.5451 - categorical_accuracy: 0.8417 - val_loss: 0.7779 - val_categorical_crossentropy: 0.7779 - val_categorical_accuracy: 0.7234
# Epoch 86/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5796 - categorical_crossentropy: 0.5796 - categorical_accuracy: 0.8000 - val_loss: 0.7779 - val_categorical_crossentropy: 0.7779 - val_categorical_accuracy: 0.7021
# Epoch 87/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5583 - categorical_crossentropy: 0.5583 - categorical_accuracy: 0.8417 - val_loss: 0.7872 - val_categorical_crossentropy: 0.7872 - val_categorical_accuracy: 0.7234
# Epoch 88/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6076 - categorical_crossentropy: 0.6076 - categorical_accuracy: 0.8083 - val_loss: 0.7778 - val_categorical_crossentropy: 0.7778 - val_categorical_accuracy: 0.7234
# Epoch 89/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5655 - categorical_crossentropy: 0.5655 - categorical_accuracy: 0.7958 - val_loss: 0.7734 - val_categorical_crossentropy: 0.7734 - val_categorical_accuracy: 0.7234
# Epoch 90/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5556 - categorical_crossentropy: 0.5556 - categorical_accuracy: 0.8125 - val_loss: 0.7804 - val_categorical_crossentropy: 0.7804 - val_categorical_accuracy: 0.7021
# Epoch 91/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5437 - categorical_crossentropy: 0.5437 - categorical_accuracy: 0.8583 - val_loss: 0.7848 - val_categorical_crossentropy: 0.7848 - val_categorical_accuracy: 0.6809
# Epoch 92/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5501 - categorical_crossentropy: 0.5501 - categorical_accuracy: 0.8292 - val_loss: 0.7959 - val_categorical_crossentropy: 0.7959 - val_categorical_accuracy: 0.7234
# Epoch 93/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5549 - categorical_crossentropy: 0.5549 - categorical_accuracy: 0.8167 - val_loss: 0.7944 - val_categorical_crossentropy: 0.7944 - val_categorical_accuracy: 0.7021
# Epoch 94/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5527 - categorical_crossentropy: 0.5527 - categorical_accuracy: 0.8417 - val_loss: 0.7772 - val_categorical_crossentropy: 0.7772 - val_categorical_accuracy: 0.7234
# Epoch 95/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5395 - categorical_crossentropy: 0.5395 - categorical_accuracy: 0.8417 - val_loss: 0.7684 - val_categorical_crossentropy: 0.7684 - val_categorical_accuracy: 0.7021
# Epoch 96/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5666 - categorical_crossentropy: 0.5666 - categorical_accuracy: 0.8167 - val_loss: 0.7759 - val_categorical_crossentropy: 0.7759 - val_categorical_accuracy: 0.7021
# Epoch 97/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5831 - categorical_crossentropy: 0.5831 - categorical_accuracy: 0.8125 - val_loss: 0.7807 - val_categorical_crossentropy: 0.7807 - val_categorical_accuracy: 0.6809
# Epoch 98/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5411 - categorical_crossentropy: 0.5411 - categorical_accuracy: 0.8458 - val_loss: 0.7719 - val_categorical_crossentropy: 0.7719 - val_categorical_accuracy: 0.7021
# Epoch 99/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5357 - categorical_crossentropy: 0.5357 - categorical_accuracy: 0.8500 - val_loss: 0.7843 - val_categorical_crossentropy: 0.7843 - val_categorical_accuracy: 0.6809
# Epoch 100/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5668 - categorical_crossentropy: 0.5668 - categorical_accuracy: 0.8167 - val_loss: 0.7805 - val_categorical_crossentropy: 0.7805 - val_categorical_accuracy: 0.7234
# Epoch 101/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5165 - categorical_crossentropy: 0.5165 - categorical_accuracy: 0.8625 - val_loss: 0.7567 - val_categorical_crossentropy: 0.7567 - val_categorical_accuracy: 0.7234
# Epoch 102/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5313 - categorical_crossentropy: 0.5313 - categorical_accuracy: 0.8375 - val_loss: 0.7625 - val_categorical_crossentropy: 0.7625 - val_categorical_accuracy: 0.7234
# Epoch 103/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5781 - categorical_crossentropy: 0.5781 - categorical_accuracy: 0.8083 - val_loss: 0.7775 - val_categorical_crossentropy: 0.7775 - val_categorical_accuracy: 0.7021
# Epoch 104/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5600 - categorical_crossentropy: 0.5600 - categorical_accuracy: 0.8458 - val_loss: 0.7654 - val_categorical_crossentropy: 0.7654 - val_categorical_accuracy: 0.6809
# Epoch 105/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5507 - categorical_crossentropy: 0.5507 - categorical_accuracy: 0.8167 - val_loss: 0.7742 - val_categorical_crossentropy: 0.7742 - val_categorical_accuracy: 0.7234
# Epoch 106/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5298 - categorical_crossentropy: 0.5298 - categorical_accuracy: 0.8250 - val_loss: 0.7685 - val_categorical_crossentropy: 0.7685 - val_categorical_accuracy: 0.7021
# Epoch 107/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5419 - categorical_crossentropy: 0.5419 - categorical_accuracy: 0.8333 - val_loss: 0.7367 - val_categorical_crossentropy: 0.7367 - val_categorical_accuracy: 0.7234
# Epoch 108/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5234 - categorical_crossentropy: 0.5234 - categorical_accuracy: 0.8458 - val_loss: 0.7336 - val_categorical_crossentropy: 0.7336 - val_categorical_accuracy: 0.7234
# Epoch 109/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5427 - categorical_crossentropy: 0.5427 - categorical_accuracy: 0.8208 - val_loss: 0.7222 - val_categorical_crossentropy: 0.7222 - val_categorical_accuracy: 0.7234
# Epoch 110/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5466 - categorical_crossentropy: 0.5466 - categorical_accuracy: 0.8167 - val_loss: 0.7197 - val_categorical_crossentropy: 0.7197 - val_categorical_accuracy: 0.7021
# Epoch 111/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5124 - categorical_crossentropy: 0.5124 - categorical_accuracy: 0.8333 - val_loss: 0.7287 - val_categorical_crossentropy: 0.7287 - val_categorical_accuracy: 0.7234
# Epoch 112/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5391 - categorical_crossentropy: 0.5391 - categorical_accuracy: 0.8125 - val_loss: 0.7451 - val_categorical_crossentropy: 0.7451 - val_categorical_accuracy: 0.7234
# Epoch 113/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5459 - categorical_crossentropy: 0.5459 - categorical_accuracy: 0.8042 - val_loss: 0.7482 - val_categorical_crossentropy: 0.7482 - val_categorical_accuracy: 0.7234
# Epoch 114/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5161 - categorical_crossentropy: 0.5161 - categorical_accuracy: 0.8542 - val_loss: 0.7440 - val_categorical_crossentropy: 0.7440 - val_categorical_accuracy: 0.6809
# Epoch 115/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4888 - categorical_crossentropy: 0.4888 - categorical_accuracy: 0.8750 - val_loss: 0.7292 - val_categorical_crossentropy: 0.7292 - val_categorical_accuracy: 0.7021
# Epoch 116/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5236 - categorical_crossentropy: 0.5236 - categorical_accuracy: 0.8708 - val_loss: 0.7374 - val_categorical_crossentropy: 0.7374 - val_categorical_accuracy: 0.7234
# Epoch 117/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5217 - categorical_crossentropy: 0.5217 - categorical_accuracy: 0.8292 - val_loss: 0.7268 - val_categorical_crossentropy: 0.7268 - val_categorical_accuracy: 0.7447
# Epoch 118/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5149 - categorical_crossentropy: 0.5149 - categorical_accuracy: 0.8208 - val_loss: 0.7185 - val_categorical_crossentropy: 0.7185 - val_categorical_accuracy: 0.7660
# Epoch 119/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5116 - categorical_crossentropy: 0.5116 - categorical_accuracy: 0.8333 - val_loss: 0.7339 - val_categorical_crossentropy: 0.7339 - val_categorical_accuracy: 0.7021
# Epoch 120/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5120 - categorical_crossentropy: 0.5120 - categorical_accuracy: 0.8500 - val_loss: 0.7445 - val_categorical_crossentropy: 0.7445 - val_categorical_accuracy: 0.6596
# Epoch 121/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5103 - categorical_crossentropy: 0.5103 - categorical_accuracy: 0.8417 - val_loss: 0.7418 - val_categorical_crossentropy: 0.7418 - val_categorical_accuracy: 0.7447
# Epoch 122/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4740 - categorical_crossentropy: 0.4740 - categorical_accuracy: 0.8667 - val_loss: 0.7387 - val_categorical_crossentropy: 0.7387 - val_categorical_accuracy: 0.7447
# Epoch 123/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5000 - categorical_crossentropy: 0.5000 - categorical_accuracy: 0.8542 - val_loss: 0.7263 - val_categorical_crossentropy: 0.7263 - val_categorical_accuracy: 0.7660
# Epoch 124/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4810 - categorical_crossentropy: 0.4810 - categorical_accuracy: 0.8625 - val_loss: 0.7210 - val_categorical_crossentropy: 0.7210 - val_categorical_accuracy: 0.6809
# Epoch 125/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5271 - categorical_crossentropy: 0.5271 - categorical_accuracy: 0.8250 - val_loss: 0.7147 - val_categorical_crossentropy: 0.7147 - val_categorical_accuracy: 0.7660
# Epoch 126/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5044 - categorical_crossentropy: 0.5044 - categorical_accuracy: 0.8583 - val_loss: 0.7150 - val_categorical_crossentropy: 0.7150 - val_categorical_accuracy: 0.7660
# Epoch 127/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5093 - categorical_crossentropy: 0.5093 - categorical_accuracy: 0.8167 - val_loss: 0.7113 - val_categorical_crossentropy: 0.7113 - val_categorical_accuracy: 0.7447
# Epoch 128/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4999 - categorical_crossentropy: 0.4999 - categorical_accuracy: 0.8417 - val_loss: 0.7139 - val_categorical_crossentropy: 0.7139 - val_categorical_accuracy: 0.7660
# Epoch 129/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4964 - categorical_crossentropy: 0.4964 - categorical_accuracy: 0.8542 - val_loss: 0.7087 - val_categorical_crossentropy: 0.7087 - val_categorical_accuracy: 0.7872
# Epoch 130/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4980 - categorical_crossentropy: 0.4980 - categorical_accuracy: 0.8250 - val_loss: 0.7220 - val_categorical_crossentropy: 0.7220 - val_categorical_accuracy: 0.7447
# Epoch 131/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4791 - categorical_crossentropy: 0.4791 - categorical_accuracy: 0.8625 - val_loss: 0.7375 - val_categorical_crossentropy: 0.7375 - val_categorical_accuracy: 0.7447
# Epoch 132/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4998 - categorical_crossentropy: 0.4998 - categorical_accuracy: 0.8417 - val_loss: 0.7154 - val_categorical_crossentropy: 0.7154 - val_categorical_accuracy: 0.7234
# Epoch 133/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4902 - categorical_crossentropy: 0.4902 - categorical_accuracy: 0.8583 - val_loss: 0.7071 - val_categorical_crossentropy: 0.7071 - val_categorical_accuracy: 0.7021
# Epoch 134/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4896 - categorical_crossentropy: 0.4896 - categorical_accuracy: 0.8458 - val_loss: 0.7199 - val_categorical_crossentropy: 0.7199 - val_categorical_accuracy: 0.7234
# Epoch 135/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4791 - categorical_crossentropy: 0.4791 - categorical_accuracy: 0.8583 - val_loss: 0.7301 - val_categorical_crossentropy: 0.7301 - val_categorical_accuracy: 0.7234
# Epoch 136/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4747 - categorical_crossentropy: 0.4747 - categorical_accuracy: 0.8667 - val_loss: 0.7207 - val_categorical_crossentropy: 0.7207 - val_categorical_accuracy: 0.7234
# Epoch 137/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5078 - categorical_crossentropy: 0.5078 - categorical_accuracy: 0.8250 - val_loss: 0.7111 - val_categorical_crossentropy: 0.7111 - val_categorical_accuracy: 0.7021
# Epoch 138/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4832 - categorical_crossentropy: 0.4832 - categorical_accuracy: 0.8458 - val_loss: 0.7076 - val_categorical_crossentropy: 0.7076 - val_categorical_accuracy: 0.7234
# Epoch 139/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5109 - categorical_crossentropy: 0.5109 - categorical_accuracy: 0.8333 - val_loss: 0.6992 - val_categorical_crossentropy: 0.6992 - val_categorical_accuracy: 0.7234
# Epoch 140/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4803 - categorical_crossentropy: 0.4803 - categorical_accuracy: 0.8250 - val_loss: 0.7178 - val_categorical_crossentropy: 0.7178 - val_categorical_accuracy: 0.6809
# Epoch 141/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4920 - categorical_crossentropy: 0.4920 - categorical_accuracy: 0.8417 - val_loss: 0.7340 - val_categorical_crossentropy: 0.7340 - val_categorical_accuracy: 0.7234
# Epoch 142/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4638 - categorical_crossentropy: 0.4638 - categorical_accuracy: 0.8625 - val_loss: 0.7304 - val_categorical_crossentropy: 0.7304 - val_categorical_accuracy: 0.7021
# Epoch 143/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4792 - categorical_crossentropy: 0.4792 - categorical_accuracy: 0.8417 - val_loss: 0.7334 - val_categorical_crossentropy: 0.7334 - val_categorical_accuracy: 0.7021
# Epoch 144/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4975 - categorical_crossentropy: 0.4975 - categorical_accuracy: 0.8208 - val_loss: 0.7426 - val_categorical_crossentropy: 0.7426 - val_categorical_accuracy: 0.7234
# Epoch 145/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4868 - categorical_crossentropy: 0.4868 - categorical_accuracy: 0.8667 - val_loss: 0.7239 - val_categorical_crossentropy: 0.7239 - val_categorical_accuracy: 0.7021
# Epoch 146/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4503 - categorical_crossentropy: 0.4503 - categorical_accuracy: 0.8458 - val_loss: 0.7306 - val_categorical_crossentropy: 0.7306 - val_categorical_accuracy: 0.7234
# Epoch 147/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4511 - categorical_crossentropy: 0.4511 - categorical_accuracy: 0.8833 - val_loss: 0.7222 - val_categorical_crossentropy: 0.7222 - val_categorical_accuracy: 0.7234
# Epoch 148/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4585 - categorical_crossentropy: 0.4585 - categorical_accuracy: 0.8583 - val_loss: 0.6974 - val_categorical_crossentropy: 0.6974 - val_categorical_accuracy: 0.7234
# Epoch 149/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4830 - categorical_crossentropy: 0.4830 - categorical_accuracy: 0.8708 - val_loss: 0.6954 - val_categorical_crossentropy: 0.6954 - val_categorical_accuracy: 0.7447
# Epoch 150/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4388 - categorical_crossentropy: 0.4388 - categorical_accuracy: 0.8708 - val_loss: 0.7070 - val_categorical_crossentropy: 0.7070 - val_categorical_accuracy: 0.7021
# Epoch 151/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4287 - categorical_crossentropy: 0.4287 - categorical_accuracy: 0.8708 - val_loss: 0.7173 - val_categorical_crossentropy: 0.7173 - val_categorical_accuracy: 0.7021
# Epoch 152/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4683 - categorical_crossentropy: 0.4683 - categorical_accuracy: 0.8625 - val_loss: 0.6943 - val_categorical_crossentropy: 0.6943 - val_categorical_accuracy: 0.7021
# Epoch 153/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4242 - categorical_crossentropy: 0.4242 - categorical_accuracy: 0.8875 - val_loss: 0.6778 - val_categorical_crossentropy: 0.6778 - val_categorical_accuracy: 0.7660
# Epoch 154/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4602 - categorical_crossentropy: 0.4602 - categorical_accuracy: 0.8500 - val_loss: 0.6844 - val_categorical_crossentropy: 0.6844 - val_categorical_accuracy: 0.7447
# Epoch 155/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4533 - categorical_crossentropy: 0.4533 - categorical_accuracy: 0.8792 - val_loss: 0.6772 - val_categorical_crossentropy: 0.6772 - val_categorical_accuracy: 0.7447
# Epoch 156/500
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4374 - categorical_crossentropy: 0.4374 - categorical_accuracy: 0.8875 - val_loss: 0.6891 - val_categorical_crossentropy: 0.6891 - val_categorical_accuracy: 0.7447
# Epoch 157/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4347 - categorical_crossentropy: 0.4347 - categorical_accuracy: 0.8792 - val_loss: 0.6926 - val_categorical_crossentropy: 0.6926 - val_categorical_accuracy: 0.7447
# Epoch 158/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4385 - categorical_crossentropy: 0.4385 - categorical_accuracy: 0.8583 - val_loss: 0.6807 - val_categorical_crossentropy: 0.6807 - val_categorical_accuracy: 0.7660
# Epoch 159/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4344 - categorical_crossentropy: 0.4344 - categorical_accuracy: 0.8875 - val_loss: 0.6973 - val_categorical_crossentropy: 0.6973 - val_categorical_accuracy: 0.7021
# Epoch 160/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4140 - categorical_crossentropy: 0.4140 - categorical_accuracy: 0.9042 - val_loss: 0.6693 - val_categorical_crossentropy: 0.6693 - val_categorical_accuracy: 0.7447
# Epoch 161/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4491 - categorical_crossentropy: 0.4491 - categorical_accuracy: 0.8792 - val_loss: 0.6709 - val_categorical_crossentropy: 0.6709 - val_categorical_accuracy: 0.7234
# Epoch 162/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4571 - categorical_crossentropy: 0.4571 - categorical_accuracy: 0.8583 - val_loss: 0.6958 - val_categorical_crossentropy: 0.6958 - val_categorical_accuracy: 0.7447
# Epoch 163/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4520 - categorical_crossentropy: 0.4520 - categorical_accuracy: 0.8458 - val_loss: 0.6925 - val_categorical_crossentropy: 0.6925 - val_categorical_accuracy: 0.7021
# Epoch 164/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4298 - categorical_crossentropy: 0.4298 - categorical_accuracy: 0.8750 - val_loss: 0.7133 - val_categorical_crossentropy: 0.7133 - val_categorical_accuracy: 0.7021
# Epoch 165/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4255 - categorical_crossentropy: 0.4255 - categorical_accuracy: 0.8625 - val_loss: 0.6996 - val_categorical_crossentropy: 0.6996 - val_categorical_accuracy: 0.7447
# Epoch 166/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4378 - categorical_crossentropy: 0.4378 - categorical_accuracy: 0.9042 - val_loss: 0.7009 - val_categorical_crossentropy: 0.7009 - val_categorical_accuracy: 0.7660
# Epoch 167/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4019 - categorical_crossentropy: 0.4019 - categorical_accuracy: 0.8833 - val_loss: 0.6922 - val_categorical_crossentropy: 0.6922 - val_categorical_accuracy: 0.7660
# Epoch 168/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4156 - categorical_crossentropy: 0.4156 - categorical_accuracy: 0.8750 - val_loss: 0.6889 - val_categorical_crossentropy: 0.6889 - val_categorical_accuracy: 0.7447
# Epoch 169/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4488 - categorical_crossentropy: 0.4488 - categorical_accuracy: 0.8667 - val_loss: 0.6866 - val_categorical_crossentropy: 0.6866 - val_categorical_accuracy: 0.7660
# Epoch 170/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4151 - categorical_crossentropy: 0.4151 - categorical_accuracy: 0.8792 - val_loss: 0.6945 - val_categorical_crossentropy: 0.6945 - val_categorical_accuracy: 0.7447
# Epoch 171/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4164 - categorical_crossentropy: 0.4164 - categorical_accuracy: 0.8958 - val_loss: 0.6699 - val_categorical_crossentropy: 0.6699 - val_categorical_accuracy: 0.7234
# Epoch 172/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4134 - categorical_crossentropy: 0.4134 - categorical_accuracy: 0.8708 - val_loss: 0.6817 - val_categorical_crossentropy: 0.6817 - val_categorical_accuracy: 0.7234
# Epoch 173/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4511 - categorical_crossentropy: 0.4511 - categorical_accuracy: 0.8708 - val_loss: 0.7100 - val_categorical_crossentropy: 0.7100 - val_categorical_accuracy: 0.7021
# Epoch 174/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4233 - categorical_crossentropy: 0.4233 - categorical_accuracy: 0.8750 - val_loss: 0.6873 - val_categorical_crossentropy: 0.6873 - val_categorical_accuracy: 0.6809
# Epoch 175/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4321 - categorical_crossentropy: 0.4321 - categorical_accuracy: 0.8458 - val_loss: 0.6976 - val_categorical_crossentropy: 0.6976 - val_categorical_accuracy: 0.7234
# Epoch 176/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4162 - categorical_crossentropy: 0.4162 - categorical_accuracy: 0.8958 - val_loss: 0.6808 - val_categorical_crossentropy: 0.6808 - val_categorical_accuracy: 0.7234
# Epoch 177/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4240 - categorical_crossentropy: 0.4240 - categorical_accuracy: 0.8917 - val_loss: 0.6536 - val_categorical_crossentropy: 0.6536 - val_categorical_accuracy: 0.7447
# Epoch 178/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4139 - categorical_crossentropy: 0.4139 - categorical_accuracy: 0.8625 - val_loss: 0.6520 - val_categorical_crossentropy: 0.6520 - val_categorical_accuracy: 0.7660
# Epoch 179/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4047 - categorical_crossentropy: 0.4047 - categorical_accuracy: 0.9042 - val_loss: 0.6323 - val_categorical_crossentropy: 0.6323 - val_categorical_accuracy: 0.7872
# Epoch 180/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4300 - categorical_crossentropy: 0.4300 - categorical_accuracy: 0.8542 - val_loss: 0.6558 - val_categorical_crossentropy: 0.6558 - val_categorical_accuracy: 0.7447
# Epoch 181/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4090 - categorical_crossentropy: 0.4090 - categorical_accuracy: 0.9000 - val_loss: 0.6482 - val_categorical_crossentropy: 0.6482 - val_categorical_accuracy: 0.7234
# Epoch 182/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4252 - categorical_crossentropy: 0.4252 - categorical_accuracy: 0.8500 - val_loss: 0.6753 - val_categorical_crossentropy: 0.6753 - val_categorical_accuracy: 0.7234
# Epoch 183/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4127 - categorical_crossentropy: 0.4127 - categorical_accuracy: 0.8917 - val_loss: 0.6478 - val_categorical_crossentropy: 0.6478 - val_categorical_accuracy: 0.7660
# Epoch 184/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3967 - categorical_crossentropy: 0.3967 - categorical_accuracy: 0.9125 - val_loss: 0.6562 - val_categorical_crossentropy: 0.6562 - val_categorical_accuracy: 0.7234
# Epoch 185/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3827 - categorical_crossentropy: 0.3827 - categorical_accuracy: 0.9167 - val_loss: 0.6292 - val_categorical_crossentropy: 0.6292 - val_categorical_accuracy: 0.7872
# Epoch 186/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3917 - categorical_crossentropy: 0.3917 - categorical_accuracy: 0.8833 - val_loss: 0.6227 - val_categorical_crossentropy: 0.6227 - val_categorical_accuracy: 0.7660
# Epoch 187/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3913 - categorical_crossentropy: 0.3913 - categorical_accuracy: 0.8958 - val_loss: 0.6512 - val_categorical_crossentropy: 0.6512 - val_categorical_accuracy: 0.7447
# Epoch 188/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4044 - categorical_crossentropy: 0.4044 - categorical_accuracy: 0.8625 - val_loss: 0.6190 - val_categorical_crossentropy: 0.6190 - val_categorical_accuracy: 0.7872
# Epoch 189/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3845 - categorical_crossentropy: 0.3845 - categorical_accuracy: 0.9000 - val_loss: 0.6155 - val_categorical_crossentropy: 0.6155 - val_categorical_accuracy: 0.7447
# Epoch 190/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3856 - categorical_crossentropy: 0.3856 - categorical_accuracy: 0.8958 - val_loss: 0.6127 - val_categorical_crossentropy: 0.6127 - val_categorical_accuracy: 0.7660
# Epoch 191/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3928 - categorical_crossentropy: 0.3928 - categorical_accuracy: 0.8792 - val_loss: 0.6056 - val_categorical_crossentropy: 0.6056 - val_categorical_accuracy: 0.7872
# Epoch 192/500
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3931 - categorical_crossentropy: 0.3931 - categorical_accuracy: 0.8750 - val_loss: 0.6275 - val_categorical_crossentropy: 0.6275 - val_categorical_accuracy: 0.7021
# Epoch 193/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3700 - categorical_crossentropy: 0.3700 - categorical_accuracy: 0.9083 - val_loss: 0.6194 - val_categorical_crossentropy: 0.6194 - val_categorical_accuracy: 0.7234
# Epoch 194/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3977 - categorical_crossentropy: 0.3977 - categorical_accuracy: 0.8833 - val_loss: 0.5765 - val_categorical_crossentropy: 0.5765 - val_categorical_accuracy: 0.7872
# Epoch 195/500
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3868 - categorical_crossentropy: 0.3868 - categorical_accuracy: 0.8958 - val_loss: 0.5738 - val_categorical_crossentropy: 0.5738 - val_categorical_accuracy: 0.8085
# ...
# Epoch 436/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0755 - categorical_crossentropy: 0.0755 - categorical_accuracy: 0.9917 - val_loss: 0.6677 - val_categorical_crossentropy: 0.6677 - val_categorical_accuracy: 0.8085
# Epoch 437/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0702 - categorical_crossentropy: 0.0702 - categorical_accuracy: 0.9875 - val_loss: 0.6927 - val_categorical_crossentropy: 0.6927 - val_categorical_accuracy: 0.8085
# Epoch 438/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0689 - categorical_crossentropy: 0.0689 - categorical_accuracy: 0.9875 - val_loss: 0.6906 - val_categorical_crossentropy: 0.6906 - val_categorical_accuracy: 0.7872
# Epoch 439/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0724 - categorical_crossentropy: 0.0724 - categorical_accuracy: 0.9917 - val_loss: 0.7084 - val_categorical_crossentropy: 0.7084 - val_categorical_accuracy: 0.7872
# Epoch 440/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0828 - categorical_crossentropy: 0.0828 - categorical_accuracy: 0.9792 - val_loss: 0.6862 - val_categorical_crossentropy: 0.6862 - val_categorical_accuracy: 0.7872
# Epoch 441/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0645 - categorical_crossentropy: 0.0645 - categorical_accuracy: 0.9958 - val_loss: 0.6822 - val_categorical_crossentropy: 0.6822 - val_categorical_accuracy: 0.8298
# Epoch 442/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0767 - categorical_crossentropy: 0.0767 - categorical_accuracy: 0.9917 - val_loss: 0.6758 - val_categorical_crossentropy: 0.6758 - val_categorical_accuracy: 0.7872
# Epoch 443/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0720 - categorical_crossentropy: 0.0720 - categorical_accuracy: 0.9875 - val_loss: 0.6971 - val_categorical_crossentropy: 0.6971 - val_categorical_accuracy: 0.7660
# Epoch 444/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0811 - categorical_crossentropy: 0.0811 - categorical_accuracy: 0.9917 - val_loss: 0.6749 - val_categorical_crossentropy: 0.6749 - val_categorical_accuracy: 0.7660
# Epoch 445/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0829 - categorical_crossentropy: 0.0829 - categorical_accuracy: 0.9750 - val_loss: 0.6684 - val_categorical_crossentropy: 0.6684 - val_categorical_accuracy: 0.7872
# Epoch 446/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0714 - categorical_crossentropy: 0.0714 - categorical_accuracy: 0.9875 - val_loss: 0.6318 - val_categorical_crossentropy: 0.6318 - val_categorical_accuracy: 0.7660
# Epoch 447/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0770 - categorical_crossentropy: 0.0770 - categorical_accuracy: 0.9875 - val_loss: 0.6676 - val_categorical_crossentropy: 0.6676 - val_categorical_accuracy: 0.7660
# Epoch 448/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0848 - categorical_crossentropy: 0.0848 - categorical_accuracy: 0.9750 - val_loss: 0.6875 - val_categorical_crossentropy: 0.6875 - val_categorical_accuracy: 0.7660
# Epoch 449/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0617 - categorical_crossentropy: 0.0617 - categorical_accuracy: 0.9958 - val_loss: 0.6764 - val_categorical_crossentropy: 0.6764 - val_categorical_accuracy: 0.7447
# Epoch 450/500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0635 - categorical_crossentropy: 0.0635 - categorical_accuracy: 1.0000 - val_loss: 0.7187 - val_categorical_crossentropy: 0.7187 - val_categorical_accuracy: 0.7660
# Epoch 451/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0600 - categorical_crossentropy: 0.0600 - categorical_accuracy: 0.9917 - val_loss: 0.7165 - val_categorical_crossentropy: 0.7165 - val_categorical_accuracy: 0.7447
# Epoch 452/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0828 - categorical_crossentropy: 0.0828 - categorical_accuracy: 0.9875 - val_loss: 0.7089 - val_categorical_crossentropy: 0.7089 - val_categorical_accuracy: 0.7234
# Epoch 453/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0684 - categorical_crossentropy: 0.0684 - categorical_accuracy: 0.9917 - val_loss: 0.6987 - val_categorical_crossentropy: 0.6987 - val_categorical_accuracy: 0.7660
# Epoch 454/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0759 - categorical_crossentropy: 0.0759 - categorical_accuracy: 0.9833 - val_loss: 0.6311 - val_categorical_crossentropy: 0.6311 - val_categorical_accuracy: 0.8085
# Epoch 455/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0847 - categorical_crossentropy: 0.0847 - categorical_accuracy: 0.9750 - val_loss: 0.6690 - val_categorical_crossentropy: 0.6690 - val_categorical_accuracy: 0.7872
# Epoch 456/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0847 - categorical_crossentropy: 0.0847 - categorical_accuracy: 0.9875 - val_loss: 0.8192 - val_categorical_crossentropy: 0.8192 - val_categorical_accuracy: 0.7660
# Epoch 457/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0769 - categorical_crossentropy: 0.0769 - categorical_accuracy: 0.9917 - val_loss: 0.8081 - val_categorical_crossentropy: 0.8081 - val_categorical_accuracy: 0.7660
# Epoch 458/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0747 - categorical_crossentropy: 0.0747 - categorical_accuracy: 0.9917 - val_loss: 0.7345 - val_categorical_crossentropy: 0.7345 - val_categorical_accuracy: 0.7660
# Epoch 459/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0746 - categorical_crossentropy: 0.0746 - categorical_accuracy: 0.9875 - val_loss: 0.6827 - val_categorical_crossentropy: 0.6827 - val_categorical_accuracy: 0.7447
# Epoch 460/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0802 - categorical_crossentropy: 0.0802 - categorical_accuracy: 0.9792 - val_loss: 0.6891 - val_categorical_crossentropy: 0.6891 - val_categorical_accuracy: 0.7872
# Epoch 461/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0547 - categorical_crossentropy: 0.0547 - categorical_accuracy: 0.9958 - val_loss: 0.7536 - val_categorical_crossentropy: 0.7536 - val_categorical_accuracy: 0.7660
# Epoch 462/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0803 - categorical_crossentropy: 0.0803 - categorical_accuracy: 0.9833 - val_loss: 0.7497 - val_categorical_crossentropy: 0.7497 - val_categorical_accuracy: 0.7872
# Epoch 463/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0684 - categorical_crossentropy: 0.0684 - categorical_accuracy: 1.0000 - val_loss: 0.7554 - val_categorical_crossentropy: 0.7554 - val_categorical_accuracy: 0.7872
# Epoch 464/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0715 - categorical_crossentropy: 0.0715 - categorical_accuracy: 0.9917 - val_loss: 0.7328 - val_categorical_crossentropy: 0.7328 - val_categorical_accuracy: 0.8085
# Epoch 465/500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0656 - categorical_crossentropy: 0.0656 - categorical_accuracy: 0.9958 - val_loss: 0.7266 - val_categorical_crossentropy: 0.7266 - val_categorical_accuracy: 0.8085
# Epoch 466/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0680 - categorical_crossentropy: 0.0680 - categorical_accuracy: 0.9917 - val_loss: 0.7003 - val_categorical_crossentropy: 0.7003 - val_categorical_accuracy: 0.8085
# Epoch 467/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0869 - categorical_crossentropy: 0.0869 - categorical_accuracy: 0.9750 - val_loss: 0.6379 - val_categorical_crossentropy: 0.6379 - val_categorical_accuracy: 0.8085
# Epoch 468/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0727 - categorical_crossentropy: 0.0727 - categorical_accuracy: 0.9792 - val_loss: 0.6876 - val_categorical_crossentropy: 0.6876 - val_categorical_accuracy: 0.7872
# Epoch 469/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0694 - categorical_crossentropy: 0.0694 - categorical_accuracy: 0.9917 - val_loss: 0.7154 - val_categorical_crossentropy: 0.7154 - val_categorical_accuracy: 0.7660
# Epoch 470/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0684 - categorical_crossentropy: 0.0684 - categorical_accuracy: 0.9917 - val_loss: 0.7245 - val_categorical_crossentropy: 0.7245 - val_categorical_accuracy: 0.7872
# Epoch 471/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0944 - categorical_crossentropy: 0.0944 - categorical_accuracy: 0.9792 - val_loss: 0.7380 - val_categorical_crossentropy: 0.7380 - val_categorical_accuracy: 0.7872
# Epoch 472/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0694 - categorical_crossentropy: 0.0694 - categorical_accuracy: 0.9875 - val_loss: 0.7642 - val_categorical_crossentropy: 0.7642 - val_categorical_accuracy: 0.8085
# Epoch 473/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0843 - categorical_crossentropy: 0.0843 - categorical_accuracy: 0.9750 - val_loss: 0.7642 - val_categorical_crossentropy: 0.7642 - val_categorical_accuracy: 0.7660
# Epoch 474/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0818 - categorical_crossentropy: 0.0818 - categorical_accuracy: 0.9792 - val_loss: 0.7056 - val_categorical_crossentropy: 0.7056 - val_categorical_accuracy: 0.7872
# Epoch 475/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0716 - categorical_crossentropy: 0.0716 - categorical_accuracy: 0.9917 - val_loss: 0.7013 - val_categorical_crossentropy: 0.7013 - val_categorical_accuracy: 0.7872
# Epoch 476/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0863 - categorical_crossentropy: 0.0863 - categorical_accuracy: 0.9833 - val_loss: 0.7177 - val_categorical_crossentropy: 0.7177 - val_categorical_accuracy: 0.7660
# Epoch 477/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0598 - categorical_crossentropy: 0.0598 - categorical_accuracy: 0.9917 - val_loss: 0.7163 - val_categorical_crossentropy: 0.7163 - val_categorical_accuracy: 0.7660
# Epoch 478/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0769 - categorical_crossentropy: 0.0769 - categorical_accuracy: 0.9833 - val_loss: 0.6754 - val_categorical_crossentropy: 0.6754 - val_categorical_accuracy: 0.7872
# Epoch 479/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0735 - categorical_crossentropy: 0.0735 - categorical_accuracy: 0.9917 - val_loss: 0.6330 - val_categorical_crossentropy: 0.6330 - val_categorical_accuracy: 0.8085
# Epoch 480/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0703 - categorical_crossentropy: 0.0703 - categorical_accuracy: 0.9917 - val_loss: 0.6677 - val_categorical_crossentropy: 0.6677 - val_categorical_accuracy: 0.7872
# Epoch 481/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0822 - categorical_crossentropy: 0.0822 - categorical_accuracy: 0.9833 - val_loss: 0.7158 - val_categorical_crossentropy: 0.7158 - val_categorical_accuracy: 0.7660
# Epoch 482/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0860 - categorical_crossentropy: 0.0860 - categorical_accuracy: 0.9708 - val_loss: 0.6640 - val_categorical_crossentropy: 0.6640 - val_categorical_accuracy: 0.7660
# Epoch 483/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0914 - categorical_crossentropy: 0.0914 - categorical_accuracy: 0.9667 - val_loss: 0.6158 - val_categorical_crossentropy: 0.6158 - val_categorical_accuracy: 0.8298
# Epoch 484/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0783 - categorical_crossentropy: 0.0783 - categorical_accuracy: 0.9833 - val_loss: 0.6300 - val_categorical_crossentropy: 0.6300 - val_categorical_accuracy: 0.7447
# Epoch 485/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0840 - categorical_crossentropy: 0.0840 - categorical_accuracy: 0.9750 - val_loss: 0.6374 - val_categorical_crossentropy: 0.6374 - val_categorical_accuracy: 0.8298
# Epoch 486/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0723 - categorical_crossentropy: 0.0723 - categorical_accuracy: 0.9917 - val_loss: 0.7071 - val_categorical_crossentropy: 0.7071 - val_categorical_accuracy: 0.7872
# Epoch 487/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0668 - categorical_crossentropy: 0.0668 - categorical_accuracy: 0.9875 - val_loss: 0.7449 - val_categorical_crossentropy: 0.7449 - val_categorical_accuracy: 0.7660
# Epoch 488/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0853 - categorical_crossentropy: 0.0853 - categorical_accuracy: 0.9875 - val_loss: 0.7449 - val_categorical_crossentropy: 0.7449 - val_categorical_accuracy: 0.8085
# Epoch 489/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0785 - categorical_crossentropy: 0.0785 - categorical_accuracy: 0.9875 - val_loss: 0.6880 - val_categorical_crossentropy: 0.6880 - val_categorical_accuracy: 0.8085
# Epoch 490/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0866 - categorical_crossentropy: 0.0866 - categorical_accuracy: 0.9792 - val_loss: 0.6880 - val_categorical_crossentropy: 0.6880 - val_categorical_accuracy: 0.8085
# Epoch 491/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0798 - categorical_crossentropy: 0.0798 - categorical_accuracy: 0.9792 - val_loss: 0.8271 - val_categorical_crossentropy: 0.8271 - val_categorical_accuracy: 0.7660
# Epoch 492/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0723 - categorical_crossentropy: 0.0723 - categorical_accuracy: 0.9917 - val_loss: 0.9264 - val_categorical_crossentropy: 0.9264 - val_categorical_accuracy: 0.7447
# Epoch 493/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0984 - categorical_crossentropy: 0.0984 - categorical_accuracy: 0.9750 - val_loss: 0.8184 - val_categorical_crossentropy: 0.8184 - val_categorical_accuracy: 0.7872
# Epoch 494/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0669 - categorical_crossentropy: 0.0669 - categorical_accuracy: 0.9833 - val_loss: 0.8517 - val_categorical_crossentropy: 0.8517 - val_categorical_accuracy: 0.7660
# Epoch 495/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0640 - categorical_crossentropy: 0.0640 - categorical_accuracy: 0.9917 - val_loss: 0.7643 - val_categorical_crossentropy: 0.7643 - val_categorical_accuracy: 0.7660
# Epoch 496/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0748 - categorical_crossentropy: 0.0748 - categorical_accuracy: 0.9917 - val_loss: 0.6838 - val_categorical_crossentropy: 0.6838 - val_categorical_accuracy: 0.8085
# Epoch 497/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0630 - categorical_crossentropy: 0.0630 - categorical_accuracy: 0.9958 - val_loss: 0.6671 - val_categorical_crossentropy: 0.6671 - val_categorical_accuracy: 0.7872
# Epoch 498/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0594 - categorical_crossentropy: 0.0594 - categorical_accuracy: 0.9958 - val_loss: 0.6504 - val_categorical_crossentropy: 0.6504 - val_categorical_accuracy: 0.7872
# Epoch 499/500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0740 - categorical_crossentropy: 0.0740 - categorical_accuracy: 0.9750 - val_loss: 0.7045 - val_categorical_crossentropy: 0.7045 - val_categorical_accuracy: 0.7660
# Epoch 500/500
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0565 - categorical_crossentropy: 0.0565 - categorical_accuracy: 0.9958 - val_loss: 0.7324 - val_categorical_crossentropy: 0.7324 - val_categorical_accuracy: 0.7660
#
# # Evaluate on test data
# 9/9 [==============================] - 1s 100ms/step - loss: 3.0272 - categorical_crossentropy: 3.0272 - categorical_accuracy: 0.2500
# test loss, test acc: [3.0271910296546087, 3.0271912, 0.25]
