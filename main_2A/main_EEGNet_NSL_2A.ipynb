# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_2A/main_EEGNet_NSL_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# fatal: destination path 'EEG_Deep' already exists and is not an empty directory.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Requirement already satisfied: neural_structured_learning in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.5)
# Using TensorFlow backend.

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()

# Initialize parameter
h_cut = [40]
drop_out = [0.5]
k_len = [32, 64, 128]
n_epochs = 300

out_f_name = 'acc_NSL_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_accuracy = zeros([nsub, nfilt,ndrop,nkl])

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])

for sub_idx, x in enumerate(range(1,10)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
      y_tr = y_tr.flatten() 
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered 

      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, 
                                               highcut=40, fs=250, order=4)  
        
      # tril_filtered = tril_filtered.transpose()
      X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          print(id_kl, id_d)
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

          adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
          adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
          # compile the model and set the optimizers
          adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
          batch_size = 32

          X_train = tf.cast(X_train, tf.float32)
          X_test = tf.cast(X_test, tf.float32)
          X_val = tf.cast(X_val, tf.float32)


          train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
          val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
          test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)

          val_steps = X_val.shape[0] // batch_size

  
          # adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=500, verbose=1)

          history = adv_model.fit(train_data, validation_data=val_data, 
                                  validation_steps=None, epochs=n_epochs, verbose=1)
          
          print('\n# Evaluate on test data')
          results = adv_model.evaluate(test_data)
          print('test loss, test acc:', results)

          loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          categorical_accuracy[sub_idx,h_indx,id_d, id_kl] = results[2]

          del model

#           del train_data, val_data, test_data

          # from keras import backend as K 
          # K.clear_session()

np.save(out_f_name, categorical_accuracy)
# Out:
# acc_NSL_EEGNet_epochs_300_filter_[40]_drop_[0.5]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288,)
# (240, 22, 750)
# (240,)
# (47, 22, 750)
# (47,)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# 0 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/neural_structured_learning/keras/adversarial_regularization.py:167: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/300
# 8/8 [==============================] - 2s 229ms/step - loss: 1.3878 - categorical_crossentropy: 1.3878 - categorical_accuracy: 0.2792 - val_loss: 1.3883 - val_categorical_crossentropy: 1.3883 - val_categorical_accuracy: 0.2128
# Epoch 2/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3731 - categorical_crossentropy: 1.3731 - categorical_accuracy: 0.2500 - val_loss: 1.3873 - val_categorical_crossentropy: 1.3873 - val_categorical_accuracy: 0.2766
# Epoch 3/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3677 - categorical_crossentropy: 1.3677 - categorical_accuracy: 0.3167 - val_loss: 1.3864 - val_categorical_crossentropy: 1.3864 - val_categorical_accuracy: 0.3404
# Epoch 4/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3540 - categorical_crossentropy: 1.3540 - categorical_accuracy: 0.3208 - val_loss: 1.3856 - val_categorical_crossentropy: 1.3856 - val_categorical_accuracy: 0.3191
# Epoch 5/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3486 - categorical_crossentropy: 1.3486 - categorical_accuracy: 0.3208 - val_loss: 1.3836 - val_categorical_crossentropy: 1.3836 - val_categorical_accuracy: 0.3191
# Epoch 6/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.3311 - categorical_crossentropy: 1.3311 - categorical_accuracy: 0.3583 - val_loss: 1.3796 - val_categorical_crossentropy: 1.3796 - val_categorical_accuracy: 0.4255
# Epoch 7/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.2744 - categorical_crossentropy: 1.2744 - categorical_accuracy: 0.5375 - val_loss: 1.3726 - val_categorical_crossentropy: 1.3726 - val_categorical_accuracy: 0.3617
# Epoch 8/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.2390 - categorical_crossentropy: 1.2390 - categorical_accuracy: 0.5375 - val_loss: 1.3603 - val_categorical_crossentropy: 1.3603 - val_categorical_accuracy: 0.4255
# Epoch 9/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.1830 - categorical_crossentropy: 1.1830 - categorical_accuracy: 0.5625 - val_loss: 1.3398 - val_categorical_crossentropy: 1.3398 - val_categorical_accuracy: 0.4255
# Epoch 10/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.1148 - categorical_crossentropy: 1.1148 - categorical_accuracy: 0.5375 - val_loss: 1.3106 - val_categorical_crossentropy: 1.3106 - val_categorical_accuracy: 0.4468
# Epoch 11/300
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0507 - categorical_crossentropy: 1.0507 - categorical_accuracy: 0.5792 - val_loss: 1.2806 - val_categorical_crossentropy: 1.2806 - val_categorical_accuracy: 0.4043
# Epoch 12/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9867 - categorical_crossentropy: 0.9867 - categorical_accuracy: 0.6542 - val_loss: 1.2574 - val_categorical_crossentropy: 1.2574 - val_categorical_accuracy: 0.3617
# Epoch 13/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9550 - categorical_crossentropy: 0.9550 - categorical_accuracy: 0.5792 - val_loss: 1.2445 - val_categorical_crossentropy: 1.2445 - val_categorical_accuracy: 0.3404
# Epoch 14/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8904 - categorical_crossentropy: 0.8904 - categorical_accuracy: 0.6750 - val_loss: 1.2402 - val_categorical_crossentropy: 1.2402 - val_categorical_accuracy: 0.3617
# Epoch 15/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8760 - categorical_crossentropy: 0.8760 - categorical_accuracy: 0.6792 - val_loss: 1.2418 - val_categorical_crossentropy: 1.2418 - val_categorical_accuracy: 0.3617
# Epoch 16/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8867 - categorical_crossentropy: 0.8867 - categorical_accuracy: 0.6625 - val_loss: 1.2532 - val_categorical_crossentropy: 1.2532 - val_categorical_accuracy: 0.3830
# Epoch 17/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8289 - categorical_crossentropy: 0.8289 - categorical_accuracy: 0.6833 - val_loss: 1.2890 - val_categorical_crossentropy: 1.2890 - val_categorical_accuracy: 0.3830
# Epoch 18/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8469 - categorical_crossentropy: 0.8469 - categorical_accuracy: 0.6875 - val_loss: 1.3227 - val_categorical_crossentropy: 1.3227 - val_categorical_accuracy: 0.4043
# Epoch 19/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8340 - categorical_crossentropy: 0.8340 - categorical_accuracy: 0.6375 - val_loss: 1.3277 - val_categorical_crossentropy: 1.3277 - val_categorical_accuracy: 0.3617
# Epoch 20/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8290 - categorical_crossentropy: 0.8290 - categorical_accuracy: 0.6500 - val_loss: 1.3328 - val_categorical_crossentropy: 1.3328 - val_categorical_accuracy: 0.2766
# Epoch 21/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7961 - categorical_crossentropy: 0.7961 - categorical_accuracy: 0.6833 - val_loss: 1.3427 - val_categorical_crossentropy: 1.3427 - val_categorical_accuracy: 0.2766
# Epoch 22/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7905 - categorical_crossentropy: 0.7905 - categorical_accuracy: 0.6542 - val_loss: 1.3596 - val_categorical_crossentropy: 1.3596 - val_categorical_accuracy: 0.2979
# Epoch 23/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7816 - categorical_crossentropy: 0.7816 - categorical_accuracy: 0.6542 - val_loss: 1.3698 - val_categorical_crossentropy: 1.3698 - val_categorical_accuracy: 0.2979
# Epoch 24/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7759 - categorical_crossentropy: 0.7759 - categorical_accuracy: 0.6875 - val_loss: 1.3760 - val_categorical_crossentropy: 1.3760 - val_categorical_accuracy: 0.2979
# Epoch 25/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7695 - categorical_crossentropy: 0.7695 - categorical_accuracy: 0.7083 - val_loss: 1.3699 - val_categorical_crossentropy: 1.3699 - val_categorical_accuracy: 0.2766
# Epoch 26/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7532 - categorical_crossentropy: 0.7532 - categorical_accuracy: 0.7333 - val_loss: 1.3344 - val_categorical_crossentropy: 1.3344 - val_categorical_accuracy: 0.2766
# Epoch 27/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7600 - categorical_crossentropy: 0.7600 - categorical_accuracy: 0.7167 - val_loss: 1.2846 - val_categorical_crossentropy: 1.2846 - val_categorical_accuracy: 0.2766
# Epoch 28/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7527 - categorical_crossentropy: 0.7527 - categorical_accuracy: 0.7000 - val_loss: 1.2689 - val_categorical_crossentropy: 1.2689 - val_categorical_accuracy: 0.3617
# Epoch 29/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7837 - categorical_crossentropy: 0.7837 - categorical_accuracy: 0.7000 - val_loss: 1.2535 - val_categorical_crossentropy: 1.2535 - val_categorical_accuracy: 0.3830
# Epoch 30/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6983 - categorical_crossentropy: 0.6983 - categorical_accuracy: 0.7833 - val_loss: 1.2356 - val_categorical_crossentropy: 1.2356 - val_categorical_accuracy: 0.3617
# Epoch 31/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7183 - categorical_crossentropy: 0.7183 - categorical_accuracy: 0.7375 - val_loss: 1.1992 - val_categorical_crossentropy: 1.1992 - val_categorical_accuracy: 0.3830
# Epoch 32/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7096 - categorical_crossentropy: 0.7096 - categorical_accuracy: 0.7375 - val_loss: 1.1522 - val_categorical_crossentropy: 1.1522 - val_categorical_accuracy: 0.5106
# Epoch 33/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7090 - categorical_crossentropy: 0.7090 - categorical_accuracy: 0.7333 - val_loss: 1.1334 - val_categorical_crossentropy: 1.1334 - val_categorical_accuracy: 0.4894
# Epoch 34/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7298 - categorical_crossentropy: 0.7298 - categorical_accuracy: 0.7375 - val_loss: 1.1113 - val_categorical_crossentropy: 1.1113 - val_categorical_accuracy: 0.5319
# Epoch 35/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7182 - categorical_crossentropy: 0.7182 - categorical_accuracy: 0.7417 - val_loss: 1.0533 - val_categorical_crossentropy: 1.0533 - val_categorical_accuracy: 0.5319
# Epoch 36/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6971 - categorical_crossentropy: 0.6971 - categorical_accuracy: 0.7417 - val_loss: 0.9984 - val_categorical_crossentropy: 0.9984 - val_categorical_accuracy: 0.5319
# Epoch 37/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6838 - categorical_crossentropy: 0.6838 - categorical_accuracy: 0.7333 - val_loss: 1.0006 - val_categorical_crossentropy: 1.0006 - val_categorical_accuracy: 0.4894
# Epoch 38/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7102 - categorical_crossentropy: 0.7102 - categorical_accuracy: 0.7292 - val_loss: 0.9931 - val_categorical_crossentropy: 0.9931 - val_categorical_accuracy: 0.5745
# Epoch 39/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6833 - categorical_crossentropy: 0.6833 - categorical_accuracy: 0.7542 - val_loss: 0.9908 - val_categorical_crossentropy: 0.9908 - val_categorical_accuracy: 0.5319
# Epoch 40/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6864 - categorical_crossentropy: 0.6864 - categorical_accuracy: 0.7542 - val_loss: 0.9985 - val_categorical_crossentropy: 0.9985 - val_categorical_accuracy: 0.5319
# Epoch 41/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6723 - categorical_crossentropy: 0.6723 - categorical_accuracy: 0.7667 - val_loss: 0.9913 - val_categorical_crossentropy: 0.9913 - val_categorical_accuracy: 0.5106
# Epoch 42/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6538 - categorical_crossentropy: 0.6538 - categorical_accuracy: 0.7875 - val_loss: 0.9576 - val_categorical_crossentropy: 0.9576 - val_categorical_accuracy: 0.5532
# Epoch 43/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6437 - categorical_crossentropy: 0.6437 - categorical_accuracy: 0.8000 - val_loss: 0.9324 - val_categorical_crossentropy: 0.9324 - val_categorical_accuracy: 0.5532
# Epoch 44/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6677 - categorical_crossentropy: 0.6677 - categorical_accuracy: 0.7333 - val_loss: 0.9208 - val_categorical_crossentropy: 0.9208 - val_categorical_accuracy: 0.5532
# Epoch 45/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6513 - categorical_crossentropy: 0.6513 - categorical_accuracy: 0.7542 - val_loss: 0.8939 - val_categorical_crossentropy: 0.8939 - val_categorical_accuracy: 0.6170
# Epoch 46/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6537 - categorical_crossentropy: 0.6537 - categorical_accuracy: 0.7583 - val_loss: 0.8892 - val_categorical_crossentropy: 0.8892 - val_categorical_accuracy: 0.6596
# Epoch 47/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6487 - categorical_crossentropy: 0.6487 - categorical_accuracy: 0.7375 - val_loss: 0.8783 - val_categorical_crossentropy: 0.8783 - val_categorical_accuracy: 0.6809
# Epoch 48/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6397 - categorical_crossentropy: 0.6397 - categorical_accuracy: 0.7667 - val_loss: 0.8515 - val_categorical_crossentropy: 0.8515 - val_categorical_accuracy: 0.7021
# Epoch 49/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6450 - categorical_crossentropy: 0.6450 - categorical_accuracy: 0.7500 - val_loss: 0.8420 - val_categorical_crossentropy: 0.8420 - val_categorical_accuracy: 0.6809
# Epoch 50/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6533 - categorical_crossentropy: 0.6533 - categorical_accuracy: 0.7542 - val_loss: 0.8281 - val_categorical_crossentropy: 0.8281 - val_categorical_accuracy: 0.6596
# Epoch 51/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6391 - categorical_crossentropy: 0.6391 - categorical_accuracy: 0.7792 - val_loss: 0.8162 - val_categorical_crossentropy: 0.8162 - val_categorical_accuracy: 0.6596
# Epoch 52/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6196 - categorical_crossentropy: 0.6196 - categorical_accuracy: 0.8208 - val_loss: 0.8119 - val_categorical_crossentropy: 0.8119 - val_categorical_accuracy: 0.7021
# Epoch 53/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6403 - categorical_crossentropy: 0.6403 - categorical_accuracy: 0.7792 - val_loss: 0.8163 - val_categorical_crossentropy: 0.8163 - val_categorical_accuracy: 0.7234
# Epoch 54/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6288 - categorical_crossentropy: 0.6288 - categorical_accuracy: 0.7958 - val_loss: 0.8201 - val_categorical_crossentropy: 0.8201 - val_categorical_accuracy: 0.7234
# Epoch 55/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6152 - categorical_crossentropy: 0.6152 - categorical_accuracy: 0.7417 - val_loss: 0.8167 - val_categorical_crossentropy: 0.8167 - val_categorical_accuracy: 0.6596
# Epoch 56/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6426 - categorical_crossentropy: 0.6426 - categorical_accuracy: 0.7667 - val_loss: 0.7898 - val_categorical_crossentropy: 0.7898 - val_categorical_accuracy: 0.6596
# Epoch 57/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6176 - categorical_crossentropy: 0.6176 - categorical_accuracy: 0.8083 - val_loss: 0.7919 - val_categorical_crossentropy: 0.7919 - val_categorical_accuracy: 0.7021
# Epoch 58/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6087 - categorical_crossentropy: 0.6087 - categorical_accuracy: 0.8000 - val_loss: 0.7964 - val_categorical_crossentropy: 0.7964 - val_categorical_accuracy: 0.7021
# Epoch 59/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6294 - categorical_crossentropy: 0.6294 - categorical_accuracy: 0.7375 - val_loss: 0.7850 - val_categorical_crossentropy: 0.7850 - val_categorical_accuracy: 0.7021
# Epoch 60/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6344 - categorical_crossentropy: 0.6344 - categorical_accuracy: 0.7708 - val_loss: 0.7895 - val_categorical_crossentropy: 0.7895 - val_categorical_accuracy: 0.6596
# Epoch 61/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6031 - categorical_crossentropy: 0.6031 - categorical_accuracy: 0.7667 - val_loss: 0.7818 - val_categorical_crossentropy: 0.7818 - val_categorical_accuracy: 0.7021
# Epoch 62/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6105 - categorical_crossentropy: 0.6105 - categorical_accuracy: 0.8250 - val_loss: 0.7710 - val_categorical_crossentropy: 0.7710 - val_categorical_accuracy: 0.7234
# Epoch 63/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6308 - categorical_crossentropy: 0.6308 - categorical_accuracy: 0.7667 - val_loss: 0.7725 - val_categorical_crossentropy: 0.7725 - val_categorical_accuracy: 0.6809
# Epoch 64/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6243 - categorical_crossentropy: 0.6243 - categorical_accuracy: 0.7500 - val_loss: 0.7759 - val_categorical_crossentropy: 0.7759 - val_categorical_accuracy: 0.6596
# Epoch 65/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6201 - categorical_crossentropy: 0.6201 - categorical_accuracy: 0.7542 - val_loss: 0.7655 - val_categorical_crossentropy: 0.7655 - val_categorical_accuracy: 0.6809
# Epoch 66/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5751 - categorical_crossentropy: 0.5751 - categorical_accuracy: 0.8167 - val_loss: 0.7488 - val_categorical_crossentropy: 0.7488 - val_categorical_accuracy: 0.7021
# Epoch 67/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6189 - categorical_crossentropy: 0.6189 - categorical_accuracy: 0.7708 - val_loss: 0.7503 - val_categorical_crossentropy: 0.7503 - val_categorical_accuracy: 0.6809
# Epoch 68/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6059 - categorical_crossentropy: 0.6059 - categorical_accuracy: 0.7833 - val_loss: 0.7408 - val_categorical_crossentropy: 0.7408 - val_categorical_accuracy: 0.6809
# Epoch 69/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6032 - categorical_crossentropy: 0.6032 - categorical_accuracy: 0.8083 - val_loss: 0.7463 - val_categorical_crossentropy: 0.7463 - val_categorical_accuracy: 0.6809
# Epoch 70/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6099 - categorical_crossentropy: 0.6099 - categorical_accuracy: 0.7542 - val_loss: 0.7584 - val_categorical_crossentropy: 0.7584 - val_categorical_accuracy: 0.6809
# Epoch 71/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6014 - categorical_crossentropy: 0.6014 - categorical_accuracy: 0.7500 - val_loss: 0.7387 - val_categorical_crossentropy: 0.7387 - val_categorical_accuracy: 0.7234
# Epoch 72/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5837 - categorical_crossentropy: 0.5837 - categorical_accuracy: 0.8042 - val_loss: 0.7359 - val_categorical_crossentropy: 0.7359 - val_categorical_accuracy: 0.7447
# Epoch 73/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6132 - categorical_crossentropy: 0.6132 - categorical_accuracy: 0.7583 - val_loss: 0.7325 - val_categorical_crossentropy: 0.7325 - val_categorical_accuracy: 0.7021
# Epoch 74/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5747 - categorical_crossentropy: 0.5747 - categorical_accuracy: 0.8125 - val_loss: 0.7387 - val_categorical_crossentropy: 0.7387 - val_categorical_accuracy: 0.7021
# Epoch 75/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5969 - categorical_crossentropy: 0.5969 - categorical_accuracy: 0.8000 - val_loss: 0.7420 - val_categorical_crossentropy: 0.7420 - val_categorical_accuracy: 0.6809
# Epoch 76/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5737 - categorical_crossentropy: 0.5737 - categorical_accuracy: 0.8042 - val_loss: 0.7441 - val_categorical_crossentropy: 0.7441 - val_categorical_accuracy: 0.6809
# Epoch 77/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5481 - categorical_crossentropy: 0.5481 - categorical_accuracy: 0.8292 - val_loss: 0.7332 - val_categorical_crossentropy: 0.7332 - val_categorical_accuracy: 0.7021
# Epoch 78/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5670 - categorical_crossentropy: 0.5670 - categorical_accuracy: 0.7833 - val_loss: 0.7437 - val_categorical_crossentropy: 0.7437 - val_categorical_accuracy: 0.7021
# Epoch 79/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5583 - categorical_crossentropy: 0.5583 - categorical_accuracy: 0.8375 - val_loss: 0.7614 - val_categorical_crossentropy: 0.7614 - val_categorical_accuracy: 0.7234
# Epoch 80/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5841 - categorical_crossentropy: 0.5841 - categorical_accuracy: 0.7958 - val_loss: 0.7660 - val_categorical_crossentropy: 0.7660 - val_categorical_accuracy: 0.7447
# Epoch 81/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5138 - categorical_crossentropy: 0.5138 - categorical_accuracy: 0.8375 - val_loss: 0.7538 - val_categorical_crossentropy: 0.7538 - val_categorical_accuracy: 0.7234
# Epoch 82/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5353 - categorical_crossentropy: 0.5353 - categorical_accuracy: 0.8458 - val_loss: 0.7608 - val_categorical_crossentropy: 0.7608 - val_categorical_accuracy: 0.6809
# Epoch 83/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5599 - categorical_crossentropy: 0.5599 - categorical_accuracy: 0.8000 - val_loss: 0.7389 - val_categorical_crossentropy: 0.7389 - val_categorical_accuracy: 0.7021
# Epoch 84/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5724 - categorical_crossentropy: 0.5724 - categorical_accuracy: 0.7917 - val_loss: 0.7251 - val_categorical_crossentropy: 0.7251 - val_categorical_accuracy: 0.7234
# Epoch 85/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5721 - categorical_crossentropy: 0.5721 - categorical_accuracy: 0.7917 - val_loss: 0.7359 - val_categorical_crossentropy: 0.7359 - val_categorical_accuracy: 0.7447
# Epoch 86/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5716 - categorical_crossentropy: 0.5716 - categorical_accuracy: 0.8083 - val_loss: 0.7448 - val_categorical_crossentropy: 0.7448 - val_categorical_accuracy: 0.7234
# Epoch 87/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5526 - categorical_crossentropy: 0.5526 - categorical_accuracy: 0.8292 - val_loss: 0.7499 - val_categorical_crossentropy: 0.7499 - val_categorical_accuracy: 0.6809
# Epoch 88/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5863 - categorical_crossentropy: 0.5863 - categorical_accuracy: 0.7667 - val_loss: 0.7556 - val_categorical_crossentropy: 0.7556 - val_categorical_accuracy: 0.6596
# Epoch 89/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5246 - categorical_crossentropy: 0.5246 - categorical_accuracy: 0.8250 - val_loss: 0.7464 - val_categorical_crossentropy: 0.7464 - val_categorical_accuracy: 0.6809
# Epoch 90/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5410 - categorical_crossentropy: 0.5410 - categorical_accuracy: 0.7958 - val_loss: 0.7447 - val_categorical_crossentropy: 0.7447 - val_categorical_accuracy: 0.7021
# Epoch 91/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5528 - categorical_crossentropy: 0.5528 - categorical_accuracy: 0.8000 - val_loss: 0.7424 - val_categorical_crossentropy: 0.7424 - val_categorical_accuracy: 0.7234
# Epoch 92/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5356 - categorical_crossentropy: 0.5356 - categorical_accuracy: 0.8167 - val_loss: 0.7398 - val_categorical_crossentropy: 0.7398 - val_categorical_accuracy: 0.7021
# Epoch 93/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5619 - categorical_crossentropy: 0.5619 - categorical_accuracy: 0.8125 - val_loss: 0.7469 - val_categorical_crossentropy: 0.7469 - val_categorical_accuracy: 0.7021
# Epoch 94/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5506 - categorical_crossentropy: 0.5506 - categorical_accuracy: 0.8375 - val_loss: 0.7376 - val_categorical_crossentropy: 0.7376 - val_categorical_accuracy: 0.7234
# Epoch 95/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5543 - categorical_crossentropy: 0.5543 - categorical_accuracy: 0.7833 - val_loss: 0.7279 - val_categorical_crossentropy: 0.7279 - val_categorical_accuracy: 0.7021
# Epoch 96/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5634 - categorical_crossentropy: 0.5634 - categorical_accuracy: 0.7958 - val_loss: 0.7622 - val_categorical_crossentropy: 0.7622 - val_categorical_accuracy: 0.6809
# Epoch 97/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5369 - categorical_crossentropy: 0.5369 - categorical_accuracy: 0.8250 - val_loss: 0.7435 - val_categorical_crossentropy: 0.7435 - val_categorical_accuracy: 0.6809
# Epoch 98/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5645 - categorical_crossentropy: 0.5645 - categorical_accuracy: 0.7958 - val_loss: 0.7263 - val_categorical_crossentropy: 0.7263 - val_categorical_accuracy: 0.7021
# Epoch 99/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5202 - categorical_crossentropy: 0.5202 - categorical_accuracy: 0.8208 - val_loss: 0.7358 - val_categorical_crossentropy: 0.7358 - val_categorical_accuracy: 0.7021
# Epoch 100/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5288 - categorical_crossentropy: 0.5288 - categorical_accuracy: 0.8333 - val_loss: 0.7397 - val_categorical_crossentropy: 0.7397 - val_categorical_accuracy: 0.7021
# Epoch 101/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5228 - categorical_crossentropy: 0.5228 - categorical_accuracy: 0.8250 - val_loss: 0.7412 - val_categorical_crossentropy: 0.7412 - val_categorical_accuracy: 0.7234
# Epoch 102/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5143 - categorical_crossentropy: 0.5143 - categorical_accuracy: 0.8542 - val_loss: 0.7310 - val_categorical_crossentropy: 0.7310 - val_categorical_accuracy: 0.7447
# Epoch 103/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5420 - categorical_crossentropy: 0.5420 - categorical_accuracy: 0.8167 - val_loss: 0.7340 - val_categorical_crossentropy: 0.7340 - val_categorical_accuracy: 0.7660
# Epoch 104/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5195 - categorical_crossentropy: 0.5195 - categorical_accuracy: 0.8042 - val_loss: 0.7399 - val_categorical_crossentropy: 0.7399 - val_categorical_accuracy: 0.7234
# Epoch 105/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5442 - categorical_crossentropy: 0.5442 - categorical_accuracy: 0.8125 - val_loss: 0.7343 - val_categorical_crossentropy: 0.7343 - val_categorical_accuracy: 0.7234
# Epoch 106/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5194 - categorical_crossentropy: 0.5194 - categorical_accuracy: 0.8167 - val_loss: 0.7253 - val_categorical_crossentropy: 0.7253 - val_categorical_accuracy: 0.7660
# Epoch 107/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5277 - categorical_crossentropy: 0.5277 - categorical_accuracy: 0.8250 - val_loss: 0.7232 - val_categorical_crossentropy: 0.7232 - val_categorical_accuracy: 0.7447
# Epoch 108/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5305 - categorical_crossentropy: 0.5305 - categorical_accuracy: 0.8083 - val_loss: 0.7286 - val_categorical_crossentropy: 0.7286 - val_categorical_accuracy: 0.7234
# Epoch 109/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4975 - categorical_crossentropy: 0.4975 - categorical_accuracy: 0.8500 - val_loss: 0.7131 - val_categorical_crossentropy: 0.7131 - val_categorical_accuracy: 0.7660
# Epoch 110/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5308 - categorical_crossentropy: 0.5308 - categorical_accuracy: 0.8125 - val_loss: 0.7096 - val_categorical_crossentropy: 0.7096 - val_categorical_accuracy: 0.7234
# Epoch 111/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5411 - categorical_crossentropy: 0.5411 - categorical_accuracy: 0.7875 - val_loss: 0.7207 - val_categorical_crossentropy: 0.7207 - val_categorical_accuracy: 0.7021
# Epoch 112/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5099 - categorical_crossentropy: 0.5099 - categorical_accuracy: 0.8417 - val_loss: 0.7142 - val_categorical_crossentropy: 0.7142 - val_categorical_accuracy: 0.7447
# Epoch 113/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5262 - categorical_crossentropy: 0.5262 - categorical_accuracy: 0.7917 - val_loss: 0.7193 - val_categorical_crossentropy: 0.7193 - val_categorical_accuracy: 0.7021
# Epoch 114/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4950 - categorical_crossentropy: 0.4950 - categorical_accuracy: 0.8250 - val_loss: 0.7109 - val_categorical_crossentropy: 0.7109 - val_categorical_accuracy: 0.7447
# Epoch 115/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5043 - categorical_crossentropy: 0.5043 - categorical_accuracy: 0.8417 - val_loss: 0.7294 - val_categorical_crossentropy: 0.7294 - val_categorical_accuracy: 0.7447
# Epoch 116/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5207 - categorical_crossentropy: 0.5207 - categorical_accuracy: 0.7917 - val_loss: 0.7322 - val_categorical_crossentropy: 0.7322 - val_categorical_accuracy: 0.7447
# Epoch 117/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5151 - categorical_crossentropy: 0.5151 - categorical_accuracy: 0.8208 - val_loss: 0.7328 - val_categorical_crossentropy: 0.7328 - val_categorical_accuracy: 0.7234
# Epoch 118/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5251 - categorical_crossentropy: 0.5251 - categorical_accuracy: 0.8375 - val_loss: 0.7339 - val_categorical_crossentropy: 0.7339 - val_categorical_accuracy: 0.7447
# Epoch 119/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5174 - categorical_crossentropy: 0.5174 - categorical_accuracy: 0.8250 - val_loss: 0.7342 - val_categorical_crossentropy: 0.7342 - val_categorical_accuracy: 0.7234
# Epoch 120/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5396 - categorical_crossentropy: 0.5396 - categorical_accuracy: 0.7833 - val_loss: 0.7621 - val_categorical_crossentropy: 0.7621 - val_categorical_accuracy: 0.7447
# Epoch 121/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5189 - categorical_crossentropy: 0.5189 - categorical_accuracy: 0.8083 - val_loss: 0.7607 - val_categorical_crossentropy: 0.7607 - val_categorical_accuracy: 0.7447
# Epoch 122/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4910 - categorical_crossentropy: 0.4910 - categorical_accuracy: 0.8583 - val_loss: 0.7465 - val_categorical_crossentropy: 0.7465 - val_categorical_accuracy: 0.7234
# Epoch 123/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4746 - categorical_crossentropy: 0.4746 - categorical_accuracy: 0.8500 - val_loss: 0.7316 - val_categorical_crossentropy: 0.7316 - val_categorical_accuracy: 0.7447
# Epoch 124/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4989 - categorical_crossentropy: 0.4989 - categorical_accuracy: 0.8417 - val_loss: 0.7132 - val_categorical_crossentropy: 0.7132 - val_categorical_accuracy: 0.7660
# Epoch 125/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5027 - categorical_crossentropy: 0.5027 - categorical_accuracy: 0.8250 - val_loss: 0.7121 - val_categorical_crossentropy: 0.7121 - val_categorical_accuracy: 0.7447
# Epoch 126/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4716 - categorical_crossentropy: 0.4716 - categorical_accuracy: 0.8417 - val_loss: 0.7141 - val_categorical_crossentropy: 0.7141 - val_categorical_accuracy: 0.7447
# Epoch 127/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4897 - categorical_crossentropy: 0.4897 - categorical_accuracy: 0.8417 - val_loss: 0.7249 - val_categorical_crossentropy: 0.7249 - val_categorical_accuracy: 0.7447
# Epoch 128/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4546 - categorical_crossentropy: 0.4546 - categorical_accuracy: 0.8625 - val_loss: 0.7291 - val_categorical_crossentropy: 0.7291 - val_categorical_accuracy: 0.7447
# Epoch 129/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5163 - categorical_crossentropy: 0.5163 - categorical_accuracy: 0.8500 - val_loss: 0.7404 - val_categorical_crossentropy: 0.7404 - val_categorical_accuracy: 0.7447
# Epoch 130/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5019 - categorical_crossentropy: 0.5019 - categorical_accuracy: 0.8250 - val_loss: 0.7315 - val_categorical_crossentropy: 0.7315 - val_categorical_accuracy: 0.7447
# Epoch 131/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5031 - categorical_crossentropy: 0.5031 - categorical_accuracy: 0.8125 - val_loss: 0.7198 - val_categorical_crossentropy: 0.7198 - val_categorical_accuracy: 0.7447
# Epoch 132/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4948 - categorical_crossentropy: 0.4948 - categorical_accuracy: 0.8667 - val_loss: 0.7285 - val_categorical_crossentropy: 0.7285 - val_categorical_accuracy: 0.7447
# Epoch 133/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4682 - categorical_crossentropy: 0.4682 - categorical_accuracy: 0.8458 - val_loss: 0.7525 - val_categorical_crossentropy: 0.7525 - val_categorical_accuracy: 0.7234
# Epoch 134/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4947 - categorical_crossentropy: 0.4947 - categorical_accuracy: 0.8208 - val_loss: 0.7533 - val_categorical_crossentropy: 0.7533 - val_categorical_accuracy: 0.7234
# Epoch 135/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4905 - categorical_crossentropy: 0.4905 - categorical_accuracy: 0.8292 - val_loss: 0.7184 - val_categorical_crossentropy: 0.7184 - val_categorical_accuracy: 0.7234
# Epoch 136/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4844 - categorical_crossentropy: 0.4844 - categorical_accuracy: 0.8500 - val_loss: 0.7137 - val_categorical_crossentropy: 0.7137 - val_categorical_accuracy: 0.7234
# Epoch 137/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4771 - categorical_crossentropy: 0.4771 - categorical_accuracy: 0.8500 - val_loss: 0.7295 - val_categorical_crossentropy: 0.7295 - val_categorical_accuracy: 0.7021
# Epoch 138/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4692 - categorical_crossentropy: 0.4692 - categorical_accuracy: 0.8625 - val_loss: 0.7428 - val_categorical_crossentropy: 0.7428 - val_categorical_accuracy: 0.7447
# Epoch 139/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4795 - categorical_crossentropy: 0.4795 - categorical_accuracy: 0.8458 - val_loss: 0.7346 - val_categorical_crossentropy: 0.7346 - val_categorical_accuracy: 0.7447
# Epoch 140/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4816 - categorical_crossentropy: 0.4816 - categorical_accuracy: 0.8292 - val_loss: 0.7363 - val_categorical_crossentropy: 0.7363 - val_categorical_accuracy: 0.7234
# Epoch 141/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4390 - categorical_crossentropy: 0.4390 - categorical_accuracy: 0.8750 - val_loss: 0.7398 - val_categorical_crossentropy: 0.7398 - val_categorical_accuracy: 0.7234
# Epoch 142/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5003 - categorical_crossentropy: 0.5003 - categorical_accuracy: 0.8292 - val_loss: 0.7381 - val_categorical_crossentropy: 0.7381 - val_categorical_accuracy: 0.7234
# Epoch 143/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4369 - categorical_crossentropy: 0.4369 - categorical_accuracy: 0.8792 - val_loss: 0.7178 - val_categorical_crossentropy: 0.7178 - val_categorical_accuracy: 0.7447
# Epoch 144/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4851 - categorical_crossentropy: 0.4851 - categorical_accuracy: 0.8333 - val_loss: 0.7247 - val_categorical_crossentropy: 0.7247 - val_categorical_accuracy: 0.7234
# Epoch 145/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4507 - categorical_crossentropy: 0.4507 - categorical_accuracy: 0.8792 - val_loss: 0.7071 - val_categorical_crossentropy: 0.7071 - val_categorical_accuracy: 0.7234
# Epoch 146/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4466 - categorical_crossentropy: 0.4466 - categorical_accuracy: 0.8708 - val_loss: 0.7137 - val_categorical_crossentropy: 0.7137 - val_categorical_accuracy: 0.7234
# Epoch 147/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4641 - categorical_crossentropy: 0.4641 - categorical_accuracy: 0.8458 - val_loss: 0.7296 - val_categorical_crossentropy: 0.7296 - val_categorical_accuracy: 0.7234
# Epoch 148/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4664 - categorical_crossentropy: 0.4664 - categorical_accuracy: 0.8417 - val_loss: 0.7238 - val_categorical_crossentropy: 0.7238 - val_categorical_accuracy: 0.7447
# Epoch 149/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4493 - categorical_crossentropy: 0.4493 - categorical_accuracy: 0.8417 - val_loss: 0.7319 - val_categorical_crossentropy: 0.7319 - val_categorical_accuracy: 0.7447
# Epoch 150/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4936 - categorical_crossentropy: 0.4936 - categorical_accuracy: 0.8375 - val_loss: 0.7484 - val_categorical_crossentropy: 0.7484 - val_categorical_accuracy: 0.7447
# Epoch 151/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4654 - categorical_crossentropy: 0.4654 - categorical_accuracy: 0.8250 - val_loss: 0.7362 - val_categorical_crossentropy: 0.7362 - val_categorical_accuracy: 0.7234
# Epoch 152/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4392 - categorical_crossentropy: 0.4392 - categorical_accuracy: 0.8458 - val_loss: 0.7337 - val_categorical_crossentropy: 0.7337 - val_categorical_accuracy: 0.7660
# Epoch 153/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5042 - categorical_crossentropy: 0.5042 - categorical_accuracy: 0.8208 - val_loss: 0.7601 - val_categorical_crossentropy: 0.7601 - val_categorical_accuracy: 0.7660
# Epoch 154/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4547 - categorical_crossentropy: 0.4547 - categorical_accuracy: 0.8542 - val_loss: 0.7579 - val_categorical_crossentropy: 0.7579 - val_categorical_accuracy: 0.7447
# Epoch 155/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4540 - categorical_crossentropy: 0.4540 - categorical_accuracy: 0.8792 - val_loss: 0.7685 - val_categorical_crossentropy: 0.7685 - val_categorical_accuracy: 0.7021
# Epoch 156/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4577 - categorical_crossentropy: 0.4577 - categorical_accuracy: 0.8625 - val_loss: 0.7603 - val_categorical_crossentropy: 0.7603 - val_categorical_accuracy: 0.7447
# Epoch 157/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4280 - categorical_crossentropy: 0.4280 - categorical_accuracy: 0.8708 - val_loss: 0.7510 - val_categorical_crossentropy: 0.7510 - val_categorical_accuracy: 0.7447
# Epoch 158/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4388 - categorical_crossentropy: 0.4388 - categorical_accuracy: 0.8542 - val_loss: 0.7318 - val_categorical_crossentropy: 0.7318 - val_categorical_accuracy: 0.7021
# Epoch 159/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4530 - categorical_crossentropy: 0.4530 - categorical_accuracy: 0.8708 - val_loss: 0.7249 - val_categorical_crossentropy: 0.7249 - val_categorical_accuracy: 0.6809
# Epoch 160/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4415 - categorical_crossentropy: 0.4415 - categorical_accuracy: 0.8500 - val_loss: 0.7158 - val_categorical_crossentropy: 0.7158 - val_categorical_accuracy: 0.6809
# Epoch 161/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4243 - categorical_crossentropy: 0.4243 - categorical_accuracy: 0.8875 - val_loss: 0.7287 - val_categorical_crossentropy: 0.7287 - val_categorical_accuracy: 0.7234
# Epoch 162/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4318 - categorical_crossentropy: 0.4318 - categorical_accuracy: 0.8542 - val_loss: 0.7269 - val_categorical_crossentropy: 0.7269 - val_categorical_accuracy: 0.7021
# Epoch 163/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4525 - categorical_crossentropy: 0.4525 - categorical_accuracy: 0.8375 - val_loss: 0.7230 - val_categorical_crossentropy: 0.7230 - val_categorical_accuracy: 0.7234
# Epoch 164/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4284 - categorical_crossentropy: 0.4284 - categorical_accuracy: 0.8417 - val_loss: 0.7466 - val_categorical_crossentropy: 0.7466 - val_categorical_accuracy: 0.7447
# Epoch 165/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4357 - categorical_crossentropy: 0.4357 - categorical_accuracy: 0.8625 - val_loss: 0.7234 - val_categorical_crossentropy: 0.7234 - val_categorical_accuracy: 0.7234
# Epoch 166/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4361 - categorical_crossentropy: 0.4361 - categorical_accuracy: 0.8667 - val_loss: 0.7274 - val_categorical_crossentropy: 0.7274 - val_categorical_accuracy: 0.7234
# Epoch 167/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4548 - categorical_crossentropy: 0.4548 - categorical_accuracy: 0.8208 - val_loss: 0.7448 - val_categorical_crossentropy: 0.7448 - val_categorical_accuracy: 0.7021
# Epoch 168/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4615 - categorical_crossentropy: 0.4615 - categorical_accuracy: 0.8208 - val_loss: 0.7558 - val_categorical_crossentropy: 0.7558 - val_categorical_accuracy: 0.7234
# Epoch 169/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4382 - categorical_crossentropy: 0.4382 - categorical_accuracy: 0.8583 - val_loss: 0.7536 - val_categorical_crossentropy: 0.7536 - val_categorical_accuracy: 0.7234
# Epoch 170/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4487 - categorical_crossentropy: 0.4487 - categorical_accuracy: 0.8625 - val_loss: 0.7645 - val_categorical_crossentropy: 0.7645 - val_categorical_accuracy: 0.6809
# Epoch 171/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4410 - categorical_crossentropy: 0.4410 - categorical_accuracy: 0.8417 - val_loss: 0.7606 - val_categorical_crossentropy: 0.7606 - val_categorical_accuracy: 0.7234
# Epoch 172/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4178 - categorical_crossentropy: 0.4178 - categorical_accuracy: 0.8542 - val_loss: 0.7339 - val_categorical_crossentropy: 0.7339 - val_categorical_accuracy: 0.7234
# Epoch 173/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3983 - categorical_crossentropy: 0.3983 - categorical_accuracy: 0.8833 - val_loss: 0.7548 - val_categorical_crossentropy: 0.7548 - val_categorical_accuracy: 0.7021
# Epoch 174/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4369 - categorical_crossentropy: 0.4369 - categorical_accuracy: 0.8542 - val_loss: 0.7729 - val_categorical_crossentropy: 0.7729 - val_categorical_accuracy: 0.7234
# Epoch 175/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4455 - categorical_crossentropy: 0.4455 - categorical_accuracy: 0.8458 - val_loss: 0.7559 - val_categorical_crossentropy: 0.7559 - val_categorical_accuracy: 0.7234
# Epoch 176/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4286 - categorical_crossentropy: 0.4286 - categorical_accuracy: 0.8750 - val_loss: 0.7330 - val_categorical_crossentropy: 0.7330 - val_categorical_accuracy: 0.7234
# Epoch 177/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4187 - categorical_crossentropy: 0.4187 - categorical_accuracy: 0.8792 - val_loss: 0.7124 - val_categorical_crossentropy: 0.7124 - val_categorical_accuracy: 0.7021
# Epoch 178/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4411 - categorical_crossentropy: 0.4411 - categorical_accuracy: 0.8458 - val_loss: 0.7196 - val_categorical_crossentropy: 0.7196 - val_categorical_accuracy: 0.7234
# Epoch 179/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4224 - categorical_crossentropy: 0.4224 - categorical_accuracy: 0.8583 - val_loss: 0.7144 - val_categorical_crossentropy: 0.7144 - val_categorical_accuracy: 0.7021
# Epoch 180/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4196 - categorical_crossentropy: 0.4196 - categorical_accuracy: 0.8833 - val_loss: 0.7157 - val_categorical_crossentropy: 0.7157 - val_categorical_accuracy: 0.7021
# Epoch 181/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3843 - categorical_crossentropy: 0.3843 - categorical_accuracy: 0.8792 - val_loss: 0.6960 - val_categorical_crossentropy: 0.6960 - val_categorical_accuracy: 0.7447
# Epoch 182/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4082 - categorical_crossentropy: 0.4082 - categorical_accuracy: 0.8875 - val_loss: 0.6970 - val_categorical_crossentropy: 0.6970 - val_categorical_accuracy: 0.7234
# Epoch 183/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4171 - categorical_crossentropy: 0.4171 - categorical_accuracy: 0.8917 - val_loss: 0.6941 - val_categorical_crossentropy: 0.6941 - val_categorical_accuracy: 0.7021
# Epoch 184/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3940 - categorical_crossentropy: 0.3940 - categorical_accuracy: 0.8833 - val_loss: 0.7063 - val_categorical_crossentropy: 0.7063 - val_categorical_accuracy: 0.7234
# Epoch 185/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4017 - categorical_crossentropy: 0.4017 - categorical_accuracy: 0.8875 - val_loss: 0.7234 - val_categorical_crossentropy: 0.7234 - val_categorical_accuracy: 0.7021
# Epoch 186/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4367 - categorical_crossentropy: 0.4367 - categorical_accuracy: 0.8708 - val_loss: 0.7090 - val_categorical_crossentropy: 0.7090 - val_categorical_accuracy: 0.7234
# Epoch 187/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4290 - categorical_crossentropy: 0.4290 - categorical_accuracy: 0.8667 - val_loss: 0.7185 - val_categorical_crossentropy: 0.7185 - val_categorical_accuracy: 0.7447
# Epoch 188/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4034 - categorical_crossentropy: 0.4034 - categorical_accuracy: 0.8875 - val_loss: 0.7127 - val_categorical_crossentropy: 0.7127 - val_categorical_accuracy: 0.7447
# Epoch 189/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4067 - categorical_crossentropy: 0.4067 - categorical_accuracy: 0.8667 - val_loss: 0.7196 - val_categorical_crossentropy: 0.7196 - val_categorical_accuracy: 0.7234
# Epoch 190/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4162 - categorical_crossentropy: 0.4162 - categorical_accuracy: 0.8750 - val_loss: 0.6971 - val_categorical_crossentropy: 0.6971 - val_categorical_accuracy: 0.7447
# Epoch 191/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4092 - categorical_crossentropy: 0.4092 - categorical_accuracy: 0.8792 - val_loss: 0.6795 - val_categorical_crossentropy: 0.6795 - val_categorical_accuracy: 0.7447
# Epoch 192/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4370 - categorical_crossentropy: 0.4370 - categorical_accuracy: 0.8625 - val_loss: 0.6999 - val_categorical_crossentropy: 0.6999 - val_categorical_accuracy: 0.7447
# Epoch 193/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4080 - categorical_crossentropy: 0.4080 - categorical_accuracy: 0.8500 - val_loss: 0.6940 - val_categorical_crossentropy: 0.6940 - val_categorical_accuracy: 0.7021
# Epoch 194/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3779 - categorical_crossentropy: 0.3779 - categorical_accuracy: 0.9000 - val_loss: 0.6902 - val_categorical_crossentropy: 0.6902 - val_categorical_accuracy: 0.7447
# Epoch 195/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4143 - categorical_crossentropy: 0.4143 - categorical_accuracy: 0.8708 - val_loss: 0.6993 - val_categorical_crossentropy: 0.6993 - val_categorical_accuracy: 0.7660
# ...
# Epoch 236/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1633 - categorical_crossentropy: 0.1633 - categorical_accuracy: 0.9750 - val_loss: 0.5279 - val_categorical_crossentropy: 0.5279 - val_categorical_accuracy: 0.7872
# Epoch 237/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1667 - categorical_crossentropy: 0.1667 - categorical_accuracy: 0.9667 - val_loss: 0.5115 - val_categorical_crossentropy: 0.5115 - val_categorical_accuracy: 0.7660
# Epoch 238/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1446 - categorical_crossentropy: 0.1446 - categorical_accuracy: 0.9750 - val_loss: 0.5103 - val_categorical_crossentropy: 0.5103 - val_categorical_accuracy: 0.7660
# Epoch 239/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1585 - categorical_crossentropy: 0.1585 - categorical_accuracy: 0.9583 - val_loss: 0.5068 - val_categorical_crossentropy: 0.5068 - val_categorical_accuracy: 0.7872
# Epoch 240/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1643 - categorical_crossentropy: 0.1643 - categorical_accuracy: 0.9625 - val_loss: 0.5739 - val_categorical_crossentropy: 0.5739 - val_categorical_accuracy: 0.7447
# Epoch 241/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1436 - categorical_crossentropy: 0.1436 - categorical_accuracy: 0.9667 - val_loss: 0.5811 - val_categorical_crossentropy: 0.5811 - val_categorical_accuracy: 0.7447
# Epoch 242/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1519 - categorical_crossentropy: 0.1519 - categorical_accuracy: 0.9500 - val_loss: 0.5770 - val_categorical_crossentropy: 0.5770 - val_categorical_accuracy: 0.7234
# Epoch 243/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1509 - categorical_crossentropy: 0.1509 - categorical_accuracy: 0.9792 - val_loss: 0.5919 - val_categorical_crossentropy: 0.5919 - val_categorical_accuracy: 0.7234
# Epoch 244/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1705 - categorical_crossentropy: 0.1705 - categorical_accuracy: 0.9542 - val_loss: 0.5676 - val_categorical_crossentropy: 0.5676 - val_categorical_accuracy: 0.7447
# Epoch 245/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1651 - categorical_crossentropy: 0.1651 - categorical_accuracy: 0.9583 - val_loss: 0.5421 - val_categorical_crossentropy: 0.5421 - val_categorical_accuracy: 0.7660
# Epoch 246/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1640 - categorical_crossentropy: 0.1640 - categorical_accuracy: 0.9625 - val_loss: 0.5198 - val_categorical_crossentropy: 0.5198 - val_categorical_accuracy: 0.7447
# Epoch 247/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1496 - categorical_crossentropy: 0.1496 - categorical_accuracy: 0.9625 - val_loss: 0.5234 - val_categorical_crossentropy: 0.5234 - val_categorical_accuracy: 0.7234
# Epoch 248/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1547 - categorical_crossentropy: 0.1547 - categorical_accuracy: 0.9667 - val_loss: 0.5731 - val_categorical_crossentropy: 0.5731 - val_categorical_accuracy: 0.7234
# Epoch 249/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1658 - categorical_crossentropy: 0.1658 - categorical_accuracy: 0.9667 - val_loss: 0.5182 - val_categorical_crossentropy: 0.5182 - val_categorical_accuracy: 0.7447
# Epoch 250/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1516 - categorical_crossentropy: 0.1516 - categorical_accuracy: 0.9625 - val_loss: 0.4870 - val_categorical_crossentropy: 0.4870 - val_categorical_accuracy: 0.8085
# Epoch 251/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1417 - categorical_crossentropy: 0.1417 - categorical_accuracy: 0.9833 - val_loss: 0.5223 - val_categorical_crossentropy: 0.5223 - val_categorical_accuracy: 0.7234
# Epoch 252/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1633 - categorical_crossentropy: 0.1633 - categorical_accuracy: 0.9667 - val_loss: 0.5464 - val_categorical_crossentropy: 0.5464 - val_categorical_accuracy: 0.7234
# Epoch 253/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1307 - categorical_crossentropy: 0.1307 - categorical_accuracy: 0.9875 - val_loss: 0.5005 - val_categorical_crossentropy: 0.5005 - val_categorical_accuracy: 0.7447
# Epoch 254/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1559 - categorical_crossentropy: 0.1559 - categorical_accuracy: 0.9625 - val_loss: 0.5101 - val_categorical_crossentropy: 0.5101 - val_categorical_accuracy: 0.7447
# Epoch 255/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1458 - categorical_crossentropy: 0.1458 - categorical_accuracy: 0.9792 - val_loss: 0.5056 - val_categorical_crossentropy: 0.5056 - val_categorical_accuracy: 0.7660
# Epoch 256/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1401 - categorical_crossentropy: 0.1401 - categorical_accuracy: 0.9792 - val_loss: 0.5226 - val_categorical_crossentropy: 0.5226 - val_categorical_accuracy: 0.7447
# Epoch 257/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1510 - categorical_crossentropy: 0.1510 - categorical_accuracy: 0.9583 - val_loss: 0.5700 - val_categorical_crossentropy: 0.5700 - val_categorical_accuracy: 0.7447
# Epoch 258/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1450 - categorical_crossentropy: 0.1450 - categorical_accuracy: 0.9833 - val_loss: 0.5629 - val_categorical_crossentropy: 0.5629 - val_categorical_accuracy: 0.7234
# Epoch 259/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1278 - categorical_crossentropy: 0.1278 - categorical_accuracy: 0.9792 - val_loss: 0.5667 - val_categorical_crossentropy: 0.5667 - val_categorical_accuracy: 0.7660
# Epoch 260/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1249 - categorical_crossentropy: 0.1249 - categorical_accuracy: 0.9875 - val_loss: 0.5559 - val_categorical_crossentropy: 0.5559 - val_categorical_accuracy: 0.7872
# Epoch 261/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1397 - categorical_crossentropy: 0.1397 - categorical_accuracy: 0.9625 - val_loss: 0.5605 - val_categorical_crossentropy: 0.5605 - val_categorical_accuracy: 0.7660
# Epoch 262/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1364 - categorical_crossentropy: 0.1364 - categorical_accuracy: 0.9750 - val_loss: 0.5534 - val_categorical_crossentropy: 0.5534 - val_categorical_accuracy: 0.7447
# Epoch 263/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1317 - categorical_crossentropy: 0.1317 - categorical_accuracy: 0.9750 - val_loss: 0.5792 - val_categorical_crossentropy: 0.5792 - val_categorical_accuracy: 0.7447
# Epoch 264/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1246 - categorical_crossentropy: 0.1246 - categorical_accuracy: 0.9750 - val_loss: 0.5871 - val_categorical_crossentropy: 0.5871 - val_categorical_accuracy: 0.7447
# Epoch 265/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1801 - categorical_crossentropy: 0.1801 - categorical_accuracy: 0.9625 - val_loss: 0.5873 - val_categorical_crossentropy: 0.5873 - val_categorical_accuracy: 0.7021
# Epoch 266/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1438 - categorical_crossentropy: 0.1438 - categorical_accuracy: 0.9708 - val_loss: 0.5583 - val_categorical_crossentropy: 0.5583 - val_categorical_accuracy: 0.7660
# Epoch 267/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1387 - categorical_crossentropy: 0.1387 - categorical_accuracy: 0.9667 - val_loss: 0.5551 - val_categorical_crossentropy: 0.5551 - val_categorical_accuracy: 0.7872
# Epoch 268/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1416 - categorical_crossentropy: 0.1416 - categorical_accuracy: 0.9750 - val_loss: 0.5412 - val_categorical_crossentropy: 0.5412 - val_categorical_accuracy: 0.7447
# Epoch 269/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1366 - categorical_crossentropy: 0.1366 - categorical_accuracy: 0.9708 - val_loss: 0.5309 - val_categorical_crossentropy: 0.5309 - val_categorical_accuracy: 0.7234
# Epoch 270/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1308 - categorical_crossentropy: 0.1308 - categorical_accuracy: 0.9792 - val_loss: 0.5520 - val_categorical_crossentropy: 0.5520 - val_categorical_accuracy: 0.7447
# Epoch 271/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1486 - categorical_crossentropy: 0.1486 - categorical_accuracy: 0.9667 - val_loss: 0.5841 - val_categorical_crossentropy: 0.5841 - val_categorical_accuracy: 0.7234
# Epoch 272/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1350 - categorical_crossentropy: 0.1350 - categorical_accuracy: 0.9792 - val_loss: 0.5331 - val_categorical_crossentropy: 0.5331 - val_categorical_accuracy: 0.7447
# Epoch 273/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1424 - categorical_crossentropy: 0.1424 - categorical_accuracy: 0.9833 - val_loss: 0.5327 - val_categorical_crossentropy: 0.5327 - val_categorical_accuracy: 0.7234
# Epoch 274/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1396 - categorical_crossentropy: 0.1396 - categorical_accuracy: 0.9667 - val_loss: 0.5551 - val_categorical_crossentropy: 0.5551 - val_categorical_accuracy: 0.7872
# Epoch 275/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1312 - categorical_crossentropy: 0.1312 - categorical_accuracy: 0.9708 - val_loss: 0.5405 - val_categorical_crossentropy: 0.5405 - val_categorical_accuracy: 0.7234
# Epoch 276/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1346 - categorical_crossentropy: 0.1346 - categorical_accuracy: 0.9667 - val_loss: 0.5542 - val_categorical_crossentropy: 0.5542 - val_categorical_accuracy: 0.7234
# Epoch 277/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1331 - categorical_crossentropy: 0.1331 - categorical_accuracy: 0.9625 - val_loss: 0.5535 - val_categorical_crossentropy: 0.5535 - val_categorical_accuracy: 0.7234
# Epoch 278/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1336 - categorical_crossentropy: 0.1336 - categorical_accuracy: 0.9833 - val_loss: 0.5536 - val_categorical_crossentropy: 0.5536 - val_categorical_accuracy: 0.7234
# Epoch 279/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1295 - categorical_crossentropy: 0.1295 - categorical_accuracy: 0.9792 - val_loss: 0.5514 - val_categorical_crossentropy: 0.5514 - val_categorical_accuracy: 0.7447
# Epoch 280/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1400 - categorical_crossentropy: 0.1400 - categorical_accuracy: 0.9833 - val_loss: 0.5359 - val_categorical_crossentropy: 0.5359 - val_categorical_accuracy: 0.7872
# Epoch 281/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1213 - categorical_crossentropy: 0.1213 - categorical_accuracy: 0.9917 - val_loss: 0.5887 - val_categorical_crossentropy: 0.5887 - val_categorical_accuracy: 0.7447
# Epoch 282/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1408 - categorical_crossentropy: 0.1408 - categorical_accuracy: 0.9667 - val_loss: 0.5940 - val_categorical_crossentropy: 0.5940 - val_categorical_accuracy: 0.7447
# Epoch 283/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1583 - categorical_crossentropy: 0.1583 - categorical_accuracy: 0.9500 - val_loss: 0.6120 - val_categorical_crossentropy: 0.6120 - val_categorical_accuracy: 0.7660
# Epoch 284/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1467 - categorical_crossentropy: 0.1467 - categorical_accuracy: 0.9625 - val_loss: 0.5741 - val_categorical_crossentropy: 0.5741 - val_categorical_accuracy: 0.7872
# Epoch 285/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1132 - categorical_crossentropy: 0.1132 - categorical_accuracy: 0.9917 - val_loss: 0.5368 - val_categorical_crossentropy: 0.5368 - val_categorical_accuracy: 0.7872
# Epoch 286/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1553 - categorical_crossentropy: 0.1553 - categorical_accuracy: 0.9500 - val_loss: 0.5752 - val_categorical_crossentropy: 0.5752 - val_categorical_accuracy: 0.7660
# Epoch 287/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1429 - categorical_crossentropy: 0.1429 - categorical_accuracy: 0.9750 - val_loss: 0.6058 - val_categorical_crossentropy: 0.6058 - val_categorical_accuracy: 0.7021
# Epoch 288/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1461 - categorical_crossentropy: 0.1461 - categorical_accuracy: 0.9708 - val_loss: 0.6434 - val_categorical_crossentropy: 0.6434 - val_categorical_accuracy: 0.6809
# Epoch 289/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1369 - categorical_crossentropy: 0.1369 - categorical_accuracy: 0.9708 - val_loss: 0.6468 - val_categorical_crossentropy: 0.6468 - val_categorical_accuracy: 0.7234
# Epoch 290/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1482 - categorical_crossentropy: 0.1482 - categorical_accuracy: 0.9667 - val_loss: 0.5964 - val_categorical_crossentropy: 0.5964 - val_categorical_accuracy: 0.7234
# Epoch 291/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1182 - categorical_crossentropy: 0.1182 - categorical_accuracy: 0.9792 - val_loss: 0.5435 - val_categorical_crossentropy: 0.5435 - val_categorical_accuracy: 0.7234
# Epoch 292/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1502 - categorical_crossentropy: 0.1502 - categorical_accuracy: 0.9625 - val_loss: 0.5712 - val_categorical_crossentropy: 0.5712 - val_categorical_accuracy: 0.7234
# Epoch 293/300
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1288 - categorical_crossentropy: 0.1288 - categorical_accuracy: 0.9750 - val_loss: 0.6304 - val_categorical_crossentropy: 0.6304 - val_categorical_accuracy: 0.7234
# Epoch 294/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1251 - categorical_crossentropy: 0.1251 - categorical_accuracy: 0.9875 - val_loss: 0.5886 - val_categorical_crossentropy: 0.5886 - val_categorical_accuracy: 0.7021
# Epoch 295/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1204 - categorical_crossentropy: 0.1204 - categorical_accuracy: 0.9667 - val_loss: 0.5744 - val_categorical_crossentropy: 0.5744 - val_categorical_accuracy: 0.7234
# Epoch 296/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1390 - categorical_crossentropy: 0.1390 - categorical_accuracy: 0.9667 - val_loss: 0.5572 - val_categorical_crossentropy: 0.5572 - val_categorical_accuracy: 0.7234
# Epoch 297/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1315 - categorical_crossentropy: 0.1315 - categorical_accuracy: 0.9708 - val_loss: 0.6109 - val_categorical_crossentropy: 0.6109 - val_categorical_accuracy: 0.7234
# Epoch 298/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1265 - categorical_crossentropy: 0.1265 - categorical_accuracy: 0.9750 - val_loss: 0.5937 - val_categorical_crossentropy: 0.5937 - val_categorical_accuracy: 0.7234
# Epoch 299/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1316 - categorical_crossentropy: 0.1316 - categorical_accuracy: 0.9875 - val_loss: 0.5743 - val_categorical_crossentropy: 0.5743 - val_categorical_accuracy: 0.7872
# Epoch 300/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1362 - categorical_crossentropy: 0.1362 - categorical_accuracy: 0.9750 - val_loss: 0.5624 - val_categorical_crossentropy: 0.5624 - val_categorical_accuracy: 0.7660
#
# # Evaluate on test data
# 9/9 [==============================] - 1s 84ms/step - loss: 2.6982 - categorical_crossentropy: 2.6982 - categorical_accuracy: 0.2535
# test loss, test acc: [2.6981772581736245, 2.698177, 0.2534722]
