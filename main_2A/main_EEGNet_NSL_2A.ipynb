# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_2A/main_EEGNet_NSL_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (109/109), done.
# Receiving objects: 100% (422/422), 1.69 GiB | 33.28 MiB/s, done.
# remote: Total 422 (delta 67), reused 0 (delta 0), pack-reused 313
# Resolving deltas: 100% (195/195), done.
# Checking out files: 100% (98/98), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter

# !pip install neural_structured_learning
import neural_structured_learning as nsl
import tensorflow as tf

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting neural_structured_learning
#   Downloading https://files.pythonhosted.org/packages/08/2e/22b1385d7d601ad0c81457a5b66b3bb6f3c400348c62ea3f07a5fc1b13bc/neural_structured_learning-1.1.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 6.6MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.17.5)
# Installing collected packages: neural-structured-learning
# Successfully installed neural-structured-learning-1.1.0
# Using TensorFlow backend.

# %%
# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()

# Initialize parameter
h_cut = [24]
drop_out = [0.25]
k_len = [32, 64, 128]
n_epochs = 100

out_f_name = 'acc_NSL_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_accuracy = zeros([nsub, nfilt,ndrop,nkl])

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])

for sub_idx, x in enumerate(range(1,10)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
      y_tr = y_tr.flatten() 
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered 

      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val       = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, 
                                               highcut=40, fs=250, order=4)  
        
      # tril_filtered = tril_filtered.transpose()
      X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test      = X_test.reshape(X_test.shape[0], kernels, chans, samples)

      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          print(id_kl, id_d)
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

          adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.5, adv_grad_norm='infinity')
          adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)
  
          # compile the model and set the optimizers
          adv_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
          batch_size = 32

          X_train = tf.cast(X_train, tf.float32)
          X_test = tf.cast(X_test, tf.float32)
          X_val = tf.cast(X_val, tf.float32)


          train_data = tf.data.Dataset.from_tensor_slices({'input': X_train, 'label': Y_train}).batch(batch_size)
          val_data = tf.data.Dataset.from_tensor_slices({'input': X_val, 'label': Y_val}).batch(batch_size)
          test_data = tf.data.Dataset.from_tensor_slices({'input': X_test, 'label': Y_test}).batch(batch_size)

          val_steps = X_val.shape[0] // batch_size

  
          # adv_model.fit(train_data, validation_data=val_data, validation_steps=None, epochs=500, verbose=1)

          history = adv_model.fit(train_data, validation_data=val_data, 
                                  validation_steps=None, epochs=n_epochs, verbose=1)
          
          print('\n# Evaluate on test data')
          results = adv_model.evaluate(test_data)
          print('test loss, test acc:', results)

          loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          categorical_accuracy[sub_idx,h_indx,id_d, id_kl] = results[2]

          del model

#           del train_data, val_data, test_data

# #           from keras import backend as K 
#           K.clear_session()

np.save(out_f_name, categorical_accuracy)
# Out:
# acc_NSL_EEGNet_epochs_100_filter_[24]_drop_[0.25]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288,)
# (240, 22, 750)
# (240,)
# (47, 22, 750)
# (47,)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# 0 0
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/100
# 8/8 [==============================] - 1s 65ms/step - loss: 1.3879 - categorical_crossentropy: 1.3879 - categorical_accuracy: 0.2667 - val_loss: 1.3881 - val_categorical_crossentropy: 1.3881 - val_categorical_accuracy: 0.2340
# Epoch 2/100
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3555 - categorical_crossentropy: 1.3555 - categorical_accuracy: 0.3500 - val_loss: 1.3868 - val_categorical_crossentropy: 1.3868 - val_categorical_accuracy: 0.2340
# Epoch 3/100
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3334 - categorical_crossentropy: 1.3334 - categorical_accuracy: 0.4083 - val_loss: 1.3841 - val_categorical_crossentropy: 1.3841 - val_categorical_accuracy: 0.2766
# Epoch 4/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.2868 - categorical_crossentropy: 1.2868 - categorical_accuracy: 0.4500 - val_loss: 1.3786 - val_categorical_crossentropy: 1.3786 - val_categorical_accuracy: 0.3191
# Epoch 5/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.2290 - categorical_crossentropy: 1.2290 - categorical_accuracy: 0.5917 - val_loss: 1.3687 - val_categorical_crossentropy: 1.3687 - val_categorical_accuracy: 0.2979
# Epoch 6/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.1708 - categorical_crossentropy: 1.1708 - categorical_accuracy: 0.6292 - val_loss: 1.3535 - val_categorical_crossentropy: 1.3535 - val_categorical_accuracy: 0.3191
# Epoch 7/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.0932 - categorical_crossentropy: 1.0932 - categorical_accuracy: 0.6500 - val_loss: 1.3349 - val_categorical_crossentropy: 1.3349 - val_categorical_accuracy: 0.3191
# Epoch 8/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0012 - categorical_crossentropy: 1.0012 - categorical_accuracy: 0.6458 - val_loss: 1.3132 - val_categorical_crossentropy: 1.3132 - val_categorical_accuracy: 0.3191
# Epoch 9/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9404 - categorical_crossentropy: 0.9404 - categorical_accuracy: 0.6917 - val_loss: 1.2927 - val_categorical_crossentropy: 1.2927 - val_categorical_accuracy: 0.2766
# Epoch 10/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.9055 - categorical_crossentropy: 0.9055 - categorical_accuracy: 0.6583 - val_loss: 1.2719 - val_categorical_crossentropy: 1.2719 - val_categorical_accuracy: 0.2766
# Epoch 11/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8483 - categorical_crossentropy: 0.8483 - categorical_accuracy: 0.6958 - val_loss: 1.2619 - val_categorical_crossentropy: 1.2619 - val_categorical_accuracy: 0.2766
# Epoch 12/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8208 - categorical_crossentropy: 0.8208 - categorical_accuracy: 0.7042 - val_loss: 1.2552 - val_categorical_crossentropy: 1.2552 - val_categorical_accuracy: 0.2766
# Epoch 13/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8089 - categorical_crossentropy: 0.8089 - categorical_accuracy: 0.6583 - val_loss: 1.2552 - val_categorical_crossentropy: 1.2552 - val_categorical_accuracy: 0.2766
# Epoch 14/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7953 - categorical_crossentropy: 0.7953 - categorical_accuracy: 0.6917 - val_loss: 1.2590 - val_categorical_crossentropy: 1.2590 - val_categorical_accuracy: 0.2766
# Epoch 15/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7777 - categorical_crossentropy: 0.7777 - categorical_accuracy: 0.7000 - val_loss: 1.2595 - val_categorical_crossentropy: 1.2595 - val_categorical_accuracy: 0.2553
# Epoch 16/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7502 - categorical_crossentropy: 0.7502 - categorical_accuracy: 0.7333 - val_loss: 1.2497 - val_categorical_crossentropy: 1.2497 - val_categorical_accuracy: 0.2766
# Epoch 17/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7341 - categorical_crossentropy: 0.7341 - categorical_accuracy: 0.7542 - val_loss: 1.2348 - val_categorical_crossentropy: 1.2348 - val_categorical_accuracy: 0.2766
# Epoch 18/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7264 - categorical_crossentropy: 0.7264 - categorical_accuracy: 0.7500 - val_loss: 1.2280 - val_categorical_crossentropy: 1.2280 - val_categorical_accuracy: 0.2766
# Epoch 19/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7195 - categorical_crossentropy: 0.7195 - categorical_accuracy: 0.7708 - val_loss: 1.2262 - val_categorical_crossentropy: 1.2262 - val_categorical_accuracy: 0.2766
# Epoch 20/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7342 - categorical_crossentropy: 0.7342 - categorical_accuracy: 0.7583 - val_loss: 1.2279 - val_categorical_crossentropy: 1.2279 - val_categorical_accuracy: 0.2766
# Epoch 21/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7111 - categorical_crossentropy: 0.7111 - categorical_accuracy: 0.7375 - val_loss: 1.2173 - val_categorical_crossentropy: 1.2173 - val_categorical_accuracy: 0.2766
# Epoch 22/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6666 - categorical_crossentropy: 0.6666 - categorical_accuracy: 0.8042 - val_loss: 1.2044 - val_categorical_crossentropy: 1.2044 - val_categorical_accuracy: 0.2766
# Epoch 23/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6908 - categorical_crossentropy: 0.6908 - categorical_accuracy: 0.7875 - val_loss: 1.2022 - val_categorical_crossentropy: 1.2022 - val_categorical_accuracy: 0.2979
# Epoch 24/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6771 - categorical_crossentropy: 0.6771 - categorical_accuracy: 0.7875 - val_loss: 1.1941 - val_categorical_crossentropy: 1.1941 - val_categorical_accuracy: 0.3404
# Epoch 25/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6811 - categorical_crossentropy: 0.6811 - categorical_accuracy: 0.7833 - val_loss: 1.1854 - val_categorical_crossentropy: 1.1854 - val_categorical_accuracy: 0.3617
# Epoch 26/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6459 - categorical_crossentropy: 0.6459 - categorical_accuracy: 0.8500 - val_loss: 1.1766 - val_categorical_crossentropy: 1.1766 - val_categorical_accuracy: 0.3617
# Epoch 27/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6498 - categorical_crossentropy: 0.6498 - categorical_accuracy: 0.8417 - val_loss: 1.1813 - val_categorical_crossentropy: 1.1813 - val_categorical_accuracy: 0.3404
# Epoch 28/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6492 - categorical_crossentropy: 0.6492 - categorical_accuracy: 0.8042 - val_loss: 1.1617 - val_categorical_crossentropy: 1.1617 - val_categorical_accuracy: 0.4043
# Epoch 29/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6426 - categorical_crossentropy: 0.6426 - categorical_accuracy: 0.8000 - val_loss: 1.1417 - val_categorical_crossentropy: 1.1417 - val_categorical_accuracy: 0.4043
# Epoch 30/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6107 - categorical_crossentropy: 0.6107 - categorical_accuracy: 0.8458 - val_loss: 1.1029 - val_categorical_crossentropy: 1.1029 - val_categorical_accuracy: 0.4043
# Epoch 31/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6557 - categorical_crossentropy: 0.6557 - categorical_accuracy: 0.8042 - val_loss: 1.0830 - val_categorical_crossentropy: 1.0830 - val_categorical_accuracy: 0.4043
# Epoch 32/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6225 - categorical_crossentropy: 0.6225 - categorical_accuracy: 0.8333 - val_loss: 1.0833 - val_categorical_crossentropy: 1.0833 - val_categorical_accuracy: 0.4255
# Epoch 33/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6006 - categorical_crossentropy: 0.6006 - categorical_accuracy: 0.8375 - val_loss: 1.0652 - val_categorical_crossentropy: 1.0652 - val_categorical_accuracy: 0.4255
# Epoch 34/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6129 - categorical_crossentropy: 0.6129 - categorical_accuracy: 0.8500 - val_loss: 1.0610 - val_categorical_crossentropy: 1.0610 - val_categorical_accuracy: 0.4255
# Epoch 35/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6114 - categorical_crossentropy: 0.6114 - categorical_accuracy: 0.8208 - val_loss: 1.0527 - val_categorical_crossentropy: 1.0527 - val_categorical_accuracy: 0.4681
# Epoch 36/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6107 - categorical_crossentropy: 0.6107 - categorical_accuracy: 0.8083 - val_loss: 1.0380 - val_categorical_crossentropy: 1.0380 - val_categorical_accuracy: 0.4468
# Epoch 37/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6254 - categorical_crossentropy: 0.6254 - categorical_accuracy: 0.7917 - val_loss: 1.0289 - val_categorical_crossentropy: 1.0289 - val_categorical_accuracy: 0.4681
# Epoch 38/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6031 - categorical_crossentropy: 0.6031 - categorical_accuracy: 0.8250 - val_loss: 1.0049 - val_categorical_crossentropy: 1.0049 - val_categorical_accuracy: 0.4894
# Epoch 39/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5828 - categorical_crossentropy: 0.5828 - categorical_accuracy: 0.8250 - val_loss: 0.9946 - val_categorical_crossentropy: 0.9946 - val_categorical_accuracy: 0.5532
# Epoch 40/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5794 - categorical_crossentropy: 0.5794 - categorical_accuracy: 0.8208 - val_loss: 0.9802 - val_categorical_crossentropy: 0.9802 - val_categorical_accuracy: 0.5106
# Epoch 41/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5778 - categorical_crossentropy: 0.5778 - categorical_accuracy: 0.8417 - val_loss: 0.9551 - val_categorical_crossentropy: 0.9551 - val_categorical_accuracy: 0.5319
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5859 - categorical_crossentropy: 0.5859 - categorical_accuracy: 0.8208 - val_loss: 0.9368 - val_categorical_crossentropy: 0.9368 - val_categorical_accuracy: 0.5319
# Epoch 43/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5668 - categorical_crossentropy: 0.5668 - categorical_accuracy: 0.8625 - val_loss: 0.9375 - val_categorical_crossentropy: 0.9375 - val_categorical_accuracy: 0.5957
# Epoch 44/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5623 - categorical_crossentropy: 0.5623 - categorical_accuracy: 0.8542 - val_loss: 0.9258 - val_categorical_crossentropy: 0.9258 - val_categorical_accuracy: 0.5319
# Epoch 45/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5631 - categorical_crossentropy: 0.5631 - categorical_accuracy: 0.8417 - val_loss: 0.9167 - val_categorical_crossentropy: 0.9167 - val_categorical_accuracy: 0.5745
# Epoch 46/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5615 - categorical_crossentropy: 0.5615 - categorical_accuracy: 0.8625 - val_loss: 0.9024 - val_categorical_crossentropy: 0.9024 - val_categorical_accuracy: 0.6170
# Epoch 47/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5636 - categorical_crossentropy: 0.5636 - categorical_accuracy: 0.8542 - val_loss: 0.8959 - val_categorical_crossentropy: 0.8959 - val_categorical_accuracy: 0.5957
# Epoch 48/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5459 - categorical_crossentropy: 0.5459 - categorical_accuracy: 0.8458 - val_loss: 0.8949 - val_categorical_crossentropy: 0.8949 - val_categorical_accuracy: 0.5957
# Epoch 49/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5487 - categorical_crossentropy: 0.5487 - categorical_accuracy: 0.8500 - val_loss: 0.8853 - val_categorical_crossentropy: 0.8853 - val_categorical_accuracy: 0.6809
# Epoch 50/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5408 - categorical_crossentropy: 0.5408 - categorical_accuracy: 0.8542 - val_loss: 0.8801 - val_categorical_crossentropy: 0.8801 - val_categorical_accuracy: 0.6809
# Epoch 51/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5389 - categorical_crossentropy: 0.5389 - categorical_accuracy: 0.8500 - val_loss: 0.8809 - val_categorical_crossentropy: 0.8809 - val_categorical_accuracy: 0.6596
# Epoch 52/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5489 - categorical_crossentropy: 0.5489 - categorical_accuracy: 0.8458 - val_loss: 0.9071 - val_categorical_crossentropy: 0.9071 - val_categorical_accuracy: 0.6596
# Epoch 53/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5526 - categorical_crossentropy: 0.5526 - categorical_accuracy: 0.8542 - val_loss: 0.9064 - val_categorical_crossentropy: 0.9064 - val_categorical_accuracy: 0.6809
# Epoch 54/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5254 - categorical_crossentropy: 0.5254 - categorical_accuracy: 0.8542 - val_loss: 0.8872 - val_categorical_crossentropy: 0.8872 - val_categorical_accuracy: 0.6809
# Epoch 55/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5290 - categorical_crossentropy: 0.5290 - categorical_accuracy: 0.8708 - val_loss: 0.8896 - val_categorical_crossentropy: 0.8896 - val_categorical_accuracy: 0.6809
# Epoch 56/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5226 - categorical_crossentropy: 0.5226 - categorical_accuracy: 0.8833 - val_loss: 0.8798 - val_categorical_crossentropy: 0.8798 - val_categorical_accuracy: 0.6170
# Epoch 57/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5172 - categorical_crossentropy: 0.5172 - categorical_accuracy: 0.8583 - val_loss: 0.8513 - val_categorical_crossentropy: 0.8513 - val_categorical_accuracy: 0.7021
# Epoch 58/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5199 - categorical_crossentropy: 0.5199 - categorical_accuracy: 0.8708 - val_loss: 0.8449 - val_categorical_crossentropy: 0.8449 - val_categorical_accuracy: 0.6809
# Epoch 59/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5306 - categorical_crossentropy: 0.5306 - categorical_accuracy: 0.8667 - val_loss: 0.8447 - val_categorical_crossentropy: 0.8447 - val_categorical_accuracy: 0.6809
# Epoch 60/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5219 - categorical_crossentropy: 0.5219 - categorical_accuracy: 0.8750 - val_loss: 0.8294 - val_categorical_crossentropy: 0.8294 - val_categorical_accuracy: 0.7234
# Epoch 61/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5102 - categorical_crossentropy: 0.5102 - categorical_accuracy: 0.9042 - val_loss: 0.8342 - val_categorical_crossentropy: 0.8342 - val_categorical_accuracy: 0.7234
# Epoch 62/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5033 - categorical_crossentropy: 0.5033 - categorical_accuracy: 0.8833 - val_loss: 0.8314 - val_categorical_crossentropy: 0.8314 - val_categorical_accuracy: 0.7447
# Epoch 63/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5368 - categorical_crossentropy: 0.5368 - categorical_accuracy: 0.8292 - val_loss: 0.8281 - val_categorical_crossentropy: 0.8281 - val_categorical_accuracy: 0.7234
# Epoch 64/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5109 - categorical_crossentropy: 0.5109 - categorical_accuracy: 0.8958 - val_loss: 0.8423 - val_categorical_crossentropy: 0.8423 - val_categorical_accuracy: 0.6383
# Epoch 65/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5053 - categorical_crossentropy: 0.5053 - categorical_accuracy: 0.8625 - val_loss: 0.8285 - val_categorical_crossentropy: 0.8285 - val_categorical_accuracy: 0.7234
# Epoch 66/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4732 - categorical_crossentropy: 0.4732 - categorical_accuracy: 0.9083 - val_loss: 0.8287 - val_categorical_crossentropy: 0.8287 - val_categorical_accuracy: 0.7234
# Epoch 67/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4779 - categorical_crossentropy: 0.4779 - categorical_accuracy: 0.9167 - val_loss: 0.8247 - val_categorical_crossentropy: 0.8247 - val_categorical_accuracy: 0.7234
# Epoch 68/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4978 - categorical_crossentropy: 0.4978 - categorical_accuracy: 0.8833 - val_loss: 0.8291 - val_categorical_crossentropy: 0.8291 - val_categorical_accuracy: 0.7021
# Epoch 69/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5108 - categorical_crossentropy: 0.5108 - categorical_accuracy: 0.8542 - val_loss: 0.8457 - val_categorical_crossentropy: 0.8457 - val_categorical_accuracy: 0.5745
# Epoch 70/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4734 - categorical_crossentropy: 0.4734 - categorical_accuracy: 0.9042 - val_loss: 0.8389 - val_categorical_crossentropy: 0.8389 - val_categorical_accuracy: 0.6170
# Epoch 71/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4747 - categorical_crossentropy: 0.4747 - categorical_accuracy: 0.8917 - val_loss: 0.8485 - val_categorical_crossentropy: 0.8485 - val_categorical_accuracy: 0.6596
# Epoch 72/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4711 - categorical_crossentropy: 0.4711 - categorical_accuracy: 0.8667 - val_loss: 0.8423 - val_categorical_crossentropy: 0.8423 - val_categorical_accuracy: 0.5745
# Epoch 73/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4789 - categorical_crossentropy: 0.4789 - categorical_accuracy: 0.9125 - val_loss: 0.8211 - val_categorical_crossentropy: 0.8211 - val_categorical_accuracy: 0.5532
# Epoch 74/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4715 - categorical_crossentropy: 0.4715 - categorical_accuracy: 0.8750 - val_loss: 0.8038 - val_categorical_crossentropy: 0.8038 - val_categorical_accuracy: 0.6170
# Epoch 75/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4631 - categorical_crossentropy: 0.4631 - categorical_accuracy: 0.8958 - val_loss: 0.7988 - val_categorical_crossentropy: 0.7988 - val_categorical_accuracy: 0.5957
# Epoch 76/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4480 - categorical_crossentropy: 0.4480 - categorical_accuracy: 0.9208 - val_loss: 0.8184 - val_categorical_crossentropy: 0.8184 - val_categorical_accuracy: 0.6596
# Epoch 77/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4703 - categorical_crossentropy: 0.4703 - categorical_accuracy: 0.8833 - val_loss: 0.8089 - val_categorical_crossentropy: 0.8089 - val_categorical_accuracy: 0.7021
# Epoch 78/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4697 - categorical_crossentropy: 0.4697 - categorical_accuracy: 0.8750 - val_loss: 0.7898 - val_categorical_crossentropy: 0.7898 - val_categorical_accuracy: 0.7021
# Epoch 79/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4711 - categorical_crossentropy: 0.4711 - categorical_accuracy: 0.8875 - val_loss: 0.8131 - val_categorical_crossentropy: 0.8131 - val_categorical_accuracy: 0.7021
# Epoch 80/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4567 - categorical_crossentropy: 0.4567 - categorical_accuracy: 0.8958 - val_loss: 0.8061 - val_categorical_crossentropy: 0.8061 - val_categorical_accuracy: 0.6170
# Epoch 81/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4621 - categorical_crossentropy: 0.4621 - categorical_accuracy: 0.8958 - val_loss: 0.7929 - val_categorical_crossentropy: 0.7929 - val_categorical_accuracy: 0.6809
# Epoch 82/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4349 - categorical_crossentropy: 0.4349 - categorical_accuracy: 0.9208 - val_loss: 0.8004 - val_categorical_crossentropy: 0.8004 - val_categorical_accuracy: 0.7234
# Epoch 83/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4514 - categorical_crossentropy: 0.4514 - categorical_accuracy: 0.8792 - val_loss: 0.7962 - val_categorical_crossentropy: 0.7962 - val_categorical_accuracy: 0.7447
# Epoch 84/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4616 - categorical_crossentropy: 0.4616 - categorical_accuracy: 0.9000 - val_loss: 0.8062 - val_categorical_crossentropy: 0.8062 - val_categorical_accuracy: 0.7234
# Epoch 85/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4356 - categorical_crossentropy: 0.4356 - categorical_accuracy: 0.9042 - val_loss: 0.7936 - val_categorical_crossentropy: 0.7936 - val_categorical_accuracy: 0.7660
# Epoch 86/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4350 - categorical_crossentropy: 0.4350 - categorical_accuracy: 0.9000 - val_loss: 0.7917 - val_categorical_crossentropy: 0.7917 - val_categorical_accuracy: 0.7021
# Epoch 87/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4250 - categorical_crossentropy: 0.4250 - categorical_accuracy: 0.9042 - val_loss: 0.7932 - val_categorical_crossentropy: 0.7932 - val_categorical_accuracy: 0.6596
# Epoch 88/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4403 - categorical_crossentropy: 0.4403 - categorical_accuracy: 0.9000 - val_loss: 0.7967 - val_categorical_crossentropy: 0.7967 - val_categorical_accuracy: 0.7021
# Epoch 89/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4401 - categorical_crossentropy: 0.4401 - categorical_accuracy: 0.8917 - val_loss: 0.8127 - val_categorical_crossentropy: 0.8127 - val_categorical_accuracy: 0.7447
# Epoch 90/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4323 - categorical_crossentropy: 0.4323 - categorical_accuracy: 0.8917 - val_loss: 0.8220 - val_categorical_crossentropy: 0.8220 - val_categorical_accuracy: 0.7447
# Epoch 91/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4390 - categorical_crossentropy: 0.4390 - categorical_accuracy: 0.9000 - val_loss: 0.8138 - val_categorical_crossentropy: 0.8138 - val_categorical_accuracy: 0.7447
# Epoch 92/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4349 - categorical_crossentropy: 0.4349 - categorical_accuracy: 0.8958 - val_loss: 0.8243 - val_categorical_crossentropy: 0.8243 - val_categorical_accuracy: 0.7447
# Epoch 93/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4453 - categorical_crossentropy: 0.4453 - categorical_accuracy: 0.8875 - val_loss: 0.8460 - val_categorical_crossentropy: 0.8460 - val_categorical_accuracy: 0.6809
# Epoch 94/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4098 - categorical_crossentropy: 0.4098 - categorical_accuracy: 0.9375 - val_loss: 0.8422 - val_categorical_crossentropy: 0.8422 - val_categorical_accuracy: 0.6809
# Epoch 95/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4152 - categorical_crossentropy: 0.4152 - categorical_accuracy: 0.9292 - val_loss: 0.8577 - val_categorical_crossentropy: 0.8577 - val_categorical_accuracy: 0.6809
# Epoch 96/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4149 - categorical_crossentropy: 0.4149 - categorical_accuracy: 0.9125 - val_loss: 0.8312 - val_categorical_crossentropy: 0.8312 - val_categorical_accuracy: 0.7021
# Epoch 97/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3952 - categorical_crossentropy: 0.3952 - categorical_accuracy: 0.9417 - val_loss: 0.8218 - val_categorical_crossentropy: 0.8218 - val_categorical_accuracy: 0.6809
# Epoch 98/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4211 - categorical_crossentropy: 0.4211 - categorical_accuracy: 0.9125 - val_loss: 0.7925 - val_categorical_crossentropy: 0.7925 - val_categorical_accuracy: 0.6596
# Epoch 99/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4037 - categorical_crossentropy: 0.4037 - categorical_accuracy: 0.9292 - val_loss: 0.7938 - val_categorical_crossentropy: 0.7938 - val_categorical_accuracy: 0.6596
# Epoch 100/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4254 - categorical_crossentropy: 0.4254 - categorical_accuracy: 0.9125 - val_loss: 0.8061 - val_categorical_crossentropy: 0.8061 - val_categorical_accuracy: 0.7447
#
# # Evaluate on test data
# 9/9 [==============================] - 0s 16ms/step - loss: 2.8871 - categorical_crossentropy: 2.8871 - categorical_accuracy: 0.2083
# test loss, test acc: [2.8871080610487194, 2.8871083, 0.20833333]
# 1 0
# WARNING:tensorflow:Expected a shuffled dataset but input dataset `x` is not shuffled. Please invoke `shuffle()` on input dataset.
# WARNING:tensorflow:Output output_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to output_1.
# Train on 8 steps, validate on 2 steps
# Epoch 1/100
# 8/8 [==============================] - 1s 73ms/step - loss: 1.3989 - categorical_crossentropy: 1.3989 - categorical_accuracy: 0.2542 - val_loss: 1.3872 - val_categorical_crossentropy: 1.3872 - val_categorical_accuracy: 0.1915
# Epoch 2/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3512 - categorical_crossentropy: 1.3512 - categorical_accuracy: 0.4042 - val_loss: 1.3863 - val_categorical_crossentropy: 1.3863 - val_categorical_accuracy: 0.2766
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3185 - categorical_crossentropy: 1.3185 - categorical_accuracy: 0.4708 - val_loss: 1.3814 - val_categorical_crossentropy: 1.3814 - val_categorical_accuracy: 0.3404
# Epoch 4/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.2607 - categorical_crossentropy: 1.2607 - categorical_accuracy: 0.5833 - val_loss: 1.3698 - val_categorical_crossentropy: 1.3698 - val_categorical_accuracy: 0.4468
# Epoch 5/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.1797 - categorical_crossentropy: 1.1797 - categorical_accuracy: 0.6458 - val_loss: 1.3466 - val_categorical_crossentropy: 1.3466 - val_categorical_accuracy: 0.4681
# Epoch 6/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.0851 - categorical_crossentropy: 1.0851 - categorical_accuracy: 0.6292 - val_loss: 1.3124 - val_categorical_crossentropy: 1.3124 - val_categorical_accuracy: 0.4681
# Epoch 7/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9751 - categorical_crossentropy: 0.9751 - categorical_accuracy: 0.6875 - val_loss: 1.2697 - val_categorical_crossentropy: 1.2697 - val_categorical_accuracy: 0.5106
# Epoch 8/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9059 - categorical_crossentropy: 0.9059 - categorical_accuracy: 0.7167 - val_loss: 1.2279 - val_categorical_crossentropy: 1.2279 - val_categorical_accuracy: 0.5319
# Epoch 9/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8612 - categorical_crossentropy: 0.8612 - categorical_accuracy: 0.7042 - val_loss: 1.1959 - val_categorical_crossentropy: 1.1959 - val_categorical_accuracy: 0.5532
# Epoch 10/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8130 - categorical_crossentropy: 0.8130 - categorical_accuracy: 0.7208 - val_loss: 1.1699 - val_categorical_crossentropy: 1.1699 - val_categorical_accuracy: 0.5957
# Epoch 11/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7876 - categorical_crossentropy: 0.7876 - categorical_accuracy: 0.7208 - val_loss: 1.1501 - val_categorical_crossentropy: 1.1501 - val_categorical_accuracy: 0.6383
# Epoch 12/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7714 - categorical_crossentropy: 0.7714 - categorical_accuracy: 0.7417 - val_loss: 1.1352 - val_categorical_crossentropy: 1.1352 - val_categorical_accuracy: 0.6809
# Epoch 13/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7459 - categorical_crossentropy: 0.7459 - categorical_accuracy: 0.7667 - val_loss: 1.1265 - val_categorical_crossentropy: 1.1265 - val_categorical_accuracy: 0.5745
# Epoch 14/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7204 - categorical_crossentropy: 0.7204 - categorical_accuracy: 0.7625 - val_loss: 1.1238 - val_categorical_crossentropy: 1.1238 - val_categorical_accuracy: 0.5532
# Epoch 15/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7354 - categorical_crossentropy: 0.7354 - categorical_accuracy: 0.7500 - val_loss: 1.1217 - val_categorical_crossentropy: 1.1217 - val_categorical_accuracy: 0.4894
# Epoch 16/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6870 - categorical_crossentropy: 0.6870 - categorical_accuracy: 0.7792 - val_loss: 1.1162 - val_categorical_crossentropy: 1.1162 - val_categorical_accuracy: 0.4894
# Epoch 17/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6892 - categorical_crossentropy: 0.6892 - categorical_accuracy: 0.7708 - val_loss: 1.1135 - val_categorical_crossentropy: 1.1135 - val_categorical_accuracy: 0.4894
# Epoch 18/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6787 - categorical_crossentropy: 0.6787 - categorical_accuracy: 0.7750 - val_loss: 1.1187 - val_categorical_crossentropy: 1.1187 - val_categorical_accuracy: 0.4681
# Epoch 19/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6843 - categorical_crossentropy: 0.6843 - categorical_accuracy: 0.7625 - val_loss: 1.1151 - val_categorical_crossentropy: 1.1151 - val_categorical_accuracy: 0.4043
# Epoch 20/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6869 - categorical_crossentropy: 0.6869 - categorical_accuracy: 0.7708 - val_loss: 1.1144 - val_categorical_crossentropy: 1.1144 - val_categorical_accuracy: 0.4043
# Epoch 21/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6561 - categorical_crossentropy: 0.6561 - categorical_accuracy: 0.8000 - val_loss: 1.1128 - val_categorical_crossentropy: 1.1128 - val_categorical_accuracy: 0.4894
# Epoch 22/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6557 - categorical_crossentropy: 0.6557 - categorical_accuracy: 0.8167 - val_loss: 1.1116 - val_categorical_crossentropy: 1.1116 - val_categorical_accuracy: 0.4043
# Epoch 23/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6445 - categorical_crossentropy: 0.6445 - categorical_accuracy: 0.7708 - val_loss: 1.1047 - val_categorical_crossentropy: 1.1047 - val_categorical_accuracy: 0.4255
# Epoch 24/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6403 - categorical_crossentropy: 0.6403 - categorical_accuracy: 0.8125 - val_loss: 1.1192 - val_categorical_crossentropy: 1.1192 - val_categorical_accuracy: 0.2979
# Epoch 25/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6381 - categorical_crossentropy: 0.6381 - categorical_accuracy: 0.7958 - val_loss: 1.1245 - val_categorical_crossentropy: 1.1245 - val_categorical_accuracy: 0.3404
# Epoch 26/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6230 - categorical_crossentropy: 0.6230 - categorical_accuracy: 0.8000 - val_loss: 1.1234 - val_categorical_crossentropy: 1.1234 - val_categorical_accuracy: 0.4043
# Epoch 27/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6263 - categorical_crossentropy: 0.6263 - categorical_accuracy: 0.8083 - val_loss: 1.1035 - val_categorical_crossentropy: 1.1035 - val_categorical_accuracy: 0.4468
# Epoch 28/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6166 - categorical_crossentropy: 0.6166 - categorical_accuracy: 0.7875 - val_loss: 1.1051 - val_categorical_crossentropy: 1.1051 - val_categorical_accuracy: 0.3830
# Epoch 29/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6111 - categorical_crossentropy: 0.6111 - categorical_accuracy: 0.8083 - val_loss: 1.1014 - val_categorical_crossentropy: 1.1014 - val_categorical_accuracy: 0.4043
# Epoch 30/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6002 - categorical_crossentropy: 0.6002 - categorical_accuracy: 0.8083 - val_loss: 1.0807 - val_categorical_crossentropy: 1.0807 - val_categorical_accuracy: 0.4043
# Epoch 31/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5881 - categorical_crossentropy: 0.5881 - categorical_accuracy: 0.8292 - val_loss: 1.0794 - val_categorical_crossentropy: 1.0794 - val_categorical_accuracy: 0.4468
# Epoch 32/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5887 - categorical_crossentropy: 0.5887 - categorical_accuracy: 0.8208 - val_loss: 1.0959 - val_categorical_crossentropy: 1.0959 - val_categorical_accuracy: 0.4255
# Epoch 33/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6028 - categorical_crossentropy: 0.6028 - categorical_accuracy: 0.8417 - val_loss: 1.0711 - val_categorical_crossentropy: 1.0711 - val_categorical_accuracy: 0.4681
# Epoch 34/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5832 - categorical_crossentropy: 0.5832 - categorical_accuracy: 0.8208 - val_loss: 1.0506 - val_categorical_crossentropy: 1.0506 - val_categorical_accuracy: 0.5106
# Epoch 35/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5899 - categorical_crossentropy: 0.5899 - categorical_accuracy: 0.8125 - val_loss: 1.0635 - val_categorical_crossentropy: 1.0635 - val_categorical_accuracy: 0.4894
# Epoch 36/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5772 - categorical_crossentropy: 0.5772 - categorical_accuracy: 0.8250 - val_loss: 1.0510 - val_categorical_crossentropy: 1.0510 - val_categorical_accuracy: 0.4255
# Epoch 37/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5638 - categorical_crossentropy: 0.5638 - categorical_accuracy: 0.8458 - val_loss: 1.0257 - val_categorical_crossentropy: 1.0257 - val_categorical_accuracy: 0.4681
# Epoch 38/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5651 - categorical_crossentropy: 0.5651 - categorical_accuracy: 0.8458 - val_loss: 1.0105 - val_categorical_crossentropy: 1.0105 - val_categorical_accuracy: 0.4681
# Epoch 39/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5723 - categorical_crossentropy: 0.5723 - categorical_accuracy: 0.8125 - val_loss: 1.0100 - val_categorical_crossentropy: 1.0100 - val_categorical_accuracy: 0.4894
# Epoch 40/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5740 - categorical_crossentropy: 0.5740 - categorical_accuracy: 0.8208 - val_loss: 1.0125 - val_categorical_crossentropy: 1.0125 - val_categorical_accuracy: 0.4894
# Epoch 41/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5437 - categorical_crossentropy: 0.5437 - categorical_accuracy: 0.8667 - val_loss: 0.9891 - val_categorical_crossentropy: 0.9891 - val_categorical_accuracy: 0.5532
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5476 - categorical_crossentropy: 0.5476 - categorical_accuracy: 0.8542 - val_loss: 0.9732 - val_categorical_crossentropy: 0.9732 - val_categorical_accuracy: 0.5319
# Epoch 43/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5603 - categorical_crossentropy: 0.5603 - categorical_accuracy: 0.8375 - val_loss: 0.9601 - val_categorical_crossentropy: 0.9601 - val_categorical_accuracy: 0.5106
# Epoch 44/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5538 - categorical_crossentropy: 0.5538 - categorical_accuracy: 0.8208 - val_loss: 0.9540 - val_categorical_crossentropy: 0.9540 - val_categorical_accuracy: 0.4894
# Epoch 45/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5376 - categorical_crossentropy: 0.5376 - categorical_accuracy: 0.8542 - val_loss: 0.9550 - val_categorical_crossentropy: 0.9550 - val_categorical_accuracy: 0.5106
# Epoch 46/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5480 - categorical_crossentropy: 0.5480 - categorical_accuracy: 0.8375 - val_loss: 0.9672 - val_categorical_crossentropy: 0.9672 - val_categorical_accuracy: 0.4894
# Epoch 47/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5441 - categorical_crossentropy: 0.5441 - categorical_accuracy: 0.8375 - val_loss: 0.9806 - val_categorical_crossentropy: 0.9806 - val_categorical_accuracy: 0.4894
# Epoch 48/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5243 - categorical_crossentropy: 0.5243 - categorical_accuracy: 0.8708 - val_loss: 0.9773 - val_categorical_crossentropy: 0.9773 - val_categorical_accuracy: 0.5106
# Epoch 49/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5172 - categorical_crossentropy: 0.5172 - categorical_accuracy: 0.8750 - val_loss: 0.9652 - val_categorical_crossentropy: 0.9652 - val_categorical_accuracy: 0.5319
# Epoch 50/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5214 - categorical_crossentropy: 0.5214 - categorical_accuracy: 0.8500 - val_loss: 0.9672 - val_categorical_crossentropy: 0.9672 - val_categorical_accuracy: 0.5745
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5220 - categorical_crossentropy: 0.5220 - categorical_accuracy: 0.8375 - val_loss: 0.9337 - val_categorical_crossentropy: 0.9337 - val_categorical_accuracy: 0.5745
# Epoch 52/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5003 - categorical_crossentropy: 0.5003 - categorical_accuracy: 0.8833 - val_loss: 0.9073 - val_categorical_crossentropy: 0.9073 - val_categorical_accuracy: 0.5532
# Epoch 53/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4999 - categorical_crossentropy: 0.4999 - categorical_accuracy: 0.8833 - val_loss: 0.9371 - val_categorical_crossentropy: 0.9371 - val_categorical_accuracy: 0.4681
# Epoch 54/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4973 - categorical_crossentropy: 0.4973 - categorical_accuracy: 0.9000 - val_loss: 0.9482 - val_categorical_crossentropy: 0.9482 - val_categorical_accuracy: 0.4681
# Epoch 55/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4942 - categorical_crossentropy: 0.4942 - categorical_accuracy: 0.8625 - val_loss: 0.9234 - val_categorical_crossentropy: 0.9234 - val_categorical_accuracy: 0.5106
# Epoch 56/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5079 - categorical_crossentropy: 0.5079 - categorical_accuracy: 0.8542 - val_loss: 0.9179 - val_categorical_crossentropy: 0.9179 - val_categorical_accuracy: 0.5957
# Epoch 57/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4864 - categorical_crossentropy: 0.4864 - categorical_accuracy: 0.8750 - val_loss: 0.9106 - val_categorical_crossentropy: 0.9106 - val_categorical_accuracy: 0.5532
# Epoch 58/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4877 - categorical_crossentropy: 0.4877 - categorical_accuracy: 0.8750 - val_loss: 0.9067 - val_categorical_crossentropy: 0.9067 - val_categorical_accuracy: 0.5319
# Epoch 59/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4835 - categorical_crossentropy: 0.4835 - categorical_accuracy: 0.8750 - val_loss: 0.8687 - val_categorical_crossentropy: 0.8687 - val_categorical_accuracy: 0.6170
# Epoch 60/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4734 - categorical_crossentropy: 0.4734 - categorical_accuracy: 0.8875 - val_loss: 0.8889 - val_categorical_crossentropy: 0.8889 - val_categorical_accuracy: 0.6170
# Epoch 61/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4901 - categorical_crossentropy: 0.4901 - categorical_accuracy: 0.8917 - val_loss: 0.8801 - val_categorical_crossentropy: 0.8801 - val_categorical_accuracy: 0.5957
# Epoch 62/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4749 - categorical_crossentropy: 0.4749 - categorical_accuracy: 0.8917 - val_loss: 0.8808 - val_categorical_crossentropy: 0.8808 - val_categorical_accuracy: 0.5957
# Epoch 63/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4571 - categorical_crossentropy: 0.4571 - categorical_accuracy: 0.9250 - val_loss: 0.8701 - val_categorical_crossentropy: 0.8701 - val_categorical_accuracy: 0.5745
# Epoch 64/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4576 - categorical_crossentropy: 0.4576 - categorical_accuracy: 0.9208 - val_loss: 0.8643 - val_categorical_crossentropy: 0.8643 - val_categorical_accuracy: 0.5745
# Epoch 65/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4740 - categorical_crossentropy: 0.4740 - categorical_accuracy: 0.8875 - val_loss: 0.8492 - val_categorical_crossentropy: 0.8492 - val_categorical_accuracy: 0.5532
# Epoch 66/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4554 - categorical_crossentropy: 0.4554 - categorical_accuracy: 0.8792 - val_loss: 0.8185 - val_categorical_crossentropy: 0.8185 - val_categorical_accuracy: 0.6170
# Epoch 67/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4552 - categorical_crossentropy: 0.4552 - categorical_accuracy: 0.8875 - val_loss: 0.8363 - val_categorical_crossentropy: 0.8363 - val_categorical_accuracy: 0.5957
# Epoch 68/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4586 - categorical_crossentropy: 0.4586 - categorical_accuracy: 0.8833 - val_loss: 0.8171 - val_categorical_crossentropy: 0.8171 - val_categorical_accuracy: 0.6596
# Epoch 69/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4480 - categorical_crossentropy: 0.4480 - categorical_accuracy: 0.8750 - val_loss: 0.8107 - val_categorical_crossentropy: 0.8107 - val_categorical_accuracy: 0.6383
# Epoch 70/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4384 - categorical_crossentropy: 0.4384 - categorical_accuracy: 0.8958 - val_loss: 0.8103 - val_categorical_crossentropy: 0.8103 - val_categorical_accuracy: 0.6383
# Epoch 71/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4363 - categorical_crossentropy: 0.4363 - categorical_accuracy: 0.9042 - val_loss: 0.8122 - val_categorical_crossentropy: 0.8122 - val_categorical_accuracy: 0.6383
# Epoch 72/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4495 - categorical_crossentropy: 0.4495 - categorical_accuracy: 0.8917 - val_loss: 0.8025 - val_categorical_crossentropy: 0.8025 - val_categorical_accuracy: 0.6809
# Epoch 73/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4363 - categorical_crossentropy: 0.4363 - categorical_accuracy: 0.9083 - val_loss: 0.8001 - val_categorical_crossentropy: 0.8001 - val_categorical_accuracy: 0.6596
# Epoch 74/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4179 - categorical_crossentropy: 0.4179 - categorical_accuracy: 0.9042 - val_loss: 0.8061 - val_categorical_crossentropy: 0.8061 - val_categorical_accuracy: 0.7021
# Epoch 75/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4249 - categorical_crossentropy: 0.4249 - categorical_accuracy: 0.9250 - val_loss: 0.7796 - val_categorical_crossentropy: 0.7796 - val_categorical_accuracy: 0.6809
# Epoch 76/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4176 - categorical_crossentropy: 0.4176 - categorical_accuracy: 0.9083 - val_loss: 0.7924 - val_categorical_crossentropy: 0.7924 - val_categorical_accuracy: 0.6596
# Epoch 77/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4254 - categorical_crossentropy: 0.4254 - categorical_accuracy: 0.9167 - val_loss: 0.7977 - val_categorical_crossentropy: 0.7977 - val_categorical_accuracy: 0.6383
# Epoch 78/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4139 - categorical_crossentropy: 0.4139 - categorical_accuracy: 0.9375 - val_loss: 0.8009 - val_categorical_crossentropy: 0.8009 - val_categorical_accuracy: 0.6596
# Epoch 79/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4251 - categorical_crossentropy: 0.4251 - categorical_accuracy: 0.9083 - val_loss: 0.8132 - val_categorical_crossentropy: 0.8132 - val_categorical_accuracy: 0.5957
# Epoch 80/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4057 - categorical_crossentropy: 0.4057 - categorical_accuracy: 0.9208 - val_loss: 0.8132 - val_categorical_crossentropy: 0.8132 - val_categorical_accuracy: 0.6383
# Epoch 81/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4188 - categorical_crossentropy: 0.4188 - categorical_accuracy: 0.9000 - val_loss: 0.7827 - val_categorical_crossentropy: 0.7827 - val_categorical_accuracy: 0.6809
# Epoch 82/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3967 - categorical_crossentropy: 0.3967 - categorical_accuracy: 0.9083 - val_loss: 0.7807 - val_categorical_crossentropy: 0.7807 - val_categorical_accuracy: 0.6383
# Epoch 83/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4012 - categorical_crossentropy: 0.4012 - categorical_accuracy: 0.9208 - val_loss: 0.7936 - val_categorical_crossentropy: 0.7936 - val_categorical_accuracy: 0.6596
# Epoch 84/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4080 - categorical_crossentropy: 0.4080 - categorical_accuracy: 0.9167 - val_loss: 0.7799 - val_categorical_crossentropy: 0.7799 - val_categorical_accuracy: 0.6170
# Epoch 85/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3770 - categorical_crossentropy: 0.3770 - categorical_accuracy: 0.9125 - val_loss: 0.7853 - val_categorical_crossentropy: 0.7853 - val_categorical_accuracy: 0.6596
# Epoch 86/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3859 - categorical_crossentropy: 0.3859 - categorical_accuracy: 0.9375 - val_loss: 0.7780 - val_categorical_crossentropy: 0.7780 - val_categorical_accuracy: 0.7234
# Epoch 87/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4051 - categorical_crossentropy: 0.4051 - categorical_accuracy: 0.9167 - val_loss: 0.7691 - val_categorical_crossentropy: 0.7691 - val_categorical_accuracy: 0.6809
# Epoch 88/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4015 - categorical_crossentropy: 0.4015 - categorical_accuracy: 0.8958 - val_loss: 0.7572 - val_categorical_crossentropy: 0.7572 - val_categorical_accuracy: 0.7021
# Epoch 89/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3863 - categorical_crossentropy: 0.3863 - categorical_accuracy: 0.9125 - val_loss: 0.7646 - val_categorical_crossentropy: 0.7646 - val_categorical_accuracy: 0.6596
# Epoch 90/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3644 - categorical_crossentropy: 0.3644 - categorical_accuracy: 0.9333 - val_loss: 0.7889 - val_categorical_crossentropy: 0.7889 - val_categorical_accuracy: 0.7021
# Epoch 91/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3750 - categorical_crossentropy: 0.3750 - categorical_accuracy: 0.9417 - val_loss: 0.7815 - val_categorical_crossentropy: 0.7815 - val_categorical_accuracy: 0.6809
# Epoch 92/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3985 - categorical_crossentropy: 0.3985 - categorical_accuracy: 0.9208 - val_loss: 0.7896 - val_categorical_crossentropy: 0.7896 - val_categorical_accuracy: 0.6809
# Epoch 93/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3663 - categorical_crossentropy: 0.3663 - categorical_accuracy: 0.9375 - val_loss: 0.8130 - val_categorical_crossentropy: 0.8130 - val_categorical_accuracy: 0.7021
# Epoch 94/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3616 - categorical_crossentropy: 0.3616 - categorical_accuracy: 0.9083 - val_loss: 0.8217 - val_categorical_crossentropy: 0.8217 - val_categorical_accuracy: 0.7234
# Epoch 95/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3687 - categorical_crossentropy: 0.3687 - categorical_accuracy: 0.9417 - val_loss: 0.7823 - val_categorical_crossentropy: 0.7823 - val_categorical_accuracy: 0.6383
# Epoch 96/100
# ...
# Epoch 45/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3492 - categorical_crossentropy: 0.3492 - categorical_accuracy: 0.9250 - val_loss: 1.0498 - val_categorical_crossentropy: 1.0498 - val_categorical_accuracy: 0.6383
# Epoch 46/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3474 - categorical_crossentropy: 0.3474 - categorical_accuracy: 0.9083 - val_loss: 1.0131 - val_categorical_crossentropy: 1.0131 - val_categorical_accuracy: 0.6383
# Epoch 47/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3266 - categorical_crossentropy: 0.3266 - categorical_accuracy: 0.9292 - val_loss: 0.9752 - val_categorical_crossentropy: 0.9752 - val_categorical_accuracy: 0.6596
# Epoch 48/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3289 - categorical_crossentropy: 0.3289 - categorical_accuracy: 0.9458 - val_loss: 0.9775 - val_categorical_crossentropy: 0.9775 - val_categorical_accuracy: 0.6383
# Epoch 49/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3290 - categorical_crossentropy: 0.3290 - categorical_accuracy: 0.9417 - val_loss: 1.0030 - val_categorical_crossentropy: 1.0030 - val_categorical_accuracy: 0.6383
# Epoch 50/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3202 - categorical_crossentropy: 0.3202 - categorical_accuracy: 0.9417 - val_loss: 0.9852 - val_categorical_crossentropy: 0.9852 - val_categorical_accuracy: 0.6383
# Epoch 51/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3229 - categorical_crossentropy: 0.3229 - categorical_accuracy: 0.9375 - val_loss: 0.9615 - val_categorical_crossentropy: 0.9615 - val_categorical_accuracy: 0.6383
# Epoch 52/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3194 - categorical_crossentropy: 0.3194 - categorical_accuracy: 0.9500 - val_loss: 0.9633 - val_categorical_crossentropy: 0.9633 - val_categorical_accuracy: 0.6383
# Epoch 53/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3128 - categorical_crossentropy: 0.3128 - categorical_accuracy: 0.9458 - val_loss: 0.9515 - val_categorical_crossentropy: 0.9515 - val_categorical_accuracy: 0.6383
# Epoch 54/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2924 - categorical_crossentropy: 0.2924 - categorical_accuracy: 0.9458 - val_loss: 0.9396 - val_categorical_crossentropy: 0.9396 - val_categorical_accuracy: 0.6809
# Epoch 55/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3124 - categorical_crossentropy: 0.3124 - categorical_accuracy: 0.9417 - val_loss: 0.8924 - val_categorical_crossentropy: 0.8924 - val_categorical_accuracy: 0.6596
# Epoch 56/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3017 - categorical_crossentropy: 0.3017 - categorical_accuracy: 0.9417 - val_loss: 0.8725 - val_categorical_crossentropy: 0.8725 - val_categorical_accuracy: 0.6809
# Epoch 57/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2915 - categorical_crossentropy: 0.2915 - categorical_accuracy: 0.9542 - val_loss: 0.8551 - val_categorical_crossentropy: 0.8551 - val_categorical_accuracy: 0.6596
# Epoch 58/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2996 - categorical_crossentropy: 0.2996 - categorical_accuracy: 0.9375 - val_loss: 0.8404 - val_categorical_crossentropy: 0.8404 - val_categorical_accuracy: 0.6809
# Epoch 59/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2896 - categorical_crossentropy: 0.2896 - categorical_accuracy: 0.9542 - val_loss: 0.7860 - val_categorical_crossentropy: 0.7860 - val_categorical_accuracy: 0.6596
# Epoch 60/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2911 - categorical_crossentropy: 0.2911 - categorical_accuracy: 0.9500 - val_loss: 0.7820 - val_categorical_crossentropy: 0.7820 - val_categorical_accuracy: 0.7234
# Epoch 61/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2826 - categorical_crossentropy: 0.2826 - categorical_accuracy: 0.9583 - val_loss: 0.7494 - val_categorical_crossentropy: 0.7494 - val_categorical_accuracy: 0.7234
# Epoch 62/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2725 - categorical_crossentropy: 0.2725 - categorical_accuracy: 0.9542 - val_loss: 0.7268 - val_categorical_crossentropy: 0.7268 - val_categorical_accuracy: 0.7021
# Epoch 63/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2671 - categorical_crossentropy: 0.2671 - categorical_accuracy: 0.9625 - val_loss: 0.7064 - val_categorical_crossentropy: 0.7064 - val_categorical_accuracy: 0.7234
# Epoch 64/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2747 - categorical_crossentropy: 0.2747 - categorical_accuracy: 0.9542 - val_loss: 0.6762 - val_categorical_crossentropy: 0.6762 - val_categorical_accuracy: 0.7234
# Epoch 65/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2608 - categorical_crossentropy: 0.2608 - categorical_accuracy: 0.9625 - val_loss: 0.6584 - val_categorical_crossentropy: 0.6584 - val_categorical_accuracy: 0.7234
# Epoch 66/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2643 - categorical_crossentropy: 0.2643 - categorical_accuracy: 0.9625 - val_loss: 0.6494 - val_categorical_crossentropy: 0.6494 - val_categorical_accuracy: 0.7234
# Epoch 67/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2601 - categorical_crossentropy: 0.2601 - categorical_accuracy: 0.9833 - val_loss: 0.6702 - val_categorical_crossentropy: 0.6702 - val_categorical_accuracy: 0.7234
# Epoch 68/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2554 - categorical_crossentropy: 0.2554 - categorical_accuracy: 0.9708 - val_loss: 0.6767 - val_categorical_crossentropy: 0.6767 - val_categorical_accuracy: 0.6809
# Epoch 69/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2495 - categorical_crossentropy: 0.2495 - categorical_accuracy: 0.9458 - val_loss: 0.6819 - val_categorical_crossentropy: 0.6819 - val_categorical_accuracy: 0.6596
# Epoch 70/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2463 - categorical_crossentropy: 0.2463 - categorical_accuracy: 0.9667 - val_loss: 0.6642 - val_categorical_crossentropy: 0.6642 - val_categorical_accuracy: 0.7021
# Epoch 71/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2477 - categorical_crossentropy: 0.2477 - categorical_accuracy: 0.9667 - val_loss: 0.6506 - val_categorical_crossentropy: 0.6506 - val_categorical_accuracy: 0.7234
# Epoch 72/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2479 - categorical_crossentropy: 0.2479 - categorical_accuracy: 0.9625 - val_loss: 0.6470 - val_categorical_crossentropy: 0.6470 - val_categorical_accuracy: 0.7447
# Epoch 73/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2545 - categorical_crossentropy: 0.2545 - categorical_accuracy: 0.9500 - val_loss: 0.6631 - val_categorical_crossentropy: 0.6631 - val_categorical_accuracy: 0.6809
# Epoch 74/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2504 - categorical_crossentropy: 0.2504 - categorical_accuracy: 0.9458 - val_loss: 0.6647 - val_categorical_crossentropy: 0.6647 - val_categorical_accuracy: 0.6596
# Epoch 75/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2396 - categorical_crossentropy: 0.2396 - categorical_accuracy: 0.9708 - val_loss: 0.6185 - val_categorical_crossentropy: 0.6185 - val_categorical_accuracy: 0.7234
# Epoch 76/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2328 - categorical_crossentropy: 0.2328 - categorical_accuracy: 0.9833 - val_loss: 0.5771 - val_categorical_crossentropy: 0.5771 - val_categorical_accuracy: 0.7447
# Epoch 77/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2515 - categorical_crossentropy: 0.2515 - categorical_accuracy: 0.9500 - val_loss: 0.5684 - val_categorical_crossentropy: 0.5684 - val_categorical_accuracy: 0.7021
# Epoch 78/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2368 - categorical_crossentropy: 0.2368 - categorical_accuracy: 0.9542 - val_loss: 0.5664 - val_categorical_crossentropy: 0.5664 - val_categorical_accuracy: 0.7234
# Epoch 79/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2384 - categorical_crossentropy: 0.2384 - categorical_accuracy: 0.9625 - val_loss: 0.5694 - val_categorical_crossentropy: 0.5694 - val_categorical_accuracy: 0.7234
# Epoch 80/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2330 - categorical_crossentropy: 0.2330 - categorical_accuracy: 0.9583 - val_loss: 0.5815 - val_categorical_crossentropy: 0.5815 - val_categorical_accuracy: 0.6809
# Epoch 81/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2100 - categorical_crossentropy: 0.2100 - categorical_accuracy: 0.9833 - val_loss: 0.5751 - val_categorical_crossentropy: 0.5751 - val_categorical_accuracy: 0.7021
# Epoch 82/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2188 - categorical_crossentropy: 0.2188 - categorical_accuracy: 0.9792 - val_loss: 0.5821 - val_categorical_crossentropy: 0.5821 - val_categorical_accuracy: 0.7234
# Epoch 83/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2359 - categorical_crossentropy: 0.2359 - categorical_accuracy: 0.9625 - val_loss: 0.5839 - val_categorical_crossentropy: 0.5839 - val_categorical_accuracy: 0.7447
# Epoch 84/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2216 - categorical_crossentropy: 0.2216 - categorical_accuracy: 0.9625 - val_loss: 0.5709 - val_categorical_crossentropy: 0.5709 - val_categorical_accuracy: 0.7660
# Epoch 85/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2214 - categorical_crossentropy: 0.2214 - categorical_accuracy: 0.9750 - val_loss: 0.5695 - val_categorical_crossentropy: 0.5695 - val_categorical_accuracy: 0.7447
# Epoch 86/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2050 - categorical_crossentropy: 0.2050 - categorical_accuracy: 0.9625 - val_loss: 0.5736 - val_categorical_crossentropy: 0.5736 - val_categorical_accuracy: 0.7447
# Epoch 87/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2199 - categorical_crossentropy: 0.2199 - categorical_accuracy: 0.9625 - val_loss: 0.5688 - val_categorical_crossentropy: 0.5688 - val_categorical_accuracy: 0.7234
# Epoch 88/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2144 - categorical_crossentropy: 0.2144 - categorical_accuracy: 0.9667 - val_loss: 0.5498 - val_categorical_crossentropy: 0.5498 - val_categorical_accuracy: 0.7447
# Epoch 89/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2031 - categorical_crossentropy: 0.2031 - categorical_accuracy: 0.9708 - val_loss: 0.5494 - val_categorical_crossentropy: 0.5494 - val_categorical_accuracy: 0.7660
# Epoch 90/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2098 - categorical_crossentropy: 0.2098 - categorical_accuracy: 0.9667 - val_loss: 0.5406 - val_categorical_crossentropy: 0.5406 - val_categorical_accuracy: 0.7234
# Epoch 91/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2104 - categorical_crossentropy: 0.2104 - categorical_accuracy: 0.9708 - val_loss: 0.5372 - val_categorical_crossentropy: 0.5372 - val_categorical_accuracy: 0.7660
# Epoch 92/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2017 - categorical_crossentropy: 0.2017 - categorical_accuracy: 0.9792 - val_loss: 0.5441 - val_categorical_crossentropy: 0.5441 - val_categorical_accuracy: 0.7660
# Epoch 93/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1942 - categorical_crossentropy: 0.1942 - categorical_accuracy: 0.9792 - val_loss: 0.5468 - val_categorical_crossentropy: 0.5468 - val_categorical_accuracy: 0.7447
# Epoch 94/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1910 - categorical_crossentropy: 0.1910 - categorical_accuracy: 0.9875 - val_loss: 0.5679 - val_categorical_crossentropy: 0.5679 - val_categorical_accuracy: 0.7447
# Epoch 95/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1951 - categorical_crossentropy: 0.1951 - categorical_accuracy: 0.9833 - val_loss: 0.5882 - val_categorical_crossentropy: 0.5882 - val_categorical_accuracy: 0.7660
# Epoch 96/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1892 - categorical_crossentropy: 0.1892 - categorical_accuracy: 0.9792 - val_loss: 0.5821 - val_categorical_crossentropy: 0.5821 - val_categorical_accuracy: 0.7660
# Epoch 97/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1977 - categorical_crossentropy: 0.1977 - categorical_accuracy: 0.9750 - val_loss: 0.5738 - val_categorical_crossentropy: 0.5738 - val_categorical_accuracy: 0.7872
# Epoch 98/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1941 - categorical_crossentropy: 0.1941 - categorical_accuracy: 0.9792 - val_loss: 0.5782 - val_categorical_crossentropy: 0.5782 - val_categorical_accuracy: 0.7872
# Epoch 99/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1958 - categorical_crossentropy: 0.1958 - categorical_accuracy: 0.9667 - val_loss: 0.5782 - val_categorical_crossentropy: 0.5782 - val_categorical_accuracy: 0.7872
# Epoch 100/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1983 - categorical_crossentropy: 0.1983 - categorical_accuracy: 0.9833 - val_loss: 0.5594 - val_categorical_crossentropy: 0.5594 - val_categorical_accuracy: 0.7447
#
# # Evaluate on test data
# 9/9 [==============================] - 1s 106ms/step - loss: 2.7758 - categorical_crossentropy: 2.7758 - categorical_accuracy: 0.2396
# test loss, test acc: [2.77577985657586, 2.77578, 0.23958333]
# EEG_Deep/Data2A/Data_A010T.mat
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'EEG_Deep/Data2A/Data_A010T.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-2a096c1aa4a5> in <module>()
#      26       fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
#      27       print(fName)
# ---> 28       mat = spio.loadmat(fName)
#      29       r_X_tr = mat['cleanRawEEGData']
#      30       y_tr = mat['cleanClassLabels']
#
# /usr/local/lib/python3.6/dist-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     214     """
#     215     variable_names = kwargs.pop('variable_names', None)
# --> 216     with _open_file_context(file_name, appendmat) as f:
#     217         MR, _ = mat_reader_factory(f, **kwargs)
#     218         matfile_dict = MR.get_variables(variable_names)
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/scipy/io/matlab/mio.py in _open_file_context(file_like, appendmat, mode)
#      17 @contextmanager
#      18 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 19     f, opened = _open_file(file_like, appendmat, mode)
#      20     yield f
#      21     if opened:
#
# /usr/local/lib/python3.6/dist-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      43             if appendmat and not file_like.endswith('.mat'):
#      44                 file_like += '.mat'
# ---> 45             return open(file_like, mode), True
#      46         else:
#      47             raise IOError('Reader needs file name or open file-like object')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'EEG_Deep/Data2A/Data_A010T.mat'
