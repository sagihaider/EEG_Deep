# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/EEG_Deep/blob/master/main_2A/main_EEGNet_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sagihaider/EEG_Deep.git
# Out:
# Cloning into 'EEG_Deep'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 489 (delta 6), reused 0 (delta 0), pack-reused 477
# Receiving objects: 100% (489/489), 1.69 GiB | 48.84 MiB/s, done.
# Resolving deltas: 100% (236/236), done.
# Checking out files: 100% (93/93), done.

# %%
import scipy.io as spio
import numpy as np
from importlib.machinery import SourceFileLoader

# EEGNet-specific imports
from EEG_Deep.EEGModels import EEGNet, ShallowConvNet, DeepConvNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_first')

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt
from scipy.signal import butter, lfilter


# Band-pass Filter
def butter_bandpass_filter(data, lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

# %%
from numpy import zeros
K.clear_session()

X_tr = np.empty([288, 22, 1875])
X_ts = np.empty([288, 22, 1875])


# Initialize parameter
h_cut = [24]
drop_out = [0.5]
k_len = [15, 30, 60]
n_epochs = 10

out_f_name = 'acc_EEGNet' + '_epochs_' + str(n_epochs) + '_filter_' + str(h_cut) +'_drop_' + str(drop_out) +'_2AData.npy'
print(out_f_name)

nsub = 9
nfilt = len(h_cut)
ndrop = len(drop_out)
nkl = len(k_len)
loss_score = zeros([nsub, nfilt,ndrop,nkl])
categorical_crossentropy_score = zeros([nsub, nfilt,ndrop,nkl])
acc_all = zeros([nsub, nfilt,ndrop,nkl])

for sub_idx, x in enumerate(range(1,10)):
    for h_indx, h in enumerate(h_cut):
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'T.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_tr = mat['cleanRawEEGData']
      y_tr = mat['cleanClassLabels']
  
      print(np.shape(r_X_tr))
      print(np.shape(y_tr))

      for t in range(r_X_tr.shape[0]):
        tril = r_X_tr[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250, order=4)
        # tril_filtered = tril_filtered.transpose()
        X_tr[t,:,:] = tril_filtered
      # split data of each subject in training and validation
      X_train      = X_tr[0:240,:,500:1250]
      Y_train      = y_tr[0:240]
      X_val       = X_tr[241:,:,500:1250]
      Y_val       = y_tr[241:]

      print(np.shape(X_train))
      print(np.shape(Y_train))
      print(np.shape(X_val))
      print(np.shape(Y_val))

      # convert labels to one-hot encodings.
      Y_train      = np_utils.to_categorical(Y_train-1)
      Y_val       = np_utils.to_categorical(Y_val-1)

      kernels, chans, samples = 1, 22, 750
      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_train = X_train.reshape(X_train.shape[0], kernels, chans, samples)
      X_val = X_val.reshape(X_val.shape[0], kernels, chans, samples)
   
      print('X_train shape:', X_train.shape)
      print(X_train.shape[0], 'train samples')
      print(X_val.shape[0], 'val samples')

      # Load test data         
      fName = 'EEG_Deep/Data2A/Data_A0' + str(x) + 'E.mat'  # Load Data
      print(fName)
      mat = spio.loadmat(fName)
      r_X_ts = mat['cleanRawEEGData']
      y_ts = mat['cleanClassLabels']

      print(np.shape(r_X_ts))
      print(np.shape(y_ts))

      for t in range(r_X_ts.shape[0]):
        tril = r_X_ts[t,:,:]
        # tril = tril.transpose()
        tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h, 
                                               fs=250,order=4)
        # tril_filtered = tril_filtered.transpose()
        X_ts[t,:,:] = tril_filtered 

      X_test      = X_ts[:,:,500:1250]
      Y_test      = y_ts[:]
      print(np.shape(X_test))
      print(np.shape(Y_test))

      #convert labels to one-hot encodings.
      Y_test      = np_utils.to_categorical(Y_test-1)

      # convert data to NCHW (trials, kernels, channels, samples) format. Data 
      # contains 22 channels and 500 time-points. Set the number of kernels to 1.
      X_test = X_test.reshape(X_test.shape[0], kernels, chans, samples)
      print('X_train shape:', X_test.shape)
      print(X_test.shape[0], 'train samples')

      for id_d, d in enumerate(drop_out):
        for id_kl, kl in enumerate(k_len):
          # configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
          # model configurations may do better, but this is a good starting point)
          model = EEGNet(nb_classes = 4, Chans = 22, Samples = 750, 
                         dropoutRate = d, kernLength = kl, F1 = 8, 
                         D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')
          
          # compile the model and set the optimizers
          model.compile(loss='categorical_crossentropy', optimizer='adam', 
                        metrics = ['accuracy'])

          # count number of parameters in the model
          numParams    = model.count_params() 

          # set a valid path for your system to record model checkpoints
          checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', 
                                         verbose=1, save_best_only=True)
          
          # the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
          # the weights all to be 1
          class_weights = {0:1, 1:1, 2:1, 3:1}
          
          history = model.fit(X_train, Y_train, batch_size = 16, epochs = n_epochs, 
                              verbose = 2, validation_data=(X_val, Y_val),
                              callbacks=[checkpointer], class_weight = class_weights)
          
          print('\n# Evaluate on test data')
          results = model.evaluate(X_test, Y_test, batch_size=1)
          print('test loss, test acc:', results)

          # loss_score[sub_idx,h_indx,id_d, id_kl] = results[0]
          # categorical_crossentropy_score[sub_idx,h_indx,id_d, id_kl] = results[1]
          acc_all[sub_idx,h_indx,id_d, id_kl] = results[1]

          # from keras import backend as K 
          # Do some code, e.g. train and save model
          # K.clear_session()


np.save(out_f_name, acc_all)
# Out:
# acc_EEGNet_epochs_10_filter_[24]_drop_[0.5]_2AData.npy
# EEG_Deep/Data2A/Data_A01T.mat
# (288, 22, 1875)
# (288, 1)
# (240, 22, 750)
# (240, 1)
# (47, 22, 750)
# (47, 1)
# X_train shape: (240, 1, 22, 750)
# 240 train samples
# 47 val samples
# EEG_Deep/Data2A/Data_A01E.mat
# (288, 22, 1875)
# (288, 1)
# (288, 22, 750)
# (288, 1)
# X_train shape: (288, 1, 22, 750)
# 288 train samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 240 samples, validate on 47 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 1.38408, saving model to /tmp/checkpoint.h5
# 240/240 - 7s - loss: 1.3870 - acc: 0.2542 - val_loss: 1.3841 - val_acc: 0.2553
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 1.38408 to 1.38310, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3622 - acc: 0.3208 - val_loss: 1.3831 - val_acc: 0.2979
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 1.38310 to 1.38089, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3527 - acc: 0.3250 - val_loss: 1.3809 - val_acc: 0.2979
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 1.38089 to 1.37743, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3373 - acc: 0.3750 - val_loss: 1.3774 - val_acc: 0.4255
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 1.37743 to 1.37169, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3110 - acc: 0.4083 - val_loss: 1.3717 - val_acc: 0.4468
# Epoch 6/10
#
# Epoch 00006: val_loss improved from 1.37169 to 1.35720, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.2673 - acc: 0.4708 - val_loss: 1.3572 - val_acc: 0.5106
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 1.35720 to 1.32362, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.2195 - acc: 0.5250 - val_loss: 1.3236 - val_acc: 0.5532
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 1.32362 to 1.26984, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.1496 - acc: 0.5750 - val_loss: 1.2698 - val_acc: 0.5532
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 1.26984 to 1.20507, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.0460 - acc: 0.6292 - val_loss: 1.2051 - val_acc: 0.5106
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 1.20507 to 1.17581, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.0067 - acc: 0.5625 - val_loss: 1.1758 - val_acc: 0.4468
#
# # Evaluate on test data
# 288/288 [==============================] - 1s 2ms/sample - loss: 1.1559 - acc: 0.4340
# test loss, test acc: [1.1559432718074985, 0.4340278]
# Train on 240 samples, validate on 47 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 1.38670, saving model to /tmp/checkpoint.h5
# 240/240 - 1s - loss: 1.3908 - acc: 0.2458 - val_loss: 1.3867 - val_acc: 0.2340
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 1.38670 to 1.38590, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3696 - acc: 0.3375 - val_loss: 1.3859 - val_acc: 0.2766
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 1.38590 to 1.38537, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3618 - acc: 0.2958 - val_loss: 1.3854 - val_acc: 0.2340
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 1.38537 to 1.38285, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3423 - acc: 0.4500 - val_loss: 1.3828 - val_acc: 0.2553
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 1.38285 to 1.37651, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3187 - acc: 0.4375 - val_loss: 1.3765 - val_acc: 0.2553
# Epoch 6/10
#
# Epoch 00006: val_loss improved from 1.37651 to 1.36081, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.2575 - acc: 0.5083 - val_loss: 1.3608 - val_acc: 0.2766
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 1.36081 to 1.33048, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.2029 - acc: 0.5042 - val_loss: 1.3305 - val_acc: 0.3830
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 1.33048 to 1.29199, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.1024 - acc: 0.6333 - val_loss: 1.2920 - val_acc: 0.3191
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 1.29199 to 1.25548, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.0713 - acc: 0.5667 - val_loss: 1.2555 - val_acc: 0.3191
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 1.25548 to 1.22411, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.0055 - acc: 0.5833 - val_loss: 1.2241 - val_acc: 0.3191
#
# # Evaluate on test data
# 288/288 [==============================] - 1s 2ms/sample - loss: 1.1886 - acc: 0.4444
# test loss, test acc: [1.188600554027491, 0.44444445]
# Train on 240 samples, validate on 47 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 1.38806, saving model to /tmp/checkpoint.h5
# 240/240 - 1s - loss: 1.3925 - acc: 0.2292 - val_loss: 1.3881 - val_acc: 0.1915
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 1.38806 to 1.38369, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3567 - acc: 0.3500 - val_loss: 1.3837 - val_acc: 0.2979
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 1.38369 to 1.37750, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.3375 - acc: 0.3375 - val_loss: 1.3775 - val_acc: 0.3404
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 1.37750 to 1.36220, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.2861 - acc: 0.4708 - val_loss: 1.3622 - val_acc: 0.4255
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 1.36220 to 1.32792, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.2274 - acc: 0.5333 - val_loss: 1.3279 - val_acc: 0.4894
# Epoch 6/10
#
# Epoch 00006: val_loss improved from 1.32792 to 1.26233, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.1428 - acc: 0.5542 - val_loss: 1.2623 - val_acc: 0.4894
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 1.26233 to 1.21948, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 1.0646 - acc: 0.5333 - val_loss: 1.2195 - val_acc: 0.4468
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 1.21948 to 1.20437, saving model to /tmp/checkpoint.h5
# 240/240 - 0s - loss: 0.9758 - acc: 0.5958 - val_loss: 1.2044 - val_acc: 0.4043
# Epoch 9/10
#
# Epoch 00009: val_loss did not improve from 1.20437
# 240/240 - 0s - loss: 0.9096 - acc: 0.6292 - val_loss: 1.2102 - val_acc: 0.3830
# Epoch 10/10
#
# Epoch 00010: val_loss did not improve from 1.20437
# 240/240 - 0s - loss: 0.8731 - acc: 0.6083 - val_loss: 1.2123 - val_acc: 0.3404
#
# # Evaluate on test data
# 288/288 [==============================] - 1s 2ms/sample - loss: 1.1827 - acc: 0.3819
# test loss, test acc: [1.18272581220501, 0.38194445]
# EEG_Deep/Data2A/Data_A02T.mat
# (288, 22, 1875)
# (288, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3244733e830c> in <module>()
#      38         # tril = tril.transpose()
#      39         tril_filtered = butter_bandpass_filter(tril, lowcut=4, highcut=h,
# ---> 40                                                fs=250, order=4)
#      41         # tril_filtered = tril_filtered.transpose()
#      42         X_tr[t,:,:] = tril_filtered
#
# <ipython-input-3-19b83197d391> in butter_bandpass_filter(data, lowcut, highcut, fs, order)
#      24     high = highcut / nyq
#      25     b, a = butter(order, [low, high], btype='band')
# ---> 26     y = lfilter(b, a, data)
#      27     return y
#
# /usr/local/lib/python3.6/dist-packages/scipy/signal/signaltools.py in lfilter(b, a, x, axis, zi)
#    1881     else:
#    1882         if zi is None:
# -> 1883             return sigtools._linear_filter(b, a, x, axis)
#    1884         else:
#    1885             return sigtools._linear_filter(b, a, x, axis, zi)
#
# KeyboardInterrupt:
